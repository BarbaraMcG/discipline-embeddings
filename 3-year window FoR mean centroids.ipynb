# %% [markdown]
# # Preliminaries

# %%
import gensim
import os
from gensim.models import Word2Vec
import numpy as np
import pandas as pd 
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from matplotlib import pyplot
from google.colab import drive
from google.colab import auth
auth.authenticate_user()
print("Authenticated!")

# project id
pid = "springer-nature-analytics"
# Out:
# Authenticated!

# %% [markdown]
# # Connect to drive

# %%
# Run the cell and authorise connection to Google drive by pasting in the access token
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Prep and train code

# %%
def train_and_save(df, f, f_type="f1"):

  gpath='/content/drive/My Drive/Research/Data/Mean-title-centroids-3yrs-v02'
  df.to_csv(os.path.join(gpath, '{}_{}.csv'.format(f, f_type)), sep=" ", header=False, index=False)
  print('Saved mean vectors to \"{}/{}\"'.format(gpath, '{}_{}.csv'.format(f, f_type)))

# %% [markdown]
# # 2017-2019

# %%
# %%bigquery --project $pid for_17_19
#
# SELECT * FROM (
# SELECT f1,
#
# AVG(d0) AS d0_mean,
# AVG(d1) AS d1_mean,
# AVG(d2) AS d2_mean,
# AVG(d3) AS d3_mean,
# AVG(d4) AS d4_mean,
# AVG(d5) AS d5_mean,
# AVG(d6) AS d6_mean,
# AVG(d7) AS d7_mean,
# AVG(d8) AS d8_mean,
# AVG(d9) AS d9_mean,
# AVG(d10) AS d10_mean,
# AVG(d11) AS d11_mean,
# AVG(d12) AS d12_mean,
# AVG(d13) AS d13_mean,
# AVG(d14) AS d14_mean,
# AVG(d15) AS d15_mean,
# AVG(d16) AS d16_mean,
# AVG(d17) AS d17_mean,
# AVG(d18) AS d18_mean,
# AVG(d19) AS d19_mean,
# AVG(d20) AS d20_mean,
# AVG(d21) AS d21_mean,
# AVG(d22) AS d22_mean,
# AVG(d23) AS d23_mean,
# AVG(d24) AS d24_mean,
# AVG(d25) AS d25_mean,
# AVG(d26) AS d26_mean,
# AVG(d27) AS d27_mean,
# AVG(d28) AS d28_mean,
# AVG(d29) AS d29_mean,
# AVG(d30) AS d30_mean,
# AVG(d31) AS d31_mean,
# AVG(d32) AS d32_mean,
# AVG(d33) AS d33_mean,
# AVG(d34) AS d34_mean,
# AVG(d35) AS d35_mean,
# AVG(d36) AS d36_mean,
# AVG(d37) AS d37_mean,
# AVG(d38) AS d38_mean,
# AVG(d39) AS d39_mean,
# AVG(d40) AS d40_mean,
# AVG(d41) AS d41_mean,
# AVG(d42) AS d42_mean,
# AVG(d43) AS d43_mean,
# AVG(d44) AS d44_mean,
# AVG(d45) AS d45_mean,
# AVG(d46) AS d46_mean,
# AVG(d47) AS d47_mean,
# AVG(d48) AS d48_mean,
# AVG(d49) AS d49_mean,
# AVG(d50) AS d50_mean,
# AVG(d51) AS d51_mean,
# AVG(d52) AS d52_mean,
# AVG(d53) AS d53_mean,
# AVG(d54) AS d54_mean,
# AVG(d55) AS d55_mean,
# AVG(d56) AS d56_mean,
# AVG(d57) AS d57_mean,
# AVG(d58) AS d58_mean,
# AVG(d59) AS d59_mean,
# AVG(d60) AS d60_mean,
# AVG(d61) AS d61_mean,
# AVG(d62) AS d62_mean,
# AVG(d63) AS d63_mean,
# AVG(d64) AS d64_mean,
# AVG(d65) AS d65_mean,
# AVG(d66) AS d66_mean,
# AVG(d67) AS d67_mean,
# AVG(d68) AS d68_mean,
# AVG(d69) AS d69_mean,
# AVG(d70) AS d70_mean,
# AVG(d71) AS d71_mean,
# AVG(d72) AS d72_mean,
# AVG(d73) AS d73_mean,
# AVG(d74) AS d74_mean,
# AVG(d75) AS d75_mean,
# AVG(d76) AS d76_mean,
# AVG(d77) AS d77_mean,
# AVG(d78) AS d78_mean,
# AVG(d79) AS d79_mean,
# AVG(d80) AS d80_mean,
# AVG(d81) AS d81_mean,
# AVG(d82) AS d82_mean,
# AVG(d83) AS d83_mean,
# AVG(d84) AS d84_mean,
# AVG(d85) AS d85_mean,
# AVG(d86) AS d86_mean,
# AVG(d87) AS d87_mean,
# AVG(d88) AS d88_mean,
# AVG(d89) AS d89_mean,
# AVG(d90) AS d90_mean,
# AVG(d91) AS d91_mean,
# AVG(d92) AS d92_mean,
# AVG(d93) AS d93_mean,
# AVG(d94) AS d94_mean,
# AVG(d95) AS d95_mean,
# AVG(d96) AS d96_mean,
# AVG(d97) AS d97_mean,
# AVG(d98) AS d98_mean,
# AVG(d99) AS d99_mean,
# AVG(d100) AS d100_mean,
# AVG(d101) AS d101_mean,
# AVG(d102) AS d102_mean,
# AVG(d103) AS d103_mean,
# AVG(d104) AS d104_mean,
# AVG(d105) AS d105_mean,
# AVG(d106) AS d106_mean,
# AVG(d107) AS d107_mean,
# AVG(d108) AS d108_mean,
# AVG(d109) AS d109_mean,
# AVG(d110) AS d110_mean,
# AVG(d111) AS d111_mean,
# AVG(d112) AS d112_mean,
# AVG(d113) AS d113_mean,
# AVG(d114) AS d114_mean,
# AVG(d115) AS d115_mean,
# AVG(d116) AS d116_mean,
# AVG(d117) AS d117_mean,
# AVG(d118) AS d118_mean,
# AVG(d119) AS d119_mean,
# AVG(d120) AS d120_mean,
# AVG(d121) AS d121_mean,
# AVG(d122) AS d122_mean,
# AVG(d123) AS d123_mean,
# AVG(d124) AS d124_mean,
# AVG(d125) AS d125_mean,
# AVG(d126) AS d126_mean,
# AVG(d127) AS d127_mean,
# AVG(d128) AS d128_mean,
# AVG(d129) AS d129_mean,
# AVG(d130) AS d130_mean,
# AVG(d131) AS d131_mean,
# AVG(d132) AS d132_mean,
# AVG(d133) AS d133_mean,
# AVG(d134) AS d134_mean,
# AVG(d135) AS d135_mean,
# AVG(d136) AS d136_mean,
# AVG(d137) AS d137_mean,
# AVG(d138) AS d138_mean,
# AVG(d139) AS d139_mean,
# AVG(d140) AS d140_mean,
# AVG(d141) AS d141_mean,
# AVG(d142) AS d142_mean,
# AVG(d143) AS d143_mean,
# AVG(d144) AS d144_mean,
# AVG(d145) AS d145_mean,
# AVG(d146) AS d146_mean,
# AVG(d147) AS d147_mean,
# AVG(d148) AS d148_mean,
# AVG(d149) AS d149_mean,
# AVG(d150) AS d150_mean,
# AVG(d151) AS d151_mean,
# AVG(d152) AS d152_mean,
# AVG(d153) AS d153_mean,
# AVG(d154) AS d154_mean,
# AVG(d155) AS d155_mean,
# AVG(d156) AS d156_mean,
# AVG(d157) AS d157_mean,
# AVG(d158) AS d158_mean,
# AVG(d159) AS d159_mean,
# AVG(d160) AS d160_mean,
# AVG(d161) AS d161_mean,
# AVG(d162) AS d162_mean,
# AVG(d163) AS d163_mean,
# AVG(d164) AS d164_mean,
# AVG(d165) AS d165_mean,
# AVG(d166) AS d166_mean,
# AVG(d167) AS d167_mean,
# AVG(d168) AS d168_mean,
# AVG(d169) AS d169_mean,
# AVG(d170) AS d170_mean,
# AVG(d171) AS d171_mean,
# AVG(d172) AS d172_mean,
# AVG(d173) AS d173_mean,
# AVG(d174) AS d174_mean,
# AVG(d175) AS d175_mean,
# AVG(d176) AS d176_mean,
# AVG(d177) AS d177_mean,
# AVG(d178) AS d178_mean,
# AVG(d179) AS d179_mean,
# AVG(d180) AS d180_mean,
# AVG(d181) AS d181_mean,
# AVG(d182) AS d182_mean,
# AVG(d183) AS d183_mean,
# AVG(d184) AS d184_mean,
# AVG(d185) AS d185_mean,
# AVG(d186) AS d186_mean,
# AVG(d187) AS d187_mean,
# AVG(d188) AS d188_mean,
# AVG(d189) AS d189_mean,
# AVG(d190) AS d190_mean,
# AVG(d191) AS d191_mean,
# AVG(d192) AS d192_mean,
# AVG(d193) AS d193_mean,
# AVG(d194) AS d194_mean,
# AVG(d195) AS d195_mean,
# AVG(d196) AS d196_mean,
# AVG(d197) AS d197_mean,
# AVG(d198) AS d198_mean,
# AVG(d199) AS d199_mean,
# AVG(d200) AS d200_mean,
# AVG(d201) AS d201_mean,
# AVG(d202) AS d202_mean,
# AVG(d203) AS d203_mean,
# AVG(d204) AS d204_mean,
# AVG(d205) AS d205_mean,
# AVG(d206) AS d206_mean,
# AVG(d207) AS d207_mean,
# AVG(d208) AS d208_mean,
# AVG(d209) AS d209_mean,
# AVG(d210) AS d210_mean,
# AVG(d211) AS d211_mean,
# AVG(d212) AS d212_mean,
# AVG(d213) AS d213_mean,
# AVG(d214) AS d214_mean,
# AVG(d215) AS d215_mean,
# AVG(d216) AS d216_mean,
# AVG(d217) AS d217_mean,
# AVG(d218) AS d218_mean,
# AVG(d219) AS d219_mean,
# AVG(d220) AS d220_mean,
# AVG(d221) AS d221_mean,
# AVG(d222) AS d222_mean,
# AVG(d223) AS d223_mean,
# AVG(d224) AS d224_mean,
# AVG(d225) AS d225_mean,
# AVG(d226) AS d226_mean,
# AVG(d227) AS d227_mean,
# AVG(d228) AS d228_mean,
# AVG(d229) AS d229_mean,
# AVG(d230) AS d230_mean,
# AVG(d231) AS d231_mean,
# AVG(d232) AS d232_mean,
# AVG(d233) AS d233_mean,
# AVG(d234) AS d234_mean,
# AVG(d235) AS d235_mean,
# AVG(d236) AS d236_mean,
# AVG(d237) AS d237_mean,
# AVG(d238) AS d238_mean,
# AVG(d239) AS d239_mean,
# AVG(d240) AS d240_mean,
# AVG(d241) AS d241_mean,
# AVG(d242) AS d242_mean,
# AVG(d243) AS d243_mean,
# AVG(d244) AS d244_mean,
# AVG(d245) AS d245_mean,
# AVG(d246) AS d246_mean,
# AVG(d247) AS d247_mean,
# AVG(d248) AS d248_mean,
# AVG(d249) AS d249_mean,
# AVG(d250) AS d250_mean,
# AVG(d251) AS d251_mean,
# AVG(d252) AS d252_mean,
# AVG(d253) AS d253_mean,
# AVG(d254) AS d254_mean,
# AVG(d255) AS d255_mean,
# AVG(d256) AS d256_mean,
# AVG(d257) AS d257_mean,
# AVG(d258) AS d258_mean,
# AVG(d259) AS d259_mean,
# AVG(d260) AS d260_mean,
# AVG(d261) AS d261_mean,
# AVG(d262) AS d262_mean,
# AVG(d263) AS d263_mean,
# AVG(d264) AS d264_mean,
# AVG(d265) AS d265_mean,
# AVG(d266) AS d266_mean,
# AVG(d267) AS d267_mean,
# AVG(d268) AS d268_mean,
# AVG(d269) AS d269_mean,
# AVG(d270) AS d270_mean,
# AVG(d271) AS d271_mean,
# AVG(d272) AS d272_mean,
# AVG(d273) AS d273_mean,
# AVG(d274) AS d274_mean,
# AVG(d275) AS d275_mean,
# AVG(d276) AS d276_mean,
# AVG(d277) AS d277_mean,
# AVG(d278) AS d278_mean,
# AVG(d279) AS d279_mean,
# AVG(d280) AS d280_mean,
# AVG(d281) AS d281_mean,
# AVG(d282) AS d282_mean,
# AVG(d283) AS d283_mean,
# AVG(d284) AS d284_mean,
# AVG(d285) AS d285_mean,
# AVG(d286) AS d286_mean,
# AVG(d287) AS d287_mean,
# AVG(d288) AS d288_mean,
# AVG(d289) AS d289_mean,
# AVG(d290) AS d290_mean,
# AVG(d291) AS d291_mean,
# AVG(d292) AS d292_mean,
# AVG(d293) AS d293_mean,
# AVG(d294) AS d294_mean,
# AVG(d295) AS d295_mean,
# AVG(d296) AS d296_mean,
# AVG(d297) AS d297_mean,
# AVG(d298) AS d298_mean,
# AVG(d299) AS d299_mean,
# AVG(d300) AS d300_mean,
# AVG(d301) AS d301_mean,
# AVG(d302) AS d302_mean,
# AVG(d303) AS d303_mean,
# AVG(d304) AS d304_mean,
# AVG(d305) AS d305_mean,
# AVG(d306) AS d306_mean,
# AVG(d307) AS d307_mean,
# AVG(d308) AS d308_mean,
# AVG(d309) AS d309_mean,
# AVG(d310) AS d310_mean,
# AVG(d311) AS d311_mean,
# AVG(d312) AS d312_mean,
# AVG(d313) AS d313_mean,
# AVG(d314) AS d314_mean,
# AVG(d315) AS d315_mean,
# AVG(d316) AS d316_mean,
# AVG(d317) AS d317_mean,
# AVG(d318) AS d318_mean,
# AVG(d319) AS d319_mean,
# AVG(d320) AS d320_mean,
# AVG(d321) AS d321_mean,
# AVG(d322) AS d322_mean,
# AVG(d323) AS d323_mean,
# AVG(d324) AS d324_mean,
# AVG(d325) AS d325_mean,
# AVG(d326) AS d326_mean,
# AVG(d327) AS d327_mean,
# AVG(d328) AS d328_mean,
# AVG(d329) AS d329_mean,
# AVG(d330) AS d330_mean,
# AVG(d331) AS d331_mean,
# AVG(d332) AS d332_mean,
# AVG(d333) AS d333_mean,
# AVG(d334) AS d334_mean,
# AVG(d335) AS d335_mean,
# AVG(d336) AS d336_mean,
# AVG(d337) AS d337_mean,
# AVG(d338) AS d338_mean,
# AVG(d339) AS d339_mean,
# AVG(d340) AS d340_mean,
# AVG(d341) AS d341_mean,
# AVG(d342) AS d342_mean,
# AVG(d343) AS d343_mean,
# AVG(d344) AS d344_mean,
# AVG(d345) AS d345_mean,
# AVG(d346) AS d346_mean,
# AVG(d347) AS d347_mean,
# AVG(d348) AS d348_mean,
# AVG(d349) AS d349_mean,
# AVG(d350) AS d350_mean,
# AVG(d351) AS d351_mean,
# AVG(d352) AS d352_mean,
# AVG(d353) AS d353_mean,
# AVG(d354) AS d354_mean,
# AVG(d355) AS d355_mean,
# AVG(d356) AS d356_mean,
# AVG(d357) AS d357_mean,
# AVG(d358) AS d358_mean,
# AVG(d359) AS d359_mean,
# AVG(d360) AS d360_mean,
# AVG(d361) AS d361_mean,
# AVG(d362) AS d362_mean,
# AVG(d363) AS d363_mean,
# AVG(d364) AS d364_mean,
# AVG(d365) AS d365_mean,
# AVG(d366) AS d366_mean,
# AVG(d367) AS d367_mean,
# AVG(d368) AS d368_mean,
# AVG(d369) AS d369_mean,
# AVG(d370) AS d370_mean,
# AVG(d371) AS d371_mean,
# AVG(d372) AS d372_mean,
# AVG(d373) AS d373_mean,
# AVG(d374) AS d374_mean,
# AVG(d375) AS d375_mean,
# AVG(d376) AS d376_mean,
# AVG(d377) AS d377_mean,
# AVG(d378) AS d378_mean,
# AVG(d379) AS d379_mean,
# AVG(d380) AS d380_mean,
# AVG(d381) AS d381_mean,
# AVG(d382) AS d382_mean,
# AVG(d383) AS d383_mean,
# AVG(d384) AS d384_mean,
# AVG(d385) AS d385_mean,
# AVG(d386) AS d386_mean,
# AVG(d387) AS d387_mean,
# AVG(d388) AS d388_mean,
# AVG(d389) AS d389_mean,
# AVG(d390) AS d390_mean,
# AVG(d391) AS d391_mean,
# AVG(d392) AS d392_mean,
# AVG(d393) AS d393_mean,
# AVG(d394) AS d394_mean,
# AVG(d395) AS d395_mean,
# AVG(d396) AS d396_mean,
# AVG(d397) AS d397_mean,
# AVG(d398) AS d398_mean,
# AVG(d399) AS d399_mean,
# AVG(d400) AS d400_mean,
# AVG(d401) AS d401_mean,
# AVG(d402) AS d402_mean,
# AVG(d403) AS d403_mean,
# AVG(d404) AS d404_mean,
# AVG(d405) AS d405_mean,
# AVG(d406) AS d406_mean,
# AVG(d407) AS d407_mean,
# AVG(d408) AS d408_mean,
# AVG(d409) AS d409_mean,
# AVG(d410) AS d410_mean,
# AVG(d411) AS d411_mean,
# AVG(d412) AS d412_mean,
# AVG(d413) AS d413_mean,
# AVG(d414) AS d414_mean,
# AVG(d415) AS d415_mean,
# AVG(d416) AS d416_mean,
# AVG(d417) AS d417_mean,
# AVG(d418) AS d418_mean,
# AVG(d419) AS d419_mean,
# AVG(d420) AS d420_mean,
# AVG(d421) AS d421_mean,
# AVG(d422) AS d422_mean,
# AVG(d423) AS d423_mean,
# AVG(d424) AS d424_mean,
# AVG(d425) AS d425_mean,
# AVG(d426) AS d426_mean,
# AVG(d427) AS d427_mean,
# AVG(d428) AS d428_mean,
# AVG(d429) AS d429_mean,
# AVG(d430) AS d430_mean,
# AVG(d431) AS d431_mean,
# AVG(d432) AS d432_mean,
# AVG(d433) AS d433_mean,
# AVG(d434) AS d434_mean,
# AVG(d435) AS d435_mean,
# AVG(d436) AS d436_mean,
# AVG(d437) AS d437_mean,
# AVG(d438) AS d438_mean,
# AVG(d439) AS d439_mean,
# AVG(d440) AS d440_mean,
# AVG(d441) AS d441_mean,
# AVG(d442) AS d442_mean,
# AVG(d443) AS d443_mean,
# AVG(d444) AS d444_mean,
# AVG(d445) AS d445_mean,
# AVG(d446) AS d446_mean,
# AVG(d447) AS d447_mean,
# AVG(d448) AS d448_mean,
# AVG(d449) AS d449_mean,
# AVG(d450) AS d450_mean,
# AVG(d451) AS d451_mean,
# AVG(d452) AS d452_mean,
# AVG(d453) AS d453_mean,
# AVG(d454) AS d454_mean,
# AVG(d455) AS d455_mean,
# AVG(d456) AS d456_mean,
# AVG(d457) AS d457_mean,
# AVG(d458) AS d458_mean,
# AVG(d459) AS d459_mean,
# AVG(d460) AS d460_mean,
# AVG(d461) AS d461_mean,
# AVG(d462) AS d462_mean,
# AVG(d463) AS d463_mean,
# AVG(d464) AS d464_mean,
# AVG(d465) AS d465_mean,
# AVG(d466) AS d466_mean,
# AVG(d467) AS d467_mean,
# AVG(d468) AS d468_mean,
# AVG(d469) AS d469_mean,
# AVG(d470) AS d470_mean,
# AVG(d471) AS d471_mean,
# AVG(d472) AS d472_mean,
# AVG(d473) AS d473_mean,
# AVG(d474) AS d474_mean,
# AVG(d475) AS d475_mean,
# AVG(d476) AS d476_mean,
# AVG(d477) AS d477_mean,
# AVG(d478) AS d478_mean,
# AVG(d479) AS d479_mean,
# AVG(d480) AS d480_mean,
# AVG(d481) AS d481_mean,
# AVG(d482) AS d482_mean,
# AVG(d483) AS d483_mean,
# AVG(d484) AS d484_mean,
# AVG(d485) AS d485_mean,
# AVG(d486) AS d486_mean,
# AVG(d487) AS d487_mean,
# AVG(d488) AS d488_mean,
# AVG(d489) AS d489_mean,
# AVG(d490) AS d490_mean,
# AVG(d491) AS d491_mean,
# AVG(d492) AS d492_mean,
# AVG(d493) AS d493_mean,
# AVG(d494) AS d494_mean,
# AVG(d495) AS d495_mean,
# AVG(d496) AS d496_mean,
# AVG(d497) AS d497_mean,
# AVG(d498) AS d498_mean,
# AVG(d499) AS d499_mean,
# AVG(d500) AS d500_mean,
# AVG(d501) AS d501_mean,
# AVG(d502) AS d502_mean,
# AVG(d503) AS d503_mean,
# AVG(d504) AS d504_mean,
# AVG(d505) AS d505_mean,
# AVG(d506) AS d506_mean,
# AVG(d507) AS d507_mean,
# AVG(d508) AS d508_mean,
# AVG(d509) AS d509_mean,
# AVG(d510) AS d510_mean,
# AVG(d511) AS d511_mean,
#
# FROM (
# SELECT f.first_level.name AS f1,
#
# title_embed[OFFSET(0)] AS d0,
# title_embed[OFFSET(1)] AS d1,
# title_embed[OFFSET(2)] AS d2,
# title_embed[OFFSET(3)] AS d3,
# title_embed[OFFSET(4)] AS d4,
# title_embed[OFFSET(5)] AS d5,
# title_embed[OFFSET(6)] AS d6,
# title_embed[OFFSET(7)] AS d7,
# title_embed[OFFSET(8)] AS d8,
# title_embed[OFFSET(9)] AS d9,
# title_embed[OFFSET(10)] AS d10,
# title_embed[OFFSET(11)] AS d11,
# title_embed[OFFSET(12)] AS d12,
# title_embed[OFFSET(13)] AS d13,
# title_embed[OFFSET(14)] AS d14,
# title_embed[OFFSET(15)] AS d15,
# title_embed[OFFSET(16)] AS d16,
# title_embed[OFFSET(17)] AS d17,
# title_embed[OFFSET(18)] AS d18,
# title_embed[OFFSET(19)] AS d19,
# title_embed[OFFSET(20)] AS d20,
# title_embed[OFFSET(21)] AS d21,
# title_embed[OFFSET(22)] AS d22,
# title_embed[OFFSET(23)] AS d23,
# title_embed[OFFSET(24)] AS d24,
# title_embed[OFFSET(25)] AS d25,
# title_embed[OFFSET(26)] AS d26,
# title_embed[OFFSET(27)] AS d27,
# title_embed[OFFSET(28)] AS d28,
# title_embed[OFFSET(29)] AS d29,
# title_embed[OFFSET(30)] AS d30,
# title_embed[OFFSET(31)] AS d31,
# title_embed[OFFSET(32)] AS d32,
# title_embed[OFFSET(33)] AS d33,
# title_embed[OFFSET(34)] AS d34,
# title_embed[OFFSET(35)] AS d35,
# title_embed[OFFSET(36)] AS d36,
# title_embed[OFFSET(37)] AS d37,
# title_embed[OFFSET(38)] AS d38,
# title_embed[OFFSET(39)] AS d39,
# title_embed[OFFSET(40)] AS d40,
# title_embed[OFFSET(41)] AS d41,
# title_embed[OFFSET(42)] AS d42,
# title_embed[OFFSET(43)] AS d43,
# title_embed[OFFSET(44)] AS d44,
# title_embed[OFFSET(45)] AS d45,
# title_embed[OFFSET(46)] AS d46,
# title_embed[OFFSET(47)] AS d47,
# title_embed[OFFSET(48)] AS d48,
# title_embed[OFFSET(49)] AS d49,
# title_embed[OFFSET(50)] AS d50,
# title_embed[OFFSET(51)] AS d51,
# title_embed[OFFSET(52)] AS d52,
# title_embed[OFFSET(53)] AS d53,
# title_embed[OFFSET(54)] AS d54,
# title_embed[OFFSET(55)] AS d55,
# title_embed[OFFSET(56)] AS d56,
# title_embed[OFFSET(57)] AS d57,
# title_embed[OFFSET(58)] AS d58,
# title_embed[OFFSET(59)] AS d59,
# title_embed[OFFSET(60)] AS d60,
# title_embed[OFFSET(61)] AS d61,
# title_embed[OFFSET(62)] AS d62,
# title_embed[OFFSET(63)] AS d63,
# title_embed[OFFSET(64)] AS d64,
# title_embed[OFFSET(65)] AS d65,
# title_embed[OFFSET(66)] AS d66,
# title_embed[OFFSET(67)] AS d67,
# title_embed[OFFSET(68)] AS d68,
# title_embed[OFFSET(69)] AS d69,
# title_embed[OFFSET(70)] AS d70,
# title_embed[OFFSET(71)] AS d71,
# title_embed[OFFSET(72)] AS d72,
# title_embed[OFFSET(73)] AS d73,
# title_embed[OFFSET(74)] AS d74,
# title_embed[OFFSET(75)] AS d75,
# title_embed[OFFSET(76)] AS d76,
# title_embed[OFFSET(77)] AS d77,
# title_embed[OFFSET(78)] AS d78,
# title_embed[OFFSET(79)] AS d79,
# title_embed[OFFSET(80)] AS d80,
# title_embed[OFFSET(81)] AS d81,
# title_embed[OFFSET(82)] AS d82,
# title_embed[OFFSET(83)] AS d83,
# title_embed[OFFSET(84)] AS d84,
# title_embed[OFFSET(85)] AS d85,
# title_embed[OFFSET(86)] AS d86,
# title_embed[OFFSET(87)] AS d87,
# title_embed[OFFSET(88)] AS d88,
# title_embed[OFFSET(89)] AS d89,
# title_embed[OFFSET(90)] AS d90,
# title_embed[OFFSET(91)] AS d91,
# title_embed[OFFSET(92)] AS d92,
# title_embed[OFFSET(93)] AS d93,
# title_embed[OFFSET(94)] AS d94,
# title_embed[OFFSET(95)] AS d95,
# title_embed[OFFSET(96)] AS d96,
# title_embed[OFFSET(97)] AS d97,
# title_embed[OFFSET(98)] AS d98,
# title_embed[OFFSET(99)] AS d99,
# title_embed[OFFSET(100)] AS d100,
# title_embed[OFFSET(101)] AS d101,
# title_embed[OFFSET(102)] AS d102,
# title_embed[OFFSET(103)] AS d103,
# title_embed[OFFSET(104)] AS d104,
# title_embed[OFFSET(105)] AS d105,
# title_embed[OFFSET(106)] AS d106,
# title_embed[OFFSET(107)] AS d107,
# title_embed[OFFSET(108)] AS d108,
# title_embed[OFFSET(109)] AS d109,
# title_embed[OFFSET(110)] AS d110,
# title_embed[OFFSET(111)] AS d111,
# title_embed[OFFSET(112)] AS d112,
# title_embed[OFFSET(113)] AS d113,
# title_embed[OFFSET(114)] AS d114,
# title_embed[OFFSET(115)] AS d115,
# title_embed[OFFSET(116)] AS d116,
# title_embed[OFFSET(117)] AS d117,
# title_embed[OFFSET(118)] AS d118,
# title_embed[OFFSET(119)] AS d119,
# title_embed[OFFSET(120)] AS d120,
# title_embed[OFFSET(121)] AS d121,
# title_embed[OFFSET(122)] AS d122,
# title_embed[OFFSET(123)] AS d123,
# title_embed[OFFSET(124)] AS d124,
# title_embed[OFFSET(125)] AS d125,
# title_embed[OFFSET(126)] AS d126,
# title_embed[OFFSET(127)] AS d127,
# title_embed[OFFSET(128)] AS d128,
# title_embed[OFFSET(129)] AS d129,
# title_embed[OFFSET(130)] AS d130,
# title_embed[OFFSET(131)] AS d131,
# title_embed[OFFSET(132)] AS d132,
# title_embed[OFFSET(133)] AS d133,
# title_embed[OFFSET(134)] AS d134,
# title_embed[OFFSET(135)] AS d135,
# title_embed[OFFSET(136)] AS d136,
# title_embed[OFFSET(137)] AS d137,
# title_embed[OFFSET(138)] AS d138,
# title_embed[OFFSET(139)] AS d139,
# title_embed[OFFSET(140)] AS d140,
# title_embed[OFFSET(141)] AS d141,
# title_embed[OFFSET(142)] AS d142,
# title_embed[OFFSET(143)] AS d143,
# title_embed[OFFSET(144)] AS d144,
# title_embed[OFFSET(145)] AS d145,
# title_embed[OFFSET(146)] AS d146,
# title_embed[OFFSET(147)] AS d147,
# title_embed[OFFSET(148)] AS d148,
# title_embed[OFFSET(222)] AS d222,
# title_embed[OFFSET(223)] AS d223,
# title_embed[OFFSET(224)] AS d224,
# title_embed[OFFSET(225)] AS d225,
# title_embed[OFFSET(226)] AS d226,
# title_embed[OFFSET(227)] AS d227,
# title_embed[OFFSET(228)] AS d228,
# title_embed[OFFSET(229)] AS d229,
# title_embed[OFFSET(230)] AS d230,
# title_embed[OFFSET(231)] AS d231,
# title_embed[OFFSET(232)] AS d232,
# title_embed[OFFSET(233)] AS d233,
# title_embed[OFFSET(234)] AS d234,
# title_embed[OFFSET(235)] AS d235,
# title_embed[OFFSET(236)] AS d236,
# title_embed[OFFSET(237)] AS d237,
# title_embed[OFFSET(238)] AS d238,
# title_embed[OFFSET(239)] AS d239,
# title_embed[OFFSET(240)] AS d240,
# title_embed[OFFSET(241)] AS d241,
# title_embed[OFFSET(242)] AS d242,
# title_embed[OFFSET(243)] AS d243,
# title_embed[OFFSET(244)] AS d244,
# title_embed[OFFSET(245)] AS d245,
# title_embed[OFFSET(246)] AS d246,
# title_embed[OFFSET(247)] AS d247,
# title_embed[OFFSET(248)] AS d248,
# title_embed[OFFSET(249)] AS d249,
# title_embed[OFFSET(250)] AS d250,
# title_embed[OFFSET(251)] AS d251,
# title_embed[OFFSET(252)] AS d252,
# title_embed[OFFSET(253)] AS d253,
# title_embed[OFFSET(254)] AS d254,
# title_embed[OFFSET(255)] AS d255,
# title_embed[OFFSET(256)] AS d256,
# title_embed[OFFSET(257)] AS d257,
# title_embed[OFFSET(258)] AS d258,
# title_embed[OFFSET(259)] AS d259,
# title_embed[OFFSET(260)] AS d260,
# title_embed[OFFSET(261)] AS d261,
# title_embed[OFFSET(262)] AS d262,
# title_embed[OFFSET(263)] AS d263,
# title_embed[OFFSET(264)] AS d264,
# title_embed[OFFSET(265)] AS d265,
# title_embed[OFFSET(266)] AS d266,
# title_embed[OFFSET(267)] AS d267,
# title_embed[OFFSET(268)] AS d268,
# title_embed[OFFSET(269)] AS d269,
# title_embed[OFFSET(270)] AS d270,
# title_embed[OFFSET(271)] AS d271,
# title_embed[OFFSET(272)] AS d272,
# title_embed[OFFSET(273)] AS d273,
# title_embed[OFFSET(274)] AS d274,
# title_embed[OFFSET(275)] AS d275,
# title_embed[OFFSET(276)] AS d276,
# title_embed[OFFSET(277)] AS d277,
# title_embed[OFFSET(278)] AS d278,
# title_embed[OFFSET(279)] AS d279,
# title_embed[OFFSET(280)] AS d280,
# title_embed[OFFSET(281)] AS d281,
# title_embed[OFFSET(282)] AS d282,
# title_embed[OFFSET(283)] AS d283,
# title_embed[OFFSET(284)] AS d284,
# title_embed[OFFSET(285)] AS d285,
# title_embed[OFFSET(286)] AS d286,
# title_embed[OFFSET(287)] AS d287,
# title_embed[OFFSET(288)] AS d288,
# title_embed[OFFSET(289)] AS d289,
# title_embed[OFFSET(290)] AS d290,
# title_embed[OFFSET(291)] AS d291,
# title_embed[OFFSET(292)] AS d292,
# title_embed[OFFSET(293)] AS d293,
# title_embed[OFFSET(294)] AS d294,
# title_embed[OFFSET(295)] AS d295,
# title_embed[OFFSET(369)] AS d369,
# title_embed[OFFSET(370)] AS d370,
# title_embed[OFFSET(371)] AS d371,
# title_embed[OFFSET(372)] AS d372,
# title_embed[OFFSET(373)] AS d373,
# title_embed[OFFSET(374)] AS d374,
# title_embed[OFFSET(375)] AS d375,
# title_embed[OFFSET(376)] AS d376,
# title_embed[OFFSET(377)] AS d377,
# title_embed[OFFSET(378)] AS d378,
# title_embed[OFFSET(379)] AS d379,
# title_embed[OFFSET(380)] AS d380,
# title_embed[OFFSET(381)] AS d381,
# title_embed[OFFSET(382)] AS d382,
# title_embed[OFFSET(383)] AS d383,
# title_embed[OFFSET(384)] AS d384,
# title_embed[OFFSET(385)] AS d385,
# title_embed[OFFSET(386)] AS d386,
# title_embed[OFFSET(387)] AS d387,
# title_embed[OFFSET(388)] AS d388,
# title_embed[OFFSET(389)] AS d389,
# title_embed[OFFSET(390)] AS d390,
# title_embed[OFFSET(391)] AS d391,
# title_embed[OFFSET(392)] AS d392,
# title_embed[OFFSET(393)] AS d393,
# title_embed[OFFSET(394)] AS d394,
# title_embed[OFFSET(395)] AS d395,
# title_embed[OFFSET(396)] AS d396,
# title_embed[OFFSET(397)] AS d397,
# title_embed[OFFSET(398)] AS d398,
# title_embed[OFFSET(399)] AS d399,
# title_embed[OFFSET(400)] AS d400,
# title_embed[OFFSET(401)] AS d401,
# title_embed[OFFSET(402)] AS d402,
# title_embed[OFFSET(403)] AS d403,
# title_embed[OFFSET(404)] AS d404,
# title_embed[OFFSET(405)] AS d405,
# title_embed[OFFSET(406)] AS d406,
# title_embed[OFFSET(407)] AS d407,
# title_embed[OFFSET(408)] AS d408,
# title_embed[OFFSET(409)] AS d409,
# title_embed[OFFSET(410)] AS d410,
# title_embed[OFFSET(411)] AS d411,
# title_embed[OFFSET(412)] AS d412,
# title_embed[OFFSET(413)] AS d413,
# title_embed[OFFSET(414)] AS d414,
# title_embed[OFFSET(415)] AS d415,
# title_embed[OFFSET(416)] AS d416,
# title_embed[OFFSET(417)] AS d417,
# title_embed[OFFSET(418)] AS d418,
# title_embed[OFFSET(419)] AS d419,
# title_embed[OFFSET(420)] AS d420,
# title_embed[OFFSET(421)] AS d421,
# title_embed[OFFSET(422)] AS d422,
# title_embed[OFFSET(423)] AS d423,
# title_embed[OFFSET(424)] AS d424,
# title_embed[OFFSET(425)] AS d425,
# title_embed[OFFSET(426)] AS d426,
# title_embed[OFFSET(427)] AS d427,
# title_embed[OFFSET(428)] AS d428,
# title_embed[OFFSET(429)] AS d429,
# title_embed[OFFSET(430)] AS d430,
# title_embed[OFFSET(431)] AS d431,
# title_embed[OFFSET(432)] AS d432,
# title_embed[OFFSET(433)] AS d433,
# title_embed[OFFSET(434)] AS d434,
# title_embed[OFFSET(435)] AS d435,
# title_embed[OFFSET(436)] AS d436,
# title_embed[OFFSET(437)] AS d437,
# title_embed[OFFSET(438)] AS d438,
# title_embed[OFFSET(439)] AS d439,
# title_embed[OFFSET(440)] AS d440,
# title_embed[OFFSET(441)] AS d441,
# title_embed[OFFSET(442)] AS d442,
# title_embed[OFFSET(443)] AS d443,
# title_embed[OFFSET(444)] AS d444,
# title_embed[OFFSET(445)] AS d445,
# title_embed[OFFSET(446)] AS d446,
# title_embed[OFFSET(447)] AS d447,
# title_embed[OFFSET(448)] AS d448,
# title_embed[OFFSET(449)] AS d449,
# title_embed[OFFSET(450)] AS d450,
# title_embed[OFFSET(451)] AS d451,
# title_embed[OFFSET(452)] AS d452,
# title_embed[OFFSET(453)] AS d453,
# title_embed[OFFSET(454)] AS d454,
# title_embed[OFFSET(455)] AS d455,
# title_embed[OFFSET(456)] AS d456,
# title_embed[OFFSET(457)] AS d457,
# title_embed[OFFSET(458)] AS d458,
# title_embed[OFFSET(459)] AS d459,
# title_embed[OFFSET(460)] AS d460,
# title_embed[OFFSET(461)] AS d461,
# title_embed[OFFSET(462)] AS d462,
# title_embed[OFFSET(463)] AS d463,
# title_embed[OFFSET(464)] AS d464,
# title_embed[OFFSET(465)] AS d465,
# title_embed[OFFSET(466)] AS d466,
# title_embed[OFFSET(467)] AS d467,
# title_embed[OFFSET(468)] AS d468,
# title_embed[OFFSET(469)] AS d469,
# title_embed[OFFSET(470)] AS d470,
# title_embed[OFFSET(471)] AS d471,
# title_embed[OFFSET(472)] AS d472,
# title_embed[OFFSET(473)] AS d473,
# title_embed[OFFSET(474)] AS d474,
# title_embed[OFFSET(475)] AS d475,
# title_embed[OFFSET(476)] AS d476,
# title_embed[OFFSET(477)] AS d477,
# title_embed[OFFSET(478)] AS d478,
# title_embed[OFFSET(479)] AS d479,
# title_embed[OFFSET(480)] AS d480,
# title_embed[OFFSET(481)] AS d481,
# title_embed[OFFSET(482)] AS d482,
# title_embed[OFFSET(483)] AS d483,
# title_embed[OFFSET(484)] AS d484,
# title_embed[OFFSET(485)] AS d485,
# title_embed[OFFSET(486)] AS d486,
# title_embed[OFFSET(487)] AS d487,
# title_embed[OFFSET(488)] AS d488,
# title_embed[OFFSET(489)] AS d489,
# title_embed[OFFSET(490)] AS d490,
# title_embed[OFFSET(491)] AS d491,
# title_embed[OFFSET(492)] AS d492,
# title_embed[OFFSET(493)] AS d493,
# title_embed[OFFSET(494)] AS d494,
# title_embed[OFFSET(495)] AS d495,
# title_embed[OFFSET(496)] AS d496,
# title_embed[OFFSET(497)] AS d497,
# title_embed[OFFSET(498)] AS d498,
# title_embed[OFFSET(499)] AS d499,
# title_embed[OFFSET(500)] AS d500,
# title_embed[OFFSET(501)] AS d501,
# title_embed[OFFSET(502)] AS d502,
# title_embed[OFFSET(503)] AS d503,
# title_embed[OFFSET(504)] AS d504,
# title_embed[OFFSET(505)] AS d505,
# title_embed[OFFSET(506)] AS d506,
# title_embed[OFFSET(507)] AS d507,
# title_embed[OFFSET(508)] AS d508,
# title_embed[OFFSET(509)] AS d509,
# title_embed[OFFSET(510)] AS d510,
# title_embed[OFFSET(511)] AS d511,
#
# FROM `springer-nature-analytics.DS_dimensions.publications_full_refresh`
# LEFT JOIN UNNEST(`for`) AS f LEFT JOIN UNNEST(journal) AS j
# WHERE ARRAY_LENGTH(title_embed) = 512
# AND
# publication_type LIKE "article"
#         AND j.title IN (SELECT title FROM `springer-nature-analytics.core_journals.core_2018_v01`)
#         AND year >= 2017
#         AND year <= 2019
#         AND language LIKE "en"
#         AND ARRAY_LENGTH(references) > 4
#
# ) GROUP BY f1
#  ) WHERE f1 IS NOT NULL

# %%
train_and_save(for_17_19, "wv_17_19")
# Out:
# Saved mean vectors to "/content/drive/My Drive/Research/Data/Mean-title-centroids-3yrs-v02/wv_17_19_f1.csv"

# %%
# %%bigquery --project $pid for_17_19
#
# SELECT * FROM (
# SELECT f2,
#
# AVG(d0) AS d0_mean,
# AVG(d1) AS d1_mean,
# AVG(d2) AS d2_mean,
# AVG(d3) AS d3_mean,
# AVG(d4) AS d4_mean,
# AVG(d5) AS d5_mean,
# AVG(d6) AS d6_mean,
# AVG(d7) AS d7_mean,
# AVG(d8) AS d8_mean,
# AVG(d9) AS d9_mean,
# AVG(d10) AS d10_mean,
# AVG(d11) AS d11_mean,
# AVG(d12) AS d12_mean,
# AVG(d13) AS d13_mean,
# AVG(d14) AS d14_mean,
# AVG(d15) AS d15_mean,
# AVG(d16) AS d16_mean,
# AVG(d17) AS d17_mean,
# AVG(d18) AS d18_mean,
# AVG(d19) AS d19_mean,
# AVG(d20) AS d20_mean,
# AVG(d21) AS d21_mean,
# AVG(d22) AS d22_mean,
# AVG(d23) AS d23_mean,
# AVG(d24) AS d24_mean,
# AVG(d25) AS d25_mean,
# AVG(d26) AS d26_mean,
# AVG(d27) AS d27_mean,
# AVG(d28) AS d28_mean,
# AVG(d29) AS d29_mean,
# AVG(d30) AS d30_mean,
# AVG(d31) AS d31_mean,
# AVG(d32) AS d32_mean,
# AVG(d33) AS d33_mean,
# AVG(d34) AS d34_mean,
# AVG(d35) AS d35_mean,
# AVG(d36) AS d36_mean,
# AVG(d37) AS d37_mean,
# AVG(d38) AS d38_mean,
# AVG(d39) AS d39_mean,
# AVG(d40) AS d40_mean,
# AVG(d41) AS d41_mean,
# AVG(d42) AS d42_mean,
# AVG(d43) AS d43_mean,
# AVG(d44) AS d44_mean,
# AVG(d45) AS d45_mean,
# AVG(d46) AS d46_mean,
# AVG(d47) AS d47_mean,
# AVG(d48) AS d48_mean,
# AVG(d49) AS d49_mean,
# AVG(d50) AS d50_mean,
# AVG(d51) AS d51_mean,
# AVG(d52) AS d52_mean,
# AVG(d53) AS d53_mean,
# AVG(d54) AS d54_mean,
# AVG(d55) AS d55_mean,
# AVG(d56) AS d56_mean,
# AVG(d57) AS d57_mean,
# AVG(d58) AS d58_mean,
# AVG(d59) AS d59_mean,
# AVG(d60) AS d60_mean,
# AVG(d61) AS d61_mean,
# AVG(d62) AS d62_mean,
# AVG(d63) AS d63_mean,
# AVG(d64) AS d64_mean,
# AVG(d65) AS d65_mean,
# AVG(d66) AS d66_mean,
# AVG(d67) AS d67_mean,
# AVG(d68) AS d68_mean,
# AVG(d69) AS d69_mean,
# AVG(d70) AS d70_mean,
# AVG(d71) AS d71_mean,
# AVG(d72) AS d72_mean,
# AVG(d73) AS d73_mean,
# AVG(d74) AS d74_mean,
# AVG(d75) AS d75_mean,
# AVG(d76) AS d76_mean,
# AVG(d77) AS d77_mean,
# AVG(d78) AS d78_mean,
# AVG(d79) AS d79_mean,
# AVG(d80) AS d80_mean,
# AVG(d81) AS d81_mean,
# AVG(d82) AS d82_mean,
# AVG(d83) AS d83_mean,
# AVG(d84) AS d84_mean,
# AVG(d85) AS d85_mean,
# AVG(d86) AS d86_mean,
# AVG(d87) AS d87_mean,
# AVG(d88) AS d88_mean,
# AVG(d89) AS d89_mean,
# AVG(d90) AS d90_mean,
# AVG(d91) AS d91_mean,
# AVG(d92) AS d92_mean,
# AVG(d93) AS d93_mean,
# AVG(d94) AS d94_mean,
# AVG(d95) AS d95_mean,
# AVG(d96) AS d96_mean,
# AVG(d97) AS d97_mean,
# AVG(d98) AS d98_mean,
# AVG(d99) AS d99_mean,
# AVG(d100) AS d100_mean,
# AVG(d101) AS d101_mean,
# AVG(d102) AS d102_mean,
# AVG(d103) AS d103_mean,
# AVG(d104) AS d104_mean,
# AVG(d105) AS d105_mean,
# AVG(d106) AS d106_mean,
# AVG(d107) AS d107_mean,
# AVG(d108) AS d108_mean,
# AVG(d109) AS d109_mean,
# AVG(d110) AS d110_mean,
# AVG(d111) AS d111_mean,
# AVG(d112) AS d112_mean,
# AVG(d113) AS d113_mean,
# AVG(d114) AS d114_mean,
# AVG(d115) AS d115_mean,
# AVG(d116) AS d116_mean,
# AVG(d117) AS d117_mean,
# AVG(d118) AS d118_mean,
# AVG(d119) AS d119_mean,
# AVG(d120) AS d120_mean,
# AVG(d121) AS d121_mean,
# AVG(d122) AS d122_mean,
# AVG(d123) AS d123_mean,
# AVG(d124) AS d124_mean,
# AVG(d125) AS d125_mean,
# AVG(d126) AS d126_mean,
# AVG(d127) AS d127_mean,
# AVG(d128) AS d128_mean,
# AVG(d129) AS d129_mean,
# AVG(d130) AS d130_mean,
# AVG(d131) AS d131_mean,
# AVG(d132) AS d132_mean,
# AVG(d133) AS d133_mean,
# AVG(d134) AS d134_mean,
# AVG(d135) AS d135_mean,
# AVG(d136) AS d136_mean,
# AVG(d137) AS d137_mean,
# AVG(d138) AS d138_mean,
# AVG(d139) AS d139_mean,
# AVG(d140) AS d140_mean,
# AVG(d141) AS d141_mean,
# AVG(d142) AS d142_mean,
# AVG(d143) AS d143_mean,
# AVG(d144) AS d144_mean,
# AVG(d145) AS d145_mean,
# AVG(d146) AS d146_mean,
# AVG(d147) AS d147_mean,
# AVG(d148) AS d148_mean,
# AVG(d149) AS d149_mean,
# AVG(d150) AS d150_mean,
# AVG(d151) AS d151_mean,
# AVG(d152) AS d152_mean,
# AVG(d153) AS d153_mean,
# AVG(d154) AS d154_mean,
# AVG(d155) AS d155_mean,
# AVG(d156) AS d156_mean,
# AVG(d157) AS d157_mean,
# AVG(d158) AS d158_mean,
# AVG(d159) AS d159_mean,
# AVG(d160) AS d160_mean,
# AVG(d161) AS d161_mean,
# AVG(d162) AS d162_mean,
# AVG(d163) AS d163_mean,
# AVG(d164) AS d164_mean,
# AVG(d165) AS d165_mean,
# AVG(d166) AS d166_mean,
# AVG(d167) AS d167_mean,
# AVG(d168) AS d168_mean,
# AVG(d169) AS d169_mean,
# AVG(d170) AS d170_mean,
# AVG(d171) AS d171_mean,
# AVG(d172) AS d172_mean,
# AVG(d173) AS d173_mean,
# AVG(d174) AS d174_mean,
# AVG(d175) AS d175_mean,
# AVG(d176) AS d176_mean,
# AVG(d177) AS d177_mean,
# AVG(d178) AS d178_mean,
# AVG(d179) AS d179_mean,
# AVG(d180) AS d180_mean,
# AVG(d181) AS d181_mean,
# AVG(d182) AS d182_mean,
# AVG(d183) AS d183_mean,
# AVG(d184) AS d184_mean,
# AVG(d185) AS d185_mean,
# AVG(d186) AS d186_mean,
# AVG(d187) AS d187_mean,
# AVG(d188) AS d188_mean,
# AVG(d189) AS d189_mean,
# AVG(d190) AS d190_mean,
# AVG(d191) AS d191_mean,
# AVG(d192) AS d192_mean,
# AVG(d193) AS d193_mean,
# AVG(d194) AS d194_mean,
# AVG(d195) AS d195_mean,
# AVG(d196) AS d196_mean,
# AVG(d197) AS d197_mean,
# AVG(d198) AS d198_mean,
# AVG(d199) AS d199_mean,
# AVG(d200) AS d200_mean,
# AVG(d201) AS d201_mean,
# AVG(d202) AS d202_mean,
# AVG(d203) AS d203_mean,
# AVG(d204) AS d204_mean,
# AVG(d205) AS d205_mean,
# AVG(d206) AS d206_mean,
# AVG(d207) AS d207_mean,
# AVG(d208) AS d208_mean,
# AVG(d209) AS d209_mean,
# AVG(d210) AS d210_mean,
# AVG(d211) AS d211_mean,
# AVG(d212) AS d212_mean,
# AVG(d213) AS d213_mean,
# AVG(d214) AS d214_mean,
# AVG(d215) AS d215_mean,
# AVG(d216) AS d216_mean,
# AVG(d217) AS d217_mean,
# AVG(d218) AS d218_mean,
# AVG(d219) AS d219_mean,
# AVG(d220) AS d220_mean,
# AVG(d221) AS d221_mean,
# AVG(d222) AS d222_mean,
# AVG(d223) AS d223_mean,
# AVG(d224) AS d224_mean,
# AVG(d225) AS d225_mean,
# AVG(d226) AS d226_mean,
# AVG(d227) AS d227_mean,
# AVG(d228) AS d228_mean,
# AVG(d229) AS d229_mean,
# AVG(d230) AS d230_mean,
# AVG(d231) AS d231_mean,
# AVG(d232) AS d232_mean,
# AVG(d233) AS d233_mean,
# AVG(d234) AS d234_mean,
# AVG(d235) AS d235_mean,
# AVG(d236) AS d236_mean,
# AVG(d237) AS d237_mean,
# AVG(d238) AS d238_mean,
# AVG(d239) AS d239_mean,
# AVG(d240) AS d240_mean,
# AVG(d241) AS d241_mean,
# AVG(d242) AS d242_mean,
# AVG(d243) AS d243_mean,
# AVG(d244) AS d244_mean,
# AVG(d245) AS d245_mean,
# AVG(d246) AS d246_mean,
# AVG(d247) AS d247_mean,
# AVG(d248) AS d248_mean,
# AVG(d249) AS d249_mean,
# AVG(d250) AS d250_mean,
# AVG(d251) AS d251_mean,
# AVG(d252) AS d252_mean,
# AVG(d253) AS d253_mean,
# AVG(d254) AS d254_mean,
# AVG(d255) AS d255_mean,
# AVG(d256) AS d256_mean,
# AVG(d257) AS d257_mean,
# AVG(d258) AS d258_mean,
# AVG(d259) AS d259_mean,
# AVG(d260) AS d260_mean,
# AVG(d261) AS d261_mean,
# AVG(d262) AS d262_mean,
# AVG(d263) AS d263_mean,
# AVG(d264) AS d264_mean,
# AVG(d265) AS d265_mean,
# AVG(d266) AS d266_mean,
# AVG(d267) AS d267_mean,
# AVG(d268) AS d268_mean,
# AVG(d269) AS d269_mean,
# AVG(d270) AS d270_mean,
# AVG(d271) AS d271_mean,
# AVG(d272) AS d272_mean,
# AVG(d273) AS d273_mean,
# AVG(d274) AS d274_mean,
# AVG(d275) AS d275_mean,
# AVG(d276) AS d276_mean,
# AVG(d277) AS d277_mean,
# AVG(d278) AS d278_mean,
# AVG(d279) AS d279_mean,
# AVG(d280) AS d280_mean,
# AVG(d281) AS d281_mean,
# AVG(d282) AS d282_mean,
# AVG(d283) AS d283_mean,
# AVG(d284) AS d284_mean,
# AVG(d285) AS d285_mean,
# AVG(d286) AS d286_mean,
# AVG(d287) AS d287_mean,
# AVG(d288) AS d288_mean,
# AVG(d289) AS d289_mean,
# AVG(d290) AS d290_mean,
# AVG(d291) AS d291_mean,
# AVG(d292) AS d292_mean,
# AVG(d293) AS d293_mean,
# AVG(d294) AS d294_mean,
# AVG(d295) AS d295_mean,
# AVG(d296) AS d296_mean,
# AVG(d297) AS d297_mean,
# AVG(d298) AS d298_mean,
# AVG(d299) AS d299_mean,
# AVG(d300) AS d300_mean,
# AVG(d301) AS d301_mean,
# AVG(d302) AS d302_mean,
# AVG(d303) AS d303_mean,
# AVG(d304) AS d304_mean,
# AVG(d305) AS d305_mean,
# AVG(d306) AS d306_mean,
# AVG(d307) AS d307_mean,
# AVG(d308) AS d308_mean,
# AVG(d309) AS d309_mean,
# AVG(d310) AS d310_mean,
# AVG(d311) AS d311_mean,
# AVG(d312) AS d312_mean,
# AVG(d313) AS d313_mean,
# AVG(d314) AS d314_mean,
# AVG(d315) AS d315_mean,
# AVG(d316) AS d316_mean,
# AVG(d317) AS d317_mean,
# AVG(d318) AS d318_mean,
# AVG(d319) AS d319_mean,
# AVG(d320) AS d320_mean,
# AVG(d321) AS d321_mean,
# AVG(d322) AS d322_mean,
# AVG(d323) AS d323_mean,
# AVG(d324) AS d324_mean,
# AVG(d325) AS d325_mean,
# AVG(d326) AS d326_mean,
# AVG(d327) AS d327_mean,
# AVG(d328) AS d328_mean,
# AVG(d329) AS d329_mean,
# AVG(d330) AS d330_mean,
# AVG(d331) AS d331_mean,
# AVG(d332) AS d332_mean,
# AVG(d333) AS d333_mean,
# AVG(d334) AS d334_mean,
# AVG(d335) AS d335_mean,
# AVG(d336) AS d336_mean,
# AVG(d337) AS d337_mean,
# AVG(d338) AS d338_mean,
# AVG(d339) AS d339_mean,
# AVG(d340) AS d340_mean,
# AVG(d341) AS d341_mean,
# AVG(d342) AS d342_mean,
# AVG(d343) AS d343_mean,
# AVG(d344) AS d344_mean,
# AVG(d345) AS d345_mean,
# AVG(d346) AS d346_mean,
# AVG(d347) AS d347_mean,
# AVG(d348) AS d348_mean,
# AVG(d349) AS d349_mean,
# AVG(d350) AS d350_mean,
# AVG(d351) AS d351_mean,
# AVG(d352) AS d352_mean,
# AVG(d353) AS d353_mean,
# AVG(d354) AS d354_mean,
# AVG(d355) AS d355_mean,
# AVG(d356) AS d356_mean,
# AVG(d357) AS d357_mean,
# AVG(d358) AS d358_mean,
# AVG(d359) AS d359_mean,
# AVG(d360) AS d360_mean,
# AVG(d361) AS d361_mean,
# AVG(d362) AS d362_mean,
# AVG(d363) AS d363_mean,
# AVG(d364) AS d364_mean,
# AVG(d365) AS d365_mean,
# AVG(d366) AS d366_mean,
# AVG(d367) AS d367_mean,
# AVG(d368) AS d368_mean,
# AVG(d369) AS d369_mean,
# AVG(d370) AS d370_mean,
# AVG(d371) AS d371_mean,
# AVG(d372) AS d372_mean,
# AVG(d373) AS d373_mean,
# AVG(d374) AS d374_mean,
# AVG(d375) AS d375_mean,
# AVG(d376) AS d376_mean,
# AVG(d377) AS d377_mean,
# AVG(d378) AS d378_mean,
# AVG(d379) AS d379_mean,
# AVG(d380) AS d380_mean,
# AVG(d381) AS d381_mean,
# AVG(d382) AS d382_mean,
# AVG(d383) AS d383_mean,
# AVG(d384) AS d384_mean,
# AVG(d385) AS d385_mean,
# AVG(d386) AS d386_mean,
# AVG(d387) AS d387_mean,
# AVG(d388) AS d388_mean,
# AVG(d389) AS d389_mean,
# AVG(d390) AS d390_mean,
# AVG(d391) AS d391_mean,
# AVG(d392) AS d392_mean,
# AVG(d393) AS d393_mean,
# AVG(d394) AS d394_mean,
# AVG(d395) AS d395_mean,
# AVG(d396) AS d396_mean,
# AVG(d397) AS d397_mean,
# AVG(d398) AS d398_mean,
# AVG(d399) AS d399_mean,
# AVG(d400) AS d400_mean,
# AVG(d401) AS d401_mean,
# AVG(d402) AS d402_mean,
# AVG(d403) AS d403_mean,
# AVG(d404) AS d404_mean,
# AVG(d405) AS d405_mean,
# AVG(d406) AS d406_mean,
# AVG(d407) AS d407_mean,
# AVG(d408) AS d408_mean,
# AVG(d409) AS d409_mean,
# AVG(d410) AS d410_mean,
# AVG(d411) AS d411_mean,
# AVG(d412) AS d412_mean,
# AVG(d413) AS d413_mean,
# AVG(d414) AS d414_mean,
# AVG(d415) AS d415_mean,
# AVG(d416) AS d416_mean,
# AVG(d417) AS d417_mean,
# AVG(d418) AS d418_mean,
# AVG(d419) AS d419_mean,
# AVG(d420) AS d420_mean,
# AVG(d421) AS d421_mean,
# AVG(d422) AS d422_mean,
# AVG(d423) AS d423_mean,
# AVG(d424) AS d424_mean,
# AVG(d425) AS d425_mean,
# AVG(d426) AS d426_mean,
# AVG(d427) AS d427_mean,
# AVG(d428) AS d428_mean,
# AVG(d429) AS d429_mean,
# AVG(d430) AS d430_mean,
# AVG(d431) AS d431_mean,
# AVG(d432) AS d432_mean,
# AVG(d433) AS d433_mean,
# AVG(d434) AS d434_mean,
# AVG(d435) AS d435_mean,
# AVG(d436) AS d436_mean,
# AVG(d437) AS d437_mean,
# AVG(d438) AS d438_mean,
# AVG(d439) AS d439_mean,
# AVG(d440) AS d440_mean,
# AVG(d441) AS d441_mean,
# AVG(d442) AS d442_mean,
# AVG(d443) AS d443_mean,
# AVG(d444) AS d444_mean,
# AVG(d445) AS d445_mean,
# AVG(d446) AS d446_mean,
# AVG(d447) AS d447_mean,
# AVG(d448) AS d448_mean,
# AVG(d449) AS d449_mean,
# AVG(d450) AS d450_mean,
# AVG(d451) AS d451_mean,
# AVG(d452) AS d452_mean,
# AVG(d453) AS d453_mean,
# AVG(d454) AS d454_mean,
# AVG(d455) AS d455_mean,
# AVG(d456) AS d456_mean,
# AVG(d457) AS d457_mean,
# AVG(d458) AS d458_mean,
# AVG(d459) AS d459_mean,
# AVG(d460) AS d460_mean,
# AVG(d461) AS d461_mean,
# AVG(d462) AS d462_mean,
# AVG(d463) AS d463_mean,
# AVG(d464) AS d464_mean,
# AVG(d465) AS d465_mean,
# AVG(d466) AS d466_mean,
# AVG(d467) AS d467_mean,
# AVG(d468) AS d468_mean,
# AVG(d469) AS d469_mean,
# AVG(d470) AS d470_mean,
# AVG(d471) AS d471_mean,
# AVG(d472) AS d472_mean,
# AVG(d473) AS d473_mean,
# AVG(d474) AS d474_mean,
# AVG(d475) AS d475_mean,
# AVG(d476) AS d476_mean,
# AVG(d477) AS d477_mean,
# AVG(d478) AS d478_mean,
# AVG(d479) AS d479_mean,
# AVG(d480) AS d480_mean,
# AVG(d481) AS d481_mean,
# AVG(d482) AS d482_mean,
# AVG(d483) AS d483_mean,
# AVG(d484) AS d484_mean,
# AVG(d485) AS d485_mean,
# AVG(d486) AS d486_mean,
# AVG(d487) AS d487_mean,
# AVG(d488) AS d488_mean,
# AVG(d489) AS d489_mean,
# AVG(d490) AS d490_mean,
# AVG(d491) AS d491_mean,
# AVG(d492) AS d492_mean,
# AVG(d493) AS d493_mean,
# AVG(d494) AS d494_mean,
# AVG(d495) AS d495_mean,
# AVG(d496) AS d496_mean,
# AVG(d497) AS d497_mean,
# AVG(d498) AS d498_mean,
# AVG(d499) AS d499_mean,
# AVG(d500) AS d500_mean,
# AVG(d501) AS d501_mean,
# AVG(d502) AS d502_mean,
# AVG(d503) AS d503_mean,
# AVG(d504) AS d504_mean,
# AVG(d505) AS d505_mean,
# AVG(d506) AS d506_mean,
# AVG(d507) AS d507_mean,
# AVG(d508) AS d508_mean,
# AVG(d509) AS d509_mean,
# AVG(d510) AS d510_mean,
# AVG(d511) AS d511_mean,
#
# FROM (
# SELECT f.second_level.name AS f2,
#
# title_embed[OFFSET(0)] AS d0,
# title_embed[OFFSET(1)] AS d1,
# title_embed[OFFSET(2)] AS d2,
# title_embed[OFFSET(3)] AS d3,
# title_embed[OFFSET(4)] AS d4,
# title_embed[OFFSET(5)] AS d5,
# title_embed[OFFSET(6)] AS d6,
# title_embed[OFFSET(7)] AS d7,
# title_embed[OFFSET(8)] AS d8,
# title_embed[OFFSET(9)] AS d9,
# title_embed[OFFSET(10)] AS d10,
# title_embed[OFFSET(11)] AS d11,
# title_embed[OFFSET(12)] AS d12,
# title_embed[OFFSET(13)] AS d13,
# title_embed[OFFSET(14)] AS d14,
# title_embed[OFFSET(15)] AS d15,
# title_embed[OFFSET(16)] AS d16,
# title_embed[OFFSET(17)] AS d17,
# title_embed[OFFSET(18)] AS d18,
# title_embed[OFFSET(19)] AS d19,
# title_embed[OFFSET(20)] AS d20,
# title_embed[OFFSET(21)] AS d21,
# title_embed[OFFSET(22)] AS d22,
# title_embed[OFFSET(23)] AS d23,
# title_embed[OFFSET(24)] AS d24,
# title_embed[OFFSET(25)] AS d25,
# title_embed[OFFSET(26)] AS d26,
# title_embed[OFFSET(27)] AS d27,
# title_embed[OFFSET(28)] AS d28,
# title_embed[OFFSET(29)] AS d29,
# title_embed[OFFSET(30)] AS d30,
# title_embed[OFFSET(31)] AS d31,
# title_embed[OFFSET(32)] AS d32,
# title_embed[OFFSET(33)] AS d33,
# title_embed[OFFSET(34)] AS d34,
# title_embed[OFFSET(35)] AS d35,
# title_embed[OFFSET(36)] AS d36,
# title_embed[OFFSET(37)] AS d37,
# title_embed[OFFSET(38)] AS d38,
# title_embed[OFFSET(39)] AS d39,
# title_embed[OFFSET(40)] AS d40,
# title_embed[OFFSET(41)] AS d41,
# title_embed[OFFSET(42)] AS d42,
# title_embed[OFFSET(43)] AS d43,
# title_embed[OFFSET(44)] AS d44,
# title_embed[OFFSET(45)] AS d45,
# title_embed[OFFSET(46)] AS d46,
# title_embed[OFFSET(47)] AS d47,
# title_embed[OFFSET(48)] AS d48,
# title_embed[OFFSET(49)] AS d49,
# title_embed[OFFSET(50)] AS d50,
# title_embed[OFFSET(51)] AS d51,
# title_embed[OFFSET(52)] AS d52,
# title_embed[OFFSET(53)] AS d53,
# title_embed[OFFSET(54)] AS d54,
# title_embed[OFFSET(55)] AS d55,
# title_embed[OFFSET(56)] AS d56,
# title_embed[OFFSET(57)] AS d57,
# title_embed[OFFSET(58)] AS d58,
# title_embed[OFFSET(59)] AS d59,
# title_embed[OFFSET(60)] AS d60,
# title_embed[OFFSET(61)] AS d61,
# title_embed[OFFSET(62)] AS d62,
# title_embed[OFFSET(63)] AS d63,
# title_embed[OFFSET(64)] AS d64,
# title_embed[OFFSET(65)] AS d65,
# title_embed[OFFSET(66)] AS d66,
# title_embed[OFFSET(67)] AS d67,
# title_embed[OFFSET(68)] AS d68,
# title_embed[OFFSET(69)] AS d69,
# title_embed[OFFSET(70)] AS d70,
# title_embed[OFFSET(71)] AS d71,
# title_embed[OFFSET(72)] AS d72,
# title_embed[OFFSET(73)] AS d73,
# title_embed[OFFSET(74)] AS d74,
# title_embed[OFFSET(75)] AS d75,
# title_embed[OFFSET(76)] AS d76,
# title_embed[OFFSET(77)] AS d77,
# title_embed[OFFSET(78)] AS d78,
# title_embed[OFFSET(79)] AS d79,
# title_embed[OFFSET(80)] AS d80,
# title_embed[OFFSET(227)] AS d227,
# title_embed[OFFSET(228)] AS d228,
# title_embed[OFFSET(229)] AS d229,
# title_embed[OFFSET(230)] AS d230,
# title_embed[OFFSET(231)] AS d231,
# title_embed[OFFSET(232)] AS d232,
# title_embed[OFFSET(233)] AS d233,
# title_embed[OFFSET(234)] AS d234,
# title_embed[OFFSET(235)] AS d235,
# title_embed[OFFSET(236)] AS d236,
# title_embed[OFFSET(237)] AS d237,
# title_embed[OFFSET(238)] AS d238,
# title_embed[OFFSET(239)] AS d239,
# title_embed[OFFSET(240)] AS d240,
# title_embed[OFFSET(241)] AS d241,
# title_embed[OFFSET(242)] AS d242,
# title_embed[OFFSET(243)] AS d243,
# title_embed[OFFSET(244)] AS d244,
# title_embed[OFFSET(245)] AS d245,
# title_embed[OFFSET(246)] AS d246,
# title_embed[OFFSET(247)] AS d247,
# title_embed[OFFSET(248)] AS d248,
# title_embed[OFFSET(249)] AS d249,
# title_embed[OFFSET(250)] AS d250,
# title_embed[OFFSET(251)] AS d251,
# title_embed[OFFSET(252)] AS d252,
# title_embed[OFFSET(253)] AS d253,
# title_embed[OFFSET(254)] AS d254,
# title_embed[OFFSET(255)] AS d255,
# title_embed[OFFSET(256)] AS d256,
# title_embed[OFFSET(257)] AS d257,
# title_embed[OFFSET(258)] AS d258,
# title_embed[OFFSET(259)] AS d259,
# title_embed[OFFSET(260)] AS d260,
# title_embed[OFFSET(261)] AS d261,
# title_embed[OFFSET(262)] AS d262,
# title_embed[OFFSET(263)] AS d263,
# title_embed[OFFSET(264)] AS d264,
# title_embed[OFFSET(265)] AS d265,
# title_embed[OFFSET(266)] AS d266,
# title_embed[OFFSET(267)] AS d267,
# title_embed[OFFSET(268)] AS d268,
# title_embed[OFFSET(269)] AS d269,
# title_embed[OFFSET(270)] AS d270,
# title_embed[OFFSET(271)] AS d271,
# title_embed[OFFSET(272)] AS d272,
# title_embed[OFFSET(273)] AS d273,
# title_embed[OFFSET(274)] AS d274,
# title_embed[OFFSET(275)] AS d275,
# title_embed[OFFSET(276)] AS d276,
# title_embed[OFFSET(277)] AS d277,
# title_embed[OFFSET(278)] AS d278,
# title_embed[OFFSET(279)] AS d279,
# title_embed[OFFSET(280)] AS d280,
# title_embed[OFFSET(281)] AS d281,
# title_embed[OFFSET(282)] AS d282,
# title_embed[OFFSET(283)] AS d283,
# title_embed[OFFSET(284)] AS d284,
# title_embed[OFFSET(285)] AS d285,
# title_embed[OFFSET(286)] AS d286,
# title_embed[OFFSET(287)] AS d287,
# title_embed[OFFSET(288)] AS d288,
# title_embed[OFFSET(289)] AS d289,
# title_embed[OFFSET(290)] AS d290,
# title_embed[OFFSET(291)] AS d291,
# title_embed[OFFSET(292)] AS d292,
# title_embed[OFFSET(293)] AS d293,
# title_embed[OFFSET(294)] AS d294,
# title_embed[OFFSET(295)] AS d295,
# title_embed[OFFSET(296)] AS d296,
# title_embed[OFFSET(297)] AS d297,
# title_embed[OFFSET(298)] AS d298,
# title_embed[OFFSET(299)] AS d299,
# title_embed[OFFSET(300)] AS d300,
# title_embed[OFFSET(374)] AS d374,
# title_embed[OFFSET(375)] AS d375,
# title_embed[OFFSET(376)] AS d376,
# title_embed[OFFSET(377)] AS d377,
# title_embed[OFFSET(378)] AS d378,
# title_embed[OFFSET(379)] AS d379,
# title_embed[OFFSET(380)] AS d380,
# title_embed[OFFSET(381)] AS d381,
# title_embed[OFFSET(382)] AS d382,
# title_embed[OFFSET(383)] AS d383,
# title_embed[OFFSET(384)] AS d384,
# title_embed[OFFSET(385)] AS d385,
# title_embed[OFFSET(386)] AS d386,
# title_embed[OFFSET(387)] AS d387,
# title_embed[OFFSET(388)] AS d388,
# title_embed[OFFSET(389)] AS d389,
# title_embed[OFFSET(390)] AS d390,
# title_embed[OFFSET(391)] AS d391,
# title_embed[OFFSET(392)] AS d392,
# title_embed[OFFSET(393)] AS d393,
# title_embed[OFFSET(394)] AS d394,
# title_embed[OFFSET(395)] AS d395,
# title_embed[OFFSET(396)] AS d396,
# title_embed[OFFSET(397)] AS d397,
# title_embed[OFFSET(398)] AS d398,
# title_embed[OFFSET(399)] AS d399,
# title_embed[OFFSET(400)] AS d400,
# title_embed[OFFSET(401)] AS d401,
# title_embed[OFFSET(402)] AS d402,
# title_embed[OFFSET(403)] AS d403,
# title_embed[OFFSET(404)] AS d404,
# title_embed[OFFSET(405)] AS d405,
# title_embed[OFFSET(406)] AS d406,
# title_embed[OFFSET(407)] AS d407,
# title_embed[OFFSET(408)] AS d408,
# title_embed[OFFSET(409)] AS d409,
# title_embed[OFFSET(410)] AS d410,
# title_embed[OFFSET(411)] AS d411,
# title_embed[OFFSET(412)] AS d412,
# title_embed[OFFSET(413)] AS d413,
# title_embed[OFFSET(414)] AS d414,
# title_embed[OFFSET(415)] AS d415,
# title_embed[OFFSET(416)] AS d416,
# title_embed[OFFSET(417)] AS d417,
# title_embed[OFFSET(418)] AS d418,
# title_embed[OFFSET(419)] AS d419,
# title_embed[OFFSET(420)] AS d420,
# title_embed[OFFSET(421)] AS d421,
# title_embed[OFFSET(422)] AS d422,
# title_embed[OFFSET(423)] AS d423,
# title_embed[OFFSET(424)] AS d424,
# title_embed[OFFSET(425)] AS d425,
# title_embed[OFFSET(426)] AS d426,
# title_embed[OFFSET(427)] AS d427,
# title_embed[OFFSET(428)] AS d428,
# title_embed[OFFSET(429)] AS d429,
# title_embed[OFFSET(430)] AS d430,
# title_embed[OFFSET(431)] AS d431,
# title_embed[OFFSET(432)] AS d432,
# title_embed[OFFSET(433)] AS d433,
# title_embed[OFFSET(434)] AS d434,
# title_embed[OFFSET(435)] AS d435,
# title_embed[OFFSET(436)] AS d436,
# title_embed[OFFSET(437)] AS d437,
# title_embed[OFFSET(438)] AS d438,
# title_embed[OFFSET(439)] AS d439,
# title_embed[OFFSET(440)] AS d440,
# title_embed[OFFSET(441)] AS d441,
# title_embed[OFFSET(442)] AS d442,
# title_embed[OFFSET(443)] AS d443,
# title_embed[OFFSET(444)] AS d444,
# title_embed[OFFSET(445)] AS d445,
# title_embed[OFFSET(446)] AS d446,
# title_embed[OFFSET(447)] AS d447,
# title_embed[OFFSET(448)] AS d448,
# title_embed[OFFSET(449)] AS d449,
# title_embed[OFFSET(450)] AS d450,
# title_embed[OFFSET(451)] AS d451,
# title_embed[OFFSET(452)] AS d452,
# title_embed[OFFSET(453)] AS d453,
# title_embed[OFFSET(454)] AS d454,
# title_embed[OFFSET(455)] AS d455,
# title_embed[OFFSET(456)] AS d456,
# title_embed[OFFSET(457)] AS d457,
# title_embed[OFFSET(458)] AS d458,
# title_embed[OFFSET(459)] AS d459,
# title_embed[OFFSET(460)] AS d460,
# title_embed[OFFSET(461)] AS d461,
# title_embed[OFFSET(462)] AS d462,
# title_embed[OFFSET(463)] AS d463,
# title_embed[OFFSET(464)] AS d464,
# title_embed[OFFSET(465)] AS d465,
# title_embed[OFFSET(466)] AS d466,
# title_embed[OFFSET(467)] AS d467,
# title_embed[OFFSET(468)] AS d468,
# title_embed[OFFSET(469)] AS d469,
# title_embed[OFFSET(470)] AS d470,
# title_embed[OFFSET(471)] AS d471,
# title_embed[OFFSET(472)] AS d472,
# title_embed[OFFSET(473)] AS d473,
# title_embed[OFFSET(474)] AS d474,
# title_embed[OFFSET(475)] AS d475,
# title_embed[OFFSET(476)] AS d476,
# title_embed[OFFSET(477)] AS d477,
# title_embed[OFFSET(478)] AS d478,
# title_embed[OFFSET(479)] AS d479,
# title_embed[OFFSET(480)] AS d480,
# title_embed[OFFSET(481)] AS d481,
# title_embed[OFFSET(482)] AS d482,
# title_embed[OFFSET(483)] AS d483,
# title_embed[OFFSET(484)] AS d484,
# title_embed[OFFSET(485)] AS d485,
# title_embed[OFFSET(486)] AS d486,
# title_embed[OFFSET(487)] AS d487,
# title_embed[OFFSET(488)] AS d488,
# title_embed[OFFSET(489)] AS d489,
# title_embed[OFFSET(490)] AS d490,
# title_embed[OFFSET(491)] AS d491,
# title_embed[OFFSET(492)] AS d492,
# title_embed[OFFSET(493)] AS d493,
# title_embed[OFFSET(494)] AS d494,
# title_embed[OFFSET(495)] AS d495,
# title_embed[OFFSET(496)] AS d496,
# title_embed[OFFSET(497)] AS d497,
# title_embed[OFFSET(498)] AS d498,
# title_embed[OFFSET(499)] AS d499,
# title_embed[OFFSET(500)] AS d500,
# title_embed[OFFSET(501)] AS d501,
# title_embed[OFFSET(502)] AS d502,
# title_embed[OFFSET(503)] AS d503,
# title_embed[OFFSET(504)] AS d504,
# title_embed[OFFSET(505)] AS d505,
# title_embed[OFFSET(506)] AS d506,
# title_embed[OFFSET(507)] AS d507,
# title_embed[OFFSET(508)] AS d508,
# title_embed[OFFSET(509)] AS d509,
# title_embed[OFFSET(510)] AS d510,
# title_embed[OFFSET(511)] AS d511,
#
# FROM `springer-nature-analytics.DS_dimensions.publications_full_refresh`
# LEFT JOIN UNNEST(`for`) AS f LEFT JOIN UNNEST(journal) AS j
# WHERE ARRAY_LENGTH(title_embed) = 512
# AND
# publication_type LIKE "article"
#         AND j.title IN (SELECT title FROM `springer-nature-analytics.core_journals.core_2018_v01`)
#         AND year >= 2017
#         AND year <= 2019
#         AND language LIKE "en"
#         AND ARRAY_LENGTH(references) > 4
#
# ) GROUP BY f2
#  ) WHERE f2 IS NOT NULL

# %%
train_and_save(for_17_19, "wv_17_19", "f2")
# Out:
# Saved mean vectors to "/content/drive/My Drive/Research/Data/Mean-title-centroids-3yrs-v02/wv_17_19_f2.csv"

# %% [markdown]
# # 2014-2016

# %%
# %%bigquery --project $pid for_14_16
#
# SELECT * FROM (
# SELECT f1,
#
# AVG(d0) AS d0_mean,
# AVG(d1) AS d1_mean,
# AVG(d2) AS d2_mean,
# AVG(d3) AS d3_mean,
# AVG(d4) AS d4_mean,
# AVG(d5) AS d5_mean,
# AVG(d6) AS d6_mean,
# AVG(d7) AS d7_mean,
# AVG(d8) AS d8_mean,
# AVG(d9) AS d9_mean,
# AVG(d10) AS d10_mean,
# AVG(d11) AS d11_mean,
# AVG(d12) AS d12_mean,
# AVG(d13) AS d13_mean,
# AVG(d14) AS d14_mean,
# AVG(d15) AS d15_mean,
# AVG(d16) AS d16_mean,
# AVG(d17) AS d17_mean,
# AVG(d18) AS d18_mean,
# AVG(d19) AS d19_mean,
# AVG(d20) AS d20_mean,
# AVG(d21) AS d21_mean,
# AVG(d22) AS d22_mean,
# AVG(d23) AS d23_mean,
# AVG(d24) AS d24_mean,
# AVG(d25) AS d25_mean,
# AVG(d26) AS d26_mean,
# AVG(d27) AS d27_mean,
# AVG(d28) AS d28_mean,
# AVG(d29) AS d29_mean,
# AVG(d30) AS d30_mean,
# AVG(d31) AS d31_mean,
# AVG(d32) AS d32_mean,
# AVG(d33) AS d33_mean,
# AVG(d34) AS d34_mean,
# AVG(d35) AS d35_mean,
# AVG(d36) AS d36_mean,
# AVG(d37) AS d37_mean,
# AVG(d38) AS d38_mean,
# AVG(d39) AS d39_mean,
# AVG(d40) AS d40_mean,
# AVG(d41) AS d41_mean,
# AVG(d42) AS d42_mean,
# AVG(d43) AS d43_mean,
# AVG(d44) AS d44_mean,
# AVG(d45) AS d45_mean,
# AVG(d46) AS d46_mean,
# AVG(d47) AS d47_mean,
# AVG(d48) AS d48_mean,
# AVG(d49) AS d49_mean,
# AVG(d50) AS d50_mean,
# AVG(d51) AS d51_mean,
# AVG(d52) AS d52_mean,
# AVG(d53) AS d53_mean,
# AVG(d54) AS d54_mean,
# AVG(d55) AS d55_mean,
# AVG(d56) AS d56_mean,
# AVG(d57) AS d57_mean,
# AVG(d58) AS d58_mean,
# AVG(d59) AS d59_mean,
# AVG(d60) AS d60_mean,
# AVG(d61) AS d61_mean,
# AVG(d62) AS d62_mean,
# AVG(d63) AS d63_mean,
# AVG(d64) AS d64_mean,
# AVG(d65) AS d65_mean,
# AVG(d66) AS d66_mean,
# AVG(d67) AS d67_mean,
# AVG(d68) AS d68_mean,
# AVG(d69) AS d69_mean,
# AVG(d70) AS d70_mean,
# AVG(d71) AS d71_mean,
# AVG(d72) AS d72_mean,
# AVG(d73) AS d73_mean,
# AVG(d74) AS d74_mean,
# AVG(d75) AS d75_mean,
# AVG(d76) AS d76_mean,
# AVG(d77) AS d77_mean,
# AVG(d78) AS d78_mean,
# AVG(d79) AS d79_mean,
# AVG(d80) AS d80_mean,
# AVG(d81) AS d81_mean,
# AVG(d82) AS d82_mean,
# AVG(d83) AS d83_mean,
# AVG(d84) AS d84_mean,
# AVG(d85) AS d85_mean,
# AVG(d86) AS d86_mean,
# AVG(d87) AS d87_mean,
# AVG(d88) AS d88_mean,
# AVG(d89) AS d89_mean,
# AVG(d90) AS d90_mean,
# AVG(d91) AS d91_mean,
# AVG(d92) AS d92_mean,
# AVG(d93) AS d93_mean,
# AVG(d94) AS d94_mean,
# AVG(d95) AS d95_mean,
# AVG(d96) AS d96_mean,
# AVG(d97) AS d97_mean,
# AVG(d98) AS d98_mean,
# AVG(d99) AS d99_mean,
# AVG(d100) AS d100_mean,
# AVG(d101) AS d101_mean,
# AVG(d102) AS d102_mean,
# AVG(d103) AS d103_mean,
# AVG(d104) AS d104_mean,
# AVG(d105) AS d105_mean,
# AVG(d106) AS d106_mean,
# AVG(d107) AS d107_mean,
# AVG(d108) AS d108_mean,
# AVG(d109) AS d109_mean,
# AVG(d110) AS d110_mean,
# AVG(d111) AS d111_mean,
# AVG(d112) AS d112_mean,
# AVG(d113) AS d113_mean,
# AVG(d114) AS d114_mean,
# AVG(d115) AS d115_mean,
# AVG(d116) AS d116_mean,
# AVG(d117) AS d117_mean,
# AVG(d118) AS d118_mean,
# AVG(d119) AS d119_mean,
# AVG(d120) AS d120_mean,
# AVG(d121) AS d121_mean,
# AVG(d122) AS d122_mean,
# AVG(d123) AS d123_mean,
# AVG(d124) AS d124_mean,
# AVG(d125) AS d125_mean,
# AVG(d126) AS d126_mean,
# AVG(d127) AS d127_mean,
# AVG(d128) AS d128_mean,
# AVG(d129) AS d129_mean,
# AVG(d130) AS d130_mean,
# AVG(d131) AS d131_mean,
# AVG(d132) AS d132_mean,
# AVG(d133) AS d133_mean,
# AVG(d134) AS d134_mean,
# AVG(d135) AS d135_mean,
# AVG(d136) AS d136_mean,
# AVG(d137) AS d137_mean,
# AVG(d138) AS d138_mean,
# AVG(d139) AS d139_mean,
# AVG(d140) AS d140_mean,
# AVG(d141) AS d141_mean,
# AVG(d142) AS d142_mean,
# AVG(d143) AS d143_mean,
# AVG(d144) AS d144_mean,
# AVG(d145) AS d145_mean,
# AVG(d146) AS d146_mean,
# AVG(d147) AS d147_mean,
# AVG(d148) AS d148_mean,
# AVG(d149) AS d149_mean,
# AVG(d150) AS d150_mean,
# AVG(d151) AS d151_mean,
# AVG(d152) AS d152_mean,
# AVG(d153) AS d153_mean,
# AVG(d154) AS d154_mean,
# AVG(d155) AS d155_mean,
# AVG(d156) AS d156_mean,
# AVG(d157) AS d157_mean,
# AVG(d158) AS d158_mean,
# AVG(d159) AS d159_mean,
# AVG(d160) AS d160_mean,
# AVG(d161) AS d161_mean,
# AVG(d162) AS d162_mean,
# AVG(d163) AS d163_mean,
# AVG(d164) AS d164_mean,
# AVG(d165) AS d165_mean,
# AVG(d166) AS d166_mean,
# AVG(d167) AS d167_mean,
# AVG(d168) AS d168_mean,
# AVG(d169) AS d169_mean,
# AVG(d170) AS d170_mean,
# AVG(d171) AS d171_mean,
# AVG(d172) AS d172_mean,
# AVG(d173) AS d173_mean,
# AVG(d174) AS d174_mean,
# AVG(d175) AS d175_mean,
# AVG(d176) AS d176_mean,
# AVG(d177) AS d177_mean,
# AVG(d178) AS d178_mean,
# AVG(d179) AS d179_mean,
# AVG(d180) AS d180_mean,
# AVG(d181) AS d181_mean,
# AVG(d182) AS d182_mean,
# AVG(d183) AS d183_mean,
# AVG(d184) AS d184_mean,
# AVG(d185) AS d185_mean,
# AVG(d186) AS d186_mean,
# AVG(d187) AS d187_mean,
# AVG(d188) AS d188_mean,
# AVG(d189) AS d189_mean,
# AVG(d190) AS d190_mean,
# AVG(d191) AS d191_mean,
# AVG(d192) AS d192_mean,
# AVG(d193) AS d193_mean,
# AVG(d194) AS d194_mean,
# AVG(d195) AS d195_mean,
# AVG(d196) AS d196_mean,
# AVG(d197) AS d197_mean,
# AVG(d198) AS d198_mean,
# AVG(d199) AS d199_mean,
# AVG(d200) AS d200_mean,
# AVG(d201) AS d201_mean,
# AVG(d202) AS d202_mean,
# AVG(d203) AS d203_mean,
# AVG(d204) AS d204_mean,
# AVG(d205) AS d205_mean,
# AVG(d206) AS d206_mean,
# AVG(d207) AS d207_mean,
# AVG(d208) AS d208_mean,
# AVG(d209) AS d209_mean,
# AVG(d210) AS d210_mean,
# AVG(d211) AS d211_mean,
# AVG(d212) AS d212_mean,
# AVG(d213) AS d213_mean,
# AVG(d214) AS d214_mean,
# AVG(d215) AS d215_mean,
# AVG(d216) AS d216_mean,
# AVG(d217) AS d217_mean,
# AVG(d218) AS d218_mean,
# AVG(d219) AS d219_mean,
# AVG(d220) AS d220_mean,
# AVG(d221) AS d221_mean,
# AVG(d222) AS d222_mean,
# AVG(d223) AS d223_mean,
# AVG(d224) AS d224_mean,
# AVG(d225) AS d225_mean,
# AVG(d226) AS d226_mean,
# AVG(d227) AS d227_mean,
# AVG(d228) AS d228_mean,
# AVG(d229) AS d229_mean,
# AVG(d230) AS d230_mean,
# AVG(d231) AS d231_mean,
# AVG(d232) AS d232_mean,
# AVG(d233) AS d233_mean,
# AVG(d234) AS d234_mean,
# AVG(d235) AS d235_mean,
# AVG(d236) AS d236_mean,
# AVG(d237) AS d237_mean,
# AVG(d238) AS d238_mean,
# AVG(d239) AS d239_mean,
# AVG(d240) AS d240_mean,
# AVG(d241) AS d241_mean,
# AVG(d242) AS d242_mean,
# AVG(d243) AS d243_mean,
# AVG(d244) AS d244_mean,
# AVG(d245) AS d245_mean,
# AVG(d246) AS d246_mean,
# AVG(d247) AS d247_mean,
# AVG(d248) AS d248_mean,
# AVG(d249) AS d249_mean,
# AVG(d250) AS d250_mean,
# AVG(d251) AS d251_mean,
# AVG(d252) AS d252_mean,
# AVG(d253) AS d253_mean,
# AVG(d254) AS d254_mean,
# AVG(d255) AS d255_mean,
# AVG(d256) AS d256_mean,
# AVG(d257) AS d257_mean,
# AVG(d258) AS d258_mean,
# AVG(d259) AS d259_mean,
# AVG(d260) AS d260_mean,
# AVG(d261) AS d261_mean,
# AVG(d262) AS d262_mean,
# AVG(d263) AS d263_mean,
# AVG(d264) AS d264_mean,
# AVG(d265) AS d265_mean,
# AVG(d266) AS d266_mean,
# AVG(d267) AS d267_mean,
# AVG(d268) AS d268_mean,
# AVG(d269) AS d269_mean,
# AVG(d270) AS d270_mean,
# AVG(d271) AS d271_mean,
# AVG(d272) AS d272_mean,
# AVG(d273) AS d273_mean,
# AVG(d274) AS d274_mean,
# AVG(d275) AS d275_mean,
# AVG(d276) AS d276_mean,
# AVG(d277) AS d277_mean,
# AVG(d278) AS d278_mean,
# AVG(d279) AS d279_mean,
# AVG(d280) AS d280_mean,
# AVG(d281) AS d281_mean,
# AVG(d282) AS d282_mean,
# AVG(d283) AS d283_mean,
# AVG(d284) AS d284_mean,
# AVG(d285) AS d285_mean,
# AVG(d286) AS d286_mean,
# AVG(d287) AS d287_mean,
# AVG(d288) AS d288_mean,
# AVG(d289) AS d289_mean,
# AVG(d290) AS d290_mean,
# AVG(d291) AS d291_mean,
# AVG(d292) AS d292_mean,
# AVG(d293) AS d293_mean,
# AVG(d294) AS d294_mean,
# AVG(d295) AS d295_mean,
# AVG(d296) AS d296_mean,
# AVG(d297) AS d297_mean,
# AVG(d298) AS d298_mean,
# AVG(d299) AS d299_mean,
# AVG(d300) AS d300_mean,
# AVG(d301) AS d301_mean,
# AVG(d302) AS d302_mean,
# AVG(d303) AS d303_mean,
# AVG(d304) AS d304_mean,
# AVG(d305) AS d305_mean,
# AVG(d306) AS d306_mean,
# AVG(d307) AS d307_mean,
# AVG(d308) AS d308_mean,
# AVG(d309) AS d309_mean,
# AVG(d310) AS d310_mean,
# AVG(d311) AS d311_mean,
# AVG(d312) AS d312_mean,
# AVG(d313) AS d313_mean,
# AVG(d314) AS d314_mean,
# AVG(d315) AS d315_mean,
# AVG(d316) AS d316_mean,
# AVG(d317) AS d317_mean,
# AVG(d318) AS d318_mean,
# AVG(d319) AS d319_mean,
# AVG(d320) AS d320_mean,
# AVG(d321) AS d321_mean,
# AVG(d322) AS d322_mean,
# AVG(d323) AS d323_mean,
# AVG(d324) AS d324_mean,
# AVG(d325) AS d325_mean,
# AVG(d326) AS d326_mean,
# AVG(d327) AS d327_mean,
# AVG(d328) AS d328_mean,
# AVG(d329) AS d329_mean,
# AVG(d330) AS d330_mean,
# AVG(d331) AS d331_mean,
# AVG(d332) AS d332_mean,
# AVG(d333) AS d333_mean,
# AVG(d334) AS d334_mean,
# AVG(d335) AS d335_mean,
# AVG(d336) AS d336_mean,
# AVG(d337) AS d337_mean,
# AVG(d338) AS d338_mean,
# AVG(d339) AS d339_mean,
# AVG(d340) AS d340_mean,
# AVG(d341) AS d341_mean,
# AVG(d342) AS d342_mean,
# AVG(d343) AS d343_mean,
# AVG(d344) AS d344_mean,
# AVG(d345) AS d345_mean,
# AVG(d346) AS d346_mean,
# AVG(d347) AS d347_mean,
# AVG(d348) AS d348_mean,
# AVG(d349) AS d349_mean,
# AVG(d350) AS d350_mean,
# AVG(d351) AS d351_mean,
# AVG(d352) AS d352_mean,
# AVG(d353) AS d353_mean,
# AVG(d354) AS d354_mean,
# AVG(d355) AS d355_mean,
# AVG(d356) AS d356_mean,
# AVG(d357) AS d357_mean,
# AVG(d358) AS d358_mean,
# AVG(d359) AS d359_mean,
# AVG(d360) AS d360_mean,
# AVG(d361) AS d361_mean,
# AVG(d362) AS d362_mean,
# AVG(d363) AS d363_mean,
# AVG(d364) AS d364_mean,
# AVG(d365) AS d365_mean,
# AVG(d366) AS d366_mean,
# AVG(d367) AS d367_mean,
# AVG(d368) AS d368_mean,
# AVG(d369) AS d369_mean,
# AVG(d370) AS d370_mean,
# AVG(d371) AS d371_mean,
# AVG(d372) AS d372_mean,
# AVG(d373) AS d373_mean,
# AVG(d374) AS d374_mean,
# AVG(d375) AS d375_mean,
# AVG(d376) AS d376_mean,
# AVG(d377) AS d377_mean,
# AVG(d378) AS d378_mean,
# AVG(d379) AS d379_mean,
# AVG(d380) AS d380_mean,
# AVG(d381) AS d381_mean,
# AVG(d382) AS d382_mean,
# AVG(d383) AS d383_mean,
# AVG(d384) AS d384_mean,
# AVG(d385) AS d385_mean,
# AVG(d386) AS d386_mean,
# AVG(d387) AS d387_mean,
# AVG(d388) AS d388_mean,
# AVG(d389) AS d389_mean,
# AVG(d390) AS d390_mean,
# AVG(d391) AS d391_mean,
# AVG(d392) AS d392_mean,
# AVG(d393) AS d393_mean,
# AVG(d394) AS d394_mean,
# AVG(d395) AS d395_mean,
# AVG(d396) AS d396_mean,
# AVG(d397) AS d397_mean,
# AVG(d398) AS d398_mean,
# AVG(d399) AS d399_mean,
# AVG(d400) AS d400_mean,
# AVG(d401) AS d401_mean,
# AVG(d402) AS d402_mean,
# AVG(d403) AS d403_mean,
# AVG(d404) AS d404_mean,
# AVG(d405) AS d405_mean,
# AVG(d406) AS d406_mean,
# AVG(d407) AS d407_mean,
# AVG(d408) AS d408_mean,
# AVG(d409) AS d409_mean,
# AVG(d410) AS d410_mean,
# AVG(d411) AS d411_mean,
# AVG(d412) AS d412_mean,
# AVG(d413) AS d413_mean,
# AVG(d414) AS d414_mean,
# AVG(d415) AS d415_mean,
# AVG(d416) AS d416_mean,
# AVG(d417) AS d417_mean,
# AVG(d418) AS d418_mean,
# AVG(d419) AS d419_mean,
# AVG(d420) AS d420_mean,
# AVG(d421) AS d421_mean,
# AVG(d422) AS d422_mean,
# AVG(d423) AS d423_mean,
# AVG(d424) AS d424_mean,
# AVG(d425) AS d425_mean,
# AVG(d426) AS d426_mean,
# AVG(d427) AS d427_mean,
# AVG(d428) AS d428_mean,
# AVG(d429) AS d429_mean,
# AVG(d430) AS d430_mean,
# AVG(d431) AS d431_mean,
# AVG(d432) AS d432_mean,
# AVG(d433) AS d433_mean,
# AVG(d434) AS d434_mean,
# AVG(d435) AS d435_mean,
# AVG(d436) AS d436_mean,
# AVG(d437) AS d437_mean,
# AVG(d438) AS d438_mean,
# AVG(d439) AS d439_mean,
# AVG(d440) AS d440_mean,
# AVG(d441) AS d441_mean,
# AVG(d442) AS d442_mean,
# AVG(d443) AS d443_mean,
# AVG(d444) AS d444_mean,
# AVG(d445) AS d445_mean,
# AVG(d446) AS d446_mean,
# AVG(d447) AS d447_mean,
# AVG(d448) AS d448_mean,
# AVG(d449) AS d449_mean,
# AVG(d450) AS d450_mean,
# AVG(d451) AS d451_mean,
# AVG(d452) AS d452_mean,
# AVG(d453) AS d453_mean,
# AVG(d454) AS d454_mean,
# AVG(d455) AS d455_mean,
# AVG(d456) AS d456_mean,
# AVG(d457) AS d457_mean,
# AVG(d458) AS d458_mean,
# AVG(d459) AS d459_mean,
# AVG(d460) AS d460_mean,
# AVG(d461) AS d461_mean,
# AVG(d462) AS d462_mean,
# AVG(d463) AS d463_mean,
# AVG(d464) AS d464_mean,
# AVG(d465) AS d465_mean,
# AVG(d466) AS d466_mean,
# AVG(d467) AS d467_mean,
# AVG(d468) AS d468_mean,
# AVG(d469) AS d469_mean,
# AVG(d470) AS d470_mean,
# AVG(d471) AS d471_mean,
# AVG(d472) AS d472_mean,
# AVG(d473) AS d473_mean,
# AVG(d474) AS d474_mean,
# AVG(d475) AS d475_mean,
# AVG(d476) AS d476_mean,
# AVG(d477) AS d477_mean,
# AVG(d478) AS d478_mean,
# AVG(d479) AS d479_mean,
# AVG(d480) AS d480_mean,
# AVG(d481) AS d481_mean,
# AVG(d482) AS d482_mean,
# AVG(d483) AS d483_mean,
# AVG(d484) AS d484_mean,
# AVG(d485) AS d485_mean,
# AVG(d486) AS d486_mean,
# AVG(d487) AS d487_mean,
# AVG(d488) AS d488_mean,
# AVG(d489) AS d489_mean,
# AVG(d490) AS d490_mean,
# AVG(d491) AS d491_mean,
# AVG(d492) AS d492_mean,
# AVG(d493) AS d493_mean,
# AVG(d494) AS d494_mean,
# AVG(d495) AS d495_mean,
# AVG(d496) AS d496_mean,
# AVG(d497) AS d497_mean,
# AVG(d498) AS d498_mean,
# AVG(d499) AS d499_mean,
# AVG(d500) AS d500_mean,
# AVG(d501) AS d501_mean,
# AVG(d502) AS d502_mean,
# AVG(d503) AS d503_mean,
# AVG(d504) AS d504_mean,
# AVG(d505) AS d505_mean,
# AVG(d506) AS d506_mean,
# AVG(d507) AS d507_mean,
# AVG(d508) AS d508_mean,
# AVG(d509) AS d509_mean,
# AVG(d510) AS d510_mean,
# AVG(d511) AS d511_mean,
#
# FROM (
# SELECT f.first_level.name AS f1,
#
# title_embed[OFFSET(0)] AS d0,
# title_embed[OFFSET(1)] AS d1,
# title_embed[OFFSET(2)] AS d2,
# title_embed[OFFSET(3)] AS d3,
# title_embed[OFFSET(4)] AS d4,
# title_embed[OFFSET(5)] AS d5,
# title_embed[OFFSET(6)] AS d6,
# title_embed[OFFSET(7)] AS d7,
# title_embed[OFFSET(8)] AS d8,
# title_embed[OFFSET(9)] AS d9,
# title_embed[OFFSET(10)] AS d10,
# title_embed[OFFSET(11)] AS d11,
# title_embed[OFFSET(231)] AS d231,
# title_embed[OFFSET(232)] AS d232,
# title_embed[OFFSET(233)] AS d233,
# title_embed[OFFSET(234)] AS d234,
# title_embed[OFFSET(235)] AS d235,
# title_embed[OFFSET(236)] AS d236,
# title_embed[OFFSET(237)] AS d237,
# title_embed[OFFSET(238)] AS d238,
# title_embed[OFFSET(239)] AS d239,
# title_embed[OFFSET(240)] AS d240,
# title_embed[OFFSET(241)] AS d241,
# title_embed[OFFSET(242)] AS d242,
# title_embed[OFFSET(243)] AS d243,
# title_embed[OFFSET(244)] AS d244,
# title_embed[OFFSET(245)] AS d245,
# title_embed[OFFSET(246)] AS d246,
# title_embed[OFFSET(247)] AS d247,
# title_embed[OFFSET(248)] AS d248,
# title_embed[OFFSET(249)] AS d249,
# title_embed[OFFSET(250)] AS d250,
# title_embed[OFFSET(251)] AS d251,
# title_embed[OFFSET(252)] AS d252,
# title_embed[OFFSET(253)] AS d253,
# title_embed[OFFSET(254)] AS d254,
# title_embed[OFFSET(255)] AS d255,
# title_embed[OFFSET(256)] AS d256,
# title_embed[OFFSET(257)] AS d257,
# title_embed[OFFSET(258)] AS d258,
# title_embed[OFFSET(259)] AS d259,
# title_embed[OFFSET(260)] AS d260,
# title_embed[OFFSET(261)] AS d261,
# title_embed[OFFSET(262)] AS d262,
# title_embed[OFFSET(263)] AS d263,
# title_embed[OFFSET(264)] AS d264,
# title_embed[OFFSET(265)] AS d265,
# title_embed[OFFSET(266)] AS d266,
# title_embed[OFFSET(267)] AS d267,
# title_embed[OFFSET(268)] AS d268,
# title_embed[OFFSET(269)] AS d269,
# title_embed[OFFSET(270)] AS d270,
# title_embed[OFFSET(271)] AS d271,
# title_embed[OFFSET(272)] AS d272,
# title_embed[OFFSET(273)] AS d273,
# title_embed[OFFSET(274)] AS d274,
# title_embed[OFFSET(275)] AS d275,
# title_embed[OFFSET(276)] AS d276,
# title_embed[OFFSET(277)] AS d277,
# title_embed[OFFSET(278)] AS d278,
# title_embed[OFFSET(279)] AS d279,
# title_embed[OFFSET(280)] AS d280,
# title_embed[OFFSET(281)] AS d281,
# title_embed[OFFSET(282)] AS d282,
# title_embed[OFFSET(283)] AS d283,
# title_embed[OFFSET(284)] AS d284,
# title_embed[OFFSET(285)] AS d285,
# title_embed[OFFSET(286)] AS d286,
# title_embed[OFFSET(287)] AS d287,
# title_embed[OFFSET(288)] AS d288,
# title_embed[OFFSET(289)] AS d289,
# title_embed[OFFSET(290)] AS d290,
# title_embed[OFFSET(291)] AS d291,
# title_embed[OFFSET(292)] AS d292,
# title_embed[OFFSET(293)] AS d293,
# title_embed[OFFSET(294)] AS d294,
# title_embed[OFFSET(295)] AS d295,
# title_embed[OFFSET(296)] AS d296,
# title_embed[OFFSET(297)] AS d297,
# title_embed[OFFSET(298)] AS d298,
# title_embed[OFFSET(299)] AS d299,
# title_embed[OFFSET(300)] AS d300,
# title_embed[OFFSET(301)] AS d301,
# title_embed[OFFSET(302)] AS d302,
# title_embed[OFFSET(303)] AS d303,
# title_embed[OFFSET(304)] AS d304,
# title_embed[OFFSET(378)] AS d378,
# title_embed[OFFSET(379)] AS d379,
# title_embed[OFFSET(380)] AS d380,
# title_embed[OFFSET(381)] AS d381,
# title_embed[OFFSET(382)] AS d382,
# title_embed[OFFSET(383)] AS d383,
# title_embed[OFFSET(384)] AS d384,
# title_embed[OFFSET(385)] AS d385,
# title_embed[OFFSET(386)] AS d386,
# title_embed[OFFSET(387)] AS d387,
# title_embed[OFFSET(388)] AS d388,
# title_embed[OFFSET(389)] AS d389,
# title_embed[OFFSET(390)] AS d390,
# title_embed[OFFSET(391)] AS d391,
# title_embed[OFFSET(392)] AS d392,
# title_embed[OFFSET(393)] AS d393,
# title_embed[OFFSET(394)] AS d394,
# title_embed[OFFSET(395)] AS d395,
# title_embed[OFFSET(396)] AS d396,
# title_embed[OFFSET(397)] AS d397,
# title_embed[OFFSET(398)] AS d398,
# title_embed[OFFSET(399)] AS d399,
# title_embed[OFFSET(400)] AS d400,
# title_embed[OFFSET(401)] AS d401,
# title_embed[OFFSET(402)] AS d402,
# title_embed[OFFSET(403)] AS d403,
# title_embed[OFFSET(404)] AS d404,
# title_embed[OFFSET(405)] AS d405,
# title_embed[OFFSET(406)] AS d406,
# title_embed[OFFSET(407)] AS d407,
# title_embed[OFFSET(408)] AS d408,
# title_embed[OFFSET(409)] AS d409,
# title_embed[OFFSET(410)] AS d410,
# title_embed[OFFSET(411)] AS d411,
# title_embed[OFFSET(412)] AS d412,
# title_embed[OFFSET(413)] AS d413,
# title_embed[OFFSET(414)] AS d414,
# title_embed[OFFSET(415)] AS d415,
# title_embed[OFFSET(416)] AS d416,
# title_embed[OFFSET(417)] AS d417,
# title_embed[OFFSET(418)] AS d418,
# title_embed[OFFSET(419)] AS d419,
# title_embed[OFFSET(420)] AS d420,
# title_embed[OFFSET(421)] AS d421,
# title_embed[OFFSET(422)] AS d422,
# title_embed[OFFSET(423)] AS d423,
# title_embed[OFFSET(424)] AS d424,
# title_embed[OFFSET(425)] AS d425,
# title_embed[OFFSET(426)] AS d426,
# title_embed[OFFSET(427)] AS d427,
# title_embed[OFFSET(428)] AS d428,
# title_embed[OFFSET(429)] AS d429,
# title_embed[OFFSET(430)] AS d430,
# title_embed[OFFSET(431)] AS d431,
# title_embed[OFFSET(432)] AS d432,
# title_embed[OFFSET(433)] AS d433,
# title_embed[OFFSET(434)] AS d434,
# title_embed[OFFSET(435)] AS d435,
# title_embed[OFFSET(436)] AS d436,
# title_embed[OFFSET(437)] AS d437,
# title_embed[OFFSET(438)] AS d438,
# title_embed[OFFSET(439)] AS d439,
# title_embed[OFFSET(440)] AS d440,
# title_embed[OFFSET(441)] AS d441,
# title_embed[OFFSET(442)] AS d442,
# title_embed[OFFSET(443)] AS d443,
# title_embed[OFFSET(444)] AS d444,
# title_embed[OFFSET(445)] AS d445,
# title_embed[OFFSET(446)] AS d446,
# title_embed[OFFSET(447)] AS d447,
# title_embed[OFFSET(448)] AS d448,
# title_embed[OFFSET(449)] AS d449,
# title_embed[OFFSET(450)] AS d450,
# title_embed[OFFSET(451)] AS d451,
# title_embed[OFFSET(452)] AS d452,
# title_embed[OFFSET(453)] AS d453,
# title_embed[OFFSET(454)] AS d454,
# title_embed[OFFSET(455)] AS d455,
# title_embed[OFFSET(456)] AS d456,
# title_embed[OFFSET(457)] AS d457,
# title_embed[OFFSET(458)] AS d458,
# title_embed[OFFSET(459)] AS d459,
# title_embed[OFFSET(460)] AS d460,
# title_embed[OFFSET(461)] AS d461,
# title_embed[OFFSET(462)] AS d462,
# title_embed[OFFSET(463)] AS d463,
# title_embed[OFFSET(464)] AS d464,
# title_embed[OFFSET(465)] AS d465,
# title_embed[OFFSET(466)] AS d466,
# title_embed[OFFSET(467)] AS d467,
# title_embed[OFFSET(468)] AS d468,
# title_embed[OFFSET(469)] AS d469,
# title_embed[OFFSET(470)] AS d470,
# title_embed[OFFSET(471)] AS d471,
# title_embed[OFFSET(472)] AS d472,
# title_embed[OFFSET(473)] AS d473,
# title_embed[OFFSET(474)] AS d474,
# title_embed[OFFSET(475)] AS d475,
# title_embed[OFFSET(476)] AS d476,
# title_embed[OFFSET(477)] AS d477,
# title_embed[OFFSET(478)] AS d478,
# title_embed[OFFSET(479)] AS d479,
# title_embed[OFFSET(480)] AS d480,
# title_embed[OFFSET(481)] AS d481,
# title_embed[OFFSET(482)] AS d482,
# title_embed[OFFSET(483)] AS d483,
# title_embed[OFFSET(484)] AS d484,
# title_embed[OFFSET(485)] AS d485,
# title_embed[OFFSET(486)] AS d486,
# title_embed[OFFSET(487)] AS d487,
# title_embed[OFFSET(488)] AS d488,
# title_embed[OFFSET(489)] AS d489,
# title_embed[OFFSET(490)] AS d490,
# title_embed[OFFSET(491)] AS d491,
# title_embed[OFFSET(492)] AS d492,
# title_embed[OFFSET(493)] AS d493,
# title_embed[OFFSET(494)] AS d494,
# title_embed[OFFSET(495)] AS d495,
# title_embed[OFFSET(496)] AS d496,
# title_embed[OFFSET(497)] AS d497,
# title_embed[OFFSET(498)] AS d498,
# title_embed[OFFSET(499)] AS d499,
# title_embed[OFFSET(500)] AS d500,
# title_embed[OFFSET(501)] AS d501,
# title_embed[OFFSET(502)] AS d502,
# title_embed[OFFSET(503)] AS d503,
# title_embed[OFFSET(504)] AS d504,
# title_embed[OFFSET(505)] AS d505,
# title_embed[OFFSET(506)] AS d506,
# title_embed[OFFSET(507)] AS d507,
# title_embed[OFFSET(508)] AS d508,
# title_embed[OFFSET(509)] AS d509,
# title_embed[OFFSET(510)] AS d510,
# title_embed[OFFSET(511)] AS d511,
#
# FROM `springer-nature-analytics.DS_dimensions.publications_full_refresh`
# LEFT JOIN UNNEST(`for`) AS f LEFT JOIN UNNEST(journal) AS j
# WHERE ARRAY_LENGTH(title_embed) = 512
# AND
# publication_type LIKE "article"
#         AND j.title IN (SELECT title FROM `springer-nature-analytics.core_journals.core_2018_v01`)
#         AND year >= 2014
#         AND year <= 2016
#         AND language LIKE "en"
#         AND ARRAY_LENGTH(references) > 4
#
# ) GROUP BY f1
#  ) WHERE f1 IS NOT NULL

# %%
train_and_save(for_14_16, "wv_14_16")
# Out:
# Saved mean vectors to "/content/drive/My Drive/Research/Data/Mean-title-centroids-3yrs-v02/wv_14_16_f1.csv"

# %%
# %%bigquery --project $pid for_14_16
#
# SELECT * FROM (
# SELECT f2,
#
# AVG(d0) AS d0_mean,
# AVG(d1) AS d1_mean,
# AVG(d2) AS d2_mean,
# AVG(d3) AS d3_mean,
# AVG(d4) AS d4_mean,
# AVG(d5) AS d5_mean,
# AVG(d6) AS d6_mean,
# AVG(d7) AS d7_mean,
# AVG(d8) AS d8_mean,
# AVG(d9) AS d9_mean,
# AVG(d10) AS d10_mean,
# AVG(d11) AS d11_mean,
# AVG(d12) AS d12_mean,
# AVG(d13) AS d13_mean,
# AVG(d14) AS d14_mean,
# AVG(d15) AS d15_mean,
# AVG(d16) AS d16_mean,
# AVG(d17) AS d17_mean,
# AVG(d18) AS d18_mean,
# AVG(d19) AS d19_mean,
# AVG(d20) AS d20_mean,
# AVG(d21) AS d21_mean,
# AVG(d22) AS d22_mean,
# AVG(d23) AS d23_mean,
# AVG(d24) AS d24_mean,
# AVG(d25) AS d25_mean,
# AVG(d26) AS d26_mean,
# AVG(d27) AS d27_mean,
# AVG(d28) AS d28_mean,
# AVG(d29) AS d29_mean,
# AVG(d30) AS d30_mean,
# AVG(d31) AS d31_mean,
# AVG(d32) AS d32_mean,
# AVG(d33) AS d33_mean,
# AVG(d34) AS d34_mean,
# AVG(d35) AS d35_mean,
# AVG(d36) AS d36_mean,
# AVG(d37) AS d37_mean,
# AVG(d38) AS d38_mean,
# AVG(d39) AS d39_mean,
# AVG(d40) AS d40_mean,
# AVG(d41) AS d41_mean,
# AVG(d42) AS d42_mean,
# AVG(d43) AS d43_mean,
# AVG(d44) AS d44_mean,
# AVG(d45) AS d45_mean,
# AVG(d46) AS d46_mean,
# AVG(d47) AS d47_mean,
# AVG(d48) AS d48_mean,
# AVG(d49) AS d49_mean,
# AVG(d50) AS d50_mean,
# AVG(d51) AS d51_mean,
# AVG(d52) AS d52_mean,
# AVG(d53) AS d53_mean,
# AVG(d54) AS d54_mean,
# AVG(d55) AS d55_mean,
# AVG(d56) AS d56_mean,
# AVG(d57) AS d57_mean,
# AVG(d58) AS d58_mean,
# AVG(d59) AS d59_mean,
# AVG(d60) AS d60_mean,
# AVG(d61) AS d61_mean,
# AVG(d62) AS d62_mean,
# AVG(d63) AS d63_mean,
# AVG(d64) AS d64_mean,
# AVG(d65) AS d65_mean,
# AVG(d66) AS d66_mean,
# AVG(d67) AS d67_mean,
# AVG(d68) AS d68_mean,
# AVG(d69) AS d69_mean,
# AVG(d70) AS d70_mean,
# AVG(d71) AS d71_mean,
# AVG(d72) AS d72_mean,
# AVG(d73) AS d73_mean,
# AVG(d74) AS d74_mean,
# AVG(d75) AS d75_mean,
# AVG(d76) AS d76_mean,
# AVG(d77) AS d77_mean,
# AVG(d78) AS d78_mean,
# AVG(d79) AS d79_mean,
# AVG(d80) AS d80_mean,
# AVG(d81) AS d81_mean,
# AVG(d82) AS d82_mean,
# AVG(d83) AS d83_mean,
# AVG(d84) AS d84_mean,
# AVG(d85) AS d85_mean,
# AVG(d86) AS d86_mean,
# AVG(d87) AS d87_mean,
# AVG(d88) AS d88_mean,
# AVG(d89) AS d89_mean,
# AVG(d90) AS d90_mean,
# AVG(d91) AS d91_mean,
# AVG(d92) AS d92_mean,
# AVG(d93) AS d93_mean,
# AVG(d94) AS d94_mean,
# AVG(d95) AS d95_mean,
# AVG(d96) AS d96_mean,
# AVG(d97) AS d97_mean,
# AVG(d98) AS d98_mean,
# AVG(d99) AS d99_mean,
# AVG(d100) AS d100_mean,
# AVG(d101) AS d101_mean,
# AVG(d102) AS d102_mean,
# AVG(d103) AS d103_mean,
# AVG(d104) AS d104_mean,
# AVG(d105) AS d105_mean,
# AVG(d106) AS d106_mean,
# AVG(d107) AS d107_mean,
# AVG(d108) AS d108_mean,
# AVG(d109) AS d109_mean,
# AVG(d110) AS d110_mean,
# AVG(d111) AS d111_mean,
# AVG(d112) AS d112_mean,
# AVG(d113) AS d113_mean,
# AVG(d114) AS d114_mean,
# AVG(d115) AS d115_mean,
# AVG(d116) AS d116_mean,
# AVG(d117) AS d117_mean,
# AVG(d118) AS d118_mean,
# AVG(d119) AS d119_mean,
# AVG(d120) AS d120_mean,
# AVG(d121) AS d121_mean,
# AVG(d122) AS d122_mean,
# AVG(d123) AS d123_mean,
# AVG(d124) AS d124_mean,
# AVG(d125) AS d125_mean,
# AVG(d126) AS d126_mean,
# AVG(d127) AS d127_mean,
# AVG(d128) AS d128_mean,
# AVG(d129) AS d129_mean,
# AVG(d130) AS d130_mean,
# AVG(d131) AS d131_mean,
# AVG(d132) AS d132_mean,
# AVG(d133) AS d133_mean,
# AVG(d134) AS d134_mean,
# AVG(d135) AS d135_mean,
# AVG(d136) AS d136_mean,
# AVG(d137) AS d137_mean,
# AVG(d138) AS d138_mean,
# AVG(d139) AS d139_mean,
# AVG(d140) AS d140_mean,
# AVG(d141) AS d141_mean,
# AVG(d142) AS d142_mean,
# AVG(d143) AS d143_mean,
# AVG(d144) AS d144_mean,
# AVG(d145) AS d145_mean,
# AVG(d146) AS d146_mean,
# AVG(d147) AS d147_mean,
# AVG(d148) AS d148_mean,
# AVG(d149) AS d149_mean,
# AVG(d150) AS d150_mean,
# AVG(d151) AS d151_mean,
# AVG(d152) AS d152_mean,
# AVG(d153) AS d153_mean,
# AVG(d154) AS d154_mean,
# AVG(d155) AS d155_mean,
# AVG(d156) AS d156_mean,
# AVG(d157) AS d157_mean,
# AVG(d158) AS d158_mean,
# AVG(d159) AS d159_mean,
# AVG(d160) AS d160_mean,
# AVG(d161) AS d161_mean,
# AVG(d162) AS d162_mean,
# AVG(d163) AS d163_mean,
# AVG(d164) AS d164_mean,
# AVG(d165) AS d165_mean,
# AVG(d166) AS d166_mean,
# AVG(d167) AS d167_mean,
# AVG(d168) AS d168_mean,
# AVG(d169) AS d169_mean,
# AVG(d170) AS d170_mean,
# AVG(d171) AS d171_mean,
# AVG(d172) AS d172_mean,
# AVG(d173) AS d173_mean,
# AVG(d174) AS d174_mean,
# AVG(d175) AS d175_mean,
# AVG(d176) AS d176_mean,
# AVG(d177) AS d177_mean,
# AVG(d178) AS d178_mean,
# AVG(d179) AS d179_mean,
# AVG(d180) AS d180_mean,
# AVG(d181) AS d181_mean,
# AVG(d182) AS d182_mean,
# AVG(d183) AS d183_mean,
# AVG(d184) AS d184_mean,
# AVG(d185) AS d185_mean,
# AVG(d186) AS d186_mean,
# AVG(d187) AS d187_mean,
# AVG(d188) AS d188_mean,
# AVG(d189) AS d189_mean,
# AVG(d190) AS d190_mean,
# AVG(d191) AS d191_mean,
# AVG(d192) AS d192_mean,
# AVG(d193) AS d193_mean,
# AVG(d194) AS d194_mean,
# AVG(d195) AS d195_mean,
# AVG(d196) AS d196_mean,
# AVG(d197) AS d197_mean,
# AVG(d198) AS d198_mean,
# AVG(d199) AS d199_mean,
# AVG(d200) AS d200_mean,
# AVG(d201) AS d201_mean,
# AVG(d202) AS d202_mean,
# AVG(d203) AS d203_mean,
# AVG(d204) AS d204_mean,
# AVG(d205) AS d205_mean,
# AVG(d206) AS d206_mean,
# AVG(d207) AS d207_mean,
# AVG(d208) AS d208_mean,
# AVG(d209) AS d209_mean,
# AVG(d210) AS d210_mean,
# AVG(d211) AS d211_mean,
# AVG(d212) AS d212_mean,
# AVG(d213) AS d213_mean,
# AVG(d214) AS d214_mean,
# AVG(d215) AS d215_mean,
# AVG(d216) AS d216_mean,
# AVG(d217) AS d217_mean,
# AVG(d218) AS d218_mean,
# AVG(d219) AS d219_mean,
# AVG(d220) AS d220_mean,
# AVG(d221) AS d221_mean,
# AVG(d222) AS d222_mean,
# AVG(d223) AS d223_mean,
# AVG(d224) AS d224_mean,
# AVG(d225) AS d225_mean,
# AVG(d226) AS d226_mean,
# AVG(d227) AS d227_mean,
# AVG(d228) AS d228_mean,
# AVG(d229) AS d229_mean,
# AVG(d230) AS d230_mean,
# AVG(d231) AS d231_mean,
# AVG(d232) AS d232_mean,
# AVG(d233) AS d233_mean,
# AVG(d234) AS d234_mean,
# AVG(d235) AS d235_mean,
# AVG(d236) AS d236_mean,
# AVG(d237) AS d237_mean,
# AVG(d238) AS d238_mean,
# AVG(d239) AS d239_mean,
# AVG(d240) AS d240_mean,
# AVG(d241) AS d241_mean,
# AVG(d242) AS d242_mean,
# AVG(d243) AS d243_mean,
# AVG(d244) AS d244_mean,
# AVG(d245) AS d245_mean,
# AVG(d246) AS d246_mean,
# AVG(d247) AS d247_mean,
# AVG(d248) AS d248_mean,
# AVG(d249) AS d249_mean,
# AVG(d250) AS d250_mean,
# AVG(d251) AS d251_mean,
# AVG(d252) AS d252_mean,
# AVG(d253) AS d253_mean,
# AVG(d254) AS d254_mean,
# AVG(d255) AS d255_mean,
# AVG(d256) AS d256_mean,
# AVG(d257) AS d257_mean,
# AVG(d258) AS d258_mean,
# AVG(d259) AS d259_mean,
# AVG(d260) AS d260_mean,
# AVG(d261) AS d261_mean,
# AVG(d262) AS d262_mean,
# AVG(d263) AS d263_mean,
# AVG(d264) AS d264_mean,
# AVG(d265) AS d265_mean,
# AVG(d266) AS d266_mean,
# AVG(d267) AS d267_mean,
# AVG(d268) AS d268_mean,
# AVG(d269) AS d269_mean,
# AVG(d270) AS d270_mean,
# AVG(d271) AS d271_mean,
# AVG(d272) AS d272_mean,
# AVG(d273) AS d273_mean,
# AVG(d274) AS d274_mean,
# AVG(d275) AS d275_mean,
# AVG(d276) AS d276_mean,
# AVG(d277) AS d277_mean,
# AVG(d278) AS d278_mean,
# AVG(d279) AS d279_mean,
# AVG(d280) AS d280_mean,
# AVG(d281) AS d281_mean,
# AVG(d282) AS d282_mean,
# AVG(d283) AS d283_mean,
# AVG(d284) AS d284_mean,
# AVG(d285) AS d285_mean,
# AVG(d286) AS d286_mean,
# AVG(d287) AS d287_mean,
# AVG(d288) AS d288_mean,
# AVG(d289) AS d289_mean,
# AVG(d290) AS d290_mean,
# AVG(d291) AS d291_mean,
# AVG(d292) AS d292_mean,
# AVG(d293) AS d293_mean,
# AVG(d294) AS d294_mean,
# AVG(d295) AS d295_mean,
# AVG(d296) AS d296_mean,
# AVG(d297) AS d297_mean,
# AVG(d298) AS d298_mean,
# AVG(d299) AS d299_mean,
# AVG(d300) AS d300_mean,
# AVG(d301) AS d301_mean,
# AVG(d302) AS d302_mean,
# AVG(d303) AS d303_mean,
# AVG(d304) AS d304_mean,
# AVG(d305) AS d305_mean,
# AVG(d306) AS d306_mean,
# AVG(d307) AS d307_mean,
# AVG(d308) AS d308_mean,
# AVG(d309) AS d309_mean,
# AVG(d310) AS d310_mean,
# AVG(d311) AS d311_mean,
# AVG(d312) AS d312_mean,
# AVG(d313) AS d313_mean,
# AVG(d314) AS d314_mean,
# AVG(d315) AS d315_mean,
# AVG(d316) AS d316_mean,
# AVG(d317) AS d317_mean,
# AVG(d318) AS d318_mean,
# AVG(d319) AS d319_mean,
# AVG(d320) AS d320_mean,
# AVG(d321) AS d321_mean,
# AVG(d322) AS d322_mean,
# AVG(d323) AS d323_mean,
# AVG(d324) AS d324_mean,
# AVG(d325) AS d325_mean,
# AVG(d326) AS d326_mean,
# AVG(d327) AS d327_mean,
# AVG(d328) AS d328_mean,
# AVG(d329) AS d329_mean,
# AVG(d330) AS d330_mean,
# AVG(d331) AS d331_mean,
# AVG(d332) AS d332_mean,
# AVG(d333) AS d333_mean,
# AVG(d334) AS d334_mean,
# AVG(d335) AS d335_mean,
# AVG(d336) AS d336_mean,
# AVG(d337) AS d337_mean,
# AVG(d338) AS d338_mean,
# AVG(d339) AS d339_mean,
# AVG(d340) AS d340_mean,
# AVG(d341) AS d341_mean,
# AVG(d342) AS d342_mean,
# AVG(d343) AS d343_mean,
# AVG(d344) AS d344_mean,
# AVG(d345) AS d345_mean,
# AVG(d346) AS d346_mean,
# AVG(d347) AS d347_mean,
# AVG(d348) AS d348_mean,
# AVG(d349) AS d349_mean,
# AVG(d350) AS d350_mean,
# AVG(d351) AS d351_mean,
# AVG(d352) AS d352_mean,
# AVG(d353) AS d353_mean,
# AVG(d354) AS d354_mean,
# AVG(d355) AS d355_mean,
# AVG(d356) AS d356_mean,
# AVG(d357) AS d357_mean,
# AVG(d358) AS d358_mean,
# AVG(d359) AS d359_mean,
# AVG(d360) AS d360_mean,
# AVG(d361) AS d361_mean,
# AVG(d362) AS d362_mean,
# AVG(d363) AS d363_mean,
# AVG(d364) AS d364_mean,
# AVG(d365) AS d365_mean,
# AVG(d366) AS d366_mean,
# AVG(d367) AS d367_mean,
# AVG(d368) AS d368_mean,
# AVG(d369) AS d369_mean,
# AVG(d370) AS d370_mean,
# AVG(d371) AS d371_mean,
# AVG(d372) AS d372_mean,
# AVG(d373) AS d373_mean,
# AVG(d374) AS d374_mean,
# AVG(d375) AS d375_mean,
# AVG(d376) AS d376_mean,
# AVG(d377) AS d377_mean,
# AVG(d378) AS d378_mean,
# AVG(d379) AS d379_mean,
# AVG(d380) AS d380_mean,
# AVG(d381) AS d381_mean,
# AVG(d382) AS d382_mean,
# AVG(d383) AS d383_mean,
# AVG(d384) AS d384_mean,
# AVG(d385) AS d385_mean,
# AVG(d386) AS d386_mean,
# AVG(d387) AS d387_mean,
# AVG(d388) AS d388_mean,
# AVG(d389) AS d389_mean,
# AVG(d390) AS d390_mean,
# AVG(d391) AS d391_mean,
# AVG(d392) AS d392_mean,
# AVG(d393) AS d393_mean,
# AVG(d394) AS d394_mean,
# AVG(d395) AS d395_mean,
# AVG(d396) AS d396_mean,
# AVG(d397) AS d397_mean,
# AVG(d398) AS d398_mean,
# AVG(d399) AS d399_mean,
# AVG(d400) AS d400_mean,
# AVG(d401) AS d401_mean,
# AVG(d402) AS d402_mean,
# AVG(d403) AS d403_mean,
# AVG(d404) AS d404_mean,
# AVG(d405) AS d405_mean,
# AVG(d406) AS d406_mean,
# AVG(d407) AS d407_mean,
# AVG(d408) AS d408_mean,
# AVG(d409) AS d409_mean,
# AVG(d410) AS d410_mean,
# AVG(d411) AS d411_mean,
# AVG(d412) AS d412_mean,
# AVG(d413) AS d413_mean,
# AVG(d414) AS d414_mean,
# AVG(d415) AS d415_mean,
# AVG(d416) AS d416_mean,
# AVG(d417) AS d417_mean,
# AVG(d418) AS d418_mean,
# AVG(d419) AS d419_mean,
# AVG(d420) AS d420_mean,
# AVG(d421) AS d421_mean,
# AVG(d422) AS d422_mean,
# AVG(d423) AS d423_mean,
# AVG(d424) AS d424_mean,
# AVG(d425) AS d425_mean,
# AVG(d426) AS d426_mean,
# AVG(d427) AS d427_mean,
# AVG(d428) AS d428_mean,
# AVG(d429) AS d429_mean,
# AVG(d430) AS d430_mean,
# AVG(d431) AS d431_mean,
# AVG(d432) AS d432_mean,
# AVG(d433) AS d433_mean,
# AVG(d434) AS d434_mean,
# AVG(d435) AS d435_mean,
# AVG(d436) AS d436_mean,
# AVG(d437) AS d437_mean,
# AVG(d438) AS d438_mean,
# AVG(d439) AS d439_mean,
# AVG(d440) AS d440_mean,
# AVG(d441) AS d441_mean,
# AVG(d442) AS d442_mean,
# AVG(d443) AS d443_mean,
# AVG(d444) AS d444_mean,
# AVG(d445) AS d445_mean,
# AVG(d446) AS d446_mean,
# AVG(d447) AS d447_mean,
# AVG(d448) AS d448_mean,
# AVG(d449) AS d449_mean,
# AVG(d450) AS d450_mean,
# AVG(d451) AS d451_mean,
# AVG(d452) AS d452_mean,
# AVG(d453) AS d453_mean,
# AVG(d454) AS d454_mean,
# AVG(d455) AS d455_mean,
# AVG(d456) AS d456_mean,
# AVG(d457) AS d457_mean,
# AVG(d458) AS d458_mean,
# AVG(d459) AS d459_mean,
# AVG(d460) AS d460_mean,
# AVG(d461) AS d461_mean,
# AVG(d462) AS d462_mean,
# AVG(d463) AS d463_mean,
# AVG(d464) AS d464_mean,
# AVG(d465) AS d465_mean,
# AVG(d466) AS d466_mean,
# AVG(d467) AS d467_mean,
# AVG(d468) AS d468_mean,
# AVG(d469) AS d469_mean,
# AVG(d470) AS d470_mean,
# AVG(d471) AS d471_mean,
# AVG(d472) AS d472_mean,
# AVG(d473) AS d473_mean,
# AVG(d474) AS d474_mean,
# AVG(d475) AS d475_mean,
# AVG(d476) AS d476_mean,
# AVG(d477) AS d477_mean,
# AVG(d478) AS d478_mean,
# AVG(d479) AS d479_mean,
# AVG(d480) AS d480_mean,
# AVG(d481) AS d481_mean,
# AVG(d482) AS d482_mean,
# AVG(d483) AS d483_mean,
# AVG(d484) AS d484_mean,
# AVG(d485) AS d485_mean,
# AVG(d486) AS d486_mean,
# AVG(d487) AS d487_mean,
# AVG(d488) AS d488_mean,
# AVG(d489) AS d489_mean,
# AVG(d490) AS d490_mean,
# AVG(d491) AS d491_mean,
# AVG(d492) AS d492_mean,
# AVG(d493) AS d493_mean,
# AVG(d494) AS d494_mean,
# AVG(d495) AS d495_mean,
# AVG(d496) AS d496_mean,
# AVG(d497) AS d497_mean,
# AVG(d498) AS d498_mean,
# AVG(d499) AS d499_mean,
# AVG(d500) AS d500_mean,
# AVG(d501) AS d501_mean,
# AVG(d502) AS d502_mean,
# AVG(d503) AS d503_mean,
# AVG(d504) AS d504_mean,
# AVG(d505) AS d505_mean,
# AVG(d506) AS d506_mean,
# AVG(d507) AS d507_mean,
# AVG(d508) AS d508_mean,
# AVG(d509) AS d509_mean,
# AVG(d510) AS d510_mean,
# AVG(d511) AS d511_mean,
#
# FROM (
# SELECT f.second_level.name AS f2,
#
# title_embed[OFFSET(0)] AS d0,
# title_embed[OFFSET(1)] AS d1,
# title_embed[OFFSET(2)] AS d2,
# title_embed[OFFSET(3)] AS d3,
# title_embed[OFFSET(4)] AS d4,
# title_embed[OFFSET(5)] AS d5,
# title_embed[OFFSET(6)] AS d6,
# title_embed[OFFSET(7)] AS d7,
# title_embed[OFFSET(8)] AS d8,
# title_embed[OFFSET(9)] AS d9,
# title_embed[OFFSET(10)] AS d10,
# title_embed[OFFSET(11)] AS d11,
# title_embed[OFFSET(12)] AS d12,
# title_embed[OFFSET(13)] AS d13,
# title_embed[OFFSET(14)] AS d14,
# title_embed[OFFSET(15)] AS d15,
# title_embed[OFFSET(16)] AS d16,
# title_embed[OFFSET(236)] AS d236,
# title_embed[OFFSET(237)] AS d237,
# title_embed[OFFSET(238)] AS d238,
# title_embed[OFFSET(239)] AS d239,
# title_embed[OFFSET(240)] AS d240,
# title_embed[OFFSET(241)] AS d241,
# title_embed[OFFSET(242)] AS d242,
# title_embed[OFFSET(243)] AS d243,
# title_embed[OFFSET(244)] AS d244,
# title_embed[OFFSET(245)] AS d245,
# title_embed[OFFSET(246)] AS d246,
# title_embed[OFFSET(247)] AS d247,
# title_embed[OFFSET(248)] AS d248,
# title_embed[OFFSET(249)] AS d249,
# title_embed[OFFSET(250)] AS d250,
# title_embed[OFFSET(251)] AS d251,
# title_embed[OFFSET(252)] AS d252,
# title_embed[OFFSET(253)] AS d253,
# title_embed[OFFSET(254)] AS d254,
# title_embed[OFFSET(255)] AS d255,
# title_embed[OFFSET(256)] AS d256,
# title_embed[OFFSET(257)] AS d257,
# title_embed[OFFSET(258)] AS d258,
# title_embed[OFFSET(259)] AS d259,
# title_embed[OFFSET(260)] AS d260,
# title_embed[OFFSET(261)] AS d261,
# title_embed[OFFSET(262)] AS d262,
# title_embed[OFFSET(263)] AS d263,
# title_embed[OFFSET(264)] AS d264,
# title_embed[OFFSET(265)] AS d265,
# title_embed[OFFSET(266)] AS d266,
# title_embed[OFFSET(267)] AS d267,
# title_embed[OFFSET(268)] AS d268,
# title_embed[OFFSET(269)] AS d269,
# title_embed[OFFSET(270)] AS d270,
# title_embed[OFFSET(271)] AS d271,
# title_embed[OFFSET(272)] AS d272,
# title_embed[OFFSET(273)] AS d273,
# title_embed[OFFSET(274)] AS d274,
# title_embed[OFFSET(275)] AS d275,
# title_embed[OFFSET(276)] AS d276,
# title_embed[OFFSET(277)] AS d277,
# title_embed[OFFSET(278)] AS d278,
# title_embed[OFFSET(279)] AS d279,
# title_embed[OFFSET(280)] AS d280,
# title_embed[OFFSET(281)] AS d281,
# title_embed[OFFSET(282)] AS d282,
# title_embed[OFFSET(283)] AS d283,
# title_embed[OFFSET(284)] AS d284,
# title_embed[OFFSET(285)] AS d285,
# title_embed[OFFSET(286)] AS d286,
# title_embed[OFFSET(287)] AS d287,
# title_embed[OFFSET(288)] AS d288,
# title_embed[OFFSET(289)] AS d289,
# title_embed[OFFSET(290)] AS d290,
# title_embed[OFFSET(291)] AS d291,
# title_embed[OFFSET(292)] AS d292,
# title_embed[OFFSET(293)] AS d293,
# title_embed[OFFSET(294)] AS d294,
# title_embed[OFFSET(295)] AS d295,
# title_embed[OFFSET(296)] AS d296,
# title_embed[OFFSET(297)] AS d297,
# title_embed[OFFSET(298)] AS d298,
# title_embed[OFFSET(299)] AS d299,
# title_embed[OFFSET(300)] AS d300,
# title_embed[OFFSET(301)] AS d301,
# title_embed[OFFSET(302)] AS d302,
# title_embed[OFFSET(303)] AS d303,
# title_embed[OFFSET(304)] AS d304,
# title_embed[OFFSET(305)] AS d305,
# title_embed[OFFSET(306)] AS d306,
# title_embed[OFFSET(307)] AS d307,
# title_embed[OFFSET(308)] AS d308,
# title_embed[OFFSET(309)] AS d309,
# title_embed[OFFSET(383)] AS d383,
# title_embed[OFFSET(384)] AS d384,
# title_embed[OFFSET(385)] AS d385,
# title_embed[OFFSET(386)] AS d386,
# title_embed[OFFSET(387)] AS d387,
# title_embed[OFFSET(388)] AS d388,
# title_embed[OFFSET(389)] AS d389,
# title_embed[OFFSET(390)] AS d390,
# title_embed[OFFSET(391)] AS d391,
# title_embed[OFFSET(392)] AS d392,
# title_embed[OFFSET(393)] AS d393,
# title_embed[OFFSET(394)] AS d394,
# title_embed[OFFSET(395)] AS d395,
# title_embed[OFFSET(396)] AS d396,
# title_embed[OFFSET(397)] AS d397,
# title_embed[OFFSET(398)] AS d398,
# title_embed[OFFSET(399)] AS d399,
# title_embed[OFFSET(400)] AS d400,
# title_embed[OFFSET(401)] AS d401,
# title_embed[OFFSET(402)] AS d402,
# title_embed[OFFSET(403)] AS d403,
# title_embed[OFFSET(404)] AS d404,
# title_embed[OFFSET(405)] AS d405,
# title_embed[OFFSET(406)] AS d406,
# title_embed[OFFSET(407)] AS d407,
# title_embed[OFFSET(408)] AS d408,
# title_embed[OFFSET(409)] AS d409,
# title_embed[OFFSET(410)] AS d410,
# title_embed[OFFSET(411)] AS d411,
# title_embed[OFFSET(412)] AS d412,
# title_embed[OFFSET(413)] AS d413,
# title_embed[OFFSET(414)] AS d414,
# title_embed[OFFSET(415)] AS d415,
# title_embed[OFFSET(416)] AS d416,
# title_embed[OFFSET(417)] AS d417,
# title_embed[OFFSET(418)] AS d418,
# title_embed[OFFSET(419)] AS d419,
# title_embed[OFFSET(420)] AS d420,
# title_embed[OFFSET(421)] AS d421,
# title_embed[OFFSET(422)] AS d422,
# title_embed[OFFSET(423)] AS d423,
# title_embed[OFFSET(424)] AS d424,
# title_embed[OFFSET(425)] AS d425,
# title_embed[OFFSET(426)] AS d426,
# title_embed[OFFSET(427)] AS d427,
# title_embed[OFFSET(428)] AS d428,
# title_embed[OFFSET(429)] AS d429,
# title_embed[OFFSET(430)] AS d430,
# title_embed[OFFSET(431)] AS d431,
# title_embed[OFFSET(432)] AS d432,
# title_embed[OFFSET(433)] AS d433,
# title_embed[OFFSET(434)] AS d434,
# title_embed[OFFSET(435)] AS d435,
# title_embed[OFFSET(436)] AS d436,
# title_embed[OFFSET(437)] AS d437,
# title_embed[OFFSET(438)] AS d438,
# title_embed[OFFSET(439)] AS d439,
# title_embed[OFFSET(440)] AS d440,
# title_embed[OFFSET(441)] AS d441,
# title_embed[OFFSET(442)] AS d442,
# title_embed[OFFSET(443)] AS d443,
# title_embed[OFFSET(444)] AS d444,
# title_embed[OFFSET(445)] AS d445,
# title_embed[OFFSET(446)] AS d446,
# title_embed[OFFSET(447)] AS d447,
# title_embed[OFFSET(448)] AS d448,
# title_embed[OFFSET(449)] AS d449,
# title_embed[OFFSET(450)] AS d450,
# title_embed[OFFSET(451)] AS d451,
# title_embed[OFFSET(452)] AS d452,
# title_embed[OFFSET(453)] AS d453,
# title_embed[OFFSET(454)] AS d454,
# title_embed[OFFSET(455)] AS d455,
# title_embed[OFFSET(456)] AS d456,
# title_embed[OFFSET(457)] AS d457,
# title_embed[OFFSET(458)] AS d458,
# title_embed[OFFSET(459)] AS d459,
# title_embed[OFFSET(460)] AS d460,
# title_embed[OFFSET(461)] AS d461,
# title_embed[OFFSET(462)] AS d462,
# title_embed[OFFSET(463)] AS d463,
# title_embed[OFFSET(464)] AS d464,
# title_embed[OFFSET(465)] AS d465,
# title_embed[OFFSET(466)] AS d466,
# title_embed[OFFSET(467)] AS d467,
# title_embed[OFFSET(468)] AS d468,
# title_embed[OFFSET(469)] AS d469,
# title_embed[OFFSET(470)] AS d470,
# title_embed[OFFSET(471)] AS d471,
# title_embed[OFFSET(472)] AS d472,
# title_embed[OFFSET(473)] AS d473,
# title_embed[OFFSET(474)] AS d474,
# title_embed[OFFSET(475)] AS d475,
# title_embed[OFFSET(476)] AS d476,
# title_embed[OFFSET(477)] AS d477,
# title_embed[OFFSET(478)] AS d478,
# title_embed[OFFSET(479)] AS d479,
# title_embed[OFFSET(480)] AS d480,
# title_embed[OFFSET(481)] AS d481,
# title_embed[OFFSET(482)] AS d482,
# title_embed[OFFSET(483)] AS d483,
# title_embed[OFFSET(484)] AS d484,
# title_embed[OFFSET(485)] AS d485,
# title_embed[OFFSET(486)] AS d486,
# title_embed[OFFSET(487)] AS d487,
# title_embed[OFFSET(488)] AS d488,
# title_embed[OFFSET(489)] AS d489,
# title_embed[OFFSET(490)] AS d490,
# title_embed[OFFSET(491)] AS d491,
# title_embed[OFFSET(492)] AS d492,
# title_embed[OFFSET(493)] AS d493,
# title_embed[OFFSET(494)] AS d494,
# title_embed[OFFSET(495)] AS d495,
# title_embed[OFFSET(496)] AS d496,
# title_embed[OFFSET(497)] AS d497,
# title_embed[OFFSET(498)] AS d498,
# title_embed[OFFSET(499)] AS d499,
# title_embed[OFFSET(500)] AS d500,
# title_embed[OFFSET(501)] AS d501,
# title_embed[OFFSET(502)] AS d502,
# title_embed[OFFSET(503)] AS d503,
# title_embed[OFFSET(504)] AS d504,
# title_embed[OFFSET(505)] AS d505,
# title_embed[OFFSET(506)] AS d506,
# title_embed[OFFSET(507)] AS d507,
# title_embed[OFFSET(508)] AS d508,
# title_embed[OFFSET(509)] AS d509,
# title_embed[OFFSET(510)] AS d510,
# title_embed[OFFSET(511)] AS d511,
#
# FROM `springer-nature-analytics.DS_dimensions.publications_full_refresh`
# LEFT JOIN UNNEST(`for`) AS f LEFT JOIN UNNEST(journal) AS j
# WHERE ARRAY_LENGTH(title_embed) = 512
# AND
# publication_type LIKE "article"
#         AND j.title IN (SELECT title FROM `springer-nature-analytics.core_journals.core_2018_v01`)
#         AND year >= 2014
#         AND year <= 2016
#         AND language LIKE "en"
#         AND ARRAY_LENGTH(references) > 4
#
# ) GROUP BY f2
#  ) WHERE f2 IS NOT NULL

# %%
train_and_save(for_14_16, "wv_14_16", "f2")
# Out:
# Saved mean vectors to "/content/drive/My Drive/Research/Data/Mean-title-centroids-3yrs-v02/wv_14_16_f2.csv"

# %% [markdown]
# # 2011-2013

# %%
# %%bigquery --project $pid for_11_13
#
# SELECT * FROM (
# SELECT f1,
#
# AVG(d0) AS d0_mean,
# AVG(d1) AS d1_mean,
# AVG(d2) AS d2_mean,
# AVG(d3) AS d3_mean,
# AVG(d4) AS d4_mean,
# AVG(d5) AS d5_mean,
# AVG(d6) AS d6_mean,
# AVG(d7) AS d7_mean,
# AVG(d8) AS d8_mean,
# AVG(d9) AS d9_mean,
# AVG(d10) AS d10_mean,
# AVG(d11) AS d11_mean,
# AVG(d12) AS d12_mean,
# AVG(d13) AS d13_mean,
# AVG(d14) AS d14_mean,
# AVG(d15) AS d15_mean,
# AVG(d16) AS d16_mean,
# AVG(d17) AS d17_mean,
# AVG(d18) AS d18_mean,
# AVG(d19) AS d19_mean,
# AVG(d20) AS d20_mean,
# AVG(d21) AS d21_mean,
# AVG(d22) AS d22_mean,
# AVG(d23) AS d23_mean,
# AVG(d24) AS d24_mean,
# AVG(d25) AS d25_mean,
# AVG(d26) AS d26_mean,
# AVG(d27) AS d27_mean,
# AVG(d28) AS d28_mean,
# AVG(d29) AS d29_mean,
# AVG(d30) AS d30_mean,
# AVG(d31) AS d31_mean,
# AVG(d32) AS d32_mean,
# AVG(d33) AS d33_mean,
# AVG(d34) AS d34_mean,
# AVG(d35) AS d35_mean,
# AVG(d36) AS d36_mean,
# AVG(d37) AS d37_mean,
# AVG(d38) AS d38_mean,
# AVG(d39) AS d39_mean,
# AVG(d40) AS d40_mean,
# AVG(d41) AS d41_mean,
# AVG(d42) AS d42_mean,
# AVG(d43) AS d43_mean,
# AVG(d44) AS d44_mean,
# AVG(d45) AS d45_mean,
# AVG(d46) AS d46_mean,
# AVG(d47) AS d47_mean,
# AVG(d48) AS d48_mean,
# AVG(d49) AS d49_mean,
# AVG(d50) AS d50_mean,
# AVG(d51) AS d51_mean,
# AVG(d52) AS d52_mean,
# AVG(d53) AS d53_mean,
# AVG(d54) AS d54_mean,
# AVG(d55) AS d55_mean,
# AVG(d56) AS d56_mean,
# AVG(d57) AS d57_mean,
# AVG(d58) AS d58_mean,
# AVG(d59) AS d59_mean,
# AVG(d60) AS d60_mean,
# AVG(d61) AS d61_mean,
# AVG(d62) AS d62_mean,
# AVG(d63) AS d63_mean,
# AVG(d64) AS d64_mean,
# AVG(d65) AS d65_mean,
# AVG(d66) AS d66_mean,
# AVG(d67) AS d67_mean,
# AVG(d68) AS d68_mean,
# AVG(d69) AS d69_mean,
# AVG(d70) AS d70_mean,
# AVG(d71) AS d71_mean,
# AVG(d72) AS d72_mean,
# AVG(d73) AS d73_mean,
# AVG(d74) AS d74_mean,
# AVG(d75) AS d75_mean,
# AVG(d76) AS d76_mean,
# AVG(d77) AS d77_mean,
# AVG(d78) AS d78_mean,
# AVG(d79) AS d79_mean,
# AVG(d80) AS d80_mean,
# AVG(d81) AS d81_mean,
# AVG(d82) AS d82_mean,
# AVG(d83) AS d83_mean,
# AVG(d84) AS d84_mean,
# AVG(d85) AS d85_mean,
# AVG(d86) AS d86_mean,
# AVG(d87) AS d87_mean,
# AVG(d88) AS d88_mean,
# AVG(d89) AS d89_mean,
# AVG(d90) AS d90_mean,
# AVG(d91) AS d91_mean,
# AVG(d92) AS d92_mean,
# AVG(d93) AS d93_mean,
# AVG(d94) AS d94_mean,
# AVG(d95) AS d95_mean,
# AVG(d96) AS d96_mean,
# AVG(d97) AS d97_mean,
# AVG(d98) AS d98_mean,
# AVG(d99) AS d99_mean,
# AVG(d100) AS d100_mean,
# AVG(d101) AS d101_mean,
# AVG(d102) AS d102_mean,
# AVG(d103) AS d103_mean,
# AVG(d104) AS d104_mean,
# AVG(d105) AS d105_mean,
# AVG(d106) AS d106_mean,
# AVG(d107) AS d107_mean,
# AVG(d108) AS d108_mean,
# AVG(d109) AS d109_mean,
# AVG(d110) AS d110_mean,
# AVG(d111) AS d111_mean,
# AVG(d112) AS d112_mean,
# AVG(d113) AS d113_mean,
# AVG(d114) AS d114_mean,
# AVG(d115) AS d115_mean,
# AVG(d116) AS d116_mean,
# AVG(d117) AS d117_mean,
# AVG(d118) AS d118_mean,
# AVG(d119) AS d119_mean,
# AVG(d120) AS d120_mean,
# AVG(d121) AS d121_mean,
# AVG(d122) AS d122_mean,
# AVG(d123) AS d123_mean,
# AVG(d124) AS d124_mean,
# AVG(d125) AS d125_mean,
# AVG(d126) AS d126_mean,
# AVG(d127) AS d127_mean,
# AVG(d128) AS d128_mean,
# AVG(d129) AS d129_mean,
# AVG(d130) AS d130_mean,
# AVG(d131) AS d131_mean,
# AVG(d132) AS d132_mean,
# AVG(d133) AS d133_mean,
# AVG(d134) AS d134_mean,
# AVG(d135) AS d135_mean,
# AVG(d136) AS d136_mean,
# AVG(d137) AS d137_mean,
# AVG(d138) AS d138_mean,
# AVG(d139) AS d139_mean,
# AVG(d140) AS d140_mean,
# AVG(d141) AS d141_mean,
# AVG(d142) AS d142_mean,
# AVG(d143) AS d143_mean,
# AVG(d144) AS d144_mean,
# AVG(d145) AS d145_mean,
# AVG(d146) AS d146_mean,
# AVG(d147) AS d147_mean,
# AVG(d148) AS d148_mean,
# AVG(d149) AS d149_mean,
# AVG(d150) AS d150_mean,
# AVG(d151) AS d151_mean,
# AVG(d152) AS d152_mean,
# AVG(d153) AS d153_mean,
# AVG(d154) AS d154_mean,
# AVG(d155) AS d155_mean,
# AVG(d156) AS d156_mean,
# AVG(d157) AS d157_mean,
# AVG(d158) AS d158_mean,
# AVG(d159) AS d159_mean,
# AVG(d160) AS d160_mean,
# AVG(d161) AS d161_mean,
# AVG(d162) AS d162_mean,
# AVG(d163) AS d163_mean,
# AVG(d164) AS d164_mean,
# AVG(d165) AS d165_mean,
# AVG(d166) AS d166_mean,
# AVG(d167) AS d167_mean,
# AVG(d168) AS d168_mean,
# AVG(d169) AS d169_mean,
# AVG(d170) AS d170_mean,
# AVG(d171) AS d171_mean,
# AVG(d172) AS d172_mean,
# AVG(d173) AS d173_mean,
# AVG(d174) AS d174_mean,
# AVG(d175) AS d175_mean,
# AVG(d176) AS d176_mean,
# AVG(d177) AS d177_mean,
# AVG(d178) AS d178_mean,
# AVG(d179) AS d179_mean,
# AVG(d180) AS d180_mean,
# AVG(d181) AS d181_mean,
# AVG(d182) AS d182_mean,
# AVG(d183) AS d183_mean,
# AVG(d184) AS d184_mean,
# AVG(d185) AS d185_mean,
# AVG(d186) AS d186_mean,
# AVG(d187) AS d187_mean,
# AVG(d188) AS d188_mean,
# AVG(d189) AS d189_mean,
# AVG(d190) AS d190_mean,
# AVG(d191) AS d191_mean,
# AVG(d192) AS d192_mean,
# AVG(d193) AS d193_mean,
# AVG(d194) AS d194_mean,
# AVG(d195) AS d195_mean,
# AVG(d196) AS d196_mean,
# AVG(d197) AS d197_mean,
# AVG(d198) AS d198_mean,
# AVG(d199) AS d199_mean,
# AVG(d200) AS d200_mean,
# AVG(d201) AS d201_mean,
# AVG(d202) AS d202_mean,
# AVG(d203) AS d203_mean,
# AVG(d204) AS d204_mean,
# AVG(d205) AS d205_mean,
# AVG(d206) AS d206_mean,
# AVG(d207) AS d207_mean,
# AVG(d208) AS d208_mean,
# AVG(d209) AS d209_mean,
# AVG(d210) AS d210_mean,
# AVG(d211) AS d211_mean,
# AVG(d212) AS d212_mean,
# AVG(d213) AS d213_mean,
# AVG(d214) AS d214_mean,
# AVG(d215) AS d215_mean,
# AVG(d216) AS d216_mean,
# AVG(d217) AS d217_mean,
# AVG(d218) AS d218_mean,
# AVG(d219) AS d219_mean,
# AVG(d220) AS d220_mean,
# AVG(d221) AS d221_mean,
# AVG(d222) AS d222_mean,
# AVG(d223) AS d223_mean,
# AVG(d224) AS d224_mean,
# AVG(d225) AS d225_mean,
# AVG(d226) AS d226_mean,
# AVG(d227) AS d227_mean,
# AVG(d228) AS d228_mean,
# AVG(d229) AS d229_mean,
# AVG(d230) AS d230_mean,
# AVG(d231) AS d231_mean,
# AVG(d232) AS d232_mean,
# AVG(d233) AS d233_mean,
# AVG(d234) AS d234_mean,
# AVG(d235) AS d235_mean,
# AVG(d236) AS d236_mean,
# AVG(d237) AS d237_mean,
# AVG(d238) AS d238_mean,
# AVG(d239) AS d239_mean,
# AVG(d240) AS d240_mean,
# AVG(d241) AS d241_mean,
# AVG(d242) AS d242_mean,
# AVG(d243) AS d243_mean,
# AVG(d244) AS d244_mean,
# AVG(d245) AS d245_mean,
# AVG(d246) AS d246_mean,
# AVG(d247) AS d247_mean,
# AVG(d248) AS d248_mean,
# AVG(d249) AS d249_mean,
# AVG(d250) AS d250_mean,
# AVG(d251) AS d251_mean,
# AVG(d252) AS d252_mean,
# AVG(d253) AS d253_mean,
# AVG(d254) AS d254_mean,
# AVG(d255) AS d255_mean,
# AVG(d256) AS d256_mean,
# AVG(d257) AS d257_mean,
# AVG(d258) AS d258_mean,
# AVG(d259) AS d259_mean,
# AVG(d260) AS d260_mean,
# AVG(d261) AS d261_mean,
# AVG(d262) AS d262_mean,
# AVG(d263) AS d263_mean,
# AVG(d264) AS d264_mean,
# AVG(d265) AS d265_mean,
# AVG(d266) AS d266_mean,
# AVG(d267) AS d267_mean,
# AVG(d268) AS d268_mean,
# AVG(d269) AS d269_mean,
# AVG(d270) AS d270_mean,
# AVG(d271) AS d271_mean,
# AVG(d272) AS d272_mean,
# AVG(d273) AS d273_mean,
# AVG(d274) AS d274_mean,
# AVG(d275) AS d275_mean,
# AVG(d276) AS d276_mean,
# AVG(d277) AS d277_mean,
# AVG(d278) AS d278_mean,
# AVG(d279) AS d279_mean,
# AVG(d280) AS d280_mean,
# AVG(d281) AS d281_mean,
# AVG(d282) AS d282_mean,
# AVG(d283) AS d283_mean,
# AVG(d284) AS d284_mean,
# AVG(d285) AS d285_mean,
# AVG(d286) AS d286_mean,
# AVG(d287) AS d287_mean,
# AVG(d288) AS d288_mean,
# AVG(d289) AS d289_mean,
# AVG(d290) AS d290_mean,
# AVG(d291) AS d291_mean,
# AVG(d292) AS d292_mean,
# AVG(d293) AS d293_mean,
# AVG(d294) AS d294_mean,
# AVG(d295) AS d295_mean,
# AVG(d296) AS d296_mean,
# AVG(d297) AS d297_mean,
# AVG(d298) AS d298_mean,
# AVG(d299) AS d299_mean,
# AVG(d300) AS d300_mean,
# AVG(d301) AS d301_mean,
# AVG(d302) AS d302_mean,
# AVG(d303) AS d303_mean,
# AVG(d304) AS d304_mean,
# AVG(d305) AS d305_mean,
# AVG(d306) AS d306_mean,
# AVG(d307) AS d307_mean,
# AVG(d308) AS d308_mean,
# AVG(d309) AS d309_mean,
# AVG(d310) AS d310_mean,
# AVG(d311) AS d311_mean,
# AVG(d312) AS d312_mean,
# AVG(d313) AS d313_mean,
# AVG(d314) AS d314_mean,
# AVG(d315) AS d315_mean,
# AVG(d316) AS d316_mean,
# AVG(d317) AS d317_mean,
# AVG(d318) AS d318_mean,
# AVG(d319) AS d319_mean,
# AVG(d320) AS d320_mean,
# AVG(d321) AS d321_mean,
# AVG(d322) AS d322_mean,
# AVG(d323) AS d323_mean,
# AVG(d324) AS d324_mean,
# AVG(d325) AS d325_mean,
# AVG(d326) AS d326_mean,
# AVG(d327) AS d327_mean,
# AVG(d328) AS d328_mean,
# AVG(d329) AS d329_mean,
# AVG(d330) AS d330_mean,
# AVG(d331) AS d331_mean,
# AVG(d332) AS d332_mean,
# AVG(d333) AS d333_mean,
# AVG(d334) AS d334_mean,
# AVG(d335) AS d335_mean,
# AVG(d336) AS d336_mean,
# AVG(d337) AS d337_mean,
# AVG(d338) AS d338_mean,
# AVG(d339) AS d339_mean,
# AVG(d340) AS d340_mean,
# AVG(d341) AS d341_mean,
# AVG(d342) AS d342_mean,
# AVG(d343) AS d343_mean,
# AVG(d344) AS d344_mean,
# AVG(d345) AS d345_mean,
# AVG(d346) AS d346_mean,
# AVG(d347) AS d347_mean,
# AVG(d348) AS d348_mean,
# AVG(d349) AS d349_mean,
# AVG(d350) AS d350_mean,
# AVG(d351) AS d351_mean,
# AVG(d352) AS d352_mean,
# AVG(d353) AS d353_mean,
# AVG(d354) AS d354_mean,
# AVG(d355) AS d355_mean,
# AVG(d356) AS d356_mean,
# AVG(d357) AS d357_mean,
# AVG(d358) AS d358_mean,
# AVG(d359) AS d359_mean,
# AVG(d360) AS d360_mean,
# AVG(d361) AS d361_mean,
# AVG(d362) AS d362_mean,
# AVG(d363) AS d363_mean,
# AVG(d364) AS d364_mean,
# AVG(d365) AS d365_mean,
# AVG(d366) AS d366_mean,
# AVG(d367) AS d367_mean,
# AVG(d368) AS d368_mean,
# AVG(d369) AS d369_mean,
# AVG(d370) AS d370_mean,
# AVG(d371) AS d371_mean,
# AVG(d372) AS d372_mean,
# AVG(d373) AS d373_mean,
# AVG(d374) AS d374_mean,
# AVG(d375) AS d375_mean,
# AVG(d376) AS d376_mean,
# AVG(d377) AS d377_mean,
# AVG(d378) AS d378_mean,
# AVG(d379) AS d379_mean,
# AVG(d380) AS d380_mean,
# AVG(d381) AS d381_mean,
# AVG(d382) AS d382_mean,
# AVG(d383) AS d383_mean,
# AVG(d384) AS d384_mean,
# AVG(d385) AS d385_mean,
# AVG(d386) AS d386_mean,
# AVG(d387) AS d387_mean,
# AVG(d388) AS d388_mean,
# AVG(d389) AS d389_mean,
# AVG(d390) AS d390_mean,
# AVG(d391) AS d391_mean,
# AVG(d392) AS d392_mean,
# AVG(d393) AS d393_mean,
# AVG(d394) AS d394_mean,
# AVG(d395) AS d395_mean,
# AVG(d396) AS d396_mean,
# AVG(d397) AS d397_mean,
# AVG(d398) AS d398_mean,
# AVG(d399) AS d399_mean,
# AVG(d400) AS d400_mean,
# AVG(d401) AS d401_mean,
# AVG(d402) AS d402_mean,
# AVG(d403) AS d403_mean,
# AVG(d404) AS d404_mean,
# AVG(d405) AS d405_mean,
# AVG(d406) AS d406_mean,
# AVG(d407) AS d407_mean,
# AVG(d408) AS d408_mean,
# AVG(d409) AS d409_mean,
# AVG(d410) AS d410_mean,
# AVG(d411) AS d411_mean,
# AVG(d412) AS d412_mean,
# AVG(d413) AS d413_mean,
# AVG(d414) AS d414_mean,
# AVG(d415) AS d415_mean,
# AVG(d416) AS d416_mean,
# AVG(d417) AS d417_mean,
# AVG(d418) AS d418_mean,
# AVG(d419) AS d419_mean,
# AVG(d420) AS d420_mean,
# AVG(d421) AS d421_mean,
# AVG(d422) AS d422_mean,
# AVG(d423) AS d423_mean,
# AVG(d424) AS d424_mean,
# AVG(d425) AS d425_mean,
# AVG(d426) AS d426_mean,
# AVG(d427) AS d427_mean,
# AVG(d428) AS d428_mean,
# AVG(d429) AS d429_mean,
# AVG(d430) AS d430_mean,
# AVG(d431) AS d431_mean,
# AVG(d432) AS d432_mean,
# AVG(d433) AS d433_mean,
# AVG(d434) AS d434_mean,
# AVG(d435) AS d435_mean,
# AVG(d436) AS d436_mean,
# AVG(d437) AS d437_mean,
# AVG(d438) AS d438_mean,
# AVG(d439) AS d439_mean,
# AVG(d440) AS d440_mean,
# AVG(d441) AS d441_mean,
# AVG(d442) AS d442_mean,
# AVG(d443) AS d443_mean,
# AVG(d444) AS d444_mean,
# AVG(d445) AS d445_mean,
# AVG(d446) AS d446_mean,
# AVG(d447) AS d447_mean,
# AVG(d448) AS d448_mean,
# AVG(d449) AS d449_mean,
# AVG(d450) AS d450_mean,
# AVG(d451) AS d451_mean,
# AVG(d452) AS d452_mean,
# AVG(d453) AS d453_mean,
# AVG(d454) AS d454_mean,
# AVG(d455) AS d455_mean,
# AVG(d456) AS d456_mean,
# AVG(d457) AS d457_mean,
# AVG(d458) AS d458_mean,
# AVG(d459) AS d459_mean,
# AVG(d460) AS d460_mean,
# AVG(d461) AS d461_mean,
# AVG(d462) AS d462_mean,
# AVG(d463) AS d463_mean,
# AVG(d464) AS d464_mean,
# AVG(d465) AS d465_mean,
# AVG(d466) AS d466_mean,
# AVG(d467) AS d467_mean,
# AVG(d468) AS d468_mean,
# AVG(d469) AS d469_mean,
# AVG(d470) AS d470_mean,
# AVG(d471) AS d471_mean,
# AVG(d472) AS d472_mean,
# AVG(d473) AS d473_mean,
# AVG(d474) AS d474_mean,
# AVG(d475) AS d475_mean,
# AVG(d476) AS d476_mean,
# AVG(d477) AS d477_mean,
# AVG(d478) AS d478_mean,
# AVG(d479) AS d479_mean,
# AVG(d480) AS d480_mean,
# AVG(d481) AS d481_mean,
# AVG(d482) AS d482_mean,
# AVG(d483) AS d483_mean,
# AVG(d484) AS d484_mean,
# AVG(d485) AS d485_mean,
# AVG(d486) AS d486_mean,
# AVG(d487) AS d487_mean,
# AVG(d488) AS d488_mean,
# AVG(d489) AS d489_mean,
# AVG(d490) AS d490_mean,
# AVG(d491) AS d491_mean,
# AVG(d492) AS d492_mean,
# AVG(d493) AS d493_mean,
# AVG(d494) AS d494_mean,
# AVG(d495) AS d495_mean,
# AVG(d496) AS d496_mean,
# AVG(d497) AS d497_mean,
# AVG(d498) AS d498_mean,
# AVG(d499) AS d499_mean,
# AVG(d500) AS d500_mean,
# AVG(d501) AS d501_mean,
# AVG(d502) AS d502_mean,
# AVG(d503) AS d503_mean,
# AVG(d504) AS d504_mean,
# AVG(d505) AS d505_mean,
# AVG(d506) AS d506_mean,
# AVG(d507) AS d507_mean,
# AVG(d508) AS d508_mean,
# AVG(d509) AS d509_mean,
# AVG(d510) AS d510_mean,
# AVG(d511) AS d511_mean,
#
# FROM (
# SELECT f.first_level.name AS f1,
#
# title_embed[OFFSET(0)] AS d0,
# title_embed[OFFSET(1)] AS d1,
# title_embed[OFFSET(2)] AS d2,
# title_embed[OFFSET(3)] AS d3,
# title_embed[OFFSET(4)] AS d4,
# title_embed[OFFSET(5)] AS d5,
# title_embed[OFFSET(6)] AS d6,
# title_embed[OFFSET(7)] AS d7,
# title_embed[OFFSET(8)] AS d8,
# title_embed[OFFSET(9)] AS d9,
# title_embed[OFFSET(10)] AS d10,
# title_embed[OFFSET(11)] AS d11,
# title_embed[OFFSET(12)] AS d12,
# title_embed[OFFSET(13)] AS d13,
# title_embed[OFFSET(14)] AS d14,
# title_embed[OFFSET(15)] AS d15,
# title_embed[OFFSET(16)] AS d16,
# title_embed[OFFSET(17)] AS d17,
# title_embed[OFFSET(18)] AS d18,
# title_embed[OFFSET(19)] AS d19,
# title_embed[OFFSET(20)] AS d20,
# title_embed[OFFSET(240)] AS d240,
# title_embed[OFFSET(241)] AS d241,
# title_embed[OFFSET(242)] AS d242,
# title_embed[OFFSET(243)] AS d243,
# title_embed[OFFSET(244)] AS d244,
# title_embed[OFFSET(245)] AS d245,
# title_embed[OFFSET(246)] AS d246,
# title_embed[OFFSET(247)] AS d247,
# title_embed[OFFSET(248)] AS d248,
# title_embed[OFFSET(249)] AS d249,
# title_embed[OFFSET(250)] AS d250,
# title_embed[OFFSET(251)] AS d251,
# title_embed[OFFSET(252)] AS d252,
# title_embed[OFFSET(253)] AS d253,
# title_embed[OFFSET(254)] AS d254,
# title_embed[OFFSET(255)] AS d255,
# title_embed[OFFSET(256)] AS d256,
# title_embed[OFFSET(257)] AS d257,
# title_embed[OFFSET(258)] AS d258,
# title_embed[OFFSET(259)] AS d259,
# title_embed[OFFSET(260)] AS d260,
# title_embed[OFFSET(261)] AS d261,
# title_embed[OFFSET(262)] AS d262,
# title_embed[OFFSET(263)] AS d263,
# title_embed[OFFSET(264)] AS d264,
# title_embed[OFFSET(265)] AS d265,
# title_embed[OFFSET(266)] AS d266,
# title_embed[OFFSET(267)] AS d267,
# title_embed[OFFSET(268)] AS d268,
# title_embed[OFFSET(269)] AS d269,
# title_embed[OFFSET(270)] AS d270,
# title_embed[OFFSET(271)] AS d271,
# title_embed[OFFSET(272)] AS d272,
# title_embed[OFFSET(273)] AS d273,
# title_embed[OFFSET(274)] AS d274,
# title_embed[OFFSET(275)] AS d275,
# title_embed[OFFSET(276)] AS d276,
# title_embed[OFFSET(277)] AS d277,
# title_embed[OFFSET(278)] AS d278,
# title_embed[OFFSET(279)] AS d279,
# title_embed[OFFSET(280)] AS d280,
# title_embed[OFFSET(281)] AS d281,
# title_embed[OFFSET(282)] AS d282,
# title_embed[OFFSET(283)] AS d283,
# title_embed[OFFSET(284)] AS d284,
# title_embed[OFFSET(285)] AS d285,
# title_embed[OFFSET(286)] AS d286,
# title_embed[OFFSET(287)] AS d287,
# title_embed[OFFSET(288)] AS d288,
# title_embed[OFFSET(289)] AS d289,
# title_embed[OFFSET(290)] AS d290,
# title_embed[OFFSET(291)] AS d291,
# title_embed[OFFSET(292)] AS d292,
# title_embed[OFFSET(293)] AS d293,
# title_embed[OFFSET(294)] AS d294,
# title_embed[OFFSET(295)] AS d295,
# title_embed[OFFSET(296)] AS d296,
# title_embed[OFFSET(297)] AS d297,
# title_embed[OFFSET(298)] AS d298,
# title_embed[OFFSET(299)] AS d299,
# title_embed[OFFSET(300)] AS d300,
# title_embed[OFFSET(301)] AS d301,
# title_embed[OFFSET(302)] AS d302,
# title_embed[OFFSET(303)] AS d303,
# title_embed[OFFSET(304)] AS d304,
# title_embed[OFFSET(305)] AS d305,
# title_embed[OFFSET(306)] AS d306,
# title_embed[OFFSET(307)] AS d307,
# title_embed[OFFSET(308)] AS d308,
# title_embed[OFFSET(309)] AS d309,
# title_embed[OFFSET(310)] AS d310,
# title_embed[OFFSET(311)] AS d311,
# title_embed[OFFSET(312)] AS d312,
# title_embed[OFFSET(313)] AS d313,
# title_embed[OFFSET(460)] AS d460,
# title_embed[OFFSET(461)] AS d461,
# title_embed[OFFSET(462)] AS d462,
# title_embed[OFFSET(463)] AS d463,
# title_embed[OFFSET(464)] AS d464,
# title_embed[OFFSET(465)] AS d465,
# title_embed[OFFSET(466)] AS d466,
# title_embed[OFFSET(467)] AS d467,
# title_embed[OFFSET(468)] AS d468,
# title_embed[OFFSET(469)] AS d469,
# title_embed[OFFSET(470)] AS d470,
# title_embed[OFFSET(471)] AS d471,
# title_embed[OFFSET(472)] AS d472,
# title_embed[OFFSET(473)] AS d473,
# title_embed[OFFSET(474)] AS d474,
# title_embed[OFFSET(475)] AS d475,
# title_embed[OFFSET(476)] AS d476,
# title_embed[OFFSET(477)] AS d477,
# title_embed[OFFSET(478)] AS d478,
# title_embed[OFFSET(479)] AS d479,
# title_embed[OFFSET(480)] AS d480,
# title_embed[OFFSET(481)] AS d481,
# title_embed[OFFSET(482)] AS d482,
# title_embed[OFFSET(483)] AS d483,
# title_embed[OFFSET(484)] AS d484,
# title_embed[OFFSET(485)] AS d485,
# title_embed[OFFSET(486)] AS d486,
# title_embed[OFFSET(487)] AS d487,
# title_embed[OFFSET(488)] AS d488,
# title_embed[OFFSET(489)] AS d489,
# title_embed[OFFSET(490)] AS d490,
# title_embed[OFFSET(491)] AS d491,
# title_embed[OFFSET(492)] AS d492,
# title_embed[OFFSET(493)] AS d493,
# title_embed[OFFSET(494)] AS d494,
# title_embed[OFFSET(495)] AS d495,
# title_embed[OFFSET(496)] AS d496,
# title_embed[OFFSET(497)] AS d497,
# title_embed[OFFSET(498)] AS d498,
# title_embed[OFFSET(499)] AS d499,
# title_embed[OFFSET(500)] AS d500,
# title_embed[OFFSET(501)] AS d501,
# title_embed[OFFSET(502)] AS d502,
# title_embed[OFFSET(503)] AS d503,
# title_embed[OFFSET(504)] AS d504,
# title_embed[OFFSET(505)] AS d505,
# title_embed[OFFSET(506)] AS d506,
# title_embed[OFFSET(507)] AS d507,
# title_embed[OFFSET(508)] AS d508,
# title_embed[OFFSET(509)] AS d509,
# title_embed[OFFSET(510)] AS d510,
# title_embed[OFFSET(511)] AS d511,
#
# FROM `springer-nature-analytics.DS_dimensions.publications_full_refresh`
# LEFT JOIN UNNEST(`for`) AS f LEFT JOIN UNNEST(journal) AS j
# WHERE ARRAY_LENGTH(title_embed) = 512
# AND
# publication_type LIKE "article"
#         AND j.title IN (SELECT title FROM `springer-nature-analytics.core_journals.core_2018_v01`)
#         AND year >= 2011
#         AND year <= 2013
#         AND language LIKE "en"
#         AND ARRAY_LENGTH(references) > 4
#
# ) GROUP BY f1
#  ) WHERE f1 IS NOT NULL

# %%
train_and_save(for_11_13, "wv_11_13")
# Out:
# Saved mean vectors to "/content/drive/My Drive/Research/Data/Mean-title-centroids-3yrs-v02/wv_11_13_f1.csv"

# %%
# %%bigquery --project $pid for_11_13
#
# SELECT * FROM (
# SELECT f2,
#
# AVG(d0) AS d0_mean,
# AVG(d1) AS d1_mean,
# AVG(d2) AS d2_mean,
# AVG(d3) AS d3_mean,
# AVG(d4) AS d4_mean,
# AVG(d5) AS d5_mean,
# AVG(d6) AS d6_mean,
# AVG(d7) AS d7_mean,
# AVG(d8) AS d8_mean,
# AVG(d9) AS d9_mean,
# AVG(d10) AS d10_mean,
# AVG(d11) AS d11_mean,
# AVG(d12) AS d12_mean,
# AVG(d13) AS d13_mean,
# AVG(d14) AS d14_mean,
# AVG(d15) AS d15_mean,
# AVG(d16) AS d16_mean,
# AVG(d17) AS d17_mean,
# AVG(d18) AS d18_mean,
# AVG(d19) AS d19_mean,
# AVG(d20) AS d20_mean,
# AVG(d21) AS d21_mean,
# AVG(d22) AS d22_mean,
# AVG(d23) AS d23_mean,
# AVG(d24) AS d24_mean,
# AVG(d25) AS d25_mean,
# AVG(d26) AS d26_mean,
# AVG(d27) AS d27_mean,
# AVG(d28) AS d28_mean,
# AVG(d29) AS d29_mean,
# AVG(d30) AS d30_mean,
# AVG(d31) AS d31_mean,
# AVG(d32) AS d32_mean,
# AVG(d33) AS d33_mean,
# AVG(d34) AS d34_mean,
# AVG(d35) AS d35_mean,
# AVG(d36) AS d36_mean,
# AVG(d37) AS d37_mean,
# AVG(d38) AS d38_mean,
# AVG(d39) AS d39_mean,
# AVG(d40) AS d40_mean,
# AVG(d41) AS d41_mean,
# AVG(d42) AS d42_mean,
# AVG(d43) AS d43_mean,
# AVG(d44) AS d44_mean,
# AVG(d45) AS d45_mean,
# AVG(d46) AS d46_mean,
# AVG(d47) AS d47_mean,
# AVG(d48) AS d48_mean,
# AVG(d49) AS d49_mean,
# AVG(d50) AS d50_mean,
# AVG(d51) AS d51_mean,
# AVG(d52) AS d52_mean,
# AVG(d53) AS d53_mean,
# AVG(d54) AS d54_mean,
# AVG(d55) AS d55_mean,
# AVG(d56) AS d56_mean,
# AVG(d57) AS d57_mean,
# AVG(d58) AS d58_mean,
# AVG(d59) AS d59_mean,
# AVG(d60) AS d60_mean,
# AVG(d61) AS d61_mean,
# AVG(d62) AS d62_mean,
# AVG(d63) AS d63_mean,
# AVG(d64) AS d64_mean,
# AVG(d65) AS d65_mean,
# AVG(d66) AS d66_mean,
# AVG(d67) AS d67_mean,
# AVG(d68) AS d68_mean,
# AVG(d69) AS d69_mean,
# AVG(d70) AS d70_mean,
# AVG(d71) AS d71_mean,
# AVG(d72) AS d72_mean,
# AVG(d73) AS d73_mean,
# AVG(d74) AS d74_mean,
# AVG(d75) AS d75_mean,
# AVG(d76) AS d76_mean,
# AVG(d77) AS d77_mean,
# AVG(d78) AS d78_mean,
# AVG(d79) AS d79_mean,
# AVG(d80) AS d80_mean,
# AVG(d81) AS d81_mean,
# AVG(d82) AS d82_mean,
# AVG(d83) AS d83_mean,
# AVG(d84) AS d84_mean,
# AVG(d85) AS d85_mean,
# AVG(d86) AS d86_mean,
# AVG(d87) AS d87_mean,
# AVG(d88) AS d88_mean,
# AVG(d89) AS d89_mean,
# AVG(d90) AS d90_mean,
# AVG(d91) AS d91_mean,
# AVG(d92) AS d92_mean,
# AVG(d93) AS d93_mean,
# AVG(d94) AS d94_mean,
# AVG(d95) AS d95_mean,
# AVG(d96) AS d96_mean,
# AVG(d97) AS d97_mean,
# AVG(d98) AS d98_mean,
# AVG(d99) AS d99_mean,
# AVG(d100) AS d100_mean,
# AVG(d101) AS d101_mean,
# AVG(d102) AS d102_mean,
# AVG(d103) AS d103_mean,
# AVG(d104) AS d104_mean,
# AVG(d105) AS d105_mean,
# AVG(d106) AS d106_mean,
# AVG(d107) AS d107_mean,
# AVG(d108) AS d108_mean,
# AVG(d109) AS d109_mean,
# AVG(d110) AS d110_mean,
# AVG(d111) AS d111_mean,
# AVG(d112) AS d112_mean,
# AVG(d113) AS d113_mean,
# AVG(d114) AS d114_mean,
# AVG(d115) AS d115_mean,
# AVG(d116) AS d116_mean,
# AVG(d117) AS d117_mean,
# AVG(d118) AS d118_mean,
# AVG(d119) AS d119_mean,
# AVG(d120) AS d120_mean,
# AVG(d121) AS d121_mean,
# AVG(d122) AS d122_mean,
# AVG(d123) AS d123_mean,
# AVG(d124) AS d124_mean,
# AVG(d125) AS d125_mean,
# AVG(d126) AS d126_mean,
# AVG(d127) AS d127_mean,
# AVG(d128) AS d128_mean,
# AVG(d129) AS d129_mean,
# AVG(d130) AS d130_mean,
# AVG(d131) AS d131_mean,
# AVG(d132) AS d132_mean,
# AVG(d133) AS d133_mean,
# AVG(d134) AS d134_mean,
# AVG(d135) AS d135_mean,
# AVG(d136) AS d136_mean,
# AVG(d137) AS d137_mean,
# AVG(d138) AS d138_mean,
# AVG(d139) AS d139_mean,
# AVG(d140) AS d140_mean,
# AVG(d141) AS d141_mean,
# AVG(d142) AS d142_mean,
# AVG(d143) AS d143_mean,
# AVG(d144) AS d144_mean,
# AVG(d145) AS d145_mean,
# AVG(d146) AS d146_mean,
# AVG(d147) AS d147_mean,
# AVG(d148) AS d148_mean,
# AVG(d149) AS d149_mean,
# AVG(d150) AS d150_mean,
# AVG(d151) AS d151_mean,
# AVG(d152) AS d152_mean,
# AVG(d153) AS d153_mean,
# AVG(d154) AS d154_mean,
# AVG(d155) AS d155_mean,
# AVG(d156) AS d156_mean,
# AVG(d157) AS d157_mean,
# AVG(d158) AS d158_mean,
# AVG(d159) AS d159_mean,
# AVG(d160) AS d160_mean,
# AVG(d161) AS d161_mean,
# AVG(d162) AS d162_mean,
# AVG(d163) AS d163_mean,
# AVG(d164) AS d164_mean,
# AVG(d165) AS d165_mean,
# AVG(d166) AS d166_mean,
# AVG(d167) AS d167_mean,
# AVG(d168) AS d168_mean,
# AVG(d169) AS d169_mean,
# AVG(d170) AS d170_mean,
# AVG(d171) AS d171_mean,
# AVG(d172) AS d172_mean,
# AVG(d173) AS d173_mean,
# AVG(d174) AS d174_mean,
# AVG(d175) AS d175_mean,
# AVG(d176) AS d176_mean,
# AVG(d177) AS d177_mean,
# AVG(d178) AS d178_mean,
# AVG(d179) AS d179_mean,
# AVG(d180) AS d180_mean,
# AVG(d181) AS d181_mean,
# AVG(d182) AS d182_mean,
# AVG(d183) AS d183_mean,
# AVG(d184) AS d184_mean,
# AVG(d185) AS d185_mean,
# AVG(d186) AS d186_mean,
# AVG(d187) AS d187_mean,
# AVG(d188) AS d188_mean,
# AVG(d189) AS d189_mean,
# AVG(d190) AS d190_mean,
# AVG(d191) AS d191_mean,
# AVG(d192) AS d192_mean,
# AVG(d193) AS d193_mean,
# AVG(d194) AS d194_mean,
# AVG(d195) AS d195_mean,
# AVG(d196) AS d196_mean,
# AVG(d197) AS d197_mean,
# AVG(d198) AS d198_mean,
# AVG(d199) AS d199_mean,
# AVG(d200) AS d200_mean,
# AVG(d201) AS d201_mean,
# AVG(d202) AS d202_mean,
# AVG(d203) AS d203_mean,
# AVG(d204) AS d204_mean,
# AVG(d205) AS d205_mean,
# AVG(d206) AS d206_mean,
# AVG(d207) AS d207_mean,
# AVG(d208) AS d208_mean,
# AVG(d209) AS d209_mean,
# AVG(d210) AS d210_mean,
# AVG(d211) AS d211_mean,
# AVG(d212) AS d212_mean,
# AVG(d213) AS d213_mean,
# AVG(d214) AS d214_mean,
# AVG(d215) AS d215_mean,
# AVG(d216) AS d216_mean,
# AVG(d217) AS d217_mean,
# AVG(d218) AS d218_mean,
# AVG(d219) AS d219_mean,
# AVG(d220) AS d220_mean,
# AVG(d221) AS d221_mean,
# AVG(d222) AS d222_mean,
# AVG(d223) AS d223_mean,
# AVG(d224) AS d224_mean,
# AVG(d225) AS d225_mean,
# AVG(d226) AS d226_mean,
# AVG(d227) AS d227_mean,
# AVG(d228) AS d228_mean,
# AVG(d229) AS d229_mean,
# AVG(d230) AS d230_mean,
# AVG(d231) AS d231_mean,
# AVG(d232) AS d232_mean,
# AVG(d233) AS d233_mean,
# AVG(d234) AS d234_mean,
# AVG(d235) AS d235_mean,
# AVG(d236) AS d236_mean,
# AVG(d237) AS d237_mean,
# AVG(d238) AS d238_mean,
# AVG(d239) AS d239_mean,
# AVG(d240) AS d240_mean,
# AVG(d241) AS d241_mean,
# AVG(d242) AS d242_mean,
# AVG(d243) AS d243_mean,
# AVG(d244) AS d244_mean,
# AVG(d245) AS d245_mean,
# AVG(d246) AS d246_mean,
# AVG(d247) AS d247_mean,
# AVG(d248) AS d248_mean,
# AVG(d249) AS d249_mean,
# AVG(d250) AS d250_mean,
# AVG(d251) AS d251_mean,
# AVG(d252) AS d252_mean,
# AVG(d253) AS d253_mean,
# AVG(d254) AS d254_mean,
# AVG(d255) AS d255_mean,
# AVG(d256) AS d256_mean,
# AVG(d257) AS d257_mean,
# AVG(d258) AS d258_mean,
# AVG(d259) AS d259_mean,
# AVG(d260) AS d260_mean,
# AVG(d261) AS d261_mean,
# AVG(d262) AS d262_mean,
# AVG(d263) AS d263_mean,
# AVG(d264) AS d264_mean,
# AVG(d265) AS d265_mean,
# AVG(d266) AS d266_mean,
# AVG(d267) AS d267_mean,
# AVG(d268) AS d268_mean,
# AVG(d269) AS d269_mean,
# AVG(d270) AS d270_mean,
# AVG(d271) AS d271_mean,
# AVG(d272) AS d272_mean,
# AVG(d273) AS d273_mean,
# AVG(d274) AS d274_mean,
# AVG(d275) AS d275_mean,
# AVG(d276) AS d276_mean,
# AVG(d277) AS d277_mean,
# AVG(d278) AS d278_mean,
# AVG(d279) AS d279_mean,
# AVG(d280) AS d280_mean,
# AVG(d281) AS d281_mean,
# AVG(d282) AS d282_mean,
# AVG(d283) AS d283_mean,
# AVG(d284) AS d284_mean,
# AVG(d285) AS d285_mean,
# AVG(d286) AS d286_mean,
# AVG(d287) AS d287_mean,
# AVG(d288) AS d288_mean,
# AVG(d289) AS d289_mean,
# AVG(d290) AS d290_mean,
# AVG(d291) AS d291_mean,
# AVG(d292) AS d292_mean,
# AVG(d293) AS d293_mean,
# AVG(d294) AS d294_mean,
# AVG(d295) AS d295_mean,
# AVG(d296) AS d296_mean,
# AVG(d297) AS d297_mean,
# AVG(d298) AS d298_mean,
# AVG(d299) AS d299_mean,
# AVG(d300) AS d300_mean,
# AVG(d301) AS d301_mean,
# AVG(d302) AS d302_mean,
# AVG(d303) AS d303_mean,
# AVG(d304) AS d304_mean,
# AVG(d305) AS d305_mean,
# AVG(d306) AS d306_mean,
# AVG(d307) AS d307_mean,
# AVG(d308) AS d308_mean,
# AVG(d309) AS d309_mean,
# AVG(d310) AS d310_mean,
# AVG(d311) AS d311_mean,
# AVG(d312) AS d312_mean,
# AVG(d313) AS d313_mean,
# AVG(d314) AS d314_mean,
# AVG(d315) AS d315_mean,
# AVG(d316) AS d316_mean,
# AVG(d317) AS d317_mean,
# AVG(d318) AS d318_mean,
# AVG(d319) AS d319_mean,
# AVG(d320) AS d320_mean,
# AVG(d321) AS d321_mean,
# AVG(d322) AS d322_mean,
# AVG(d323) AS d323_mean,
# AVG(d324) AS d324_mean,
# AVG(d325) AS d325_mean,
# AVG(d326) AS d326_mean,
# AVG(d327) AS d327_mean,
# AVG(d328) AS d328_mean,
# AVG(d329) AS d329_mean,
# AVG(d330) AS d330_mean,
# AVG(d331) AS d331_mean,
# AVG(d332) AS d332_mean,
# AVG(d333) AS d333_mean,
# AVG(d334) AS d334_mean,
# AVG(d335) AS d335_mean,
# AVG(d336) AS d336_mean,
# AVG(d337) AS d337_mean,
# AVG(d338) AS d338_mean,
# AVG(d339) AS d339_mean,
# AVG(d340) AS d340_mean,
# AVG(d341) AS d341_mean,
# AVG(d342) AS d342_mean,
# AVG(d343) AS d343_mean,
# AVG(d344) AS d344_mean,
# AVG(d345) AS d345_mean,
# AVG(d346) AS d346_mean,
# AVG(d347) AS d347_mean,
# AVG(d348) AS d348_mean,
# AVG(d349) AS d349_mean,
# AVG(d350) AS d350_mean,
# AVG(d351) AS d351_mean,
# AVG(d352) AS d352_mean,
# AVG(d353) AS d353_mean,
# AVG(d354) AS d354_mean,
# AVG(d355) AS d355_mean,
# AVG(d356) AS d356_mean,
# AVG(d357) AS d357_mean,
# AVG(d358) AS d358_mean,
# AVG(d359) AS d359_mean,
# AVG(d360) AS d360_mean,
# AVG(d361) AS d361_mean,
# AVG(d362) AS d362_mean,
# AVG(d363) AS d363_mean,
# AVG(d364) AS d364_mean,
# AVG(d365) AS d365_mean,
# AVG(d366) AS d366_mean,
# AVG(d367) AS d367_mean,
# AVG(d368) AS d368_mean,
# AVG(d369) AS d369_mean,
# AVG(d370) AS d370_mean,
# AVG(d371) AS d371_mean,
# AVG(d372) AS d372_mean,
# AVG(d373) AS d373_mean,
# AVG(d374) AS d374_mean,
# AVG(d375) AS d375_mean,
# AVG(d376) AS d376_mean,
# AVG(d377) AS d377_mean,
# AVG(d378) AS d378_mean,
# AVG(d379) AS d379_mean,
# AVG(d380) AS d380_mean,
# AVG(d381) AS d381_mean,
# AVG(d382) AS d382_mean,
# AVG(d383) AS d383_mean,
# AVG(d384) AS d384_mean,
# AVG(d385) AS d385_mean,
# AVG(d386) AS d386_mean,
# AVG(d387) AS d387_mean,
# AVG(d388) AS d388_mean,
# AVG(d389) AS d389_mean,
# AVG(d390) AS d390_mean,
# AVG(d391) AS d391_mean,
# AVG(d392) AS d392_mean,
# AVG(d393) AS d393_mean,
# AVG(d394) AS d394_mean,
# AVG(d395) AS d395_mean,
# AVG(d396) AS d396_mean,
# AVG(d397) AS d397_mean,
# AVG(d398) AS d398_mean,
# AVG(d399) AS d399_mean,
# AVG(d400) AS d400_mean,
# AVG(d401) AS d401_mean,
# AVG(d402) AS d402_mean,
# AVG(d403) AS d403_mean,
# AVG(d404) AS d404_mean,
# AVG(d405) AS d405_mean,
# AVG(d406) AS d406_mean,
# AVG(d407) AS d407_mean,
# AVG(d408) AS d408_mean,
# AVG(d409) AS d409_mean,
# AVG(d410) AS d410_mean,
# AVG(d411) AS d411_mean,
# AVG(d412) AS d412_mean,
# AVG(d413) AS d413_mean,
# AVG(d414) AS d414_mean,
# AVG(d415) AS d415_mean,
# AVG(d416) AS d416_mean,
# AVG(d417) AS d417_mean,
# AVG(d418) AS d418_mean,
# AVG(d419) AS d419_mean,
# AVG(d420) AS d420_mean,
# AVG(d421) AS d421_mean,
# AVG(d422) AS d422_mean,
# AVG(d423) AS d423_mean,
# AVG(d424) AS d424_mean,
# AVG(d425) AS d425_mean,
# AVG(d426) AS d426_mean,
# AVG(d427) AS d427_mean,
# AVG(d428) AS d428_mean,
# AVG(d429) AS d429_mean,
# AVG(d430) AS d430_mean,
# AVG(d431) AS d431_mean,
# AVG(d432) AS d432_mean,
# AVG(d433) AS d433_mean,
# AVG(d434) AS d434_mean,
# AVG(d435) AS d435_mean,
# AVG(d436) AS d436_mean,
# AVG(d437) AS d437_mean,
# AVG(d438) AS d438_mean,
# AVG(d439) AS d439_mean,
# AVG(d440) AS d440_mean,
# AVG(d441) AS d441_mean,
# AVG(d442) AS d442_mean,
# AVG(d443) AS d443_mean,
# AVG(d444) AS d444_mean,
# AVG(d445) AS d445_mean,
# AVG(d446) AS d446_mean,
# AVG(d447) AS d447_mean,
# AVG(d448) AS d448_mean,
# AVG(d449) AS d449_mean,
# AVG(d450) AS d450_mean,
# AVG(d451) AS d451_mean,
# AVG(d452) AS d452_mean,
# AVG(d453) AS d453_mean,
# AVG(d454) AS d454_mean,
# AVG(d455) AS d455_mean,
# AVG(d456) AS d456_mean,
# AVG(d457) AS d457_mean,
# AVG(d458) AS d458_mean,
# AVG(d459) AS d459_mean,
# AVG(d460) AS d460_mean,
# AVG(d461) AS d461_mean,
# AVG(d462) AS d462_mean,
# AVG(d463) AS d463_mean,
# AVG(d464) AS d464_mean,
# AVG(d465) AS d465_mean,
# AVG(d466) AS d466_mean,
# AVG(d467) AS d467_mean,
# AVG(d468) AS d468_mean,
# AVG(d469) AS d469_mean,
# AVG(d470) AS d470_mean,
# AVG(d471) AS d471_mean,
# AVG(d472) AS d472_mean,
# AVG(d473) AS d473_mean,
# AVG(d474) AS d474_mean,
# AVG(d475) AS d475_mean,
# AVG(d476) AS d476_mean,
# AVG(d477) AS d477_mean,
# AVG(d478) AS d478_mean,
# AVG(d479) AS d479_mean,
# AVG(d480) AS d480_mean,
# AVG(d481) AS d481_mean,
# AVG(d482) AS d482_mean,
# AVG(d483) AS d483_mean,
# AVG(d484) AS d484_mean,
# AVG(d485) AS d485_mean,
# AVG(d486) AS d486_mean,
# AVG(d487) AS d487_mean,
# AVG(d488) AS d488_mean,
# AVG(d489) AS d489_mean,
# AVG(d490) AS d490_mean,
# AVG(d491) AS d491_mean,
# AVG(d492) AS d492_mean,
# AVG(d493) AS d493_mean,
# AVG(d494) AS d494_mean,
# AVG(d495) AS d495_mean,
# AVG(d496) AS d496_mean,
# AVG(d497) AS d497_mean,
# AVG(d498) AS d498_mean,
# AVG(d499) AS d499_mean,
# AVG(d500) AS d500_mean,
# AVG(d501) AS d501_mean,
# AVG(d502) AS d502_mean,
# AVG(d503) AS d503_mean,
# AVG(d504) AS d504_mean,
# AVG(d505) AS d505_mean,
# AVG(d506) AS d506_mean,
# AVG(d507) AS d507_mean,
# AVG(d508) AS d508_mean,
# AVG(d509) AS d509_mean,
# AVG(d510) AS d510_mean,
# AVG(d511) AS d511_mean,
#
# FROM (
# SELECT f.second_level.name AS f2,
#
# title_embed[OFFSET(0)] AS d0,
# title_embed[OFFSET(1)] AS d1,
# title_embed[OFFSET(2)] AS d2,
# title_embed[OFFSET(3)] AS d3,
# title_embed[OFFSET(4)] AS d4,
# title_embed[OFFSET(5)] AS d5,
# title_embed[OFFSET(6)] AS d6,
# title_embed[OFFSET(7)] AS d7,
# title_embed[OFFSET(8)] AS d8,
# title_embed[OFFSET(9)] AS d9,
# title_embed[OFFSET(10)] AS d10,
# title_embed[OFFSET(11)] AS d11,
# title_embed[OFFSET(12)] AS d12,
# title_embed[OFFSET(13)] AS d13,
# title_embed[OFFSET(14)] AS d14,
# title_embed[OFFSET(15)] AS d15,
# title_embed[OFFSET(16)] AS d16,
# title_embed[OFFSET(17)] AS d17,
# title_embed[OFFSET(18)] AS d18,
# title_embed[OFFSET(19)] AS d19,
# title_embed[OFFSET(20)] AS d20,
# title_embed[OFFSET(21)] AS d21,
# title_embed[OFFSET(22)] AS d22,
# title_embed[OFFSET(23)] AS d23,
# title_embed[OFFSET(24)] AS d24,
# title_embed[OFFSET(25)] AS d25,
# title_embed[OFFSET(392)] AS d392,
# title_embed[OFFSET(393)] AS d393,
# title_embed[OFFSET(394)] AS d394,
# title_embed[OFFSET(395)] AS d395,
# title_embed[OFFSET(396)] AS d396,
# title_embed[OFFSET(397)] AS d397,
# title_embed[OFFSET(398)] AS d398,
# title_embed[OFFSET(399)] AS d399,
# title_embed[OFFSET(400)] AS d400,
# title_embed[OFFSET(401)] AS d401,
# title_embed[OFFSET(402)] AS d402,
# title_embed[OFFSET(403)] AS d403,
# title_embed[OFFSET(404)] AS d404,
# title_embed[OFFSET(405)] AS d405,
# title_embed[OFFSET(406)] AS d406,
# title_embed[OFFSET(407)] AS d407,
# title_embed[OFFSET(408)] AS d408,
# title_embed[OFFSET(409)] AS d409,
# title_embed[OFFSET(410)] AS d410,
# title_embed[OFFSET(411)] AS d411,
# title_embed[OFFSET(412)] AS d412,
# title_embed[OFFSET(413)] AS d413,
# title_embed[OFFSET(414)] AS d414,
# title_embed[OFFSET(415)] AS d415,
# title_embed[OFFSET(416)] AS d416,
# title_embed[OFFSET(417)] AS d417,
# title_embed[OFFSET(418)] AS d418,
# title_embed[OFFSET(419)] AS d419,
# title_embed[OFFSET(420)] AS d420,
# title_embed[OFFSET(421)] AS d421,
# title_embed[OFFSET(422)] AS d422,
# title_embed[OFFSET(423)] AS d423,
# title_embed[OFFSET(424)] AS d424,
# title_embed[OFFSET(425)] AS d425,
# title_embed[OFFSET(426)] AS d426,
# title_embed[OFFSET(427)] AS d427,
# title_embed[OFFSET(428)] AS d428,
# title_embed[OFFSET(429)] AS d429,
# title_embed[OFFSET(430)] AS d430,
# title_embed[OFFSET(431)] AS d431,
# title_embed[OFFSET(432)] AS d432,
# title_embed[OFFSET(433)] AS d433,
# title_embed[OFFSET(434)] AS d434,
# title_embed[OFFSET(435)] AS d435,
# title_embed[OFFSET(436)] AS d436,
# title_embed[OFFSET(437)] AS d437,
# title_embed[OFFSET(438)] AS d438,
# title_embed[OFFSET(439)] AS d439,
# title_embed[OFFSET(440)] AS d440,
# title_embed[OFFSET(441)] AS d441,
# title_embed[OFFSET(442)] AS d442,
# title_embed[OFFSET(443)] AS d443,
# title_embed[OFFSET(444)] AS d444,
# title_embed[OFFSET(445)] AS d445,
# title_embed[OFFSET(446)] AS d446,
# title_embed[OFFSET(447)] AS d447,
# title_embed[OFFSET(448)] AS d448,
# title_embed[OFFSET(449)] AS d449,
# title_embed[OFFSET(450)] AS d450,
# title_embed[OFFSET(451)] AS d451,
# title_embed[OFFSET(452)] AS d452,
# title_embed[OFFSET(453)] AS d453,
# title_embed[OFFSET(454)] AS d454,
# title_embed[OFFSET(455)] AS d455,
# title_embed[OFFSET(456)] AS d456,
# title_embed[OFFSET(457)] AS d457,
# title_embed[OFFSET(458)] AS d458,
# title_embed[OFFSET(459)] AS d459,
# title_embed[OFFSET(460)] AS d460,
# title_embed[OFFSET(461)] AS d461,
# title_embed[OFFSET(462)] AS d462,
# title_embed[OFFSET(463)] AS d463,
# title_embed[OFFSET(464)] AS d464,
# title_embed[OFFSET(465)] AS d465,
# title_embed[OFFSET(466)] AS d466,
# title_embed[OFFSET(467)] AS d467,
# title_embed[OFFSET(468)] AS d468,
# title_embed[OFFSET(469)] AS d469,
# title_embed[OFFSET(470)] AS d470,
# title_embed[OFFSET(471)] AS d471,
# title_embed[OFFSET(472)] AS d472,
# title_embed[OFFSET(473)] AS d473,
# title_embed[OFFSET(474)] AS d474,
# title_embed[OFFSET(475)] AS d475,
# title_embed[OFFSET(476)] AS d476,
# title_embed[OFFSET(477)] AS d477,
# title_embed[OFFSET(478)] AS d478,
# title_embed[OFFSET(479)] AS d479,
# title_embed[OFFSET(480)] AS d480,
# title_embed[OFFSET(481)] AS d481,
# title_embed[OFFSET(482)] AS d482,
# title_embed[OFFSET(483)] AS d483,
# title_embed[OFFSET(484)] AS d484,
# title_embed[OFFSET(485)] AS d485,
# title_embed[OFFSET(486)] AS d486,
# title_embed[OFFSET(487)] AS d487,
# title_embed[OFFSET(488)] AS d488,
# title_embed[OFFSET(489)] AS d489,
# title_embed[OFFSET(490)] AS d490,
# title_embed[OFFSET(491)] AS d491,
# title_embed[OFFSET(492)] AS d492,
# title_embed[OFFSET(493)] AS d493,
# title_embed[OFFSET(494)] AS d494,
# title_embed[OFFSET(495)] AS d495,
# title_embed[OFFSET(496)] AS d496,
# title_embed[OFFSET(497)] AS d497,
# title_embed[OFFSET(498)] AS d498,
# title_embed[OFFSET(499)] AS d499,
# title_embed[OFFSET(500)] AS d500,
# title_embed[OFFSET(501)] AS d501,
# title_embed[OFFSET(502)] AS d502,
# title_embed[OFFSET(503)] AS d503,
# title_embed[OFFSET(504)] AS d504,
# title_embed[OFFSET(505)] AS d505,
# title_embed[OFFSET(506)] AS d506,
# title_embed[OFFSET(507)] AS d507,
# title_embed[OFFSET(508)] AS d508,
# title_embed[OFFSET(509)] AS d509,
# title_embed[OFFSET(510)] AS d510,
# title_embed[OFFSET(511)] AS d511,
#
# FROM `springer-nature-analytics.DS_dimensions.publications_full_refresh`
# LEFT JOIN UNNEST(`for`) AS f LEFT JOIN UNNEST(journal) AS j
# WHERE ARRAY_LENGTH(title_embed) = 512
# AND
# publication_type LIKE "article"
#         AND j.title IN (SELECT title FROM `springer-nature-analytics.core_journals.core_2018_v01`)
#         AND year >= 2011
#         AND year <= 2013
#         AND language LIKE "en"
#         AND ARRAY_LENGTH(references) > 4
#
# ) GROUP BY f2
#  ) WHERE f2 IS NOT NULL

# %%
train_and_save(for_11_13, "wv_11_13", "f2")
# Out:
# Saved mean vectors to "/content/drive/My Drive/Research/Data/Mean-title-centroids-3yrs-v02/wv_11_13_f2.csv"

# %% [markdown]
# # 2008-2010

# %%
# %%bigquery --project $pid for_08_10
#
# SELECT * FROM (
# SELECT fc,
#
# AVG(d0) AS d0_mean,
# AVG(d1) AS d1_mean,
# AVG(d2) AS d2_mean,
# AVG(d3) AS d3_mean,
# AVG(d4) AS d4_mean,
# AVG(d5) AS d5_mean,
# AVG(d6) AS d6_mean,
# AVG(d7) AS d7_mean,
# AVG(d8) AS d8_mean,
# AVG(d9) AS d9_mean,
# AVG(d10) AS d10_mean,
# AVG(d11) AS d11_mean,
# AVG(d12) AS d12_mean,
# AVG(d13) AS d13_mean,
# AVG(d14) AS d14_mean,
# AVG(d15) AS d15_mean,
# AVG(d16) AS d16_mean,
# AVG(d17) AS d17_mean,
# AVG(d18) AS d18_mean,
# AVG(d19) AS d19_mean,
# AVG(d20) AS d20_mean,
# AVG(d21) AS d21_mean,
# AVG(d22) AS d22_mean,
# AVG(d23) AS d23_mean,
# AVG(d24) AS d24_mean,
# AVG(d25) AS d25_mean,
# AVG(d26) AS d26_mean,
# AVG(d27) AS d27_mean,
# AVG(d28) AS d28_mean,
# AVG(d29) AS d29_mean,
# AVG(d30) AS d30_mean,
# AVG(d31) AS d31_mean,
# AVG(d32) AS d32_mean,
# AVG(d33) AS d33_mean,
# AVG(d34) AS d34_mean,
# AVG(d35) AS d35_mean,
# AVG(d36) AS d36_mean,
# AVG(d37) AS d37_mean,
# AVG(d38) AS d38_mean,
# AVG(d39) AS d39_mean,
# AVG(d40) AS d40_mean,
# AVG(d41) AS d41_mean,
# AVG(d42) AS d42_mean,
# AVG(d43) AS d43_mean,
# AVG(d44) AS d44_mean,
# AVG(d45) AS d45_mean,
# AVG(d46) AS d46_mean,
# AVG(d47) AS d47_mean,
# AVG(d48) AS d48_mean,
# AVG(d49) AS d49_mean,
# AVG(d50) AS d50_mean,
# AVG(d51) AS d51_mean,
# AVG(d52) AS d52_mean,
# AVG(d53) AS d53_mean,
# AVG(d54) AS d54_mean,
# AVG(d55) AS d55_mean,
# AVG(d56) AS d56_mean,
# AVG(d57) AS d57_mean,
# AVG(d58) AS d58_mean,
# AVG(d59) AS d59_mean,
# AVG(d60) AS d60_mean,
# AVG(d61) AS d61_mean,
# AVG(d62) AS d62_mean,
# AVG(d63) AS d63_mean,
# AVG(d64) AS d64_mean,
# AVG(d65) AS d65_mean,
# AVG(d66) AS d66_mean,
# AVG(d67) AS d67_mean,
# AVG(d68) AS d68_mean,
# AVG(d69) AS d69_mean,
# AVG(d70) AS d70_mean,
# AVG(d71) AS d71_mean,
# AVG(d72) AS d72_mean,
# AVG(d73) AS d73_mean,
# AVG(d74) AS d74_mean,
# AVG(d75) AS d75_mean,
# AVG(d76) AS d76_mean,
# AVG(d77) AS d77_mean,
# AVG(d78) AS d78_mean,
# AVG(d79) AS d79_mean,
# AVG(d80) AS d80_mean,
# AVG(d81) AS d81_mean,
# AVG(d82) AS d82_mean,
# AVG(d83) AS d83_mean,
# AVG(d84) AS d84_mean,
# AVG(d85) AS d85_mean,
# AVG(d86) AS d86_mean,
# AVG(d87) AS d87_mean,
# AVG(d88) AS d88_mean,
# AVG(d89) AS d89_mean,
# AVG(d90) AS d90_mean,
# AVG(d91) AS d91_mean,
# AVG(d92) AS d92_mean,
# AVG(d93) AS d93_mean,
# AVG(d94) AS d94_mean,
# AVG(d95) AS d95_mean,
# AVG(d96) AS d96_mean,
# AVG(d97) AS d97_mean,
# AVG(d98) AS d98_mean,
# AVG(d99) AS d99_mean,
# AVG(d100) AS d100_mean,
# AVG(d101) AS d101_mean,
# AVG(d102) AS d102_mean,
# AVG(d103) AS d103_mean,
# AVG(d104) AS d104_mean,
# AVG(d105) AS d105_mean,
# AVG(d106) AS d106_mean,
# AVG(d107) AS d107_mean,
# AVG(d108) AS d108_mean,
# AVG(d109) AS d109_mean,
# AVG(d110) AS d110_mean,
# AVG(d111) AS d111_mean,
# AVG(d112) AS d112_mean,
# AVG(d113) AS d113_mean,
# AVG(d114) AS d114_mean,
# AVG(d115) AS d115_mean,
# AVG(d116) AS d116_mean,
# AVG(d117) AS d117_mean,
# AVG(d118) AS d118_mean,
# AVG(d119) AS d119_mean,
# AVG(d120) AS d120_mean,
# AVG(d121) AS d121_mean,
# AVG(d122) AS d122_mean,
# AVG(d123) AS d123_mean,
# AVG(d124) AS d124_mean,
# AVG(d125) AS d125_mean,
# AVG(d126) AS d126_mean,
# AVG(d127) AS d127_mean,
# AVG(d128) AS d128_mean,
# AVG(d129) AS d129_mean,
# AVG(d130) AS d130_mean,
# AVG(d131) AS d131_mean,
# AVG(d132) AS d132_mean,
# AVG(d133) AS d133_mean,
# AVG(d134) AS d134_mean,
# AVG(d135) AS d135_mean,
# AVG(d136) AS d136_mean,
# AVG(d137) AS d137_mean,
# AVG(d138) AS d138_mean,
# AVG(d139) AS d139_mean,
# AVG(d140) AS d140_mean,
# AVG(d141) AS d141_mean,
# AVG(d142) AS d142_mean,
# AVG(d143) AS d143_mean,
# AVG(d144) AS d144_mean,
# AVG(d145) AS d145_mean,
# AVG(d146) AS d146_mean,
# AVG(d147) AS d147_mean,
# AVG(d148) AS d148_mean,
# AVG(d149) AS d149_mean,
# AVG(d150) AS d150_mean,
# AVG(d151) AS d151_mean,
# AVG(d152) AS d152_mean,
# AVG(d153) AS d153_mean,
# AVG(d154) AS d154_mean,
# AVG(d155) AS d155_mean,
# AVG(d156) AS d156_mean,
# AVG(d157) AS d157_mean,
# AVG(d158) AS d158_mean,
# AVG(d159) AS d159_mean,
# AVG(d160) AS d160_mean,
# AVG(d161) AS d161_mean,
# AVG(d162) AS d162_mean,
# AVG(d163) AS d163_mean,
# AVG(d164) AS d164_mean,
# AVG(d165) AS d165_mean,
# AVG(d166) AS d166_mean,
# AVG(d167) AS d167_mean,
# AVG(d168) AS d168_mean,
# AVG(d169) AS d169_mean,
# AVG(d170) AS d170_mean,
# AVG(d171) AS d171_mean,
# AVG(d172) AS d172_mean,
# AVG(d173) AS d173_mean,
# AVG(d174) AS d174_mean,
# AVG(d175) AS d175_mean,
# AVG(d176) AS d176_mean,
# AVG(d177) AS d177_mean,
# AVG(d178) AS d178_mean,
# AVG(d179) AS d179_mean,
# AVG(d180) AS d180_mean,
# AVG(d181) AS d181_mean,
# AVG(d182) AS d182_mean,
# AVG(d183) AS d183_mean,
# AVG(d184) AS d184_mean,
# AVG(d185) AS d185_mean,
# AVG(d186) AS d186_mean,
# AVG(d187) AS d187_mean,
# AVG(d188) AS d188_mean,
# AVG(d189) AS d189_mean,
# AVG(d190) AS d190_mean,
# AVG(d191) AS d191_mean,
# AVG(d192) AS d192_mean,
# AVG(d193) AS d193_mean,
# AVG(d194) AS d194_mean,
# AVG(d195) AS d195_mean,
# AVG(d196) AS d196_mean,
# AVG(d197) AS d197_mean,
# AVG(d198) AS d198_mean,
# AVG(d199) AS d199_mean,
# AVG(d200) AS d200_mean,
# AVG(d201) AS d201_mean,
# AVG(d202) AS d202_mean,
# AVG(d203) AS d203_mean,
# AVG(d204) AS d204_mean,
# AVG(d205) AS d205_mean,
# AVG(d206) AS d206_mean,
# AVG(d207) AS d207_mean,
# AVG(d208) AS d208_mean,
# AVG(d209) AS d209_mean,
# AVG(d210) AS d210_mean,
# AVG(d211) AS d211_mean,
# AVG(d212) AS d212_mean,
# AVG(d213) AS d213_mean,
# AVG(d214) AS d214_mean,
# AVG(d215) AS d215_mean,
# AVG(d216) AS d216_mean,
# AVG(d217) AS d217_mean,
# AVG(d218) AS d218_mean,
# AVG(d219) AS d219_mean,
# AVG(d220) AS d220_mean,
# AVG(d221) AS d221_mean,
# AVG(d222) AS d222_mean,
# AVG(d223) AS d223_mean,
# AVG(d224) AS d224_mean,
# AVG(d225) AS d225_mean,
# AVG(d226) AS d226_mean,
# AVG(d227) AS d227_mean,
# AVG(d228) AS d228_mean,
# AVG(d229) AS d229_mean,
# AVG(d230) AS d230_mean,
# AVG(d231) AS d231_mean,
# AVG(d232) AS d232_mean,
# AVG(d233) AS d233_mean,
# AVG(d234) AS d234_mean,
# AVG(d235) AS d235_mean,
# AVG(d236) AS d236_mean,
# AVG(d237) AS d237_mean,
# AVG(d238) AS d238_mean,
# AVG(d239) AS d239_mean,
# AVG(d240) AS d240_mean,
# AVG(d241) AS d241_mean,
# AVG(d242) AS d242_mean,
# AVG(d243) AS d243_mean,
# AVG(d244) AS d244_mean,
# AVG(d245) AS d245_mean,
# AVG(d246) AS d246_mean,
# AVG(d247) AS d247_mean,
# AVG(d248) AS d248_mean,
# AVG(d249) AS d249_mean,
# AVG(d250) AS d250_mean,
# AVG(d251) AS d251_mean,
# AVG(d252) AS d252_mean,
# AVG(d253) AS d253_mean,
# AVG(d254) AS d254_mean,
# AVG(d255) AS d255_mean,
# AVG(d256) AS d256_mean,
# AVG(d257) AS d257_mean,
# AVG(d258) AS d258_mean,
# AVG(d259) AS d259_mean,
# AVG(d260) AS d260_mean,
# AVG(d261) AS d261_mean,
# AVG(d262) AS d262_mean,
# AVG(d263) AS d263_mean,
# AVG(d264) AS d264_mean,
# AVG(d265) AS d265_mean,
# AVG(d266) AS d266_mean,
# AVG(d267) AS d267_mean,
# AVG(d268) AS d268_mean,
# AVG(d269) AS d269_mean,
# AVG(d270) AS d270_mean,
# AVG(d271) AS d271_mean,
# AVG(d272) AS d272_mean,
# AVG(d273) AS d273_mean,
# AVG(d274) AS d274_mean,
# AVG(d275) AS d275_mean,
# AVG(d276) AS d276_mean,
# AVG(d277) AS d277_mean,
# AVG(d278) AS d278_mean,
# AVG(d279) AS d279_mean,
# AVG(d280) AS d280_mean,
# AVG(d281) AS d281_mean,
# AVG(d282) AS d282_mean,
# AVG(d283) AS d283_mean,
# AVG(d284) AS d284_mean,
# AVG(d285) AS d285_mean,
# AVG(d286) AS d286_mean,
# AVG(d287) AS d287_mean,
# AVG(d288) AS d288_mean,
# AVG(d289) AS d289_mean,
# AVG(d290) AS d290_mean,
# AVG(d291) AS d291_mean,
# AVG(d292) AS d292_mean,
# AVG(d293) AS d293_mean,
# AVG(d294) AS d294_mean,
# AVG(d295) AS d295_mean,
# AVG(d296) AS d296_mean,
# AVG(d297) AS d297_mean,
# AVG(d298) AS d298_mean,
# AVG(d299) AS d299_mean,
# AVG(d300) AS d300_mean,
# AVG(d301) AS d301_mean,
# AVG(d302) AS d302_mean,
# AVG(d303) AS d303_mean,
# AVG(d304) AS d304_mean,
# AVG(d305) AS d305_mean,
# AVG(d306) AS d306_mean,
# AVG(d307) AS d307_mean,
# AVG(d308) AS d308_mean,
# AVG(d309) AS d309_mean,
# AVG(d310) AS d310_mean,
# AVG(d311) AS d311_mean,
# AVG(d312) AS d312_mean,
# AVG(d313) AS d313_mean,
# AVG(d314) AS d314_mean,
# AVG(d315) AS d315_mean,
# AVG(d316) AS d316_mean,
# AVG(d317) AS d317_mean,
# AVG(d318) AS d318_mean,
# AVG(d319) AS d319_mean,
# AVG(d320) AS d320_mean,
# AVG(d321) AS d321_mean,
# AVG(d322) AS d322_mean,
# AVG(d323) AS d323_mean,
# AVG(d324) AS d324_mean,
# AVG(d325) AS d325_mean,
# AVG(d326) AS d326_mean,
# AVG(d327) AS d327_mean,
# AVG(d328) AS d328_mean,
# AVG(d329) AS d329_mean,
# AVG(d330) AS d330_mean,
# AVG(d331) AS d331_mean,
# AVG(d332) AS d332_mean,
# AVG(d333) AS d333_mean,
# AVG(d334) AS d334_mean,
# AVG(d335) AS d335_mean,
# AVG(d336) AS d336_mean,
# AVG(d337) AS d337_mean,
# AVG(d338) AS d338_mean,
# AVG(d339) AS d339_mean,
# AVG(d340) AS d340_mean,
# AVG(d341) AS d341_mean,
# AVG(d342) AS d342_mean,
# AVG(d343) AS d343_mean,
# AVG(d344) AS d344_mean,
# AVG(d345) AS d345_mean,
# AVG(d346) AS d346_mean,
# AVG(d347) AS d347_mean,
# AVG(d348) AS d348_mean,
# AVG(d349) AS d349_mean,
# AVG(d350) AS d350_mean,
# AVG(d351) AS d351_mean,
# AVG(d352) AS d352_mean,
# AVG(d353) AS d353_mean,
# AVG(d354) AS d354_mean,
# AVG(d355) AS d355_mean,
# AVG(d356) AS d356_mean,
# AVG(d357) AS d357_mean,
# AVG(d358) AS d358_mean,
# AVG(d359) AS d359_mean,
# AVG(d360) AS d360_mean,
# AVG(d361) AS d361_mean,
# AVG(d362) AS d362_mean,
# AVG(d363) AS d363_mean,
# AVG(d364) AS d364_mean,
# AVG(d365) AS d365_mean,
# AVG(d366) AS d366_mean,
# AVG(d367) AS d367_mean,
# AVG(d368) AS d368_mean,
# AVG(d369) AS d369_mean,
# AVG(d370) AS d370_mean,
# AVG(d371) AS d371_mean,
# AVG(d372) AS d372_mean,
# AVG(d373) AS d373_mean,
# AVG(d374) AS d374_mean,
# AVG(d375) AS d375_mean,
# AVG(d376) AS d376_mean,
# AVG(d377) AS d377_mean,
# AVG(d378) AS d378_mean,
# AVG(d379) AS d379_mean,
# AVG(d380) AS d380_mean,
# AVG(d381) AS d381_mean,
# AVG(d382) AS d382_mean,
# AVG(d383) AS d383_mean,
# AVG(d384) AS d384_mean,
# AVG(d385) AS d385_mean,
# AVG(d386) AS d386_mean,
# AVG(d387) AS d387_mean,
# AVG(d388) AS d388_mean,
# AVG(d389) AS d389_mean,
# AVG(d390) AS d390_mean,
# AVG(d391) AS d391_mean,
# AVG(d392) AS d392_mean,
# AVG(d393) AS d393_mean,
# AVG(d394) AS d394_mean,
# AVG(d395) AS d395_mean,
# AVG(d396) AS d396_mean,
# AVG(d397) AS d397_mean,
# AVG(d398) AS d398_mean,
# AVG(d399) AS d399_mean,
# AVG(d400) AS d400_mean,
# AVG(d401) AS d401_mean,
# AVG(d402) AS d402_mean,
# AVG(d403) AS d403_mean,
# AVG(d404) AS d404_mean,
# AVG(d405) AS d405_mean,
# AVG(d406) AS d406_mean,
# AVG(d407) AS d407_mean,
# AVG(d408) AS d408_mean,
# AVG(d409) AS d409_mean,
# AVG(d410) AS d410_mean,
# AVG(d411) AS d411_mean,
# AVG(d412) AS d412_mean,
# AVG(d413) AS d413_mean,
# AVG(d414) AS d414_mean,
# AVG(d415) AS d415_mean,
# AVG(d416) AS d416_mean,
# AVG(d417) AS d417_mean,
# AVG(d418) AS d418_mean,
# AVG(d419) AS d419_mean,
# AVG(d420) AS d420_mean,
# AVG(d421) AS d421_mean,
# AVG(d422) AS d422_mean,
# AVG(d423) AS d423_mean,
# AVG(d424) AS d424_mean,
# AVG(d425) AS d425_mean,
# AVG(d426) AS d426_mean,
# AVG(d427) AS d427_mean,
# AVG(d428) AS d428_mean,
# AVG(d429) AS d429_mean,
# AVG(d430) AS d430_mean,
# AVG(d431) AS d431_mean,
# AVG(d432) AS d432_mean,
# AVG(d433) AS d433_mean,
# AVG(d434) AS d434_mean,
# AVG(d435) AS d435_mean,
# AVG(d436) AS d436_mean,
# AVG(d437) AS d437_mean,
# AVG(d438) AS d438_mean,
# AVG(d439) AS d439_mean,
# AVG(d440) AS d440_mean,
# AVG(d441) AS d441_mean,
# AVG(d442) AS d442_mean,
# AVG(d443) AS d443_mean,
# AVG(d444) AS d444_mean,
# AVG(d445) AS d445_mean,
# AVG(d446) AS d446_mean,
# AVG(d447) AS d447_mean,
# AVG(d448) AS d448_mean,
# AVG(d449) AS d449_mean,
# AVG(d450) AS d450_mean,
# AVG(d451) AS d451_mean,
# AVG(d452) AS d452_mean,
# AVG(d453) AS d453_mean,
# AVG(d454) AS d454_mean,
# AVG(d455) AS d455_mean,
# AVG(d456) AS d456_mean,
# AVG(d457) AS d457_mean,
# AVG(d458) AS d458_mean,
# AVG(d459) AS d459_mean,
# AVG(d460) AS d460_mean,
# AVG(d461) AS d461_mean,
# AVG(d462) AS d462_mean,
# AVG(d463) AS d463_mean,
# AVG(d464) AS d464_mean,
# AVG(d465) AS d465_mean,
# AVG(d466) AS d466_mean,
# AVG(d467) AS d467_mean,
# AVG(d468) AS d468_mean,
# AVG(d469) AS d469_mean,
# AVG(d470) AS d470_mean,
# AVG(d471) AS d471_mean,
# AVG(d472) AS d472_mean,
# AVG(d473) AS d473_mean,
# AVG(d474) AS d474_mean,
# AVG(d475) AS d475_mean,
# AVG(d476) AS d476_mean,
# AVG(d477) AS d477_mean,
# AVG(d478) AS d478_mean,
# AVG(d479) AS d479_mean,
# AVG(d480) AS d480_mean,
# AVG(d481) AS d481_mean,
# AVG(d482) AS d482_mean,
# AVG(d483) AS d483_mean,
# AVG(d484) AS d484_mean,
# AVG(d485) AS d485_mean,
# AVG(d486) AS d486_mean,
# AVG(d487) AS d487_mean,
# AVG(d488) AS d488_mean,
# AVG(d489) AS d489_mean,
# AVG(d490) AS d490_mean,
# AVG(d491) AS d491_mean,
# AVG(d492) AS d492_mean,
# AVG(d493) AS d493_mean,
# AVG(d494) AS d494_mean,
# AVG(d495) AS d495_mean,
# AVG(d496) AS d496_mean,
# AVG(d497) AS d497_mean,
# AVG(d498) AS d498_mean,
# AVG(d499) AS d499_mean,
# AVG(d500) AS d500_mean,
# AVG(d501) AS d501_mean,
# AVG(d502) AS d502_mean,
# AVG(d503) AS d503_mean,
# AVG(d504) AS d504_mean,
# AVG(d505) AS d505_mean,
# AVG(d506) AS d506_mean,
# AVG(d507) AS d507_mean,
# AVG(d508) AS d508_mean,
# AVG(d509) AS d509_mean,
# AVG(d510) AS d510_mean,
# AVG(d511) AS d511_mean,
#
# FROM (
# SELECT f.first_level.name AS fc,
#
# title_embed[OFFSET(0)] AS d0,
# title_embed[OFFSET(1)] AS d1,
# title_embed[OFFSET(2)] AS d2,
# title_embed[OFFSET(3)] AS d3,
# title_embed[OFFSET(4)] AS d4,
# title_embed[OFFSET(5)] AS d5,
# title_embed[OFFSET(6)] AS d6,
# title_embed[OFFSET(7)] AS d7,
# title_embed[OFFSET(8)] AS d8,
# title_embed[OFFSET(9)] AS d9,
# title_embed[OFFSET(10)] AS d10,
# title_embed[OFFSET(11)] AS d11,
# title_embed[OFFSET(12)] AS d12,
# title_embed[OFFSET(13)] AS d13,
# title_embed[OFFSET(14)] AS d14,
# title_embed[OFFSET(15)] AS d15,
# title_embed[OFFSET(16)] AS d16,
# title_embed[OFFSET(17)] AS d17,
# title_embed[OFFSET(18)] AS d18,
# title_embed[OFFSET(19)] AS d19,
# title_embed[OFFSET(20)] AS d20,
# title_embed[OFFSET(21)] AS d21,
# title_embed[OFFSET(22)] AS d22,
# title_embed[OFFSET(23)] AS d23,
# title_embed[OFFSET(24)] AS d24,
# title_embed[OFFSET(25)] AS d25,
# title_embed[OFFSET(26)] AS d26,
# title_embed[OFFSET(27)] AS d27,
# title_embed[OFFSET(28)] AS d28,
# title_embed[OFFSET(29)] AS d29,
# title_embed[OFFSET(396)] AS d396,
# title_embed[OFFSET(397)] AS d397,
# title_embed[OFFSET(398)] AS d398,
# title_embed[OFFSET(399)] AS d399,
# title_embed[OFFSET(400)] AS d400,
# title_embed[OFFSET(401)] AS d401,
# title_embed[OFFSET(402)] AS d402,
# title_embed[OFFSET(403)] AS d403,
# title_embed[OFFSET(404)] AS d404,
# title_embed[OFFSET(405)] AS d405,
# title_embed[OFFSET(406)] AS d406,
# title_embed[OFFSET(407)] AS d407,
# title_embed[OFFSET(408)] AS d408,
# title_embed[OFFSET(409)] AS d409,
# title_embed[OFFSET(410)] AS d410,
# title_embed[OFFSET(411)] AS d411,
# title_embed[OFFSET(412)] AS d412,
# title_embed[OFFSET(413)] AS d413,
# title_embed[OFFSET(414)] AS d414,
# title_embed[OFFSET(415)] AS d415,
# title_embed[OFFSET(416)] AS d416,
# title_embed[OFFSET(417)] AS d417,
# title_embed[OFFSET(418)] AS d418,
# title_embed[OFFSET(419)] AS d419,
# title_embed[OFFSET(420)] AS d420,
# title_embed[OFFSET(421)] AS d421,
# title_embed[OFFSET(422)] AS d422,
# title_embed[OFFSET(423)] AS d423,
# title_embed[OFFSET(424)] AS d424,
# title_embed[OFFSET(425)] AS d425,
# title_embed[OFFSET(426)] AS d426,
# title_embed[OFFSET(427)] AS d427,
# title_embed[OFFSET(428)] AS d428,
# title_embed[OFFSET(429)] AS d429,
# title_embed[OFFSET(430)] AS d430,
# title_embed[OFFSET(431)] AS d431,
# title_embed[OFFSET(432)] AS d432,
# title_embed[OFFSET(433)] AS d433,
# title_embed[OFFSET(434)] AS d434,
# title_embed[OFFSET(435)] AS d435,
# title_embed[OFFSET(436)] AS d436,
# title_embed[OFFSET(437)] AS d437,
# title_embed[OFFSET(438)] AS d438,
# title_embed[OFFSET(439)] AS d439,
# title_embed[OFFSET(440)] AS d440,
# title_embed[OFFSET(441)] AS d441,
# title_embed[OFFSET(442)] AS d442,
# title_embed[OFFSET(443)] AS d443,
# title_embed[OFFSET(444)] AS d444,
# title_embed[OFFSET(445)] AS d445,
# title_embed[OFFSET(446)] AS d446,
# title_embed[OFFSET(447)] AS d447,
# title_embed[OFFSET(448)] AS d448,
# title_embed[OFFSET(449)] AS d449,
# title_embed[OFFSET(450)] AS d450,
# title_embed[OFFSET(451)] AS d451,
# title_embed[OFFSET(452)] AS d452,
# title_embed[OFFSET(453)] AS d453,
# title_embed[OFFSET(454)] AS d454,
# title_embed[OFFSET(455)] AS d455,
# title_embed[OFFSET(456)] AS d456,
# title_embed[OFFSET(457)] AS d457,
# title_embed[OFFSET(458)] AS d458,
# title_embed[OFFSET(459)] AS d459,
# title_embed[OFFSET(460)] AS d460,
# title_embed[OFFSET(461)] AS d461,
# title_embed[OFFSET(462)] AS d462,
# title_embed[OFFSET(463)] AS d463,
# title_embed[OFFSET(464)] AS d464,
# title_embed[OFFSET(465)] AS d465,
# title_embed[OFFSET(466)] AS d466,
# title_embed[OFFSET(467)] AS d467,
# title_embed[OFFSET(468)] AS d468,
# title_embed[OFFSET(469)] AS d469,
# title_embed[OFFSET(470)] AS d470,
# title_embed[OFFSET(471)] AS d471,
# title_embed[OFFSET(472)] AS d472,
# title_embed[OFFSET(473)] AS d473,
# title_embed[OFFSET(474)] AS d474,
# title_embed[OFFSET(475)] AS d475,
# title_embed[OFFSET(476)] AS d476,
# title_embed[OFFSET(477)] AS d477,
# title_embed[OFFSET(478)] AS d478,
# title_embed[OFFSET(479)] AS d479,
# title_embed[OFFSET(480)] AS d480,
# title_embed[OFFSET(481)] AS d481,
# title_embed[OFFSET(482)] AS d482,
# title_embed[OFFSET(483)] AS d483,
# title_embed[OFFSET(484)] AS d484,
# title_embed[OFFSET(485)] AS d485,
# title_embed[OFFSET(486)] AS d486,
# title_embed[OFFSET(487)] AS d487,
# title_embed[OFFSET(488)] AS d488,
# title_embed[OFFSET(489)] AS d489,
# title_embed[OFFSET(490)] AS d490,
# title_embed[OFFSET(491)] AS d491,
# title_embed[OFFSET(492)] AS d492,
# title_embed[OFFSET(493)] AS d493,
# title_embed[OFFSET(494)] AS d494,
# title_embed[OFFSET(495)] AS d495,
# title_embed[OFFSET(496)] AS d496,
# title_embed[OFFSET(497)] AS d497,
# title_embed[OFFSET(498)] AS d498,
# title_embed[OFFSET(499)] AS d499,
# title_embed[OFFSET(500)] AS d500,
# title_embed[OFFSET(501)] AS d501,
# title_embed[OFFSET(502)] AS d502,
# title_embed[OFFSET(503)] AS d503,
# title_embed[OFFSET(504)] AS d504,
# title_embed[OFFSET(505)] AS d505,
# title_embed[OFFSET(506)] AS d506,
# title_embed[OFFSET(507)] AS d507,
# title_embed[OFFSET(508)] AS d508,
# title_embed[OFFSET(509)] AS d509,
# title_embed[OFFSET(510)] AS d510,
# title_embed[OFFSET(511)] AS d511,
#
# FROM `springer-nature-analytics.DS_dimensions.publications_full_refresh`
# LEFT JOIN UNNEST(`for`) AS f LEFT JOIN UNNEST(journal) AS j
# WHERE ARRAY_LENGTH(title_embed) = 512
# AND
# publication_type LIKE "article"
#         AND j.title IN (SELECT title FROM `springer-nature-analytics.core_journals.core_2018_v01`)
#         AND year >= 2008
#         AND year <= 2010
#         AND language LIKE "en"
#         AND ARRAY_LENGTH(references) > 4
#
# ) GROUP BY fc
#  ) WHERE fc IS NOT NULL

# %%
train_and_save(for_08_10, "wv_08_10")
# Out:
# Saved mean vectors to "/content/drive/My Drive/Research/Data/Mean-title-centroids-3yrs-v02/wv_08_10_f1.csv"

# %%
# %%bigquery --project $pid for_08_10
#
# SELECT * FROM (
# SELECT fc,
#
# AVG(d0) AS d0_mean,
# AVG(d1) AS d1_mean,
# AVG(d2) AS d2_mean,
# AVG(d3) AS d3_mean,
# AVG(d4) AS d4_mean,
# AVG(d5) AS d5_mean,
# AVG(d6) AS d6_mean,
# AVG(d7) AS d7_mean,
# AVG(d8) AS d8_mean,
# AVG(d9) AS d9_mean,
# AVG(d10) AS d10_mean,
# AVG(d11) AS d11_mean,
# AVG(d12) AS d12_mean,
# AVG(d13) AS d13_mean,
# AVG(d14) AS d14_mean,
# AVG(d15) AS d15_mean,
# AVG(d16) AS d16_mean,
# AVG(d17) AS d17_mean,
# AVG(d18) AS d18_mean,
# AVG(d19) AS d19_mean,
# AVG(d20) AS d20_mean,
# AVG(d21) AS d21_mean,
# AVG(d22) AS d22_mean,
# AVG(d23) AS d23_mean,
# AVG(d24) AS d24_mean,
# AVG(d25) AS d25_mean,
# AVG(d26) AS d26_mean,
# AVG(d27) AS d27_mean,
# AVG(d28) AS d28_mean,
# AVG(d29) AS d29_mean,
# AVG(d30) AS d30_mean,
# AVG(d31) AS d31_mean,
# AVG(d32) AS d32_mean,
# AVG(d33) AS d33_mean,
# AVG(d34) AS d34_mean,
# AVG(d35) AS d35_mean,
# AVG(d36) AS d36_mean,
# AVG(d37) AS d37_mean,
# AVG(d38) AS d38_mean,
# AVG(d39) AS d39_mean,
# AVG(d40) AS d40_mean,
# AVG(d41) AS d41_mean,
# AVG(d42) AS d42_mean,
# AVG(d43) AS d43_mean,
# AVG(d44) AS d44_mean,
# AVG(d45) AS d45_mean,
# AVG(d46) AS d46_mean,
# AVG(d47) AS d47_mean,
# AVG(d48) AS d48_mean,
# AVG(d49) AS d49_mean,
# AVG(d50) AS d50_mean,
# AVG(d51) AS d51_mean,
# AVG(d52) AS d52_mean,
# AVG(d53) AS d53_mean,
# AVG(d54) AS d54_mean,
# AVG(d55) AS d55_mean,
# AVG(d56) AS d56_mean,
# AVG(d57) AS d57_mean,
# AVG(d58) AS d58_mean,
# AVG(d59) AS d59_mean,
# AVG(d60) AS d60_mean,
# AVG(d61) AS d61_mean,
# AVG(d62) AS d62_mean,
# AVG(d63) AS d63_mean,
# AVG(d64) AS d64_mean,
# AVG(d65) AS d65_mean,
# AVG(d66) AS d66_mean,
# AVG(d67) AS d67_mean,
# AVG(d68) AS d68_mean,
# AVG(d69) AS d69_mean,
# AVG(d70) AS d70_mean,
# AVG(d71) AS d71_mean,
# AVG(d72) AS d72_mean,
# AVG(d73) AS d73_mean,
# AVG(d74) AS d74_mean,
# AVG(d75) AS d75_mean,
# AVG(d76) AS d76_mean,
# AVG(d77) AS d77_mean,
# AVG(d78) AS d78_mean,
# AVG(d79) AS d79_mean,
# AVG(d80) AS d80_mean,
# AVG(d81) AS d81_mean,
# AVG(d82) AS d82_mean,
# AVG(d83) AS d83_mean,
# AVG(d84) AS d84_mean,
# AVG(d85) AS d85_mean,
# AVG(d86) AS d86_mean,
# AVG(d87) AS d87_mean,
# AVG(d88) AS d88_mean,
# AVG(d89) AS d89_mean,
# AVG(d90) AS d90_mean,
# AVG(d91) AS d91_mean,
# AVG(d92) AS d92_mean,
# AVG(d93) AS d93_mean,
# AVG(d94) AS d94_mean,
# AVG(d95) AS d95_mean,
# AVG(d96) AS d96_mean,
# AVG(d97) AS d97_mean,
# AVG(d98) AS d98_mean,
# AVG(d99) AS d99_mean,
# AVG(d100) AS d100_mean,
# AVG(d101) AS d101_mean,
# AVG(d102) AS d102_mean,
# AVG(d103) AS d103_mean,
# AVG(d104) AS d104_mean,
# AVG(d105) AS d105_mean,
# AVG(d106) AS d106_mean,
# AVG(d107) AS d107_mean,
# AVG(d108) AS d108_mean,
# AVG(d109) AS d109_mean,
# AVG(d110) AS d110_mean,
# AVG(d111) AS d111_mean,
# AVG(d112) AS d112_mean,
# AVG(d113) AS d113_mean,
# AVG(d114) AS d114_mean,
# AVG(d115) AS d115_mean,
# AVG(d116) AS d116_mean,
# AVG(d117) AS d117_mean,
# AVG(d118) AS d118_mean,
# AVG(d119) AS d119_mean,
# AVG(d120) AS d120_mean,
# AVG(d121) AS d121_mean,
# AVG(d122) AS d122_mean,
# AVG(d123) AS d123_mean,
# AVG(d124) AS d124_mean,
# AVG(d125) AS d125_mean,
# AVG(d126) AS d126_mean,
# AVG(d127) AS d127_mean,
# AVG(d128) AS d128_mean,
# AVG(d129) AS d129_mean,
# AVG(d130) AS d130_mean,
# AVG(d131) AS d131_mean,
# AVG(d132) AS d132_mean,
# AVG(d133) AS d133_mean,
# AVG(d134) AS d134_mean,
# AVG(d135) AS d135_mean,
# AVG(d136) AS d136_mean,
# AVG(d137) AS d137_mean,
# AVG(d138) AS d138_mean,
# AVG(d139) AS d139_mean,
# AVG(d140) AS d140_mean,
# AVG(d141) AS d141_mean,
# AVG(d142) AS d142_mean,
# AVG(d143) AS d143_mean,
# AVG(d144) AS d144_mean,
# AVG(d145) AS d145_mean,
# AVG(d146) AS d146_mean,
# AVG(d147) AS d147_mean,
# AVG(d148) AS d148_mean,
# AVG(d149) AS d149_mean,
# AVG(d150) AS d150_mean,
# AVG(d151) AS d151_mean,
# AVG(d152) AS d152_mean,
# AVG(d153) AS d153_mean,
# AVG(d154) AS d154_mean,
# AVG(d155) AS d155_mean,
# AVG(d156) AS d156_mean,
# AVG(d157) AS d157_mean,
# AVG(d158) AS d158_mean,
# AVG(d159) AS d159_mean,
# AVG(d160) AS d160_mean,
# AVG(d161) AS d161_mean,
# AVG(d162) AS d162_mean,
# AVG(d163) AS d163_mean,
# AVG(d164) AS d164_mean,
# AVG(d165) AS d165_mean,
# AVG(d166) AS d166_mean,
# AVG(d167) AS d167_mean,
# AVG(d168) AS d168_mean,
# AVG(d169) AS d169_mean,
# AVG(d170) AS d170_mean,
# AVG(d171) AS d171_mean,
# AVG(d172) AS d172_mean,
# AVG(d173) AS d173_mean,
# AVG(d174) AS d174_mean,
# AVG(d175) AS d175_mean,
# AVG(d176) AS d176_mean,
# AVG(d177) AS d177_mean,
# AVG(d178) AS d178_mean,
# AVG(d179) AS d179_mean,
# AVG(d180) AS d180_mean,
# AVG(d181) AS d181_mean,
# AVG(d182) AS d182_mean,
# AVG(d183) AS d183_mean,
# AVG(d184) AS d184_mean,
# AVG(d185) AS d185_mean,
# AVG(d186) AS d186_mean,
# AVG(d187) AS d187_mean,
# AVG(d188) AS d188_mean,
# AVG(d189) AS d189_mean,
# AVG(d190) AS d190_mean,
# AVG(d191) AS d191_mean,
# AVG(d192) AS d192_mean,
# AVG(d193) AS d193_mean,
# AVG(d194) AS d194_mean,
# AVG(d195) AS d195_mean,
# AVG(d196) AS d196_mean,
# AVG(d197) AS d197_mean,
# AVG(d198) AS d198_mean,
# AVG(d199) AS d199_mean,
# AVG(d200) AS d200_mean,
# AVG(d201) AS d201_mean,
# AVG(d202) AS d202_mean,
# AVG(d203) AS d203_mean,
# AVG(d204) AS d204_mean,
# AVG(d205) AS d205_mean,
# AVG(d206) AS d206_mean,
# AVG(d207) AS d207_mean,
# AVG(d208) AS d208_mean,
# AVG(d209) AS d209_mean,
# AVG(d210) AS d210_mean,
# AVG(d211) AS d211_mean,
# AVG(d212) AS d212_mean,
# AVG(d213) AS d213_mean,
# AVG(d214) AS d214_mean,
# AVG(d215) AS d215_mean,
# AVG(d216) AS d216_mean,
# AVG(d217) AS d217_mean,
# AVG(d218) AS d218_mean,
# AVG(d219) AS d219_mean,
# AVG(d220) AS d220_mean,
# AVG(d221) AS d221_mean,
# AVG(d222) AS d222_mean,
# AVG(d223) AS d223_mean,
# AVG(d224) AS d224_mean,
# AVG(d225) AS d225_mean,
# AVG(d226) AS d226_mean,
# AVG(d227) AS d227_mean,
# AVG(d228) AS d228_mean,
# AVG(d229) AS d229_mean,
# AVG(d230) AS d230_mean,
# AVG(d231) AS d231_mean,
# AVG(d232) AS d232_mean,
# AVG(d233) AS d233_mean,
# AVG(d234) AS d234_mean,
# AVG(d235) AS d235_mean,
# AVG(d236) AS d236_mean,
# AVG(d237) AS d237_mean,
# AVG(d238) AS d238_mean,
# AVG(d239) AS d239_mean,
# AVG(d240) AS d240_mean,
# AVG(d241) AS d241_mean,
# AVG(d242) AS d242_mean,
# AVG(d243) AS d243_mean,
# AVG(d244) AS d244_mean,
# AVG(d245) AS d245_mean,
# AVG(d246) AS d246_mean,
# AVG(d247) AS d247_mean,
# AVG(d248) AS d248_mean,
# AVG(d249) AS d249_mean,
# AVG(d250) AS d250_mean,
# AVG(d251) AS d251_mean,
# AVG(d252) AS d252_mean,
# AVG(d253) AS d253_mean,
# AVG(d254) AS d254_mean,
# AVG(d255) AS d255_mean,
# AVG(d256) AS d256_mean,
# AVG(d257) AS d257_mean,
# AVG(d258) AS d258_mean,
# AVG(d259) AS d259_mean,
# AVG(d260) AS d260_mean,
# AVG(d261) AS d261_mean,
# AVG(d262) AS d262_mean,
# AVG(d263) AS d263_mean,
# AVG(d264) AS d264_mean,
# AVG(d265) AS d265_mean,
# AVG(d266) AS d266_mean,
# AVG(d267) AS d267_mean,
# AVG(d268) AS d268_mean,
# AVG(d269) AS d269_mean,
# AVG(d270) AS d270_mean,
# AVG(d271) AS d271_mean,
# AVG(d272) AS d272_mean,
# AVG(d273) AS d273_mean,
# AVG(d274) AS d274_mean,
# AVG(d275) AS d275_mean,
# AVG(d276) AS d276_mean,
# AVG(d277) AS d277_mean,
# AVG(d278) AS d278_mean,
# AVG(d279) AS d279_mean,
# AVG(d280) AS d280_mean,
# AVG(d281) AS d281_mean,
# AVG(d282) AS d282_mean,
# AVG(d283) AS d283_mean,
# AVG(d284) AS d284_mean,
# AVG(d285) AS d285_mean,
# AVG(d286) AS d286_mean,
# AVG(d287) AS d287_mean,
# AVG(d288) AS d288_mean,
# AVG(d289) AS d289_mean,
# AVG(d290) AS d290_mean,
# AVG(d291) AS d291_mean,
# AVG(d292) AS d292_mean,
# AVG(d293) AS d293_mean,
# AVG(d294) AS d294_mean,
# AVG(d295) AS d295_mean,
# AVG(d296) AS d296_mean,
# AVG(d297) AS d297_mean,
# AVG(d298) AS d298_mean,
# AVG(d299) AS d299_mean,
# AVG(d300) AS d300_mean,
# AVG(d301) AS d301_mean,
# AVG(d302) AS d302_mean,
# AVG(d303) AS d303_mean,
# AVG(d304) AS d304_mean,
# AVG(d305) AS d305_mean,
# AVG(d306) AS d306_mean,
# AVG(d307) AS d307_mean,
# AVG(d308) AS d308_mean,
# AVG(d309) AS d309_mean,
# AVG(d310) AS d310_mean,
# AVG(d311) AS d311_mean,
# AVG(d312) AS d312_mean,
# AVG(d313) AS d313_mean,
# AVG(d314) AS d314_mean,
# AVG(d315) AS d315_mean,
# AVG(d316) AS d316_mean,
# AVG(d317) AS d317_mean,
# AVG(d318) AS d318_mean,
# AVG(d319) AS d319_mean,
# AVG(d320) AS d320_mean,
# AVG(d321) AS d321_mean,
# AVG(d322) AS d322_mean,
# AVG(d323) AS d323_mean,
# AVG(d324) AS d324_mean,
# AVG(d325) AS d325_mean,
# AVG(d326) AS d326_mean,
# AVG(d327) AS d327_mean,
# AVG(d328) AS d328_mean,
# AVG(d329) AS d329_mean,
# AVG(d330) AS d330_mean,
# AVG(d331) AS d331_mean,
# AVG(d332) AS d332_mean,
# AVG(d333) AS d333_mean,
# AVG(d334) AS d334_mean,
# AVG(d335) AS d335_mean,
# AVG(d336) AS d336_mean,
# AVG(d337) AS d337_mean,
# AVG(d338) AS d338_mean,
# AVG(d339) AS d339_mean,
# AVG(d340) AS d340_mean,
# AVG(d341) AS d341_mean,
# AVG(d342) AS d342_mean,
# AVG(d343) AS d343_mean,
# AVG(d344) AS d344_mean,
# AVG(d345) AS d345_mean,
# AVG(d346) AS d346_mean,
# AVG(d347) AS d347_mean,
# AVG(d348) AS d348_mean,
# AVG(d349) AS d349_mean,
# AVG(d350) AS d350_mean,
# AVG(d351) AS d351_mean,
# AVG(d352) AS d352_mean,
# AVG(d353) AS d353_mean,
# AVG(d354) AS d354_mean,
# AVG(d355) AS d355_mean,
# AVG(d356) AS d356_mean,
# AVG(d357) AS d357_mean,
# AVG(d358) AS d358_mean,
# AVG(d359) AS d359_mean,
# AVG(d360) AS d360_mean,
# AVG(d361) AS d361_mean,
# AVG(d362) AS d362_mean,
# AVG(d363) AS d363_mean,
# AVG(d364) AS d364_mean,
# AVG(d365) AS d365_mean,
# AVG(d366) AS d366_mean,
# AVG(d367) AS d367_mean,
# AVG(d368) AS d368_mean,
# AVG(d369) AS d369_mean,
# AVG(d370) AS d370_mean,
# AVG(d371) AS d371_mean,
# AVG(d372) AS d372_mean,
# AVG(d373) AS d373_mean,
# AVG(d374) AS d374_mean,
# AVG(d375) AS d375_mean,
# AVG(d376) AS d376_mean,
# AVG(d377) AS d377_mean,
# AVG(d378) AS d378_mean,
# AVG(d379) AS d379_mean,
# AVG(d380) AS d380_mean,
# AVG(d381) AS d381_mean,
# AVG(d382) AS d382_mean,
# AVG(d383) AS d383_mean,
# AVG(d384) AS d384_mean,
# AVG(d385) AS d385_mean,
# AVG(d386) AS d386_mean,
# AVG(d387) AS d387_mean,
# AVG(d388) AS d388_mean,
# AVG(d389) AS d389_mean,
# AVG(d390) AS d390_mean,
# AVG(d391) AS d391_mean,
# AVG(d392) AS d392_mean,
# AVG(d393) AS d393_mean,
# AVG(d394) AS d394_mean,
# AVG(d395) AS d395_mean,
# AVG(d396) AS d396_mean,
# AVG(d397) AS d397_mean,
# AVG(d398) AS d398_mean,
# AVG(d399) AS d399_mean,
# AVG(d400) AS d400_mean,
# AVG(d401) AS d401_mean,
# AVG(d402) AS d402_mean,
# AVG(d403) AS d403_mean,
# AVG(d404) AS d404_mean,
# AVG(d405) AS d405_mean,
# AVG(d406) AS d406_mean,
# AVG(d407) AS d407_mean,
# AVG(d408) AS d408_mean,
# AVG(d409) AS d409_mean,
# AVG(d410) AS d410_mean,
# AVG(d411) AS d411_mean,
# AVG(d412) AS d412_mean,
# AVG(d413) AS d413_mean,
# AVG(d414) AS d414_mean,
# AVG(d415) AS d415_mean,
# AVG(d416) AS d416_mean,
# AVG(d417) AS d417_mean,
# AVG(d418) AS d418_mean,
# AVG(d419) AS d419_mean,
# AVG(d420) AS d420_mean,
# AVG(d421) AS d421_mean,
# AVG(d422) AS d422_mean,
# AVG(d423) AS d423_mean,
# AVG(d424) AS d424_mean,
# AVG(d425) AS d425_mean,
# AVG(d426) AS d426_mean,
# AVG(d427) AS d427_mean,
# AVG(d428) AS d428_mean,
# AVG(d429) AS d429_mean,
# AVG(d430) AS d430_mean,
# AVG(d431) AS d431_mean,
# AVG(d432) AS d432_mean,
# AVG(d433) AS d433_mean,
# AVG(d434) AS d434_mean,
# AVG(d435) AS d435_mean,
# AVG(d436) AS d436_mean,
# AVG(d437) AS d437_mean,
# AVG(d438) AS d438_mean,
# AVG(d439) AS d439_mean,
# AVG(d440) AS d440_mean,
# AVG(d441) AS d441_mean,
# AVG(d442) AS d442_mean,
# AVG(d443) AS d443_mean,
# AVG(d444) AS d444_mean,
# AVG(d445) AS d445_mean,
# AVG(d446) AS d446_mean,
# AVG(d447) AS d447_mean,
# AVG(d448) AS d448_mean,
# AVG(d449) AS d449_mean,
# AVG(d450) AS d450_mean,
# AVG(d451) AS d451_mean,
# AVG(d452) AS d452_mean,
# AVG(d453) AS d453_mean,
# AVG(d454) AS d454_mean,
# AVG(d455) AS d455_mean,
# AVG(d456) AS d456_mean,
# AVG(d457) AS d457_mean,
# AVG(d458) AS d458_mean,
# AVG(d459) AS d459_mean,
# AVG(d460) AS d460_mean,
# AVG(d461) AS d461_mean,
# AVG(d462) AS d462_mean,
# AVG(d463) AS d463_mean,
# AVG(d464) AS d464_mean,
# AVG(d465) AS d465_mean,
# AVG(d466) AS d466_mean,
# AVG(d467) AS d467_mean,
# AVG(d468) AS d468_mean,
# AVG(d469) AS d469_mean,
# AVG(d470) AS d470_mean,
# AVG(d471) AS d471_mean,
# AVG(d472) AS d472_mean,
# AVG(d473) AS d473_mean,
# AVG(d474) AS d474_mean,
# AVG(d475) AS d475_mean,
# AVG(d476) AS d476_mean,
# AVG(d477) AS d477_mean,
# AVG(d478) AS d478_mean,
# AVG(d479) AS d479_mean,
# AVG(d480) AS d480_mean,
# AVG(d481) AS d481_mean,
# AVG(d482) AS d482_mean,
# AVG(d483) AS d483_mean,
# AVG(d484) AS d484_mean,
# AVG(d485) AS d485_mean,
# AVG(d486) AS d486_mean,
# AVG(d487) AS d487_mean,
# AVG(d488) AS d488_mean,
# AVG(d489) AS d489_mean,
# AVG(d490) AS d490_mean,
# AVG(d491) AS d491_mean,
# AVG(d492) AS d492_mean,
# AVG(d493) AS d493_mean,
# AVG(d494) AS d494_mean,
# AVG(d495) AS d495_mean,
# AVG(d496) AS d496_mean,
# AVG(d497) AS d497_mean,
# AVG(d498) AS d498_mean,
# AVG(d499) AS d499_mean,
# AVG(d500) AS d500_mean,
# AVG(d501) AS d501_mean,
# AVG(d502) AS d502_mean,
# AVG(d503) AS d503_mean,
# AVG(d504) AS d504_mean,
# AVG(d505) AS d505_mean,
# AVG(d506) AS d506_mean,
# AVG(d507) AS d507_mean,
# AVG(d508) AS d508_mean,
# AVG(d509) AS d509_mean,
# AVG(d510) AS d510_mean,
# AVG(d511) AS d511_mean,
#
# FROM (
# SELECT f.second_level.name AS fc,
#
# title_embed[OFFSET(0)] AS d0,
# title_embed[OFFSET(1)] AS d1,
# title_embed[OFFSET(2)] AS d2,
# title_embed[OFFSET(3)] AS d3,
# title_embed[OFFSET(4)] AS d4,
# title_embed[OFFSET(5)] AS d5,
# title_embed[OFFSET(6)] AS d6,
# title_embed[OFFSET(7)] AS d7,
# title_embed[OFFSET(8)] AS d8,
# title_embed[OFFSET(9)] AS d9,
# title_embed[OFFSET(10)] AS d10,
# title_embed[OFFSET(11)] AS d11,
# title_embed[OFFSET(12)] AS d12,
# title_embed[OFFSET(13)] AS d13,
# title_embed[OFFSET(14)] AS d14,
# title_embed[OFFSET(15)] AS d15,
# title_embed[OFFSET(16)] AS d16,
# title_embed[OFFSET(17)] AS d17,
# title_embed[OFFSET(18)] AS d18,
# title_embed[OFFSET(19)] AS d19,
# title_embed[OFFSET(20)] AS d20,
# title_embed[OFFSET(21)] AS d21,
# title_embed[OFFSET(22)] AS d22,
# title_embed[OFFSET(23)] AS d23,
# title_embed[OFFSET(24)] AS d24,
# title_embed[OFFSET(25)] AS d25,
# title_embed[OFFSET(26)] AS d26,
# title_embed[OFFSET(27)] AS d27,
# title_embed[OFFSET(28)] AS d28,
# title_embed[OFFSET(29)] AS d29,
# title_embed[OFFSET(30)] AS d30,
# title_embed[OFFSET(31)] AS d31,
# title_embed[OFFSET(32)] AS d32,
# title_embed[OFFSET(33)] AS d33,
# title_embed[OFFSET(34)] AS d34,
# title_embed[OFFSET(474)] AS d474,
# title_embed[OFFSET(475)] AS d475,
# title_embed[OFFSET(476)] AS d476,
# title_embed[OFFSET(477)] AS d477,
# title_embed[OFFSET(478)] AS d478,
# title_embed[OFFSET(479)] AS d479,
# title_embed[OFFSET(480)] AS d480,
# title_embed[OFFSET(481)] AS d481,
# title_embed[OFFSET(482)] AS d482,
# title_embed[OFFSET(483)] AS d483,
# title_embed[OFFSET(484)] AS d484,
# title_embed[OFFSET(485)] AS d485,
# title_embed[OFFSET(486)] AS d486,
# title_embed[OFFSET(487)] AS d487,
# title_embed[OFFSET(488)] AS d488,
# title_embed[OFFSET(489)] AS d489,
# title_embed[OFFSET(490)] AS d490,
# title_embed[OFFSET(491)] AS d491,
# title_embed[OFFSET(492)] AS d492,
# title_embed[OFFSET(493)] AS d493,
# title_embed[OFFSET(494)] AS d494,
# title_embed[OFFSET(495)] AS d495,
# title_embed[OFFSET(496)] AS d496,
# title_embed[OFFSET(497)] AS d497,
# title_embed[OFFSET(498)] AS d498,
# title_embed[OFFSET(499)] AS d499,
# title_embed[OFFSET(500)] AS d500,
# title_embed[OFFSET(501)] AS d501,
# title_embed[OFFSET(502)] AS d502,
# title_embed[OFFSET(503)] AS d503,
# title_embed[OFFSET(504)] AS d504,
# title_embed[OFFSET(505)] AS d505,
# title_embed[OFFSET(506)] AS d506,
# title_embed[OFFSET(507)] AS d507,
# title_embed[OFFSET(508)] AS d508,
# title_embed[OFFSET(509)] AS d509,
# title_embed[OFFSET(510)] AS d510,
# title_embed[OFFSET(511)] AS d511,
#
# FROM `springer-nature-analytics.DS_dimensions.publications_full_refresh`
# LEFT JOIN UNNEST(`for`) AS f LEFT JOIN UNNEST(journal) AS j
# WHERE ARRAY_LENGTH(title_embed) = 512
# AND
# publication_type LIKE "article"
#         AND j.title IN (SELECT title FROM `springer-nature-analytics.core_journals.core_2018_v01`)
#         AND year >= 2008
#         AND year <= 2010
#         AND language LIKE "en"
#         AND ARRAY_LENGTH(references) > 4
#
# ) GROUP BY fc
#  ) WHERE fc IS NOT NULL

# %%
train_and_save(for_08_10, "wv_08_10", "f2")
# Out:
# Saved mean vectors to "/content/drive/My Drive/Research/Data/Mean-title-centroids-3yrs-v02/wv_08_10_f2.csv"

# %% [markdown]
# # 2005-2007

# %%
# %%bigquery --project $pid for_05_07
#
# SELECT * FROM (
# SELECT f1,
#
# AVG(d0) AS d0_mean,
# AVG(d1) AS d1_mean,
# AVG(d2) AS d2_mean,
# AVG(d3) AS d3_mean,
# AVG(d4) AS d4_mean,
# AVG(d5) AS d5_mean,
# AVG(d6) AS d6_mean,
# AVG(d7) AS d7_mean,
# AVG(d8) AS d8_mean,
# AVG(d9) AS d9_mean,
# AVG(d10) AS d10_mean,
# AVG(d11) AS d11_mean,
# AVG(d12) AS d12_mean,
# AVG(d13) AS d13_mean,
# AVG(d14) AS d14_mean,
# AVG(d15) AS d15_mean,
# AVG(d16) AS d16_mean,
# AVG(d17) AS d17_mean,
# AVG(d18) AS d18_mean,
# AVG(d19) AS d19_mean,
# AVG(d20) AS d20_mean,
# AVG(d21) AS d21_mean,
# AVG(d22) AS d22_mean,
# AVG(d23) AS d23_mean,
# AVG(d24) AS d24_mean,
# AVG(d25) AS d25_mean,
# AVG(d26) AS d26_mean,
# AVG(d27) AS d27_mean,
# AVG(d28) AS d28_mean,
# AVG(d29) AS d29_mean,
# AVG(d30) AS d30_mean,
# AVG(d31) AS d31_mean,
# AVG(d32) AS d32_mean,
# AVG(d33) AS d33_mean,
# AVG(d34) AS d34_mean,
# AVG(d35) AS d35_mean,
# AVG(d36) AS d36_mean,
# AVG(d37) AS d37_mean,
# AVG(d38) AS d38_mean,
# AVG(d39) AS d39_mean,
# AVG(d40) AS d40_mean,
# AVG(d41) AS d41_mean,
# AVG(d42) AS d42_mean,
# AVG(d43) AS d43_mean,
# AVG(d44) AS d44_mean,
# AVG(d45) AS d45_mean,
# AVG(d46) AS d46_mean,
# AVG(d47) AS d47_mean,
# AVG(d48) AS d48_mean,
# AVG(d49) AS d49_mean,
# AVG(d50) AS d50_mean,
# AVG(d51) AS d51_mean,
# AVG(d52) AS d52_mean,
# AVG(d53) AS d53_mean,
# AVG(d54) AS d54_mean,
# AVG(d55) AS d55_mean,
# AVG(d56) AS d56_mean,
# AVG(d57) AS d57_mean,
# AVG(d58) AS d58_mean,
# AVG(d59) AS d59_mean,
# AVG(d60) AS d60_mean,
# AVG(d61) AS d61_mean,
# AVG(d62) AS d62_mean,
# AVG(d63) AS d63_mean,
# AVG(d64) AS d64_mean,
# AVG(d65) AS d65_mean,
# AVG(d66) AS d66_mean,
# AVG(d67) AS d67_mean,
# AVG(d68) AS d68_mean,
# AVG(d69) AS d69_mean,
# AVG(d70) AS d70_mean,
# AVG(d71) AS d71_mean,
# AVG(d72) AS d72_mean,
# AVG(d73) AS d73_mean,
# AVG(d74) AS d74_mean,
# AVG(d75) AS d75_mean,
# AVG(d76) AS d76_mean,
# AVG(d77) AS d77_mean,
# AVG(d78) AS d78_mean,
# AVG(d79) AS d79_mean,
# AVG(d80) AS d80_mean,
# AVG(d81) AS d81_mean,
# AVG(d82) AS d82_mean,
# AVG(d83) AS d83_mean,
# AVG(d84) AS d84_mean,
# AVG(d85) AS d85_mean,
# AVG(d86) AS d86_mean,
# AVG(d87) AS d87_mean,
# AVG(d88) AS d88_mean,
# AVG(d89) AS d89_mean,
# AVG(d90) AS d90_mean,
# AVG(d91) AS d91_mean,
# AVG(d92) AS d92_mean,
# AVG(d93) AS d93_mean,
# AVG(d94) AS d94_mean,
# AVG(d95) AS d95_mean,
# AVG(d96) AS d96_mean,
# AVG(d97) AS d97_mean,
# AVG(d98) AS d98_mean,
# AVG(d99) AS d99_mean,
# AVG(d100) AS d100_mean,
# AVG(d101) AS d101_mean,
# AVG(d102) AS d102_mean,
# AVG(d103) AS d103_mean,
# AVG(d104) AS d104_mean,
# AVG(d105) AS d105_mean,
# AVG(d106) AS d106_mean,
# AVG(d107) AS d107_mean,
# AVG(d108) AS d108_mean,
# AVG(d109) AS d109_mean,
# AVG(d110) AS d110_mean,
# AVG(d111) AS d111_mean,
# AVG(d112) AS d112_mean,
# AVG(d113) AS d113_mean,
# AVG(d114) AS d114_mean,
# AVG(d115) AS d115_mean,
# AVG(d116) AS d116_mean,
# AVG(d117) AS d117_mean,
# AVG(d118) AS d118_mean,
# AVG(d119) AS d119_mean,
# AVG(d120) AS d120_mean,
# AVG(d121) AS d121_mean,
# AVG(d122) AS d122_mean,
# AVG(d123) AS d123_mean,
# AVG(d124) AS d124_mean,
# AVG(d125) AS d125_mean,
# AVG(d126) AS d126_mean,
# AVG(d127) AS d127_mean,
# AVG(d128) AS d128_mean,
# AVG(d129) AS d129_mean,
# AVG(d130) AS d130_mean,
# AVG(d131) AS d131_mean,
# AVG(d132) AS d132_mean,
# AVG(d133) AS d133_mean,
# AVG(d134) AS d134_mean,
# AVG(d135) AS d135_mean,
# AVG(d136) AS d136_mean,
# AVG(d137) AS d137_mean,
# AVG(d138) AS d138_mean,
# AVG(d139) AS d139_mean,
# AVG(d140) AS d140_mean,
# AVG(d141) AS d141_mean,
# AVG(d142) AS d142_mean,
# AVG(d143) AS d143_mean,
# AVG(d144) AS d144_mean,
# AVG(d145) AS d145_mean,
# AVG(d146) AS d146_mean,
# AVG(d147) AS d147_mean,
# AVG(d148) AS d148_mean,
# AVG(d149) AS d149_mean,
# AVG(d150) AS d150_mean,
# AVG(d151) AS d151_mean,
# AVG(d152) AS d152_mean,
# AVG(d153) AS d153_mean,
# AVG(d154) AS d154_mean,
# AVG(d155) AS d155_mean,
# AVG(d156) AS d156_mean,
# AVG(d157) AS d157_mean,
# AVG(d158) AS d158_mean,
# AVG(d159) AS d159_mean,
# AVG(d160) AS d160_mean,
# AVG(d161) AS d161_mean,
# AVG(d162) AS d162_mean,
# AVG(d163) AS d163_mean,
# AVG(d164) AS d164_mean,
# AVG(d165) AS d165_mean,
# AVG(d166) AS d166_mean,
# AVG(d167) AS d167_mean,
# AVG(d168) AS d168_mean,
# AVG(d169) AS d169_mean,
# AVG(d170) AS d170_mean,
# AVG(d171) AS d171_mean,
# AVG(d172) AS d172_mean,
# AVG(d173) AS d173_mean,
# AVG(d174) AS d174_mean,
# AVG(d175) AS d175_mean,
# AVG(d176) AS d176_mean,
# AVG(d177) AS d177_mean,
# AVG(d178) AS d178_mean,
# AVG(d179) AS d179_mean,
# AVG(d180) AS d180_mean,
# AVG(d181) AS d181_mean,
# AVG(d182) AS d182_mean,
# AVG(d183) AS d183_mean,
# AVG(d184) AS d184_mean,
# AVG(d185) AS d185_mean,
# AVG(d186) AS d186_mean,
# AVG(d187) AS d187_mean,
# AVG(d188) AS d188_mean,
# AVG(d189) AS d189_mean,
# AVG(d190) AS d190_mean,
# AVG(d191) AS d191_mean,
# AVG(d192) AS d192_mean,
# AVG(d193) AS d193_mean,
# AVG(d194) AS d194_mean,
# AVG(d195) AS d195_mean,
# AVG(d196) AS d196_mean,
# AVG(d197) AS d197_mean,
# AVG(d198) AS d198_mean,
# AVG(d199) AS d199_mean,
# AVG(d200) AS d200_mean,
# AVG(d201) AS d201_mean,
# AVG(d202) AS d202_mean,
# AVG(d203) AS d203_mean,
# AVG(d204) AS d204_mean,
# AVG(d205) AS d205_mean,
# AVG(d206) AS d206_mean,
# AVG(d207) AS d207_mean,
# AVG(d208) AS d208_mean,
# AVG(d209) AS d209_mean,
# AVG(d210) AS d210_mean,
# AVG(d211) AS d211_mean,
# AVG(d212) AS d212_mean,
# AVG(d213) AS d213_mean,
# AVG(d214) AS d214_mean,
# AVG(d215) AS d215_mean,
# AVG(d216) AS d216_mean,
# AVG(d217) AS d217_mean,
# AVG(d218) AS d218_mean,
# AVG(d219) AS d219_mean,
# AVG(d220) AS d220_mean,
# AVG(d221) AS d221_mean,
# AVG(d222) AS d222_mean,
# AVG(d223) AS d223_mean,
# AVG(d224) AS d224_mean,
# AVG(d225) AS d225_mean,
# AVG(d226) AS d226_mean,
# AVG(d227) AS d227_mean,
# AVG(d228) AS d228_mean,
# AVG(d229) AS d229_mean,
# AVG(d230) AS d230_mean,
# AVG(d231) AS d231_mean,
# AVG(d232) AS d232_mean,
# AVG(d233) AS d233_mean,
# AVG(d234) AS d234_mean,
# AVG(d235) AS d235_mean,
# AVG(d236) AS d236_mean,
# AVG(d237) AS d237_mean,
# AVG(d238) AS d238_mean,
# AVG(d239) AS d239_mean,
# AVG(d240) AS d240_mean,
# AVG(d241) AS d241_mean,
# AVG(d242) AS d242_mean,
# AVG(d243) AS d243_mean,
# AVG(d244) AS d244_mean,
# AVG(d245) AS d245_mean,
# AVG(d246) AS d246_mean,
# AVG(d247) AS d247_mean,
# AVG(d248) AS d248_mean,
# AVG(d249) AS d249_mean,
# AVG(d250) AS d250_mean,
# AVG(d251) AS d251_mean,
# AVG(d252) AS d252_mean,
# AVG(d253) AS d253_mean,
# AVG(d254) AS d254_mean,
# AVG(d255) AS d255_mean,
# AVG(d256) AS d256_mean,
# AVG(d257) AS d257_mean,
# AVG(d258) AS d258_mean,
# AVG(d259) AS d259_mean,
# AVG(d260) AS d260_mean,
# AVG(d261) AS d261_mean,
# AVG(d262) AS d262_mean,
# AVG(d263) AS d263_mean,
# AVG(d264) AS d264_mean,
# AVG(d265) AS d265_mean,
# AVG(d266) AS d266_mean,
# AVG(d267) AS d267_mean,
# AVG(d268) AS d268_mean,
# AVG(d269) AS d269_mean,
# AVG(d270) AS d270_mean,
# AVG(d271) AS d271_mean,
# AVG(d272) AS d272_mean,
# AVG(d273) AS d273_mean,
# AVG(d274) AS d274_mean,
# AVG(d275) AS d275_mean,
# AVG(d276) AS d276_mean,
# AVG(d277) AS d277_mean,
# AVG(d278) AS d278_mean,
# AVG(d279) AS d279_mean,
# AVG(d280) AS d280_mean,
# AVG(d281) AS d281_mean,
# AVG(d282) AS d282_mean,
# AVG(d283) AS d283_mean,
# AVG(d284) AS d284_mean,
# AVG(d285) AS d285_mean,
# AVG(d286) AS d286_mean,
# AVG(d287) AS d287_mean,
# AVG(d288) AS d288_mean,
# AVG(d289) AS d289_mean,
# AVG(d290) AS d290_mean,
# AVG(d291) AS d291_mean,
# AVG(d292) AS d292_mean,
# AVG(d293) AS d293_mean,
# AVG(d294) AS d294_mean,
# AVG(d295) AS d295_mean,
# AVG(d296) AS d296_mean,
# AVG(d297) AS d297_mean,
# AVG(d298) AS d298_mean,
# AVG(d299) AS d299_mean,
# AVG(d300) AS d300_mean,
# AVG(d301) AS d301_mean,
# AVG(d302) AS d302_mean,
# AVG(d303) AS d303_mean,
# AVG(d304) AS d304_mean,
# AVG(d305) AS d305_mean,
# AVG(d306) AS d306_mean,
# AVG(d307) AS d307_mean,
# AVG(d308) AS d308_mean,
# AVG(d309) AS d309_mean,
# AVG(d310) AS d310_mean,
# AVG(d311) AS d311_mean,
# AVG(d312) AS d312_mean,
# AVG(d313) AS d313_mean,
# AVG(d314) AS d314_mean,
# AVG(d315) AS d315_mean,
# AVG(d316) AS d316_mean,
# AVG(d317) AS d317_mean,
# AVG(d318) AS d318_mean,
# AVG(d319) AS d319_mean,
# AVG(d320) AS d320_mean,
# AVG(d321) AS d321_mean,
# AVG(d322) AS d322_mean,
# AVG(d323) AS d323_mean,
# AVG(d324) AS d324_mean,
# AVG(d325) AS d325_mean,
# AVG(d326) AS d326_mean,
# AVG(d327) AS d327_mean,
# AVG(d328) AS d328_mean,
# AVG(d329) AS d329_mean,
# AVG(d330) AS d330_mean,
# AVG(d331) AS d331_mean,
# AVG(d332) AS d332_mean,
# AVG(d333) AS d333_mean,
# AVG(d334) AS d334_mean,
# AVG(d335) AS d335_mean,
# AVG(d336) AS d336_mean,
# AVG(d337) AS d337_mean,
# AVG(d338) AS d338_mean,
# AVG(d339) AS d339_mean,
# AVG(d340) AS d340_mean,
# AVG(d341) AS d341_mean,
# AVG(d342) AS d342_mean,
# AVG(d343) AS d343_mean,
# AVG(d344) AS d344_mean,
# AVG(d345) AS d345_mean,
# AVG(d346) AS d346_mean,
# AVG(d347) AS d347_mean,
# AVG(d348) AS d348_mean,
# AVG(d349) AS d349_mean,
# AVG(d350) AS d350_mean,
# AVG(d351) AS d351_mean,
# AVG(d352) AS d352_mean,
# AVG(d353) AS d353_mean,
# AVG(d354) AS d354_mean,
# AVG(d355) AS d355_mean,
# AVG(d356) AS d356_mean,
# AVG(d357) AS d357_mean,
# AVG(d358) AS d358_mean,
# AVG(d359) AS d359_mean,
# AVG(d360) AS d360_mean,
# AVG(d361) AS d361_mean,
# AVG(d362) AS d362_mean,
# AVG(d363) AS d363_mean,
# AVG(d364) AS d364_mean,
# AVG(d365) AS d365_mean,
# AVG(d366) AS d366_mean,
# AVG(d367) AS d367_mean,
# AVG(d368) AS d368_mean,
# AVG(d369) AS d369_mean,
# AVG(d370) AS d370_mean,
# AVG(d371) AS d371_mean,
# AVG(d372) AS d372_mean,
# AVG(d373) AS d373_mean,
# AVG(d374) AS d374_mean,
# AVG(d375) AS d375_mean,
# AVG(d376) AS d376_mean,
# AVG(d377) AS d377_mean,
# AVG(d378) AS d378_mean,
# AVG(d379) AS d379_mean,
# AVG(d380) AS d380_mean,
# AVG(d381) AS d381_mean,
# AVG(d382) AS d382_mean,
# AVG(d383) AS d383_mean,
# AVG(d384) AS d384_mean,
# AVG(d385) AS d385_mean,
# AVG(d386) AS d386_mean,
# AVG(d387) AS d387_mean,
# AVG(d388) AS d388_mean,
# AVG(d389) AS d389_mean,
# AVG(d390) AS d390_mean,
# AVG(d391) AS d391_mean,
# AVG(d392) AS d392_mean,
# AVG(d393) AS d393_mean,
# AVG(d394) AS d394_mean,
# AVG(d395) AS d395_mean,
# AVG(d396) AS d396_mean,
# AVG(d397) AS d397_mean,
# AVG(d398) AS d398_mean,
# AVG(d399) AS d399_mean,
# AVG(d400) AS d400_mean,
# AVG(d401) AS d401_mean,
# AVG(d402) AS d402_mean,
# AVG(d403) AS d403_mean,
# AVG(d404) AS d404_mean,
# AVG(d405) AS d405_mean,
# AVG(d406) AS d406_mean,
# AVG(d407) AS d407_mean,
# AVG(d408) AS d408_mean,
# AVG(d409) AS d409_mean,
# AVG(d410) AS d410_mean,
# AVG(d411) AS d411_mean,
# AVG(d412) AS d412_mean,
# AVG(d413) AS d413_mean,
# AVG(d414) AS d414_mean,
# AVG(d415) AS d415_mean,
# AVG(d416) AS d416_mean,
# AVG(d417) AS d417_mean,
# AVG(d418) AS d418_mean,
# AVG(d419) AS d419_mean,
# AVG(d420) AS d420_mean,
# AVG(d421) AS d421_mean,
# AVG(d422) AS d422_mean,
# AVG(d423) AS d423_mean,
# AVG(d424) AS d424_mean,
# AVG(d425) AS d425_mean,
# AVG(d426) AS d426_mean,
# AVG(d427) AS d427_mean,
# AVG(d428) AS d428_mean,
# AVG(d429) AS d429_mean,
# AVG(d430) AS d430_mean,
# AVG(d431) AS d431_mean,
# AVG(d432) AS d432_mean,
# AVG(d433) AS d433_mean,
# AVG(d434) AS d434_mean,
# AVG(d435) AS d435_mean,
# AVG(d436) AS d436_mean,
# AVG(d437) AS d437_mean,
# AVG(d438) AS d438_mean,
# AVG(d439) AS d439_mean,
# AVG(d440) AS d440_mean,
# AVG(d441) AS d441_mean,
# AVG(d442) AS d442_mean,
# AVG(d443) AS d443_mean,
# AVG(d444) AS d444_mean,
# AVG(d445) AS d445_mean,
# AVG(d446) AS d446_mean,
# AVG(d447) AS d447_mean,
# AVG(d448) AS d448_mean,
# AVG(d449) AS d449_mean,
# AVG(d450) AS d450_mean,
# AVG(d451) AS d451_mean,
# AVG(d452) AS d452_mean,
# AVG(d453) AS d453_mean,
# AVG(d454) AS d454_mean,
# AVG(d455) AS d455_mean,
# AVG(d456) AS d456_mean,
# AVG(d457) AS d457_mean,
# AVG(d458) AS d458_mean,
# AVG(d459) AS d459_mean,
# AVG(d460) AS d460_mean,
# AVG(d461) AS d461_mean,
# AVG(d462) AS d462_mean,
# AVG(d463) AS d463_mean,
# AVG(d464) AS d464_mean,
# AVG(d465) AS d465_mean,
# AVG(d466) AS d466_mean,
# AVG(d467) AS d467_mean,
# AVG(d468) AS d468_mean,
# AVG(d469) AS d469_mean,
# AVG(d470) AS d470_mean,
# AVG(d471) AS d471_mean,
# AVG(d472) AS d472_mean,
# AVG(d473) AS d473_mean,
# AVG(d474) AS d474_mean,
# AVG(d475) AS d475_mean,
# AVG(d476) AS d476_mean,
# AVG(d477) AS d477_mean,
# AVG(d478) AS d478_mean,
# AVG(d479) AS d479_mean,
# AVG(d480) AS d480_mean,
# AVG(d481) AS d481_mean,
# AVG(d482) AS d482_mean,
# AVG(d483) AS d483_mean,
# AVG(d484) AS d484_mean,
# AVG(d485) AS d485_mean,
# AVG(d486) AS d486_mean,
# AVG(d487) AS d487_mean,
# AVG(d488) AS d488_mean,
# AVG(d489) AS d489_mean,
# AVG(d490) AS d490_mean,
# AVG(d491) AS d491_mean,
# AVG(d492) AS d492_mean,
# AVG(d493) AS d493_mean,
# AVG(d494) AS d494_mean,
# AVG(d495) AS d495_mean,
# AVG(d496) AS d496_mean,
# AVG(d497) AS d497_mean,
# AVG(d498) AS d498_mean,
# AVG(d499) AS d499_mean,
# AVG(d500) AS d500_mean,
# AVG(d501) AS d501_mean,
# AVG(d502) AS d502_mean,
# AVG(d503) AS d503_mean,
# AVG(d504) AS d504_mean,
# AVG(d505) AS d505_mean,
# AVG(d506) AS d506_mean,
# AVG(d507) AS d507_mean,
# AVG(d508) AS d508_mean,
# AVG(d509) AS d509_mean,
# AVG(d510) AS d510_mean,
# AVG(d511) AS d511_mean,
#
# FROM (
# SELECT f.first_level.name AS f1,
#
# title_embed[OFFSET(0)] AS d0,
# title_embed[OFFSET(1)] AS d1,
# title_embed[OFFSET(2)] AS d2,
# title_embed[OFFSET(3)] AS d3,
# title_embed[OFFSET(4)] AS d4,
# title_embed[OFFSET(5)] AS d5,
# title_embed[OFFSET(6)] AS d6,
# title_embed[OFFSET(7)] AS d7,
# title_embed[OFFSET(8)] AS d8,
# title_embed[OFFSET(9)] AS d9,
# title_embed[OFFSET(10)] AS d10,
# title_embed[OFFSET(11)] AS d11,
# title_embed[OFFSET(12)] AS d12,
# title_embed[OFFSET(13)] AS d13,
# title_embed[OFFSET(14)] AS d14,
# title_embed[OFFSET(15)] AS d15,
# title_embed[OFFSET(16)] AS d16,
# title_embed[OFFSET(17)] AS d17,
# title_embed[OFFSET(18)] AS d18,
# title_embed[OFFSET(19)] AS d19,
# title_embed[OFFSET(20)] AS d20,
# title_embed[OFFSET(21)] AS d21,
# title_embed[OFFSET(22)] AS d22,
# title_embed[OFFSET(23)] AS d23,
# title_embed[OFFSET(24)] AS d24,
# title_embed[OFFSET(25)] AS d25,
# title_embed[OFFSET(26)] AS d26,
# title_embed[OFFSET(27)] AS d27,
# title_embed[OFFSET(28)] AS d28,
# title_embed[OFFSET(29)] AS d29,
# title_embed[OFFSET(30)] AS d30,
# title_embed[OFFSET(31)] AS d31,
# title_embed[OFFSET(32)] AS d32,
# title_embed[OFFSET(33)] AS d33,
# title_embed[OFFSET(34)] AS d34,
# title_embed[OFFSET(35)] AS d35,
# title_embed[OFFSET(36)] AS d36,
# title_embed[OFFSET(37)] AS d37,
# title_embed[OFFSET(38)] AS d38,
# title_embed[OFFSET(478)] AS d478,
# title_embed[OFFSET(479)] AS d479,
# title_embed[OFFSET(480)] AS d480,
# title_embed[OFFSET(481)] AS d481,
# title_embed[OFFSET(482)] AS d482,
# title_embed[OFFSET(483)] AS d483,
# title_embed[OFFSET(484)] AS d484,
# title_embed[OFFSET(485)] AS d485,
# title_embed[OFFSET(486)] AS d486,
# title_embed[OFFSET(487)] AS d487,
# title_embed[OFFSET(488)] AS d488,
# title_embed[OFFSET(489)] AS d489,
# title_embed[OFFSET(490)] AS d490,
# title_embed[OFFSET(491)] AS d491,
# title_embed[OFFSET(492)] AS d492,
# title_embed[OFFSET(493)] AS d493,
# title_embed[OFFSET(494)] AS d494,
# title_embed[OFFSET(495)] AS d495,
# title_embed[OFFSET(496)] AS d496,
# title_embed[OFFSET(497)] AS d497,
# title_embed[OFFSET(498)] AS d498,
# title_embed[OFFSET(499)] AS d499,
# title_embed[OFFSET(500)] AS d500,
# title_embed[OFFSET(501)] AS d501,
# title_embed[OFFSET(502)] AS d502,
# title_embed[OFFSET(503)] AS d503,
# title_embed[OFFSET(504)] AS d504,
# title_embed[OFFSET(505)] AS d505,
# title_embed[OFFSET(506)] AS d506,
# title_embed[OFFSET(507)] AS d507,
# title_embed[OFFSET(508)] AS d508,
# title_embed[OFFSET(509)] AS d509,
# title_embed[OFFSET(510)] AS d510,
# title_embed[OFFSET(511)] AS d511,
#
# FROM `springer-nature-analytics.DS_dimensions.publications_full_refresh`
# LEFT JOIN UNNEST(`for`) AS f LEFT JOIN UNNEST(journal) AS j
# WHERE ARRAY_LENGTH(title_embed) = 512
# AND
# publication_type LIKE "article"
#         AND j.title IN (SELECT title FROM `springer-nature-analytics.core_journals.core_2018_v01`)
#         AND year >= 2005
#         AND year <= 2007
#         AND language LIKE "en"
#         AND ARRAY_LENGTH(references) > 4
#
# ) GROUP BY f1
#  ) WHERE f1 IS NOT NULL

# %%
train_and_save(for_05_07, "wv_05_07")
# Out:
# Saved mean vectors to "/content/drive/My Drive/Research/Data/Mean-title-centroids-3yrs-v02/wv_05_07_f1.csv"

# %%
# %%bigquery --project $pid for_05_07
#
# SELECT * FROM (
# SELECT f1,
#
# AVG(d0) AS d0_mean,
# AVG(d1) AS d1_mean,
# AVG(d2) AS d2_mean,
# AVG(d3) AS d3_mean,
# AVG(d4) AS d4_mean,
# AVG(d5) AS d5_mean,
# AVG(d6) AS d6_mean,
# AVG(d7) AS d7_mean,
# AVG(d8) AS d8_mean,
# AVG(d9) AS d9_mean,
# AVG(d10) AS d10_mean,
# AVG(d11) AS d11_mean,
# AVG(d12) AS d12_mean,
# AVG(d13) AS d13_mean,
# AVG(d14) AS d14_mean,
# AVG(d15) AS d15_mean,
# AVG(d16) AS d16_mean,
# AVG(d17) AS d17_mean,
# AVG(d18) AS d18_mean,
# AVG(d19) AS d19_mean,
# AVG(d20) AS d20_mean,
# AVG(d21) AS d21_mean,
# AVG(d22) AS d22_mean,
# AVG(d23) AS d23_mean,
# AVG(d24) AS d24_mean,
# AVG(d25) AS d25_mean,
# AVG(d26) AS d26_mean,
# AVG(d27) AS d27_mean,
# AVG(d28) AS d28_mean,
# AVG(d29) AS d29_mean,
# AVG(d30) AS d30_mean,
# AVG(d31) AS d31_mean,
# AVG(d32) AS d32_mean,
# AVG(d33) AS d33_mean,
# AVG(d34) AS d34_mean,
# AVG(d35) AS d35_mean,
# AVG(d36) AS d36_mean,
# AVG(d37) AS d37_mean,
# AVG(d38) AS d38_mean,
# AVG(d39) AS d39_mean,
# AVG(d40) AS d40_mean,
# AVG(d41) AS d41_mean,
# AVG(d42) AS d42_mean,
# AVG(d43) AS d43_mean,
# AVG(d44) AS d44_mean,
# AVG(d45) AS d45_mean,
# AVG(d46) AS d46_mean,
# AVG(d47) AS d47_mean,
# AVG(d48) AS d48_mean,
# AVG(d49) AS d49_mean,
# AVG(d50) AS d50_mean,
# AVG(d51) AS d51_mean,
# AVG(d52) AS d52_mean,
# AVG(d53) AS d53_mean,
# AVG(d54) AS d54_mean,
# AVG(d55) AS d55_mean,
# AVG(d56) AS d56_mean,
# AVG(d57) AS d57_mean,
# AVG(d58) AS d58_mean,
# AVG(d59) AS d59_mean,
# AVG(d60) AS d60_mean,
# AVG(d61) AS d61_mean,
# AVG(d62) AS d62_mean,
# AVG(d63) AS d63_mean,
# AVG(d64) AS d64_mean,
# AVG(d65) AS d65_mean,
# AVG(d66) AS d66_mean,
# AVG(d67) AS d67_mean,
# AVG(d68) AS d68_mean,
# AVG(d69) AS d69_mean,
# AVG(d70) AS d70_mean,
# AVG(d71) AS d71_mean,
# AVG(d72) AS d72_mean,
# AVG(d73) AS d73_mean,
# AVG(d74) AS d74_mean,
# AVG(d75) AS d75_mean,
# AVG(d76) AS d76_mean,
# AVG(d77) AS d77_mean,
# AVG(d78) AS d78_mean,
# AVG(d79) AS d79_mean,
# AVG(d80) AS d80_mean,
# AVG(d81) AS d81_mean,
# AVG(d82) AS d82_mean,
# AVG(d83) AS d83_mean,
# AVG(d84) AS d84_mean,
# AVG(d85) AS d85_mean,
# AVG(d86) AS d86_mean,
# AVG(d87) AS d87_mean,
# AVG(d88) AS d88_mean,
# AVG(d89) AS d89_mean,
# AVG(d90) AS d90_mean,
# AVG(d91) AS d91_mean,
# AVG(d92) AS d92_mean,
# AVG(d93) AS d93_mean,
# AVG(d94) AS d94_mean,
# AVG(d95) AS d95_mean,
# AVG(d96) AS d96_mean,
# AVG(d97) AS d97_mean,
# AVG(d98) AS d98_mean,
# AVG(d99) AS d99_mean,
# AVG(d100) AS d100_mean,
# AVG(d101) AS d101_mean,
# AVG(d102) AS d102_mean,
# AVG(d103) AS d103_mean,
# AVG(d104) AS d104_mean,
# AVG(d105) AS d105_mean,
# AVG(d106) AS d106_mean,
# AVG(d107) AS d107_mean,
# AVG(d108) AS d108_mean,
# AVG(d109) AS d109_mean,
# AVG(d110) AS d110_mean,
# AVG(d111) AS d111_mean,
# AVG(d112) AS d112_mean,
# AVG(d113) AS d113_mean,
# AVG(d114) AS d114_mean,
# AVG(d115) AS d115_mean,
# AVG(d116) AS d116_mean,
# AVG(d117) AS d117_mean,
# AVG(d118) AS d118_mean,
# AVG(d119) AS d119_mean,
# AVG(d120) AS d120_mean,
# AVG(d121) AS d121_mean,
# AVG(d122) AS d122_mean,
# AVG(d123) AS d123_mean,
# AVG(d124) AS d124_mean,
# AVG(d125) AS d125_mean,
# AVG(d126) AS d126_mean,
# AVG(d127) AS d127_mean,
# AVG(d128) AS d128_mean,
# AVG(d129) AS d129_mean,
# AVG(d130) AS d130_mean,
# AVG(d131) AS d131_mean,
# AVG(d132) AS d132_mean,
# AVG(d133) AS d133_mean,
# AVG(d134) AS d134_mean,
# AVG(d135) AS d135_mean,
# AVG(d136) AS d136_mean,
# AVG(d137) AS d137_mean,
# AVG(d138) AS d138_mean,
# AVG(d139) AS d139_mean,
# AVG(d140) AS d140_mean,
# AVG(d141) AS d141_mean,
# AVG(d142) AS d142_mean,
# AVG(d143) AS d143_mean,
# AVG(d144) AS d144_mean,
# AVG(d145) AS d145_mean,
# AVG(d146) AS d146_mean,
# AVG(d147) AS d147_mean,
# AVG(d148) AS d148_mean,
# AVG(d149) AS d149_mean,
# AVG(d150) AS d150_mean,
# AVG(d151) AS d151_mean,
# AVG(d152) AS d152_mean,
# AVG(d153) AS d153_mean,
# AVG(d154) AS d154_mean,
# AVG(d155) AS d155_mean,
# AVG(d156) AS d156_mean,
# AVG(d157) AS d157_mean,
# AVG(d158) AS d158_mean,
# AVG(d159) AS d159_mean,
# AVG(d160) AS d160_mean,
# AVG(d161) AS d161_mean,
# AVG(d162) AS d162_mean,
# AVG(d163) AS d163_mean,
# AVG(d164) AS d164_mean,
# AVG(d165) AS d165_mean,
# AVG(d166) AS d166_mean,
# AVG(d167) AS d167_mean,
# AVG(d168) AS d168_mean,
# AVG(d169) AS d169_mean,
# AVG(d170) AS d170_mean,
# AVG(d171) AS d171_mean,
# AVG(d172) AS d172_mean,
# AVG(d173) AS d173_mean,
# AVG(d174) AS d174_mean,
# AVG(d175) AS d175_mean,
# AVG(d176) AS d176_mean,
# AVG(d177) AS d177_mean,
# AVG(d178) AS d178_mean,
# AVG(d179) AS d179_mean,
# AVG(d180) AS d180_mean,
# AVG(d181) AS d181_mean,
# AVG(d182) AS d182_mean,
# AVG(d183) AS d183_mean,
# AVG(d184) AS d184_mean,
# AVG(d185) AS d185_mean,
# AVG(d186) AS d186_mean,
# AVG(d187) AS d187_mean,
# AVG(d188) AS d188_mean,
# AVG(d189) AS d189_mean,
# AVG(d190) AS d190_mean,
# AVG(d191) AS d191_mean,
# AVG(d192) AS d192_mean,
# AVG(d193) AS d193_mean,
# AVG(d194) AS d194_mean,
# AVG(d195) AS d195_mean,
# AVG(d196) AS d196_mean,
# AVG(d197) AS d197_mean,
# AVG(d198) AS d198_mean,
# AVG(d199) AS d199_mean,
# AVG(d200) AS d200_mean,
# AVG(d201) AS d201_mean,
# AVG(d202) AS d202_mean,
# AVG(d203) AS d203_mean,
# AVG(d204) AS d204_mean,
# AVG(d205) AS d205_mean,
# AVG(d206) AS d206_mean,
# AVG(d207) AS d207_mean,
# AVG(d208) AS d208_mean,
# AVG(d209) AS d209_mean,
# AVG(d210) AS d210_mean,
# AVG(d211) AS d211_mean,
# AVG(d212) AS d212_mean,
# AVG(d213) AS d213_mean,
# AVG(d214) AS d214_mean,
# AVG(d215) AS d215_mean,
# AVG(d216) AS d216_mean,
# AVG(d217) AS d217_mean,
# AVG(d218) AS d218_mean,
# AVG(d219) AS d219_mean,
# AVG(d220) AS d220_mean,
# AVG(d221) AS d221_mean,
# AVG(d222) AS d222_mean,
# AVG(d223) AS d223_mean,
# AVG(d224) AS d224_mean,
# AVG(d225) AS d225_mean,
# AVG(d226) AS d226_mean,
# AVG(d227) AS d227_mean,
# AVG(d228) AS d228_mean,
# AVG(d229) AS d229_mean,
# AVG(d230) AS d230_mean,
# AVG(d231) AS d231_mean,
# AVG(d232) AS d232_mean,
# AVG(d233) AS d233_mean,
# AVG(d234) AS d234_mean,
# AVG(d235) AS d235_mean,
# AVG(d236) AS d236_mean,
# AVG(d237) AS d237_mean,
# AVG(d238) AS d238_mean,
# AVG(d239) AS d239_mean,
# AVG(d240) AS d240_mean,
# AVG(d241) AS d241_mean,
# AVG(d242) AS d242_mean,
# AVG(d243) AS d243_mean,
# AVG(d244) AS d244_mean,
# AVG(d245) AS d245_mean,
# AVG(d246) AS d246_mean,
# AVG(d247) AS d247_mean,
# AVG(d248) AS d248_mean,
# AVG(d249) AS d249_mean,
# AVG(d250) AS d250_mean,
# AVG(d251) AS d251_mean,
# AVG(d252) AS d252_mean,
# AVG(d253) AS d253_mean,
# AVG(d254) AS d254_mean,
# AVG(d255) AS d255_mean,
# AVG(d256) AS d256_mean,
# AVG(d257) AS d257_mean,
# AVG(d258) AS d258_mean,
# AVG(d259) AS d259_mean,
# AVG(d260) AS d260_mean,
# AVG(d261) AS d261_mean,
# AVG(d262) AS d262_mean,
# AVG(d263) AS d263_mean,
# AVG(d264) AS d264_mean,
# AVG(d265) AS d265_mean,
# AVG(d266) AS d266_mean,
# AVG(d267) AS d267_mean,
# AVG(d268) AS d268_mean,
# AVG(d269) AS d269_mean,
# AVG(d270) AS d270_mean,
# AVG(d271) AS d271_mean,
# AVG(d272) AS d272_mean,
# AVG(d273) AS d273_mean,
# AVG(d274) AS d274_mean,
# AVG(d275) AS d275_mean,
# AVG(d276) AS d276_mean,
# AVG(d277) AS d277_mean,
# AVG(d278) AS d278_mean,
# AVG(d279) AS d279_mean,
# AVG(d280) AS d280_mean,
# AVG(d281) AS d281_mean,
# AVG(d282) AS d282_mean,
# AVG(d283) AS d283_mean,
# AVG(d284) AS d284_mean,
# AVG(d285) AS d285_mean,
# AVG(d286) AS d286_mean,
# AVG(d287) AS d287_mean,
# AVG(d288) AS d288_mean,
# AVG(d289) AS d289_mean,
# AVG(d290) AS d290_mean,
# AVG(d291) AS d291_mean,
# AVG(d292) AS d292_mean,
# AVG(d293) AS d293_mean,
# AVG(d294) AS d294_mean,
# AVG(d295) AS d295_mean,
# AVG(d296) AS d296_mean,
# AVG(d297) AS d297_mean,
# AVG(d298) AS d298_mean,
# AVG(d299) AS d299_mean,
# AVG(d300) AS d300_mean,
# AVG(d301) AS d301_mean,
# AVG(d302) AS d302_mean,
# AVG(d303) AS d303_mean,
# AVG(d304) AS d304_mean,
# AVG(d305) AS d305_mean,
# AVG(d306) AS d306_mean,
# AVG(d307) AS d307_mean,
# AVG(d308) AS d308_mean,
# AVG(d309) AS d309_mean,
# AVG(d310) AS d310_mean,
# AVG(d311) AS d311_mean,
# AVG(d312) AS d312_mean,
# AVG(d313) AS d313_mean,
# AVG(d314) AS d314_mean,
# AVG(d315) AS d315_mean,
# AVG(d316) AS d316_mean,
# AVG(d317) AS d317_mean,
# AVG(d318) AS d318_mean,
# AVG(d319) AS d319_mean,
# AVG(d320) AS d320_mean,
# AVG(d321) AS d321_mean,
# AVG(d322) AS d322_mean,
# AVG(d323) AS d323_mean,
# AVG(d324) AS d324_mean,
# AVG(d325) AS d325_mean,
# AVG(d326) AS d326_mean,
# AVG(d327) AS d327_mean,
# AVG(d328) AS d328_mean,
# AVG(d329) AS d329_mean,
# AVG(d330) AS d330_mean,
# AVG(d331) AS d331_mean,
# AVG(d332) AS d332_mean,
# AVG(d333) AS d333_mean,
# AVG(d334) AS d334_mean,
# AVG(d335) AS d335_mean,
# AVG(d336) AS d336_mean,
# AVG(d337) AS d337_mean,
# AVG(d338) AS d338_mean,
# AVG(d339) AS d339_mean,
# AVG(d340) AS d340_mean,
# AVG(d341) AS d341_mean,
# AVG(d342) AS d342_mean,
# AVG(d343) AS d343_mean,
# AVG(d344) AS d344_mean,
# AVG(d345) AS d345_mean,
# AVG(d346) AS d346_mean,
# AVG(d347) AS d347_mean,
# AVG(d348) AS d348_mean,
# AVG(d349) AS d349_mean,
# AVG(d350) AS d350_mean,
# AVG(d351) AS d351_mean,
# AVG(d352) AS d352_mean,
# AVG(d353) AS d353_mean,
# AVG(d354) AS d354_mean,
# AVG(d355) AS d355_mean,
# AVG(d356) AS d356_mean,
# AVG(d357) AS d357_mean,
# AVG(d358) AS d358_mean,
# AVG(d359) AS d359_mean,
# AVG(d360) AS d360_mean,
# AVG(d361) AS d361_mean,
# AVG(d362) AS d362_mean,
# AVG(d363) AS d363_mean,
# AVG(d364) AS d364_mean,
# AVG(d365) AS d365_mean,
# AVG(d366) AS d366_mean,
# AVG(d367) AS d367_mean,
# AVG(d368) AS d368_mean,
# AVG(d369) AS d369_mean,
# AVG(d370) AS d370_mean,
# AVG(d371) AS d371_mean,
# AVG(d372) AS d372_mean,
# AVG(d373) AS d373_mean,
# AVG(d374) AS d374_mean,
# AVG(d375) AS d375_mean,
# AVG(d376) AS d376_mean,
# AVG(d377) AS d377_mean,
# AVG(d378) AS d378_mean,
# AVG(d379) AS d379_mean,
# AVG(d380) AS d380_mean,
# AVG(d381) AS d381_mean,
# AVG(d382) AS d382_mean,
# AVG(d383) AS d383_mean,
# AVG(d384) AS d384_mean,
# AVG(d385) AS d385_mean,
# AVG(d386) AS d386_mean,
# AVG(d387) AS d387_mean,
# AVG(d388) AS d388_mean,
# AVG(d389) AS d389_mean,
# AVG(d390) AS d390_mean,
# AVG(d391) AS d391_mean,
# AVG(d392) AS d392_mean,
# AVG(d393) AS d393_mean,
# AVG(d394) AS d394_mean,
# AVG(d395) AS d395_mean,
# AVG(d396) AS d396_mean,
# AVG(d397) AS d397_mean,
# AVG(d398) AS d398_mean,
# AVG(d399) AS d399_mean,
# AVG(d400) AS d400_mean,
# AVG(d401) AS d401_mean,
# AVG(d402) AS d402_mean,
# AVG(d403) AS d403_mean,
# AVG(d404) AS d404_mean,
# AVG(d405) AS d405_mean,
# AVG(d406) AS d406_mean,
# AVG(d407) AS d407_mean,
# AVG(d408) AS d408_mean,
# AVG(d409) AS d409_mean,
# AVG(d410) AS d410_mean,
# AVG(d411) AS d411_mean,
# AVG(d412) AS d412_mean,
# AVG(d413) AS d413_mean,
# AVG(d414) AS d414_mean,
# AVG(d415) AS d415_mean,
# AVG(d416) AS d416_mean,
# AVG(d417) AS d417_mean,
# AVG(d418) AS d418_mean,
# AVG(d419) AS d419_mean,
# AVG(d420) AS d420_mean,
# AVG(d421) AS d421_mean,
# AVG(d422) AS d422_mean,
# AVG(d423) AS d423_mean,
# AVG(d424) AS d424_mean,
# AVG(d425) AS d425_mean,
# AVG(d426) AS d426_mean,
# AVG(d427) AS d427_mean,
# AVG(d428) AS d428_mean,
# AVG(d429) AS d429_mean,
# AVG(d430) AS d430_mean,
# AVG(d431) AS d431_mean,
# AVG(d432) AS d432_mean,
# AVG(d433) AS d433_mean,
# AVG(d434) AS d434_mean,
# AVG(d435) AS d435_mean,
# AVG(d436) AS d436_mean,
# AVG(d437) AS d437_mean,
# AVG(d438) AS d438_mean,
# AVG(d439) AS d439_mean,
# AVG(d440) AS d440_mean,
# AVG(d441) AS d441_mean,
# AVG(d442) AS d442_mean,
# AVG(d443) AS d443_mean,
# AVG(d444) AS d444_mean,
# AVG(d445) AS d445_mean,
# AVG(d446) AS d446_mean,
# AVG(d447) AS d447_mean,
# AVG(d448) AS d448_mean,
# AVG(d449) AS d449_mean,
# AVG(d450) AS d450_mean,
# AVG(d451) AS d451_mean,
# AVG(d452) AS d452_mean,
# AVG(d453) AS d453_mean,
# AVG(d454) AS d454_mean,
# AVG(d455) AS d455_mean,
# AVG(d456) AS d456_mean,
# AVG(d457) AS d457_mean,
# AVG(d458) AS d458_mean,
# AVG(d459) AS d459_mean,
# AVG(d460) AS d460_mean,
# AVG(d461) AS d461_mean,
# AVG(d462) AS d462_mean,
# AVG(d463) AS d463_mean,
# AVG(d464) AS d464_mean,
# AVG(d465) AS d465_mean,
# AVG(d466) AS d466_mean,
# AVG(d467) AS d467_mean,
# AVG(d468) AS d468_mean,
# AVG(d469) AS d469_mean,
# AVG(d470) AS d470_mean,
# AVG(d471) AS d471_mean,
# AVG(d472) AS d472_mean,
# AVG(d473) AS d473_mean,
# AVG(d474) AS d474_mean,
# AVG(d475) AS d475_mean,
# AVG(d476) AS d476_mean,
# AVG(d477) AS d477_mean,
# AVG(d478) AS d478_mean,
# AVG(d479) AS d479_mean,
# AVG(d480) AS d480_mean,
# AVG(d481) AS d481_mean,
# AVG(d482) AS d482_mean,
# AVG(d483) AS d483_mean,
# AVG(d484) AS d484_mean,
# AVG(d485) AS d485_mean,
# AVG(d486) AS d486_mean,
# AVG(d487) AS d487_mean,
# AVG(d488) AS d488_mean,
# AVG(d489) AS d489_mean,
# AVG(d490) AS d490_mean,
# AVG(d491) AS d491_mean,
# AVG(d492) AS d492_mean,
# AVG(d493) AS d493_mean,
# AVG(d494) AS d494_mean,
# AVG(d495) AS d495_mean,
# AVG(d496) AS d496_mean,
# AVG(d497) AS d497_mean,
# AVG(d498) AS d498_mean,
# AVG(d499) AS d499_mean,
# AVG(d500) AS d500_mean,
# AVG(d501) AS d501_mean,
# AVG(d502) AS d502_mean,
# AVG(d503) AS d503_mean,
# AVG(d504) AS d504_mean,
# AVG(d505) AS d505_mean,
# AVG(d506) AS d506_mean,
# AVG(d507) AS d507_mean,
# AVG(d508) AS d508_mean,
# AVG(d509) AS d509_mean,
# AVG(d510) AS d510_mean,
# AVG(d511) AS d511_mean,
#
# FROM (
# SELECT f.second_level.name AS f1,
#
# title_embed[OFFSET(0)] AS d0,
# title_embed[OFFSET(1)] AS d1,
# title_embed[OFFSET(2)] AS d2,
# title_embed[OFFSET(3)] AS d3,
# title_embed[OFFSET(4)] AS d4,
# title_embed[OFFSET(5)] AS d5,
# title_embed[OFFSET(6)] AS d6,
# title_embed[OFFSET(7)] AS d7,
# title_embed[OFFSET(8)] AS d8,
# title_embed[OFFSET(9)] AS d9,
# title_embed[OFFSET(10)] AS d10,
# title_embed[OFFSET(11)] AS d11,
# title_embed[OFFSET(12)] AS d12,
# title_embed[OFFSET(13)] AS d13,
# title_embed[OFFSET(14)] AS d14,
# title_embed[OFFSET(15)] AS d15,
# title_embed[OFFSET(16)] AS d16,
# title_embed[OFFSET(17)] AS d17,
# title_embed[OFFSET(18)] AS d18,
# title_embed[OFFSET(19)] AS d19,
# title_embed[OFFSET(20)] AS d20,
# title_embed[OFFSET(21)] AS d21,
# title_embed[OFFSET(22)] AS d22,
# title_embed[OFFSET(23)] AS d23,
# title_embed[OFFSET(24)] AS d24,
# title_embed[OFFSET(25)] AS d25,
# title_embed[OFFSET(26)] AS d26,
# title_embed[OFFSET(27)] AS d27,
# title_embed[OFFSET(28)] AS d28,
# title_embed[OFFSET(29)] AS d29,
# title_embed[OFFSET(30)] AS d30,
# title_embed[OFFSET(31)] AS d31,
# title_embed[OFFSET(32)] AS d32,
# title_embed[OFFSET(33)] AS d33,
# title_embed[OFFSET(34)] AS d34,
# title_embed[OFFSET(35)] AS d35,
# title_embed[OFFSET(36)] AS d36,
# title_embed[OFFSET(37)] AS d37,
# title_embed[OFFSET(38)] AS d38,
# title_embed[OFFSET(39)] AS d39,
# title_embed[OFFSET(40)] AS d40,
# title_embed[OFFSET(41)] AS d41,
# title_embed[OFFSET(42)] AS d42,
# title_embed[OFFSET(43)] AS d43,
# title_embed[OFFSET(483)] AS d483,
# title_embed[OFFSET(484)] AS d484,
# title_embed[OFFSET(485)] AS d485,
# title_embed[OFFSET(486)] AS d486,
# title_embed[OFFSET(487)] AS d487,
# title_embed[OFFSET(488)] AS d488,
# title_embed[OFFSET(489)] AS d489,
# title_embed[OFFSET(490)] AS d490,
# title_embed[OFFSET(491)] AS d491,
# title_embed[OFFSET(492)] AS d492,
# title_embed[OFFSET(493)] AS d493,
# title_embed[OFFSET(494)] AS d494,
# title_embed[OFFSET(495)] AS d495,
# title_embed[OFFSET(496)] AS d496,
# title_embed[OFFSET(497)] AS d497,
# title_embed[OFFSET(498)] AS d498,
# title_embed[OFFSET(499)] AS d499,
# title_embed[OFFSET(500)] AS d500,
# title_embed[OFFSET(501)] AS d501,
# title_embed[OFFSET(502)] AS d502,
# title_embed[OFFSET(503)] AS d503,
# title_embed[OFFSET(504)] AS d504,
# title_embed[OFFSET(505)] AS d505,
# title_embed[OFFSET(506)] AS d506,
# title_embed[OFFSET(507)] AS d507,
# title_embed[OFFSET(508)] AS d508,
# title_embed[OFFSET(509)] AS d509,
# title_embed[OFFSET(510)] AS d510,
# title_embed[OFFSET(511)] AS d511,
#
# FROM `springer-nature-analytics.DS_dimensions.publications_full_refresh`
# LEFT JOIN UNNEST(`for`) AS f LEFT JOIN UNNEST(journal) AS j
# WHERE ARRAY_LENGTH(title_embed) = 512
# AND
# publication_type LIKE "article"
#         AND j.title IN (SELECT title FROM `springer-nature-analytics.core_journals.core_2018_v01`)
#         AND year >= 2005
#         AND year <= 2007
#         AND language LIKE "en"
#         AND ARRAY_LENGTH(references) > 4
#
# ) GROUP BY f1
#  ) WHERE f1 IS NOT NULL

# %%
train_and_save(for_05_07, "wv_05_07", "f2")
# Out:
# Saved mean vectors to "/content/drive/My Drive/Research/Data/Mean-title-centroids-3yrs-v02/wv_05_07_f2.csv"

# %% [markdown]
# # 2002-2004

# %%
# %%bigquery --project $pid for_02_04
#
# SELECT * FROM (
# SELECT f1,
#
# AVG(d0) AS d0_mean,
# AVG(d1) AS d1_mean,
# AVG(d2) AS d2_mean,
# AVG(d3) AS d3_mean,
# AVG(d4) AS d4_mean,
# AVG(d5) AS d5_mean,
# AVG(d6) AS d6_mean,
# AVG(d7) AS d7_mean,
# AVG(d8) AS d8_mean,
# AVG(d9) AS d9_mean,
# AVG(d10) AS d10_mean,
# AVG(d11) AS d11_mean,
# AVG(d12) AS d12_mean,
# AVG(d13) AS d13_mean,
# AVG(d14) AS d14_mean,
# AVG(d15) AS d15_mean,
# AVG(d16) AS d16_mean,
# AVG(d17) AS d17_mean,
# AVG(d18) AS d18_mean,
# AVG(d19) AS d19_mean,
# AVG(d20) AS d20_mean,
# AVG(d21) AS d21_mean,
# AVG(d22) AS d22_mean,
# AVG(d23) AS d23_mean,
# AVG(d24) AS d24_mean,
# AVG(d25) AS d25_mean,
# AVG(d26) AS d26_mean,
# AVG(d27) AS d27_mean,
# AVG(d28) AS d28_mean,
# AVG(d29) AS d29_mean,
# AVG(d30) AS d30_mean,
# AVG(d31) AS d31_mean,
# AVG(d32) AS d32_mean,
# AVG(d33) AS d33_mean,
# AVG(d34) AS d34_mean,
# AVG(d35) AS d35_mean,
# AVG(d36) AS d36_mean,
# AVG(d37) AS d37_mean,
# AVG(d38) AS d38_mean,
# AVG(d39) AS d39_mean,
# AVG(d40) AS d40_mean,
# AVG(d41) AS d41_mean,
# AVG(d42) AS d42_mean,
# AVG(d43) AS d43_mean,
# AVG(d44) AS d44_mean,
# AVG(d45) AS d45_mean,
# AVG(d46) AS d46_mean,
# AVG(d47) AS d47_mean,
# AVG(d48) AS d48_mean,
# AVG(d49) AS d49_mean,
# AVG(d50) AS d50_mean,
# AVG(d51) AS d51_mean,
# AVG(d52) AS d52_mean,
# AVG(d53) AS d53_mean,
# AVG(d54) AS d54_mean,
# AVG(d55) AS d55_mean,
# AVG(d56) AS d56_mean,
# AVG(d57) AS d57_mean,
# AVG(d58) AS d58_mean,
# AVG(d59) AS d59_mean,
# AVG(d60) AS d60_mean,
# AVG(d61) AS d61_mean,
# AVG(d62) AS d62_mean,
# AVG(d63) AS d63_mean,
# AVG(d64) AS d64_mean,
# AVG(d65) AS d65_mean,
# AVG(d66) AS d66_mean,
# AVG(d67) AS d67_mean,
# AVG(d68) AS d68_mean,
# AVG(d69) AS d69_mean,
# AVG(d70) AS d70_mean,
# AVG(d71) AS d71_mean,
# AVG(d72) AS d72_mean,
# AVG(d73) AS d73_mean,
# AVG(d74) AS d74_mean,
# AVG(d75) AS d75_mean,
# AVG(d76) AS d76_mean,
# AVG(d77) AS d77_mean,
# AVG(d78) AS d78_mean,
# AVG(d79) AS d79_mean,
# AVG(d80) AS d80_mean,
# AVG(d81) AS d81_mean,
# AVG(d82) AS d82_mean,
# AVG(d83) AS d83_mean,
# AVG(d84) AS d84_mean,
# AVG(d85) AS d85_mean,
# AVG(d86) AS d86_mean,
# AVG(d87) AS d87_mean,
# AVG(d88) AS d88_mean,
# AVG(d89) AS d89_mean,
# AVG(d90) AS d90_mean,
# AVG(d91) AS d91_mean,
# AVG(d92) AS d92_mean,
# AVG(d93) AS d93_mean,
# AVG(d94) AS d94_mean,
# AVG(d95) AS d95_mean,
# AVG(d96) AS d96_mean,
# AVG(d97) AS d97_mean,
# AVG(d98) AS d98_mean,
# AVG(d99) AS d99_mean,
# AVG(d100) AS d100_mean,
# AVG(d101) AS d101_mean,
# AVG(d102) AS d102_mean,
# AVG(d103) AS d103_mean,
# AVG(d104) AS d104_mean,
# AVG(d105) AS d105_mean,
# AVG(d106) AS d106_mean,
# AVG(d107) AS d107_mean,
# AVG(d108) AS d108_mean,
# AVG(d109) AS d109_mean,
# AVG(d110) AS d110_mean,
# AVG(d111) AS d111_mean,
# AVG(d112) AS d112_mean,
# AVG(d113) AS d113_mean,
# AVG(d114) AS d114_mean,
# AVG(d115) AS d115_mean,
# AVG(d116) AS d116_mean,
# AVG(d117) AS d117_mean,
# AVG(d118) AS d118_mean,
# AVG(d119) AS d119_mean,
# AVG(d120) AS d120_mean,
# AVG(d121) AS d121_mean,
# AVG(d122) AS d122_mean,
# AVG(d123) AS d123_mean,
# AVG(d124) AS d124_mean,
# AVG(d125) AS d125_mean,
# AVG(d126) AS d126_mean,
# AVG(d127) AS d127_mean,
# AVG(d128) AS d128_mean,
# AVG(d129) AS d129_mean,
# AVG(d130) AS d130_mean,
# AVG(d131) AS d131_mean,
# AVG(d132) AS d132_mean,
# AVG(d133) AS d133_mean,
# AVG(d134) AS d134_mean,
# AVG(d135) AS d135_mean,
# AVG(d136) AS d136_mean,
# AVG(d137) AS d137_mean,
# AVG(d138) AS d138_mean,
# AVG(d139) AS d139_mean,
# AVG(d140) AS d140_mean,
# AVG(d141) AS d141_mean,
# AVG(d142) AS d142_mean,
# AVG(d143) AS d143_mean,
# AVG(d144) AS d144_mean,
# AVG(d145) AS d145_mean,
# AVG(d146) AS d146_mean,
# AVG(d147) AS d147_mean,
# AVG(d148) AS d148_mean,
# AVG(d149) AS d149_mean,
# AVG(d150) AS d150_mean,
# AVG(d151) AS d151_mean,
# AVG(d152) AS d152_mean,
# AVG(d153) AS d153_mean,
# AVG(d154) AS d154_mean,
# AVG(d155) AS d155_mean,
# AVG(d156) AS d156_mean,
# AVG(d157) AS d157_mean,
# AVG(d158) AS d158_mean,
# AVG(d159) AS d159_mean,
# AVG(d160) AS d160_mean,
# AVG(d161) AS d161_mean,
# AVG(d162) AS d162_mean,
# AVG(d163) AS d163_mean,
# AVG(d164) AS d164_mean,
# AVG(d165) AS d165_mean,
# AVG(d166) AS d166_mean,
# AVG(d167) AS d167_mean,
# AVG(d168) AS d168_mean,
# AVG(d169) AS d169_mean,
# AVG(d170) AS d170_mean,
# AVG(d171) AS d171_mean,
# AVG(d172) AS d172_mean,
# AVG(d173) AS d173_mean,
# AVG(d174) AS d174_mean,
# AVG(d175) AS d175_mean,
# AVG(d176) AS d176_mean,
# AVG(d177) AS d177_mean,
# AVG(d178) AS d178_mean,
# AVG(d179) AS d179_mean,
# AVG(d180) AS d180_mean,
# AVG(d181) AS d181_mean,
# AVG(d182) AS d182_mean,
# AVG(d183) AS d183_mean,
# AVG(d184) AS d184_mean,
# AVG(d185) AS d185_mean,
# AVG(d186) AS d186_mean,
# AVG(d187) AS d187_mean,
# AVG(d188) AS d188_mean,
# AVG(d189) AS d189_mean,
# AVG(d190) AS d190_mean,
# AVG(d191) AS d191_mean,
# AVG(d192) AS d192_mean,
# AVG(d193) AS d193_mean,
# AVG(d194) AS d194_mean,
# AVG(d195) AS d195_mean,
# AVG(d196) AS d196_mean,
# AVG(d197) AS d197_mean,
# AVG(d198) AS d198_mean,
# AVG(d199) AS d199_mean,
# AVG(d200) AS d200_mean,
# AVG(d201) AS d201_mean,
# AVG(d202) AS d202_mean,
# AVG(d203) AS d203_mean,
# AVG(d204) AS d204_mean,
# AVG(d205) AS d205_mean,
# AVG(d206) AS d206_mean,
# AVG(d207) AS d207_mean,
# AVG(d208) AS d208_mean,
# AVG(d209) AS d209_mean,
# AVG(d210) AS d210_mean,
# AVG(d211) AS d211_mean,
# AVG(d212) AS d212_mean,
# AVG(d213) AS d213_mean,
# AVG(d214) AS d214_mean,
# AVG(d215) AS d215_mean,
# AVG(d216) AS d216_mean,
# AVG(d217) AS d217_mean,
# AVG(d218) AS d218_mean,
# AVG(d219) AS d219_mean,
# AVG(d220) AS d220_mean,
# AVG(d221) AS d221_mean,
# AVG(d222) AS d222_mean,
# AVG(d223) AS d223_mean,
# AVG(d224) AS d224_mean,
# AVG(d225) AS d225_mean,
# AVG(d226) AS d226_mean,
# AVG(d227) AS d227_mean,
# AVG(d228) AS d228_mean,
# AVG(d229) AS d229_mean,
# AVG(d230) AS d230_mean,
# AVG(d231) AS d231_mean,
# AVG(d232) AS d232_mean,
# AVG(d233) AS d233_mean,
# AVG(d234) AS d234_mean,
# AVG(d235) AS d235_mean,
# AVG(d236) AS d236_mean,
# AVG(d237) AS d237_mean,
# AVG(d238) AS d238_mean,
# AVG(d239) AS d239_mean,
# AVG(d240) AS d240_mean,
# AVG(d241) AS d241_mean,
# AVG(d242) AS d242_mean,
# AVG(d243) AS d243_mean,
# AVG(d244) AS d244_mean,
# AVG(d245) AS d245_mean,
# AVG(d246) AS d246_mean,
# AVG(d247) AS d247_mean,
# AVG(d248) AS d248_mean,
# AVG(d249) AS d249_mean,
# AVG(d250) AS d250_mean,
# AVG(d251) AS d251_mean,
# AVG(d252) AS d252_mean,
# AVG(d253) AS d253_mean,
# AVG(d254) AS d254_mean,
# AVG(d255) AS d255_mean,
# AVG(d256) AS d256_mean,
# AVG(d257) AS d257_mean,
# AVG(d258) AS d258_mean,
# AVG(d259) AS d259_mean,
# AVG(d260) AS d260_mean,
# AVG(d261) AS d261_mean,
# AVG(d262) AS d262_mean,
# AVG(d263) AS d263_mean,
# AVG(d264) AS d264_mean,
# AVG(d265) AS d265_mean,
# AVG(d266) AS d266_mean,
# AVG(d267) AS d267_mean,
# AVG(d268) AS d268_mean,
# AVG(d269) AS d269_mean,
# AVG(d270) AS d270_mean,
# AVG(d271) AS d271_mean,
# AVG(d272) AS d272_mean,
# AVG(d273) AS d273_mean,
# AVG(d274) AS d274_mean,
# AVG(d275) AS d275_mean,
# AVG(d276) AS d276_mean,
# AVG(d277) AS d277_mean,
# AVG(d278) AS d278_mean,
# AVG(d279) AS d279_mean,
# AVG(d280) AS d280_mean,
# AVG(d281) AS d281_mean,
# AVG(d282) AS d282_mean,
# AVG(d283) AS d283_mean,
# AVG(d284) AS d284_mean,
# AVG(d285) AS d285_mean,
# AVG(d286) AS d286_mean,
# AVG(d287) AS d287_mean,
# AVG(d288) AS d288_mean,
# AVG(d289) AS d289_mean,
# AVG(d290) AS d290_mean,
# AVG(d291) AS d291_mean,
# AVG(d292) AS d292_mean,
# AVG(d293) AS d293_mean,
# AVG(d294) AS d294_mean,
# AVG(d295) AS d295_mean,
# AVG(d296) AS d296_mean,
# AVG(d297) AS d297_mean,
# AVG(d298) AS d298_mean,
# AVG(d299) AS d299_mean,
# AVG(d300) AS d300_mean,
# AVG(d301) AS d301_mean,
# AVG(d302) AS d302_mean,
# AVG(d303) AS d303_mean,
# AVG(d304) AS d304_mean,
# AVG(d305) AS d305_mean,
# AVG(d306) AS d306_mean,
# AVG(d307) AS d307_mean,
# AVG(d308) AS d308_mean,
# AVG(d309) AS d309_mean,
# AVG(d310) AS d310_mean,
# AVG(d311) AS d311_mean,
# AVG(d312) AS d312_mean,
# AVG(d313) AS d313_mean,
# AVG(d314) AS d314_mean,
# AVG(d315) AS d315_mean,
# AVG(d316) AS d316_mean,
# AVG(d317) AS d317_mean,
# AVG(d318) AS d318_mean,
# AVG(d319) AS d319_mean,
# AVG(d320) AS d320_mean,
# AVG(d321) AS d321_mean,
# AVG(d322) AS d322_mean,
# AVG(d323) AS d323_mean,
# AVG(d324) AS d324_mean,
# AVG(d325) AS d325_mean,
# AVG(d326) AS d326_mean,
# AVG(d327) AS d327_mean,
# AVG(d328) AS d328_mean,
# AVG(d329) AS d329_mean,
# AVG(d330) AS d330_mean,
# AVG(d331) AS d331_mean,
# AVG(d332) AS d332_mean,
# AVG(d333) AS d333_mean,
# AVG(d334) AS d334_mean,
# AVG(d335) AS d335_mean,
# AVG(d336) AS d336_mean,
# AVG(d337) AS d337_mean,
# AVG(d338) AS d338_mean,
# AVG(d339) AS d339_mean,
# AVG(d340) AS d340_mean,
# AVG(d341) AS d341_mean,
# AVG(d342) AS d342_mean,
# AVG(d343) AS d343_mean,
# AVG(d344) AS d344_mean,
# AVG(d345) AS d345_mean,
# AVG(d346) AS d346_mean,
# AVG(d347) AS d347_mean,
# AVG(d348) AS d348_mean,
# AVG(d349) AS d349_mean,
# AVG(d350) AS d350_mean,
# AVG(d351) AS d351_mean,
# AVG(d352) AS d352_mean,
# AVG(d353) AS d353_mean,
# AVG(d354) AS d354_mean,
# AVG(d355) AS d355_mean,
# AVG(d356) AS d356_mean,
# AVG(d357) AS d357_mean,
# AVG(d358) AS d358_mean,
# AVG(d359) AS d359_mean,
# AVG(d360) AS d360_mean,
# AVG(d361) AS d361_mean,
# AVG(d362) AS d362_mean,
# AVG(d363) AS d363_mean,
# AVG(d364) AS d364_mean,
# AVG(d365) AS d365_mean,
# AVG(d366) AS d366_mean,
# AVG(d367) AS d367_mean,
# AVG(d368) AS d368_mean,
# AVG(d369) AS d369_mean,
# AVG(d370) AS d370_mean,
# AVG(d371) AS d371_mean,
# AVG(d372) AS d372_mean,
# AVG(d373) AS d373_mean,
# AVG(d374) AS d374_mean,
# AVG(d375) AS d375_mean,
# AVG(d376) AS d376_mean,
# AVG(d377) AS d377_mean,
# AVG(d378) AS d378_mean,
# AVG(d379) AS d379_mean,
# AVG(d380) AS d380_mean,
# AVG(d381) AS d381_mean,
# AVG(d382) AS d382_mean,
# AVG(d383) AS d383_mean,
# AVG(d384) AS d384_mean,
# AVG(d385) AS d385_mean,
# AVG(d386) AS d386_mean,
# AVG(d387) AS d387_mean,
# AVG(d388) AS d388_mean,
# AVG(d389) AS d389_mean,
# AVG(d390) AS d390_mean,
# AVG(d391) AS d391_mean,
# AVG(d392) AS d392_mean,
# AVG(d393) AS d393_mean,
# AVG(d394) AS d394_mean,
# AVG(d395) AS d395_mean,
# AVG(d396) AS d396_mean,
# AVG(d397) AS d397_mean,
# AVG(d398) AS d398_mean,
# AVG(d399) AS d399_mean,
# AVG(d400) AS d400_mean,
# AVG(d401) AS d401_mean,
# AVG(d402) AS d402_mean,
# AVG(d403) AS d403_mean,
# AVG(d404) AS d404_mean,
# AVG(d405) AS d405_mean,
# AVG(d406) AS d406_mean,
# AVG(d407) AS d407_mean,
# AVG(d408) AS d408_mean,
# AVG(d409) AS d409_mean,
# AVG(d410) AS d410_mean,
# AVG(d411) AS d411_mean,
# AVG(d412) AS d412_mean,
# AVG(d413) AS d413_mean,
# AVG(d414) AS d414_mean,
# AVG(d415) AS d415_mean,
# AVG(d416) AS d416_mean,
# AVG(d417) AS d417_mean,
# AVG(d418) AS d418_mean,
# AVG(d419) AS d419_mean,
# AVG(d420) AS d420_mean,
# AVG(d421) AS d421_mean,
# AVG(d422) AS d422_mean,
# AVG(d423) AS d423_mean,
# AVG(d424) AS d424_mean,
# AVG(d425) AS d425_mean,
# AVG(d426) AS d426_mean,
# AVG(d427) AS d427_mean,
# AVG(d428) AS d428_mean,
# AVG(d429) AS d429_mean,
# AVG(d430) AS d430_mean,
# AVG(d431) AS d431_mean,
# AVG(d432) AS d432_mean,
# AVG(d433) AS d433_mean,
# AVG(d434) AS d434_mean,
# AVG(d435) AS d435_mean,
# AVG(d436) AS d436_mean,
# AVG(d437) AS d437_mean,
# AVG(d438) AS d438_mean,
# AVG(d439) AS d439_mean,
# AVG(d440) AS d440_mean,
# AVG(d441) AS d441_mean,
# AVG(d442) AS d442_mean,
# AVG(d443) AS d443_mean,
# AVG(d444) AS d444_mean,
# AVG(d445) AS d445_mean,
# AVG(d446) AS d446_mean,
# AVG(d447) AS d447_mean,
# AVG(d448) AS d448_mean,
# AVG(d449) AS d449_mean,
# AVG(d450) AS d450_mean,
# AVG(d451) AS d451_mean,
# AVG(d452) AS d452_mean,
# AVG(d453) AS d453_mean,
# AVG(d454) AS d454_mean,
# AVG(d455) AS d455_mean,
# AVG(d456) AS d456_mean,
# AVG(d457) AS d457_mean,
# AVG(d458) AS d458_mean,
# AVG(d459) AS d459_mean,
# AVG(d460) AS d460_mean,
# AVG(d461) AS d461_mean,
# AVG(d462) AS d462_mean,
# AVG(d463) AS d463_mean,
# AVG(d464) AS d464_mean,
# AVG(d465) AS d465_mean,
# AVG(d466) AS d466_mean,
# AVG(d467) AS d467_mean,
# AVG(d468) AS d468_mean,
# AVG(d469) AS d469_mean,
# AVG(d470) AS d470_mean,
# AVG(d471) AS d471_mean,
# AVG(d472) AS d472_mean,
# AVG(d473) AS d473_mean,
# AVG(d474) AS d474_mean,
# AVG(d475) AS d475_mean,
# AVG(d476) AS d476_mean,
# AVG(d477) AS d477_mean,
# AVG(d478) AS d478_mean,
# AVG(d479) AS d479_mean,
# AVG(d480) AS d480_mean,
# AVG(d481) AS d481_mean,
# AVG(d482) AS d482_mean,
# AVG(d483) AS d483_mean,
# AVG(d484) AS d484_mean,
# AVG(d485) AS d485_mean,
# AVG(d486) AS d486_mean,
# AVG(d487) AS d487_mean,
# AVG(d488) AS d488_mean,
# AVG(d489) AS d489_mean,
# AVG(d490) AS d490_mean,
# AVG(d491) AS d491_mean,
# AVG(d492) AS d492_mean,
# AVG(d493) AS d493_mean,
# AVG(d494) AS d494_mean,
# AVG(d495) AS d495_mean,
# AVG(d496) AS d496_mean,
# AVG(d497) AS d497_mean,
# AVG(d498) AS d498_mean,
# AVG(d499) AS d499_mean,
# AVG(d500) AS d500_mean,
# AVG(d501) AS d501_mean,
# AVG(d502) AS d502_mean,
# AVG(d503) AS d503_mean,
# AVG(d504) AS d504_mean,
# AVG(d505) AS d505_mean,
# AVG(d506) AS d506_mean,
# AVG(d507) AS d507_mean,
# AVG(d508) AS d508_mean,
# AVG(d509) AS d509_mean,
# AVG(d510) AS d510_mean,
# AVG(d511) AS d511_mean,
#
# FROM (
# SELECT f.first_level.name AS f1,
#
# title_embed[OFFSET(0)] AS d0,
# title_embed[OFFSET(1)] AS d1,
# title_embed[OFFSET(2)] AS d2,
# title_embed[OFFSET(3)] AS d3,
# title_embed[OFFSET(4)] AS d4,
# title_embed[OFFSET(5)] AS d5,
# title_embed[OFFSET(6)] AS d6,
# title_embed[OFFSET(7)] AS d7,
# title_embed[OFFSET(8)] AS d8,
# title_embed[OFFSET(9)] AS d9,
# title_embed[OFFSET(10)] AS d10,
# title_embed[OFFSET(11)] AS d11,
# title_embed[OFFSET(12)] AS d12,
# title_embed[OFFSET(13)] AS d13,
# title_embed[OFFSET(14)] AS d14,
# title_embed[OFFSET(15)] AS d15,
# title_embed[OFFSET(16)] AS d16,
# title_embed[OFFSET(17)] AS d17,
# title_embed[OFFSET(18)] AS d18,
# title_embed[OFFSET(19)] AS d19,
# title_embed[OFFSET(20)] AS d20,
# title_embed[OFFSET(21)] AS d21,
# title_embed[OFFSET(22)] AS d22,
# title_embed[OFFSET(23)] AS d23,
# title_embed[OFFSET(24)] AS d24,
# title_embed[OFFSET(25)] AS d25,
# title_embed[OFFSET(26)] AS d26,
# title_embed[OFFSET(27)] AS d27,
# title_embed[OFFSET(28)] AS d28,
# title_embed[OFFSET(29)] AS d29,
# title_embed[OFFSET(30)] AS d30,
# title_embed[OFFSET(31)] AS d31,
# title_embed[OFFSET(32)] AS d32,
# title_embed[OFFSET(33)] AS d33,
# title_embed[OFFSET(34)] AS d34,
# title_embed[OFFSET(35)] AS d35,
# title_embed[OFFSET(36)] AS d36,
# title_embed[OFFSET(37)] AS d37,
# title_embed[OFFSET(38)] AS d38,
# title_embed[OFFSET(39)] AS d39,
# title_embed[OFFSET(40)] AS d40,
# title_embed[OFFSET(41)] AS d41,
# title_embed[OFFSET(42)] AS d42,
# title_embed[OFFSET(43)] AS d43,
# title_embed[OFFSET(44)] AS d44,
# title_embed[OFFSET(45)] AS d45,
# title_embed[OFFSET(46)] AS d46,
# title_embed[OFFSET(47)] AS d47,
# title_embed[OFFSET(487)] AS d487,
# title_embed[OFFSET(488)] AS d488,
# title_embed[OFFSET(489)] AS d489,
# title_embed[OFFSET(490)] AS d490,
# title_embed[OFFSET(491)] AS d491,
# title_embed[OFFSET(492)] AS d492,
# title_embed[OFFSET(493)] AS d493,
# title_embed[OFFSET(494)] AS d494,
# title_embed[OFFSET(495)] AS d495,
# title_embed[OFFSET(496)] AS d496,
# title_embed[OFFSET(497)] AS d497,
# title_embed[OFFSET(498)] AS d498,
# title_embed[OFFSET(499)] AS d499,
# title_embed[OFFSET(500)] AS d500,
# title_embed[OFFSET(501)] AS d501,
# title_embed[OFFSET(502)] AS d502,
# title_embed[OFFSET(503)] AS d503,
# title_embed[OFFSET(504)] AS d504,
# title_embed[OFFSET(505)] AS d505,
# title_embed[OFFSET(506)] AS d506,
# title_embed[OFFSET(507)] AS d507,
# title_embed[OFFSET(508)] AS d508,
# title_embed[OFFSET(509)] AS d509,
# title_embed[OFFSET(510)] AS d510,
# title_embed[OFFSET(511)] AS d511,
#
# FROM `springer-nature-analytics.DS_dimensions.publications_full_refresh`
# LEFT JOIN UNNEST(`for`) AS f LEFT JOIN UNNEST(journal) AS j
# WHERE ARRAY_LENGTH(title_embed) = 512
# AND
# publication_type LIKE "article"
#         AND j.title IN (SELECT title FROM `springer-nature-analytics.core_journals.core_2018_v01`)
#         AND year >= 2002
#         AND year <= 2004
#         AND language LIKE "en"
#         AND ARRAY_LENGTH(references) > 4
#
# ) GROUP BY f1
#  ) WHERE f1 IS NOT NULL

# %%
train_and_save(for_02_04, "wv_02_04")
# Out:
# Saved mean vectors to "/content/drive/My Drive/Research/Data/Mean-title-centroids-3yrs-v02/wv_02_04_f1.csv"

# %%
# %%bigquery --project $pid for_02_04
#
# SELECT * FROM (
# SELECT f1,
#
# AVG(d0) AS d0_mean,
# AVG(d1) AS d1_mean,
# AVG(d2) AS d2_mean,
# AVG(d3) AS d3_mean,
# AVG(d4) AS d4_mean,
# AVG(d5) AS d5_mean,
# AVG(d6) AS d6_mean,
# AVG(d7) AS d7_mean,
# AVG(d8) AS d8_mean,
# AVG(d9) AS d9_mean,
# AVG(d10) AS d10_mean,
# AVG(d11) AS d11_mean,
# AVG(d12) AS d12_mean,
# AVG(d13) AS d13_mean,
# AVG(d14) AS d14_mean,
# AVG(d15) AS d15_mean,
# AVG(d16) AS d16_mean,
# AVG(d17) AS d17_mean,
# AVG(d18) AS d18_mean,
# AVG(d19) AS d19_mean,
# AVG(d20) AS d20_mean,
# AVG(d21) AS d21_mean,
# AVG(d22) AS d22_mean,
# AVG(d23) AS d23_mean,
# AVG(d24) AS d24_mean,
# AVG(d25) AS d25_mean,
# AVG(d26) AS d26_mean,
# AVG(d27) AS d27_mean,
# AVG(d28) AS d28_mean,
# AVG(d29) AS d29_mean,
# AVG(d30) AS d30_mean,
# AVG(d31) AS d31_mean,
# AVG(d32) AS d32_mean,
# AVG(d33) AS d33_mean,
# AVG(d34) AS d34_mean,
# AVG(d35) AS d35_mean,
# AVG(d36) AS d36_mean,
# AVG(d37) AS d37_mean,
# AVG(d38) AS d38_mean,
# AVG(d39) AS d39_mean,
# AVG(d40) AS d40_mean,
# AVG(d41) AS d41_mean,
# AVG(d42) AS d42_mean,
# AVG(d43) AS d43_mean,
# AVG(d44) AS d44_mean,
# AVG(d45) AS d45_mean,
# AVG(d46) AS d46_mean,
# AVG(d47) AS d47_mean,
# AVG(d48) AS d48_mean,
# AVG(d49) AS d49_mean,
# AVG(d50) AS d50_mean,
# AVG(d51) AS d51_mean,
# AVG(d52) AS d52_mean,
# AVG(d53) AS d53_mean,
# AVG(d54) AS d54_mean,
# AVG(d55) AS d55_mean,
# AVG(d56) AS d56_mean,
# AVG(d57) AS d57_mean,
# AVG(d58) AS d58_mean,
# AVG(d59) AS d59_mean,
# AVG(d60) AS d60_mean,
# AVG(d61) AS d61_mean,
# AVG(d62) AS d62_mean,
# AVG(d63) AS d63_mean,
# AVG(d64) AS d64_mean,
# AVG(d65) AS d65_mean,
# AVG(d66) AS d66_mean,
# AVG(d67) AS d67_mean,
# AVG(d68) AS d68_mean,
# AVG(d69) AS d69_mean,
# AVG(d70) AS d70_mean,
# AVG(d71) AS d71_mean,
# AVG(d72) AS d72_mean,
# AVG(d73) AS d73_mean,
# AVG(d74) AS d74_mean,
# AVG(d75) AS d75_mean,
# AVG(d76) AS d76_mean,
# AVG(d77) AS d77_mean,
# AVG(d78) AS d78_mean,
# AVG(d79) AS d79_mean,
# AVG(d80) AS d80_mean,
# AVG(d81) AS d81_mean,
# AVG(d82) AS d82_mean,
# AVG(d83) AS d83_mean,
# AVG(d84) AS d84_mean,
# AVG(d85) AS d85_mean,
# AVG(d86) AS d86_mean,
# AVG(d87) AS d87_mean,
# AVG(d88) AS d88_mean,
# AVG(d89) AS d89_mean,
# AVG(d90) AS d90_mean,
# AVG(d91) AS d91_mean,
# AVG(d92) AS d92_mean,
# AVG(d93) AS d93_mean,
# AVG(d94) AS d94_mean,
# AVG(d95) AS d95_mean,
# AVG(d96) AS d96_mean,
# AVG(d97) AS d97_mean,
# AVG(d98) AS d98_mean,
# AVG(d99) AS d99_mean,
# AVG(d100) AS d100_mean,
# AVG(d101) AS d101_mean,
# AVG(d102) AS d102_mean,
# AVG(d103) AS d103_mean,
# AVG(d104) AS d104_mean,
# AVG(d105) AS d105_mean,
# AVG(d106) AS d106_mean,
# AVG(d107) AS d107_mean,
# AVG(d108) AS d108_mean,
# AVG(d109) AS d109_mean,
# AVG(d110) AS d110_mean,
# AVG(d111) AS d111_mean,
# AVG(d112) AS d112_mean,
# AVG(d113) AS d113_mean,
# AVG(d114) AS d114_mean,
# AVG(d115) AS d115_mean,
# AVG(d116) AS d116_mean,
# AVG(d117) AS d117_mean,
# AVG(d118) AS d118_mean,
# AVG(d119) AS d119_mean,
# AVG(d120) AS d120_mean,
# AVG(d121) AS d121_mean,
# AVG(d122) AS d122_mean,
# AVG(d123) AS d123_mean,
# AVG(d124) AS d124_mean,
# AVG(d125) AS d125_mean,
# AVG(d126) AS d126_mean,
# AVG(d127) AS d127_mean,
# AVG(d128) AS d128_mean,
# AVG(d129) AS d129_mean,
# AVG(d130) AS d130_mean,
# AVG(d131) AS d131_mean,
# AVG(d132) AS d132_mean,
# AVG(d133) AS d133_mean,
# AVG(d134) AS d134_mean,
# AVG(d135) AS d135_mean,
# AVG(d136) AS d136_mean,
# AVG(d137) AS d137_mean,
# AVG(d138) AS d138_mean,
# AVG(d139) AS d139_mean,
# AVG(d140) AS d140_mean,
# AVG(d141) AS d141_mean,
# AVG(d142) AS d142_mean,
# AVG(d143) AS d143_mean,
# AVG(d144) AS d144_mean,
# AVG(d145) AS d145_mean,
# AVG(d146) AS d146_mean,
# AVG(d147) AS d147_mean,
# AVG(d148) AS d148_mean,
# AVG(d149) AS d149_mean,
# AVG(d150) AS d150_mean,
# AVG(d151) AS d151_mean,
# AVG(d152) AS d152_mean,
# AVG(d153) AS d153_mean,
# AVG(d154) AS d154_mean,
# AVG(d155) AS d155_mean,
# AVG(d156) AS d156_mean,
# AVG(d157) AS d157_mean,
# AVG(d158) AS d158_mean,
# AVG(d159) AS d159_mean,
# AVG(d160) AS d160_mean,
# AVG(d161) AS d161_mean,
# AVG(d162) AS d162_mean,
# AVG(d163) AS d163_mean,
# AVG(d164) AS d164_mean,
# AVG(d165) AS d165_mean,
# AVG(d166) AS d166_mean,
# AVG(d167) AS d167_mean,
# AVG(d168) AS d168_mean,
# AVG(d169) AS d169_mean,
# AVG(d170) AS d170_mean,
# AVG(d171) AS d171_mean,
# AVG(d172) AS d172_mean,
# AVG(d173) AS d173_mean,
# AVG(d174) AS d174_mean,
# AVG(d175) AS d175_mean,
# AVG(d176) AS d176_mean,
# AVG(d177) AS d177_mean,
# AVG(d178) AS d178_mean,
# AVG(d179) AS d179_mean,
# AVG(d180) AS d180_mean,
# AVG(d181) AS d181_mean,
# AVG(d182) AS d182_mean,
# AVG(d183) AS d183_mean,
# AVG(d184) AS d184_mean,
# AVG(d185) AS d185_mean,
# AVG(d186) AS d186_mean,
# AVG(d187) AS d187_mean,
# AVG(d188) AS d188_mean,
# AVG(d189) AS d189_mean,
# AVG(d190) AS d190_mean,
# AVG(d191) AS d191_mean,
# AVG(d192) AS d192_mean,
# AVG(d193) AS d193_mean,
# AVG(d194) AS d194_mean,
# AVG(d195) AS d195_mean,
# AVG(d196) AS d196_mean,
# AVG(d197) AS d197_mean,
# AVG(d198) AS d198_mean,
# AVG(d199) AS d199_mean,
# AVG(d200) AS d200_mean,
# AVG(d201) AS d201_mean,
# AVG(d202) AS d202_mean,
# AVG(d203) AS d203_mean,
# AVG(d204) AS d204_mean,
# AVG(d205) AS d205_mean,
# AVG(d206) AS d206_mean,
# AVG(d207) AS d207_mean,
# AVG(d208) AS d208_mean,
# AVG(d209) AS d209_mean,
# AVG(d210) AS d210_mean,
# AVG(d211) AS d211_mean,
# AVG(d212) AS d212_mean,
# AVG(d213) AS d213_mean,
# AVG(d214) AS d214_mean,
# AVG(d215) AS d215_mean,
# AVG(d216) AS d216_mean,
# AVG(d217) AS d217_mean,
# AVG(d218) AS d218_mean,
# AVG(d219) AS d219_mean,
# AVG(d220) AS d220_mean,
# AVG(d221) AS d221_mean,
# AVG(d222) AS d222_mean,
# AVG(d223) AS d223_mean,
# AVG(d224) AS d224_mean,
# AVG(d225) AS d225_mean,
# AVG(d226) AS d226_mean,
# AVG(d227) AS d227_mean,
# AVG(d228) AS d228_mean,
# AVG(d229) AS d229_mean,
# AVG(d230) AS d230_mean,
# AVG(d231) AS d231_mean,
# AVG(d232) AS d232_mean,
# AVG(d233) AS d233_mean,
# AVG(d234) AS d234_mean,
# AVG(d235) AS d235_mean,
# AVG(d236) AS d236_mean,
# AVG(d237) AS d237_mean,
# AVG(d238) AS d238_mean,
# AVG(d239) AS d239_mean,
# AVG(d240) AS d240_mean,
# AVG(d241) AS d241_mean,
# AVG(d242) AS d242_mean,
# AVG(d243) AS d243_mean,
# AVG(d244) AS d244_mean,
# AVG(d245) AS d245_mean,
# AVG(d246) AS d246_mean,
# AVG(d247) AS d247_mean,
# AVG(d248) AS d248_mean,
# AVG(d249) AS d249_mean,
# AVG(d250) AS d250_mean,
# AVG(d251) AS d251_mean,
# AVG(d252) AS d252_mean,
# AVG(d253) AS d253_mean,
# AVG(d254) AS d254_mean,
# AVG(d255) AS d255_mean,
# AVG(d256) AS d256_mean,
# AVG(d257) AS d257_mean,
# AVG(d258) AS d258_mean,
# AVG(d259) AS d259_mean,
# AVG(d260) AS d260_mean,
# AVG(d261) AS d261_mean,
# AVG(d262) AS d262_mean,
# AVG(d263) AS d263_mean,
# AVG(d264) AS d264_mean,
# AVG(d265) AS d265_mean,
# AVG(d266) AS d266_mean,
# AVG(d267) AS d267_mean,
# AVG(d268) AS d268_mean,
# AVG(d269) AS d269_mean,
# AVG(d270) AS d270_mean,
# AVG(d271) AS d271_mean,
# AVG(d272) AS d272_mean,
# AVG(d273) AS d273_mean,
# AVG(d274) AS d274_mean,
# AVG(d275) AS d275_mean,
# AVG(d276) AS d276_mean,
# AVG(d277) AS d277_mean,
# AVG(d278) AS d278_mean,
# AVG(d279) AS d279_mean,
# AVG(d280) AS d280_mean,
# AVG(d281) AS d281_mean,
# AVG(d282) AS d282_mean,
# AVG(d283) AS d283_mean,
# AVG(d284) AS d284_mean,
# AVG(d285) AS d285_mean,
# AVG(d286) AS d286_mean,
# AVG(d287) AS d287_mean,
# AVG(d288) AS d288_mean,
# AVG(d289) AS d289_mean,
# AVG(d290) AS d290_mean,
# AVG(d291) AS d291_mean,
# AVG(d292) AS d292_mean,
# AVG(d293) AS d293_mean,
# AVG(d294) AS d294_mean,
# AVG(d295) AS d295_mean,
# AVG(d296) AS d296_mean,
# AVG(d297) AS d297_mean,
# AVG(d298) AS d298_mean,
# AVG(d299) AS d299_mean,
# AVG(d300) AS d300_mean,
# AVG(d301) AS d301_mean,
# AVG(d302) AS d302_mean,
# AVG(d303) AS d303_mean,
# AVG(d304) AS d304_mean,
# AVG(d305) AS d305_mean,
# AVG(d306) AS d306_mean,
# AVG(d307) AS d307_mean,
# AVG(d308) AS d308_mean,
# AVG(d309) AS d309_mean,
# AVG(d310) AS d310_mean,
# AVG(d311) AS d311_mean,
# AVG(d312) AS d312_mean,
# AVG(d313) AS d313_mean,
# AVG(d314) AS d314_mean,
# AVG(d315) AS d315_mean,
# AVG(d316) AS d316_mean,
# AVG(d317) AS d317_mean,
# AVG(d318) AS d318_mean,
# AVG(d319) AS d319_mean,
# AVG(d320) AS d320_mean,
# AVG(d321) AS d321_mean,
# AVG(d322) AS d322_mean,
# AVG(d323) AS d323_mean,
# AVG(d324) AS d324_mean,
# AVG(d325) AS d325_mean,
# AVG(d326) AS d326_mean,
# AVG(d327) AS d327_mean,
# AVG(d328) AS d328_mean,
# AVG(d329) AS d329_mean,
# AVG(d330) AS d330_mean,
# AVG(d331) AS d331_mean,
# AVG(d332) AS d332_mean,
# AVG(d333) AS d333_mean,
# AVG(d334) AS d334_mean,
# AVG(d335) AS d335_mean,
# AVG(d336) AS d336_mean,
# AVG(d337) AS d337_mean,
# AVG(d338) AS d338_mean,
# AVG(d339) AS d339_mean,
# AVG(d340) AS d340_mean,
# AVG(d341) AS d341_mean,
# AVG(d342) AS d342_mean,
# AVG(d343) AS d343_mean,
# AVG(d344) AS d344_mean,
# AVG(d345) AS d345_mean,
# AVG(d346) AS d346_mean,
# AVG(d347) AS d347_mean,
# AVG(d348) AS d348_mean,
# AVG(d349) AS d349_mean,
# AVG(d350) AS d350_mean,
# AVG(d351) AS d351_mean,
# AVG(d352) AS d352_mean,
# AVG(d353) AS d353_mean,
# AVG(d354) AS d354_mean,
# AVG(d355) AS d355_mean,
# AVG(d356) AS d356_mean,
# AVG(d357) AS d357_mean,
# AVG(d358) AS d358_mean,
# AVG(d359) AS d359_mean,
# AVG(d360) AS d360_mean,
# AVG(d361) AS d361_mean,
# AVG(d362) AS d362_mean,
# AVG(d363) AS d363_mean,
# AVG(d364) AS d364_mean,
# AVG(d365) AS d365_mean,
# AVG(d366) AS d366_mean,
# AVG(d367) AS d367_mean,
# AVG(d368) AS d368_mean,
# AVG(d369) AS d369_mean,
# AVG(d370) AS d370_mean,
# AVG(d371) AS d371_mean,
# AVG(d372) AS d372_mean,
# AVG(d373) AS d373_mean,
# AVG(d374) AS d374_mean,
# AVG(d375) AS d375_mean,
# AVG(d376) AS d376_mean,
# AVG(d377) AS d377_mean,
# AVG(d378) AS d378_mean,
# AVG(d379) AS d379_mean,
# AVG(d380) AS d380_mean,
# AVG(d381) AS d381_mean,
# AVG(d382) AS d382_mean,
# AVG(d383) AS d383_mean,
# AVG(d384) AS d384_mean,
# AVG(d385) AS d385_mean,
# AVG(d386) AS d386_mean,
# AVG(d387) AS d387_mean,
# AVG(d388) AS d388_mean,
# AVG(d389) AS d389_mean,
# AVG(d390) AS d390_mean,
# AVG(d391) AS d391_mean,
# AVG(d392) AS d392_mean,
# AVG(d393) AS d393_mean,
# AVG(d394) AS d394_mean,
# AVG(d395) AS d395_mean,
# AVG(d396) AS d396_mean,
# AVG(d397) AS d397_mean,
# AVG(d398) AS d398_mean,
# AVG(d399) AS d399_mean,
# AVG(d400) AS d400_mean,
# AVG(d401) AS d401_mean,
# AVG(d402) AS d402_mean,
# AVG(d403) AS d403_mean,
# AVG(d404) AS d404_mean,
# AVG(d405) AS d405_mean,
# AVG(d406) AS d406_mean,
# AVG(d407) AS d407_mean,
# AVG(d408) AS d408_mean,
# AVG(d409) AS d409_mean,
# AVG(d410) AS d410_mean,
# AVG(d411) AS d411_mean,
# AVG(d412) AS d412_mean,
# AVG(d413) AS d413_mean,
# AVG(d414) AS d414_mean,
# AVG(d415) AS d415_mean,
# AVG(d416) AS d416_mean,
# AVG(d417) AS d417_mean,
# AVG(d418) AS d418_mean,
# AVG(d419) AS d419_mean,
# AVG(d420) AS d420_mean,
# AVG(d421) AS d421_mean,
# AVG(d422) AS d422_mean,
# AVG(d423) AS d423_mean,
# AVG(d424) AS d424_mean,
# AVG(d425) AS d425_mean,
# AVG(d426) AS d426_mean,
# AVG(d427) AS d427_mean,
# AVG(d428) AS d428_mean,
# AVG(d429) AS d429_mean,
# AVG(d430) AS d430_mean,
# AVG(d431) AS d431_mean,
# AVG(d432) AS d432_mean,
# AVG(d433) AS d433_mean,
# AVG(d434) AS d434_mean,
# AVG(d435) AS d435_mean,
# AVG(d436) AS d436_mean,
# AVG(d437) AS d437_mean,
# AVG(d438) AS d438_mean,
# AVG(d439) AS d439_mean,
# AVG(d440) AS d440_mean,
# AVG(d441) AS d441_mean,
# AVG(d442) AS d442_mean,
# AVG(d443) AS d443_mean,
# AVG(d444) AS d444_mean,
# AVG(d445) AS d445_mean,
# AVG(d446) AS d446_mean,
# AVG(d447) AS d447_mean,
# AVG(d448) AS d448_mean,
# AVG(d449) AS d449_mean,
# AVG(d450) AS d450_mean,
# AVG(d451) AS d451_mean,
# AVG(d452) AS d452_mean,
# AVG(d453) AS d453_mean,
# AVG(d454) AS d454_mean,
# AVG(d455) AS d455_mean,
# AVG(d456) AS d456_mean,
# AVG(d457) AS d457_mean,
# AVG(d458) AS d458_mean,
# AVG(d459) AS d459_mean,
# AVG(d460) AS d460_mean,
# AVG(d461) AS d461_mean,
# AVG(d462) AS d462_mean,
# AVG(d463) AS d463_mean,
# AVG(d464) AS d464_mean,
# AVG(d465) AS d465_mean,
# AVG(d466) AS d466_mean,
# AVG(d467) AS d467_mean,
# AVG(d468) AS d468_mean,
# AVG(d469) AS d469_mean,
# AVG(d470) AS d470_mean,
# AVG(d471) AS d471_mean,
# AVG(d472) AS d472_mean,
# AVG(d473) AS d473_mean,
# AVG(d474) AS d474_mean,
# AVG(d475) AS d475_mean,
# AVG(d476) AS d476_mean,
# AVG(d477) AS d477_mean,
# AVG(d478) AS d478_mean,
# AVG(d479) AS d479_mean,
# AVG(d480) AS d480_mean,
# AVG(d481) AS d481_mean,
# AVG(d482) AS d482_mean,
# AVG(d483) AS d483_mean,
# AVG(d484) AS d484_mean,
# AVG(d485) AS d485_mean,
# AVG(d486) AS d486_mean,
# AVG(d487) AS d487_mean,
# AVG(d488) AS d488_mean,
# AVG(d489) AS d489_mean,
# AVG(d490) AS d490_mean,
# AVG(d491) AS d491_mean,
# AVG(d492) AS d492_mean,
# AVG(d493) AS d493_mean,
# AVG(d494) AS d494_mean,
# AVG(d495) AS d495_mean,
# AVG(d496) AS d496_mean,
# AVG(d497) AS d497_mean,
# AVG(d498) AS d498_mean,
# AVG(d499) AS d499_mean,
# AVG(d500) AS d500_mean,
# AVG(d501) AS d501_mean,
# AVG(d502) AS d502_mean,
# AVG(d503) AS d503_mean,
# AVG(d504) AS d504_mean,
# AVG(d505) AS d505_mean,
# AVG(d506) AS d506_mean,
# AVG(d507) AS d507_mean,
# AVG(d508) AS d508_mean,
# AVG(d509) AS d509_mean,
# AVG(d510) AS d510_mean,
# AVG(d511) AS d511_mean,
#
# FROM (
# SELECT f.second_level.name AS f1,
#
# title_embed[OFFSET(0)] AS d0,
# title_embed[OFFSET(1)] AS d1,
# title_embed[OFFSET(2)] AS d2,
# title_embed[OFFSET(3)] AS d3,
# title_embed[OFFSET(4)] AS d4,
# title_embed[OFFSET(5)] AS d5,
# title_embed[OFFSET(6)] AS d6,
# title_embed[OFFSET(7)] AS d7,
# title_embed[OFFSET(8)] AS d8,
# title_embed[OFFSET(9)] AS d9,
# title_embed[OFFSET(10)] AS d10,
# title_embed[OFFSET(11)] AS d11,
# title_embed[OFFSET(12)] AS d12,
# title_embed[OFFSET(13)] AS d13,
# title_embed[OFFSET(14)] AS d14,
# title_embed[OFFSET(15)] AS d15,
# title_embed[OFFSET(16)] AS d16,
# title_embed[OFFSET(17)] AS d17,
# title_embed[OFFSET(18)] AS d18,
# title_embed[OFFSET(19)] AS d19,
# title_embed[OFFSET(20)] AS d20,
# title_embed[OFFSET(21)] AS d21,
# title_embed[OFFSET(22)] AS d22,
# title_embed[OFFSET(23)] AS d23,
# title_embed[OFFSET(24)] AS d24,
# title_embed[OFFSET(25)] AS d25,
# title_embed[OFFSET(26)] AS d26,
# title_embed[OFFSET(27)] AS d27,
# title_embed[OFFSET(28)] AS d28,
# title_embed[OFFSET(29)] AS d29,
# title_embed[OFFSET(30)] AS d30,
# title_embed[OFFSET(31)] AS d31,
# title_embed[OFFSET(32)] AS d32,
# title_embed[OFFSET(33)] AS d33,
# title_embed[OFFSET(34)] AS d34,
# title_embed[OFFSET(35)] AS d35,
# title_embed[OFFSET(36)] AS d36,
# title_embed[OFFSET(37)] AS d37,
# title_embed[OFFSET(38)] AS d38,
# title_embed[OFFSET(39)] AS d39,
# title_embed[OFFSET(40)] AS d40,
# title_embed[OFFSET(41)] AS d41,
# title_embed[OFFSET(42)] AS d42,
# title_embed[OFFSET(43)] AS d43,
# title_embed[OFFSET(44)] AS d44,
# title_embed[OFFSET(45)] AS d45,
# title_embed[OFFSET(46)] AS d46,
# title_embed[OFFSET(47)] AS d47,
# title_embed[OFFSET(48)] AS d48,
# title_embed[OFFSET(49)] AS d49,
# title_embed[OFFSET(50)] AS d50,
# title_embed[OFFSET(51)] AS d51,
# title_embed[OFFSET(52)] AS d52,
# title_embed[OFFSET(492)] AS d492,
# title_embed[OFFSET(493)] AS d493,
# title_embed[OFFSET(494)] AS d494,
# title_embed[OFFSET(495)] AS d495,
# title_embed[OFFSET(496)] AS d496,
# title_embed[OFFSET(497)] AS d497,
# title_embed[OFFSET(498)] AS d498,
# title_embed[OFFSET(499)] AS d499,
# title_embed[OFFSET(500)] AS d500,
# title_embed[OFFSET(501)] AS d501,
# title_embed[OFFSET(502)] AS d502,
# title_embed[OFFSET(503)] AS d503,
# title_embed[OFFSET(504)] AS d504,
# title_embed[OFFSET(505)] AS d505,
# title_embed[OFFSET(506)] AS d506,
# title_embed[OFFSET(507)] AS d507,
# title_embed[OFFSET(508)] AS d508,
# title_embed[OFFSET(509)] AS d509,
# title_embed[OFFSET(510)] AS d510,
# title_embed[OFFSET(511)] AS d511,
#
# FROM `springer-nature-analytics.DS_dimensions.publications_full_refresh`
# LEFT JOIN UNNEST(`for`) AS f LEFT JOIN UNNEST(journal) AS j
# WHERE ARRAY_LENGTH(title_embed) = 512
# AND
# publication_type LIKE "article"
#         AND j.title IN (SELECT title FROM `springer-nature-analytics.core_journals.core_2018_v01`)
#         AND year >= 2002
#         AND year <= 2004
#         AND language LIKE "en"
#         AND ARRAY_LENGTH(references) > 4
#
# ) GROUP BY f1
#  ) WHERE f1 IS NOT NULL

# %%
train_and_save(for_02_04, "wv_02_04", "f2")
# Out:
# Saved mean vectors to "/content/drive/My Drive/Research/Data/Mean-title-centroids-3yrs-v02/wv_02_04_f2.csv"

# %% [markdown]
# # 1999-2001

# %%
# %%bigquery --project $pid for_99_01
#
# SELECT * FROM (
# SELECT f1,
#
# AVG(d0) AS d0_mean,
# AVG(d1) AS d1_mean,
# AVG(d2) AS d2_mean,
# AVG(d3) AS d3_mean,
# AVG(d4) AS d4_mean,
# AVG(d5) AS d5_mean,
# AVG(d6) AS d6_mean,
# AVG(d7) AS d7_mean,
# AVG(d8) AS d8_mean,
# AVG(d9) AS d9_mean,
# AVG(d10) AS d10_mean,
# AVG(d11) AS d11_mean,
# AVG(d12) AS d12_mean,
# AVG(d13) AS d13_mean,
# AVG(d14) AS d14_mean,
# AVG(d15) AS d15_mean,
# AVG(d16) AS d16_mean,
# AVG(d17) AS d17_mean,
# AVG(d18) AS d18_mean,
# AVG(d19) AS d19_mean,
# AVG(d20) AS d20_mean,
# AVG(d21) AS d21_mean,
# AVG(d22) AS d22_mean,
# AVG(d23) AS d23_mean,
# AVG(d24) AS d24_mean,
# AVG(d25) AS d25_mean,
# AVG(d26) AS d26_mean,
# AVG(d27) AS d27_mean,
# AVG(d28) AS d28_mean,
# AVG(d29) AS d29_mean,
# AVG(d30) AS d30_mean,
# AVG(d31) AS d31_mean,
# AVG(d32) AS d32_mean,
# AVG(d33) AS d33_mean,
# AVG(d34) AS d34_mean,
# AVG(d35) AS d35_mean,
# AVG(d36) AS d36_mean,
# AVG(d37) AS d37_mean,
# AVG(d38) AS d38_mean,
# AVG(d39) AS d39_mean,
# AVG(d40) AS d40_mean,
# AVG(d41) AS d41_mean,
# AVG(d42) AS d42_mean,
# AVG(d43) AS d43_mean,
# AVG(d44) AS d44_mean,
# AVG(d45) AS d45_mean,
# AVG(d46) AS d46_mean,
# AVG(d47) AS d47_mean,
# AVG(d48) AS d48_mean,
# AVG(d49) AS d49_mean,
# AVG(d50) AS d50_mean,
# AVG(d51) AS d51_mean,
# AVG(d52) AS d52_mean,
# AVG(d53) AS d53_mean,
# AVG(d54) AS d54_mean,
# AVG(d55) AS d55_mean,
# AVG(d56) AS d56_mean,
# AVG(d57) AS d57_mean,
# AVG(d58) AS d58_mean,
# AVG(d59) AS d59_mean,
# AVG(d60) AS d60_mean,
# AVG(d61) AS d61_mean,
# AVG(d62) AS d62_mean,
# AVG(d63) AS d63_mean,
# AVG(d64) AS d64_mean,
# AVG(d65) AS d65_mean,
# AVG(d66) AS d66_mean,
# AVG(d67) AS d67_mean,
# AVG(d68) AS d68_mean,
# AVG(d69) AS d69_mean,
# AVG(d70) AS d70_mean,
# AVG(d71) AS d71_mean,
# AVG(d72) AS d72_mean,
# AVG(d73) AS d73_mean,
# AVG(d74) AS d74_mean,
# AVG(d75) AS d75_mean,
# AVG(d76) AS d76_mean,
# AVG(d77) AS d77_mean,
# AVG(d78) AS d78_mean,
# AVG(d79) AS d79_mean,
# AVG(d80) AS d80_mean,
# AVG(d81) AS d81_mean,
# AVG(d82) AS d82_mean,
# AVG(d83) AS d83_mean,
# AVG(d84) AS d84_mean,
# AVG(d85) AS d85_mean,
# AVG(d86) AS d86_mean,
# AVG(d87) AS d87_mean,
# AVG(d88) AS d88_mean,
# AVG(d89) AS d89_mean,
# AVG(d90) AS d90_mean,
# AVG(d91) AS d91_mean,
# AVG(d92) AS d92_mean,
# AVG(d93) AS d93_mean,
# AVG(d94) AS d94_mean,
# AVG(d95) AS d95_mean,
# AVG(d96) AS d96_mean,
# AVG(d97) AS d97_mean,
# AVG(d98) AS d98_mean,
# AVG(d99) AS d99_mean,
# AVG(d100) AS d100_mean,
# AVG(d101) AS d101_mean,
# AVG(d102) AS d102_mean,
# AVG(d103) AS d103_mean,
# AVG(d104) AS d104_mean,
# AVG(d105) AS d105_mean,
# AVG(d106) AS d106_mean,
# AVG(d107) AS d107_mean,
# AVG(d108) AS d108_mean,
# AVG(d109) AS d109_mean,
# AVG(d110) AS d110_mean,
# AVG(d111) AS d111_mean,
# AVG(d112) AS d112_mean,
# AVG(d113) AS d113_mean,
# AVG(d114) AS d114_mean,
# AVG(d115) AS d115_mean,
# AVG(d116) AS d116_mean,
# AVG(d117) AS d117_mean,
# AVG(d118) AS d118_mean,
# AVG(d119) AS d119_mean,
# AVG(d120) AS d120_mean,
# AVG(d121) AS d121_mean,
# AVG(d122) AS d122_mean,
# AVG(d123) AS d123_mean,
# AVG(d124) AS d124_mean,
# AVG(d125) AS d125_mean,
# AVG(d126) AS d126_mean,
# AVG(d127) AS d127_mean,
# AVG(d128) AS d128_mean,
# AVG(d129) AS d129_mean,
# AVG(d130) AS d130_mean,
# AVG(d131) AS d131_mean,
# AVG(d132) AS d132_mean,
# AVG(d133) AS d133_mean,
# AVG(d134) AS d134_mean,
# AVG(d135) AS d135_mean,
# AVG(d136) AS d136_mean,
# AVG(d137) AS d137_mean,
# AVG(d138) AS d138_mean,
# AVG(d139) AS d139_mean,
# AVG(d140) AS d140_mean,
# AVG(d141) AS d141_mean,
# AVG(d142) AS d142_mean,
# AVG(d143) AS d143_mean,
# AVG(d144) AS d144_mean,
# AVG(d145) AS d145_mean,
# AVG(d146) AS d146_mean,
# AVG(d147) AS d147_mean,
# AVG(d148) AS d148_mean,
# AVG(d149) AS d149_mean,
# AVG(d150) AS d150_mean,
# AVG(d151) AS d151_mean,
# AVG(d152) AS d152_mean,
# AVG(d153) AS d153_mean,
# AVG(d154) AS d154_mean,
# AVG(d155) AS d155_mean,
# AVG(d156) AS d156_mean,
# AVG(d157) AS d157_mean,
# AVG(d158) AS d158_mean,
# AVG(d159) AS d159_mean,
# AVG(d160) AS d160_mean,
# AVG(d161) AS d161_mean,
# AVG(d162) AS d162_mean,
# AVG(d163) AS d163_mean,
# AVG(d164) AS d164_mean,
# AVG(d165) AS d165_mean,
# AVG(d166) AS d166_mean,
# AVG(d167) AS d167_mean,
# AVG(d168) AS d168_mean,
# AVG(d169) AS d169_mean,
# AVG(d170) AS d170_mean,
# AVG(d171) AS d171_mean,
# AVG(d172) AS d172_mean,
# AVG(d173) AS d173_mean,
# AVG(d174) AS d174_mean,
# AVG(d175) AS d175_mean,
# AVG(d176) AS d176_mean,
# AVG(d177) AS d177_mean,
# AVG(d178) AS d178_mean,
# AVG(d179) AS d179_mean,
# AVG(d180) AS d180_mean,
# AVG(d181) AS d181_mean,
# AVG(d182) AS d182_mean,
# AVG(d183) AS d183_mean,
# AVG(d184) AS d184_mean,
# AVG(d185) AS d185_mean,
# AVG(d186) AS d186_mean,
# AVG(d187) AS d187_mean,
# AVG(d188) AS d188_mean,
# AVG(d189) AS d189_mean,
# AVG(d190) AS d190_mean,
# AVG(d191) AS d191_mean,
# AVG(d192) AS d192_mean,
# AVG(d193) AS d193_mean,
# AVG(d194) AS d194_mean,
# AVG(d195) AS d195_mean,
# AVG(d196) AS d196_mean,
# AVG(d197) AS d197_mean,
# AVG(d198) AS d198_mean,
# AVG(d199) AS d199_mean,
# AVG(d200) AS d200_mean,
# AVG(d201) AS d201_mean,
# AVG(d202) AS d202_mean,
# AVG(d203) AS d203_mean,
# AVG(d204) AS d204_mean,
# AVG(d205) AS d205_mean,
# AVG(d206) AS d206_mean,
# AVG(d207) AS d207_mean,
# AVG(d208) AS d208_mean,
# AVG(d209) AS d209_mean,
# AVG(d210) AS d210_mean,
# AVG(d211) AS d211_mean,
# AVG(d212) AS d212_mean,
# AVG(d213) AS d213_mean,
# AVG(d214) AS d214_mean,
# AVG(d215) AS d215_mean,
# AVG(d216) AS d216_mean,
# AVG(d217) AS d217_mean,
# AVG(d218) AS d218_mean,
# AVG(d219) AS d219_mean,
# AVG(d220) AS d220_mean,
# AVG(d221) AS d221_mean,
# AVG(d222) AS d222_mean,
# AVG(d223) AS d223_mean,
# AVG(d224) AS d224_mean,
# AVG(d225) AS d225_mean,
# AVG(d226) AS d226_mean,
# AVG(d227) AS d227_mean,
# AVG(d228) AS d228_mean,
# AVG(d229) AS d229_mean,
# AVG(d230) AS d230_mean,
# AVG(d231) AS d231_mean,
# AVG(d232) AS d232_mean,
# AVG(d233) AS d233_mean,
# AVG(d234) AS d234_mean,
# AVG(d235) AS d235_mean,
# AVG(d236) AS d236_mean,
# AVG(d237) AS d237_mean,
# AVG(d238) AS d238_mean,
# AVG(d239) AS d239_mean,
# AVG(d240) AS d240_mean,
# AVG(d241) AS d241_mean,
# AVG(d242) AS d242_mean,
# AVG(d243) AS d243_mean,
# AVG(d244) AS d244_mean,
# AVG(d245) AS d245_mean,
# AVG(d246) AS d246_mean,
# AVG(d247) AS d247_mean,
# AVG(d248) AS d248_mean,
# AVG(d249) AS d249_mean,
# AVG(d250) AS d250_mean,
# AVG(d251) AS d251_mean,
# AVG(d252) AS d252_mean,
# AVG(d253) AS d253_mean,
# AVG(d254) AS d254_mean,
# AVG(d255) AS d255_mean,
# AVG(d256) AS d256_mean,
# AVG(d257) AS d257_mean,
# AVG(d258) AS d258_mean,
# AVG(d259) AS d259_mean,
# AVG(d260) AS d260_mean,
# AVG(d261) AS d261_mean,
# AVG(d262) AS d262_mean,
# AVG(d263) AS d263_mean,
# AVG(d264) AS d264_mean,
# AVG(d265) AS d265_mean,
# AVG(d266) AS d266_mean,
# AVG(d267) AS d267_mean,
# AVG(d268) AS d268_mean,
# AVG(d269) AS d269_mean,
# AVG(d270) AS d270_mean,
# AVG(d271) AS d271_mean,
# AVG(d272) AS d272_mean,
# AVG(d273) AS d273_mean,
# AVG(d274) AS d274_mean,
# AVG(d275) AS d275_mean,
# AVG(d276) AS d276_mean,
# AVG(d277) AS d277_mean,
# AVG(d278) AS d278_mean,
# AVG(d279) AS d279_mean,
# AVG(d280) AS d280_mean,
# AVG(d281) AS d281_mean,
# AVG(d282) AS d282_mean,
# AVG(d283) AS d283_mean,
# AVG(d284) AS d284_mean,
# AVG(d285) AS d285_mean,
# AVG(d286) AS d286_mean,
# AVG(d287) AS d287_mean,
# AVG(d288) AS d288_mean,
# AVG(d289) AS d289_mean,
# AVG(d290) AS d290_mean,
# AVG(d291) AS d291_mean,
# AVG(d292) AS d292_mean,
# AVG(d293) AS d293_mean,
# AVG(d294) AS d294_mean,
# AVG(d295) AS d295_mean,
# AVG(d296) AS d296_mean,
# AVG(d297) AS d297_mean,
# AVG(d298) AS d298_mean,
# AVG(d299) AS d299_mean,
# AVG(d300) AS d300_mean,
# AVG(d301) AS d301_mean,
# AVG(d302) AS d302_mean,
# AVG(d303) AS d303_mean,
# AVG(d304) AS d304_mean,
# AVG(d305) AS d305_mean,
# AVG(d306) AS d306_mean,
# AVG(d307) AS d307_mean,
# AVG(d308) AS d308_mean,
# AVG(d309) AS d309_mean,
# AVG(d310) AS d310_mean,
# AVG(d311) AS d311_mean,
# AVG(d312) AS d312_mean,
# AVG(d313) AS d313_mean,
# AVG(d314) AS d314_mean,
# AVG(d315) AS d315_mean,
# AVG(d316) AS d316_mean,
# AVG(d317) AS d317_mean,
# AVG(d318) AS d318_mean,
# AVG(d319) AS d319_mean,
# AVG(d320) AS d320_mean,
# AVG(d321) AS d321_mean,
# AVG(d322) AS d322_mean,
# AVG(d323) AS d323_mean,
# AVG(d324) AS d324_mean,
# AVG(d325) AS d325_mean,
# AVG(d326) AS d326_mean,
# AVG(d327) AS d327_mean,
# AVG(d328) AS d328_mean,
# AVG(d329) AS d329_mean,
# AVG(d330) AS d330_mean,
# AVG(d331) AS d331_mean,
# AVG(d332) AS d332_mean,
# AVG(d333) AS d333_mean,
# AVG(d334) AS d334_mean,
# AVG(d335) AS d335_mean,
# AVG(d336) AS d336_mean,
# AVG(d337) AS d337_mean,
# AVG(d338) AS d338_mean,
# AVG(d339) AS d339_mean,
# AVG(d340) AS d340_mean,
# AVG(d341) AS d341_mean,
# AVG(d342) AS d342_mean,
# AVG(d343) AS d343_mean,
# AVG(d344) AS d344_mean,
# AVG(d345) AS d345_mean,
# AVG(d346) AS d346_mean,
# AVG(d347) AS d347_mean,
# AVG(d348) AS d348_mean,
# AVG(d349) AS d349_mean,
# AVG(d350) AS d350_mean,
# AVG(d351) AS d351_mean,
# AVG(d352) AS d352_mean,
# AVG(d353) AS d353_mean,
# AVG(d354) AS d354_mean,
# AVG(d355) AS d355_mean,
# AVG(d356) AS d356_mean,
# AVG(d357) AS d357_mean,
# AVG(d358) AS d358_mean,
# AVG(d359) AS d359_mean,
# AVG(d360) AS d360_mean,
# AVG(d361) AS d361_mean,
# AVG(d362) AS d362_mean,
# AVG(d363) AS d363_mean,
# AVG(d364) AS d364_mean,
# AVG(d365) AS d365_mean,
# AVG(d366) AS d366_mean,
# AVG(d367) AS d367_mean,
# AVG(d368) AS d368_mean,
# AVG(d369) AS d369_mean,
# AVG(d370) AS d370_mean,
# AVG(d371) AS d371_mean,
# AVG(d372) AS d372_mean,
# AVG(d373) AS d373_mean,
# AVG(d374) AS d374_mean,
# AVG(d375) AS d375_mean,
# AVG(d376) AS d376_mean,
# AVG(d377) AS d377_mean,
# AVG(d378) AS d378_mean,
# AVG(d379) AS d379_mean,
# AVG(d380) AS d380_mean,
# AVG(d381) AS d381_mean,
# AVG(d382) AS d382_mean,
# AVG(d383) AS d383_mean,
# AVG(d384) AS d384_mean,
# AVG(d385) AS d385_mean,
# AVG(d386) AS d386_mean,
# AVG(d387) AS d387_mean,
# AVG(d388) AS d388_mean,
# AVG(d389) AS d389_mean,
# AVG(d390) AS d390_mean,
# AVG(d391) AS d391_mean,
# AVG(d392) AS d392_mean,
# AVG(d393) AS d393_mean,
# AVG(d394) AS d394_mean,
# AVG(d395) AS d395_mean,
# AVG(d396) AS d396_mean,
# AVG(d397) AS d397_mean,
# AVG(d398) AS d398_mean,
# AVG(d399) AS d399_mean,
# AVG(d400) AS d400_mean,
# AVG(d401) AS d401_mean,
# AVG(d402) AS d402_mean,
# AVG(d403) AS d403_mean,
# AVG(d404) AS d404_mean,
# AVG(d405) AS d405_mean,
# AVG(d406) AS d406_mean,
# AVG(d407) AS d407_mean,
# AVG(d408) AS d408_mean,
# AVG(d409) AS d409_mean,
# AVG(d410) AS d410_mean,
# AVG(d411) AS d411_mean,
# AVG(d412) AS d412_mean,
# AVG(d413) AS d413_mean,
# AVG(d414) AS d414_mean,
# AVG(d415) AS d415_mean,
# AVG(d416) AS d416_mean,
# AVG(d417) AS d417_mean,
# AVG(d418) AS d418_mean,
# AVG(d419) AS d419_mean,
# AVG(d420) AS d420_mean,
# AVG(d421) AS d421_mean,
# AVG(d422) AS d422_mean,
# AVG(d423) AS d423_mean,
# AVG(d424) AS d424_mean,
# AVG(d425) AS d425_mean,
# AVG(d426) AS d426_mean,
# AVG(d427) AS d427_mean,
# AVG(d428) AS d428_mean,
# AVG(d429) AS d429_mean,
# AVG(d430) AS d430_mean,
# AVG(d431) AS d431_mean,
# AVG(d432) AS d432_mean,
# AVG(d433) AS d433_mean,
# AVG(d434) AS d434_mean,
# AVG(d435) AS d435_mean,
# AVG(d436) AS d436_mean,
# AVG(d437) AS d437_mean,
# AVG(d438) AS d438_mean,
# AVG(d439) AS d439_mean,
# AVG(d440) AS d440_mean,
# AVG(d441) AS d441_mean,
# AVG(d442) AS d442_mean,
# AVG(d443) AS d443_mean,
# AVG(d444) AS d444_mean,
# AVG(d445) AS d445_mean,
# AVG(d446) AS d446_mean,
# AVG(d447) AS d447_mean,
# AVG(d448) AS d448_mean,
# AVG(d449) AS d449_mean,
# AVG(d450) AS d450_mean,
# AVG(d451) AS d451_mean,
# AVG(d452) AS d452_mean,
# AVG(d453) AS d453_mean,
# AVG(d454) AS d454_mean,
# AVG(d455) AS d455_mean,
# AVG(d456) AS d456_mean,
# AVG(d457) AS d457_mean,
# AVG(d458) AS d458_mean,
# AVG(d459) AS d459_mean,
# AVG(d460) AS d460_mean,
# AVG(d461) AS d461_mean,
# AVG(d462) AS d462_mean,
# AVG(d463) AS d463_mean,
# AVG(d464) AS d464_mean,
# AVG(d465) AS d465_mean,
# AVG(d466) AS d466_mean,
# AVG(d467) AS d467_mean,
# AVG(d468) AS d468_mean,
# AVG(d469) AS d469_mean,
# AVG(d470) AS d470_mean,
# AVG(d471) AS d471_mean,
# AVG(d472) AS d472_mean,
# AVG(d473) AS d473_mean,
# AVG(d474) AS d474_mean,
# AVG(d475) AS d475_mean,
# AVG(d476) AS d476_mean,
# AVG(d477) AS d477_mean,
# AVG(d478) AS d478_mean,
# AVG(d479) AS d479_mean,
# AVG(d480) AS d480_mean,
# AVG(d481) AS d481_mean,
# AVG(d482) AS d482_mean,
# AVG(d483) AS d483_mean,
# AVG(d484) AS d484_mean,
# AVG(d485) AS d485_mean,
# AVG(d486) AS d486_mean,
# AVG(d487) AS d487_mean,
# AVG(d488) AS d488_mean,
# AVG(d489) AS d489_mean,
# AVG(d490) AS d490_mean,
# AVG(d491) AS d491_mean,
# AVG(d492) AS d492_mean,
# AVG(d493) AS d493_mean,
# AVG(d494) AS d494_mean,
# AVG(d495) AS d495_mean,
# AVG(d496) AS d496_mean,
# AVG(d497) AS d497_mean,
# AVG(d498) AS d498_mean,
# AVG(d499) AS d499_mean,
# AVG(d500) AS d500_mean,
# AVG(d501) AS d501_mean,
# AVG(d502) AS d502_mean,
# AVG(d503) AS d503_mean,
# AVG(d504) AS d504_mean,
# AVG(d505) AS d505_mean,
# AVG(d506) AS d506_mean,
# AVG(d507) AS d507_mean,
# AVG(d508) AS d508_mean,
# AVG(d509) AS d509_mean,
# AVG(d510) AS d510_mean,
# AVG(d511) AS d511_mean,
#
# FROM (
# SELECT f.first_level.name AS f1,
#
# title_embed[OFFSET(0)] AS d0,
# title_embed[OFFSET(1)] AS d1,
# title_embed[OFFSET(2)] AS d2,
# title_embed[OFFSET(3)] AS d3,
# title_embed[OFFSET(4)] AS d4,
# title_embed[OFFSET(5)] AS d5,
# title_embed[OFFSET(6)] AS d6,
# title_embed[OFFSET(7)] AS d7,
# title_embed[OFFSET(8)] AS d8,
# title_embed[OFFSET(9)] AS d9,
# title_embed[OFFSET(10)] AS d10,
# title_embed[OFFSET(11)] AS d11,
# title_embed[OFFSET(12)] AS d12,
# title_embed[OFFSET(13)] AS d13,
# title_embed[OFFSET(14)] AS d14,
# title_embed[OFFSET(15)] AS d15,
# title_embed[OFFSET(16)] AS d16,
# title_embed[OFFSET(17)] AS d17,
# title_embed[OFFSET(18)] AS d18,
# title_embed[OFFSET(19)] AS d19,
# title_embed[OFFSET(20)] AS d20,
# title_embed[OFFSET(21)] AS d21,
# title_embed[OFFSET(22)] AS d22,
# title_embed[OFFSET(23)] AS d23,
# title_embed[OFFSET(24)] AS d24,
# title_embed[OFFSET(25)] AS d25,
# title_embed[OFFSET(26)] AS d26,
# title_embed[OFFSET(27)] AS d27,
# title_embed[OFFSET(28)] AS d28,
# title_embed[OFFSET(29)] AS d29,
# title_embed[OFFSET(30)] AS d30,
# title_embed[OFFSET(31)] AS d31,
# title_embed[OFFSET(32)] AS d32,
# title_embed[OFFSET(33)] AS d33,
# title_embed[OFFSET(34)] AS d34,
# title_embed[OFFSET(35)] AS d35,
# title_embed[OFFSET(36)] AS d36,
# title_embed[OFFSET(37)] AS d37,
# title_embed[OFFSET(38)] AS d38,
# title_embed[OFFSET(39)] AS d39,
# title_embed[OFFSET(40)] AS d40,
# title_embed[OFFSET(41)] AS d41,
# title_embed[OFFSET(42)] AS d42,
# title_embed[OFFSET(43)] AS d43,
# title_embed[OFFSET(44)] AS d44,
# title_embed[OFFSET(45)] AS d45,
# title_embed[OFFSET(46)] AS d46,
# title_embed[OFFSET(47)] AS d47,
# title_embed[OFFSET(48)] AS d48,
# title_embed[OFFSET(49)] AS d49,
# title_embed[OFFSET(50)] AS d50,
# title_embed[OFFSET(51)] AS d51,
# title_embed[OFFSET(52)] AS d52,
# title_embed[OFFSET(53)] AS d53,
# title_embed[OFFSET(54)] AS d54,
# title_embed[OFFSET(55)] AS d55,
# title_embed[OFFSET(56)] AS d56,
# title_embed[OFFSET(496)] AS d496,
# title_embed[OFFSET(497)] AS d497,
# title_embed[OFFSET(498)] AS d498,
# title_embed[OFFSET(499)] AS d499,
# title_embed[OFFSET(500)] AS d500,
# title_embed[OFFSET(501)] AS d501,
# title_embed[OFFSET(502)] AS d502,
# title_embed[OFFSET(503)] AS d503,
# title_embed[OFFSET(504)] AS d504,
# title_embed[OFFSET(505)] AS d505,
# title_embed[OFFSET(506)] AS d506,
# title_embed[OFFSET(507)] AS d507,
# title_embed[OFFSET(508)] AS d508,
# title_embed[OFFSET(509)] AS d509,
# title_embed[OFFSET(510)] AS d510,
# title_embed[OFFSET(511)] AS d511,
#
# FROM `springer-nature-analytics.DS_dimensions.publications_full_refresh`
# LEFT JOIN UNNEST(`for`) AS f LEFT JOIN UNNEST(journal) AS j
# WHERE ARRAY_LENGTH(title_embed) = 512
# AND
# publication_type LIKE "article"
#         AND j.title IN (SELECT title FROM `springer-nature-analytics.core_journals.core_2018_v01`)
#         AND year >= 1999
#         AND year <= 2001
#         AND language LIKE "en"
#         AND ARRAY_LENGTH(references) > 4
#
# ) GROUP BY f1
#  ) WHERE f1 IS NOT NULL

# %%
train_and_save(for_99_01, "wv_99_01")
# Out:
# Saved mean vectors to "/content/drive/My Drive/Research/Data/Mean-title-centroids-3yrs-v02/wv_99_01_f1.csv"

# %%
# %%bigquery --project $pid for_99_01
#
# SELECT * FROM (
# SELECT f1,
#
# AVG(d0) AS d0_mean,
# AVG(d1) AS d1_mean,
# AVG(d2) AS d2_mean,
# AVG(d3) AS d3_mean,
# AVG(d4) AS d4_mean,
# AVG(d5) AS d5_mean,
# AVG(d6) AS d6_mean,
# AVG(d7) AS d7_mean,
# AVG(d8) AS d8_mean,
# AVG(d9) AS d9_mean,
# AVG(d10) AS d10_mean,
# AVG(d11) AS d11_mean,
# AVG(d12) AS d12_mean,
# AVG(d13) AS d13_mean,
# AVG(d14) AS d14_mean,
# AVG(d15) AS d15_mean,
# AVG(d16) AS d16_mean,
# AVG(d17) AS d17_mean,
# AVG(d18) AS d18_mean,
# AVG(d19) AS d19_mean,
# AVG(d20) AS d20_mean,
# AVG(d21) AS d21_mean,
# AVG(d22) AS d22_mean,
# AVG(d23) AS d23_mean,
# AVG(d24) AS d24_mean,
# AVG(d25) AS d25_mean,
# AVG(d26) AS d26_mean,
# AVG(d27) AS d27_mean,
# AVG(d28) AS d28_mean,
# AVG(d29) AS d29_mean,
# AVG(d30) AS d30_mean,
# AVG(d31) AS d31_mean,
# AVG(d32) AS d32_mean,
# AVG(d33) AS d33_mean,
# AVG(d34) AS d34_mean,
# AVG(d35) AS d35_mean,
# AVG(d36) AS d36_mean,
# AVG(d37) AS d37_mean,
# AVG(d38) AS d38_mean,
# AVG(d39) AS d39_mean,
# AVG(d40) AS d40_mean,
# AVG(d41) AS d41_mean,
# AVG(d42) AS d42_mean,
# AVG(d43) AS d43_mean,
# AVG(d44) AS d44_mean,
# AVG(d45) AS d45_mean,
# AVG(d46) AS d46_mean,
# AVG(d47) AS d47_mean,
# AVG(d48) AS d48_mean,
# AVG(d49) AS d49_mean,
# AVG(d50) AS d50_mean,
# AVG(d51) AS d51_mean,
# AVG(d52) AS d52_mean,
# AVG(d53) AS d53_mean,
# AVG(d54) AS d54_mean,
# AVG(d55) AS d55_mean,
# AVG(d56) AS d56_mean,
# AVG(d57) AS d57_mean,
# AVG(d58) AS d58_mean,
# AVG(d59) AS d59_mean,
# AVG(d60) AS d60_mean,
# AVG(d61) AS d61_mean,
# AVG(d62) AS d62_mean,
# AVG(d63) AS d63_mean,
# AVG(d64) AS d64_mean,
# AVG(d65) AS d65_mean,
# AVG(d66) AS d66_mean,
# AVG(d67) AS d67_mean,
# AVG(d68) AS d68_mean,
# AVG(d69) AS d69_mean,
# AVG(d70) AS d70_mean,
# AVG(d71) AS d71_mean,
# AVG(d72) AS d72_mean,
# AVG(d73) AS d73_mean,
# AVG(d74) AS d74_mean,
# AVG(d75) AS d75_mean,
# AVG(d76) AS d76_mean,
# AVG(d77) AS d77_mean,
# AVG(d78) AS d78_mean,
# AVG(d79) AS d79_mean,
# AVG(d80) AS d80_mean,
# AVG(d81) AS d81_mean,
# AVG(d82) AS d82_mean,
# AVG(d83) AS d83_mean,
# AVG(d84) AS d84_mean,
# AVG(d85) AS d85_mean,
# AVG(d86) AS d86_mean,
# AVG(d87) AS d87_mean,
# AVG(d88) AS d88_mean,
# AVG(d89) AS d89_mean,
# AVG(d90) AS d90_mean,
# AVG(d91) AS d91_mean,
# AVG(d92) AS d92_mean,
# AVG(d93) AS d93_mean,
# AVG(d94) AS d94_mean,
# AVG(d95) AS d95_mean,
# AVG(d96) AS d96_mean,
# AVG(d97) AS d97_mean,
# AVG(d98) AS d98_mean,
# AVG(d99) AS d99_mean,
# AVG(d100) AS d100_mean,
# AVG(d101) AS d101_mean,
# AVG(d102) AS d102_mean,
# AVG(d103) AS d103_mean,
# AVG(d104) AS d104_mean,
# AVG(d105) AS d105_mean,
# AVG(d106) AS d106_mean,
# AVG(d107) AS d107_mean,
# AVG(d108) AS d108_mean,
# AVG(d109) AS d109_mean,
# AVG(d110) AS d110_mean,
# AVG(d111) AS d111_mean,
# AVG(d112) AS d112_mean,
# AVG(d113) AS d113_mean,
# AVG(d114) AS d114_mean,
# AVG(d115) AS d115_mean,
# AVG(d116) AS d116_mean,
# AVG(d117) AS d117_mean,
# AVG(d118) AS d118_mean,
# AVG(d119) AS d119_mean,
# AVG(d120) AS d120_mean,
# AVG(d121) AS d121_mean,
# AVG(d122) AS d122_mean,
# AVG(d123) AS d123_mean,
# AVG(d124) AS d124_mean,
# AVG(d125) AS d125_mean,
# AVG(d126) AS d126_mean,
# AVG(d127) AS d127_mean,
# AVG(d128) AS d128_mean,
# AVG(d129) AS d129_mean,
# AVG(d130) AS d130_mean,
# AVG(d131) AS d131_mean,
# AVG(d132) AS d132_mean,
# AVG(d133) AS d133_mean,
# AVG(d134) AS d134_mean,
# AVG(d135) AS d135_mean,
# AVG(d136) AS d136_mean,
# AVG(d137) AS d137_mean,
# AVG(d138) AS d138_mean,
# AVG(d139) AS d139_mean,
# AVG(d140) AS d140_mean,
# AVG(d141) AS d141_mean,
# AVG(d142) AS d142_mean,
# AVG(d143) AS d143_mean,
# AVG(d144) AS d144_mean,
# AVG(d145) AS d145_mean,
# AVG(d146) AS d146_mean,
# AVG(d147) AS d147_mean,
# AVG(d148) AS d148_mean,
# AVG(d149) AS d149_mean,
# AVG(d150) AS d150_mean,
# AVG(d151) AS d151_mean,
# AVG(d152) AS d152_mean,
# AVG(d153) AS d153_mean,
# AVG(d154) AS d154_mean,
# AVG(d155) AS d155_mean,
# AVG(d156) AS d156_mean,
# AVG(d157) AS d157_mean,
# AVG(d158) AS d158_mean,
# AVG(d159) AS d159_mean,
# AVG(d160) AS d160_mean,
# AVG(d161) AS d161_mean,
# AVG(d162) AS d162_mean,
# AVG(d163) AS d163_mean,
# AVG(d164) AS d164_mean,
# AVG(d165) AS d165_mean,
# AVG(d166) AS d166_mean,
# AVG(d167) AS d167_mean,
# AVG(d168) AS d168_mean,
# AVG(d169) AS d169_mean,
# AVG(d170) AS d170_mean,
# AVG(d171) AS d171_mean,
# AVG(d172) AS d172_mean,
# AVG(d173) AS d173_mean,
# AVG(d174) AS d174_mean,
# AVG(d175) AS d175_mean,
# AVG(d176) AS d176_mean,
# AVG(d177) AS d177_mean,
# AVG(d178) AS d178_mean,
# AVG(d179) AS d179_mean,
# AVG(d180) AS d180_mean,
# AVG(d181) AS d181_mean,
# AVG(d182) AS d182_mean,
# AVG(d183) AS d183_mean,
# AVG(d184) AS d184_mean,
# AVG(d185) AS d185_mean,
# AVG(d186) AS d186_mean,
# AVG(d187) AS d187_mean,
# AVG(d188) AS d188_mean,
# AVG(d189) AS d189_mean,
# AVG(d190) AS d190_mean,
# AVG(d191) AS d191_mean,
# AVG(d192) AS d192_mean,
# AVG(d193) AS d193_mean,
# AVG(d194) AS d194_mean,
# AVG(d195) AS d195_mean,
# AVG(d196) AS d196_mean,
# AVG(d197) AS d197_mean,
# AVG(d198) AS d198_mean,
# AVG(d199) AS d199_mean,
# AVG(d200) AS d200_mean,
# AVG(d201) AS d201_mean,
# AVG(d202) AS d202_mean,
# AVG(d203) AS d203_mean,
# AVG(d204) AS d204_mean,
# AVG(d205) AS d205_mean,
# AVG(d206) AS d206_mean,
# AVG(d207) AS d207_mean,
# AVG(d208) AS d208_mean,
# AVG(d209) AS d209_mean,
# AVG(d210) AS d210_mean,
# AVG(d211) AS d211_mean,
# AVG(d212) AS d212_mean,
# AVG(d213) AS d213_mean,
# AVG(d214) AS d214_mean,
# AVG(d215) AS d215_mean,
# AVG(d216) AS d216_mean,
# AVG(d217) AS d217_mean,
# AVG(d218) AS d218_mean,
# AVG(d219) AS d219_mean,
# AVG(d220) AS d220_mean,
# AVG(d221) AS d221_mean,
# AVG(d222) AS d222_mean,
# AVG(d223) AS d223_mean,
# AVG(d224) AS d224_mean,
# AVG(d225) AS d225_mean,
# AVG(d226) AS d226_mean,
# AVG(d227) AS d227_mean,
# AVG(d228) AS d228_mean,
# AVG(d229) AS d229_mean,
# AVG(d230) AS d230_mean,
# AVG(d231) AS d231_mean,
# AVG(d232) AS d232_mean,
# AVG(d233) AS d233_mean,
# AVG(d234) AS d234_mean,
# AVG(d235) AS d235_mean,
# AVG(d236) AS d236_mean,
# AVG(d237) AS d237_mean,
# AVG(d238) AS d238_mean,
# AVG(d239) AS d239_mean,
# AVG(d240) AS d240_mean,
# AVG(d241) AS d241_mean,
# AVG(d242) AS d242_mean,
# AVG(d243) AS d243_mean,
# AVG(d244) AS d244_mean,
# AVG(d245) AS d245_mean,
# AVG(d246) AS d246_mean,
# AVG(d247) AS d247_mean,
# AVG(d248) AS d248_mean,
# AVG(d249) AS d249_mean,
# AVG(d250) AS d250_mean,
# AVG(d251) AS d251_mean,
# AVG(d252) AS d252_mean,
# AVG(d253) AS d253_mean,
# AVG(d254) AS d254_mean,
# AVG(d255) AS d255_mean,
# AVG(d256) AS d256_mean,
# AVG(d257) AS d257_mean,
# AVG(d258) AS d258_mean,
# AVG(d259) AS d259_mean,
# AVG(d260) AS d260_mean,
# AVG(d261) AS d261_mean,
# AVG(d262) AS d262_mean,
# AVG(d263) AS d263_mean,
# AVG(d264) AS d264_mean,
# AVG(d265) AS d265_mean,
# AVG(d266) AS d266_mean,
# AVG(d267) AS d267_mean,
# AVG(d268) AS d268_mean,
# AVG(d269) AS d269_mean,
# AVG(d270) AS d270_mean,
# AVG(d271) AS d271_mean,
# AVG(d272) AS d272_mean,
# AVG(d273) AS d273_mean,
# AVG(d274) AS d274_mean,
# AVG(d275) AS d275_mean,
# AVG(d276) AS d276_mean,
# AVG(d277) AS d277_mean,
# AVG(d278) AS d278_mean,
# AVG(d279) AS d279_mean,
# AVG(d280) AS d280_mean,
# AVG(d281) AS d281_mean,
# AVG(d282) AS d282_mean,
# AVG(d283) AS d283_mean,
# AVG(d284) AS d284_mean,
# AVG(d285) AS d285_mean,
# AVG(d286) AS d286_mean,
# AVG(d287) AS d287_mean,
# AVG(d288) AS d288_mean,
# AVG(d289) AS d289_mean,
# AVG(d290) AS d290_mean,
# AVG(d291) AS d291_mean,
# AVG(d292) AS d292_mean,
# AVG(d293) AS d293_mean,
# AVG(d294) AS d294_mean,
# AVG(d295) AS d295_mean,
# AVG(d296) AS d296_mean,
# AVG(d297) AS d297_mean,
# AVG(d298) AS d298_mean,
# AVG(d299) AS d299_mean,
# AVG(d300) AS d300_mean,
# AVG(d301) AS d301_mean,
# AVG(d302) AS d302_mean,
# AVG(d303) AS d303_mean,
# AVG(d304) AS d304_mean,
# AVG(d305) AS d305_mean,
# AVG(d306) AS d306_mean,
# AVG(d307) AS d307_mean,
# AVG(d308) AS d308_mean,
# AVG(d309) AS d309_mean,
# AVG(d310) AS d310_mean,
# AVG(d311) AS d311_mean,
# AVG(d312) AS d312_mean,
# AVG(d313) AS d313_mean,
# AVG(d314) AS d314_mean,
# AVG(d315) AS d315_mean,
# AVG(d316) AS d316_mean,
# AVG(d317) AS d317_mean,
# AVG(d318) AS d318_mean,
# AVG(d319) AS d319_mean,
# AVG(d320) AS d320_mean,
# AVG(d321) AS d321_mean,
# AVG(d322) AS d322_mean,
# AVG(d323) AS d323_mean,
# AVG(d324) AS d324_mean,
# AVG(d325) AS d325_mean,
# AVG(d326) AS d326_mean,
# AVG(d327) AS d327_mean,
# AVG(d328) AS d328_mean,
# AVG(d329) AS d329_mean,
# AVG(d330) AS d330_mean,
# AVG(d331) AS d331_mean,
# AVG(d332) AS d332_mean,
# AVG(d333) AS d333_mean,
# AVG(d334) AS d334_mean,
# AVG(d335) AS d335_mean,
# AVG(d336) AS d336_mean,
# AVG(d337) AS d337_mean,
# AVG(d338) AS d338_mean,
# AVG(d339) AS d339_mean,
# AVG(d340) AS d340_mean,
# AVG(d341) AS d341_mean,
# AVG(d342) AS d342_mean,
# AVG(d343) AS d343_mean,
# AVG(d344) AS d344_mean,
# AVG(d345) AS d345_mean,
# AVG(d346) AS d346_mean,
# AVG(d347) AS d347_mean,
# AVG(d348) AS d348_mean,
# AVG(d349) AS d349_mean,
# AVG(d350) AS d350_mean,
# AVG(d351) AS d351_mean,
# AVG(d352) AS d352_mean,
# AVG(d353) AS d353_mean,
# AVG(d354) AS d354_mean,
# AVG(d355) AS d355_mean,
# AVG(d356) AS d356_mean,
# AVG(d357) AS d357_mean,
# AVG(d358) AS d358_mean,
# AVG(d359) AS d359_mean,
# AVG(d360) AS d360_mean,
# AVG(d361) AS d361_mean,
# AVG(d362) AS d362_mean,
# AVG(d363) AS d363_mean,
# AVG(d364) AS d364_mean,
# AVG(d365) AS d365_mean,
# AVG(d366) AS d366_mean,
# AVG(d367) AS d367_mean,
# AVG(d368) AS d368_mean,
# AVG(d369) AS d369_mean,
# AVG(d370) AS d370_mean,
# AVG(d371) AS d371_mean,
# AVG(d372) AS d372_mean,
# AVG(d373) AS d373_mean,
# AVG(d374) AS d374_mean,
# AVG(d375) AS d375_mean,
# AVG(d376) AS d376_mean,
# AVG(d377) AS d377_mean,
# AVG(d378) AS d378_mean,
# AVG(d379) AS d379_mean,
# AVG(d380) AS d380_mean,
# AVG(d381) AS d381_mean,
# AVG(d382) AS d382_mean,
# AVG(d383) AS d383_mean,
# AVG(d384) AS d384_mean,
# AVG(d385) AS d385_mean,
# AVG(d386) AS d386_mean,
# AVG(d387) AS d387_mean,
# AVG(d388) AS d388_mean,
# AVG(d389) AS d389_mean,
# AVG(d390) AS d390_mean,
# AVG(d391) AS d391_mean,
# AVG(d392) AS d392_mean,
# AVG(d393) AS d393_mean,
# AVG(d394) AS d394_mean,
# AVG(d395) AS d395_mean,
# AVG(d396) AS d396_mean,
# AVG(d397) AS d397_mean,
# AVG(d398) AS d398_mean,
# AVG(d399) AS d399_mean,
# AVG(d400) AS d400_mean,
# AVG(d401) AS d401_mean,
# AVG(d402) AS d402_mean,
# AVG(d403) AS d403_mean,
# AVG(d404) AS d404_mean,
# AVG(d405) AS d405_mean,
# AVG(d406) AS d406_mean,
# AVG(d407) AS d407_mean,
# AVG(d408) AS d408_mean,
# AVG(d409) AS d409_mean,
# AVG(d410) AS d410_mean,
# AVG(d411) AS d411_mean,
# AVG(d412) AS d412_mean,
# AVG(d413) AS d413_mean,
# AVG(d414) AS d414_mean,
# AVG(d415) AS d415_mean,
# AVG(d416) AS d416_mean,
# AVG(d417) AS d417_mean,
# AVG(d418) AS d418_mean,
# AVG(d419) AS d419_mean,
# AVG(d420) AS d420_mean,
# AVG(d421) AS d421_mean,
# AVG(d422) AS d422_mean,
# AVG(d423) AS d423_mean,
# AVG(d424) AS d424_mean,
# AVG(d425) AS d425_mean,
# AVG(d426) AS d426_mean,
# AVG(d427) AS d427_mean,
# AVG(d428) AS d428_mean,
# AVG(d429) AS d429_mean,
# AVG(d430) AS d430_mean,
# AVG(d431) AS d431_mean,
# AVG(d432) AS d432_mean,
# AVG(d433) AS d433_mean,
# AVG(d434) AS d434_mean,
# AVG(d435) AS d435_mean,
# AVG(d436) AS d436_mean,
# AVG(d437) AS d437_mean,
# AVG(d438) AS d438_mean,
# AVG(d439) AS d439_mean,
# AVG(d440) AS d440_mean,
# AVG(d441) AS d441_mean,
# AVG(d442) AS d442_mean,
# AVG(d443) AS d443_mean,
# AVG(d444) AS d444_mean,
# AVG(d445) AS d445_mean,
# AVG(d446) AS d446_mean,
# AVG(d447) AS d447_mean,
# AVG(d448) AS d448_mean,
# AVG(d449) AS d449_mean,
# AVG(d450) AS d450_mean,
# AVG(d451) AS d451_mean,
# AVG(d452) AS d452_mean,
# AVG(d453) AS d453_mean,
# AVG(d454) AS d454_mean,
# AVG(d455) AS d455_mean,
# AVG(d456) AS d456_mean,
# AVG(d457) AS d457_mean,
# AVG(d458) AS d458_mean,
# AVG(d459) AS d459_mean,
# AVG(d460) AS d460_mean,
# AVG(d461) AS d461_mean,
# AVG(d462) AS d462_mean,
# AVG(d463) AS d463_mean,
# AVG(d464) AS d464_mean,
# AVG(d465) AS d465_mean,
# AVG(d466) AS d466_mean,
# AVG(d467) AS d467_mean,
# AVG(d468) AS d468_mean,
# AVG(d469) AS d469_mean,
# AVG(d470) AS d470_mean,
# AVG(d471) AS d471_mean,
# AVG(d472) AS d472_mean,
# AVG(d473) AS d473_mean,
# AVG(d474) AS d474_mean,
# AVG(d475) AS d475_mean,
# AVG(d476) AS d476_mean,
# AVG(d477) AS d477_mean,
# AVG(d478) AS d478_mean,
# AVG(d479) AS d479_mean,
# AVG(d480) AS d480_mean,
# AVG(d481) AS d481_mean,
# AVG(d482) AS d482_mean,
# AVG(d483) AS d483_mean,
# AVG(d484) AS d484_mean,
# AVG(d485) AS d485_mean,
# AVG(d486) AS d486_mean,
# AVG(d487) AS d487_mean,
# AVG(d488) AS d488_mean,
# AVG(d489) AS d489_mean,
# AVG(d490) AS d490_mean,
# AVG(d491) AS d491_mean,
# AVG(d492) AS d492_mean,
# AVG(d493) AS d493_mean,
# AVG(d494) AS d494_mean,
# AVG(d495) AS d495_mean,
# AVG(d496) AS d496_mean,
# AVG(d497) AS d497_mean,
# AVG(d498) AS d498_mean,
# AVG(d499) AS d499_mean,
# AVG(d500) AS d500_mean,
# AVG(d501) AS d501_mean,
# AVG(d502) AS d502_mean,
# AVG(d503) AS d503_mean,
# AVG(d504) AS d504_mean,
# AVG(d505) AS d505_mean,
# AVG(d506) AS d506_mean,
# AVG(d507) AS d507_mean,
# AVG(d508) AS d508_mean,
# AVG(d509) AS d509_mean,
# AVG(d510) AS d510_mean,
# AVG(d511) AS d511_mean,
#
# FROM (
# SELECT f.second_level.name AS f1,
#
# title_embed[OFFSET(0)] AS d0,
# title_embed[OFFSET(1)] AS d1,
# title_embed[OFFSET(2)] AS d2,
# title_embed[OFFSET(3)] AS d3,
# title_embed[OFFSET(4)] AS d4,
# title_embed[OFFSET(5)] AS d5,
# title_embed[OFFSET(6)] AS d6,
# title_embed[OFFSET(7)] AS d7,
# title_embed[OFFSET(8)] AS d8,
# title_embed[OFFSET(9)] AS d9,
# title_embed[OFFSET(10)] AS d10,
# title_embed[OFFSET(11)] AS d11,
# title_embed[OFFSET(12)] AS d12,
# title_embed[OFFSET(13)] AS d13,
# title_embed[OFFSET(14)] AS d14,
# title_embed[OFFSET(15)] AS d15,
# title_embed[OFFSET(16)] AS d16,
# title_embed[OFFSET(17)] AS d17,
# title_embed[OFFSET(18)] AS d18,
# title_embed[OFFSET(19)] AS d19,
# title_embed[OFFSET(20)] AS d20,
# title_embed[OFFSET(21)] AS d21,
# title_embed[OFFSET(22)] AS d22,
# title_embed[OFFSET(23)] AS d23,
# title_embed[OFFSET(24)] AS d24,
# title_embed[OFFSET(25)] AS d25,
# title_embed[OFFSET(26)] AS d26,
# title_embed[OFFSET(27)] AS d27,
# title_embed[OFFSET(28)] AS d28,
# title_embed[OFFSET(29)] AS d29,
# title_embed[OFFSET(30)] AS d30,
# title_embed[OFFSET(31)] AS d31,
# title_embed[OFFSET(32)] AS d32,
# title_embed[OFFSET(33)] AS d33,
# title_embed[OFFSET(34)] AS d34,
# title_embed[OFFSET(35)] AS d35,
# title_embed[OFFSET(36)] AS d36,
# title_embed[OFFSET(37)] AS d37,
# title_embed[OFFSET(38)] AS d38,
# title_embed[OFFSET(39)] AS d39,
# title_embed[OFFSET(40)] AS d40,
# title_embed[OFFSET(41)] AS d41,
# title_embed[OFFSET(42)] AS d42,
# title_embed[OFFSET(43)] AS d43,
# title_embed[OFFSET(44)] AS d44,
# title_embed[OFFSET(45)] AS d45,
# title_embed[OFFSET(46)] AS d46,
# title_embed[OFFSET(47)] AS d47,
# title_embed[OFFSET(48)] AS d48,
# title_embed[OFFSET(49)] AS d49,
# title_embed[OFFSET(50)] AS d50,
# title_embed[OFFSET(51)] AS d51,
# title_embed[OFFSET(52)] AS d52,
# title_embed[OFFSET(53)] AS d53,
# title_embed[OFFSET(54)] AS d54,
# title_embed[OFFSET(55)] AS d55,
# title_embed[OFFSET(56)] AS d56,
# title_embed[OFFSET(57)] AS d57,
# title_embed[OFFSET(58)] AS d58,
# title_embed[OFFSET(59)] AS d59,
# title_embed[OFFSET(60)] AS d60,
# title_embed[OFFSET(61)] AS d61,
# title_embed[OFFSET(501)] AS d501,
# title_embed[OFFSET(502)] AS d502,
# title_embed[OFFSET(503)] AS d503,
# title_embed[OFFSET(504)] AS d504,
# title_embed[OFFSET(505)] AS d505,
# title_embed[OFFSET(506)] AS d506,
# title_embed[OFFSET(507)] AS d507,
# title_embed[OFFSET(508)] AS d508,
# title_embed[OFFSET(509)] AS d509,
# title_embed[OFFSET(510)] AS d510,
# title_embed[OFFSET(511)] AS d511,
#
# FROM `springer-nature-analytics.DS_dimensions.publications_full_refresh`
# LEFT JOIN UNNEST(`for`) AS f LEFT JOIN UNNEST(journal) AS j
# WHERE ARRAY_LENGTH(title_embed) = 512
# AND
# publication_type LIKE "article"
#         AND j.title IN (SELECT title FROM `springer-nature-analytics.core_journals.core_2018_v01`)
#         AND year >= 1999
#         AND year <= 2001
#         AND language LIKE "en"
#         AND ARRAY_LENGTH(references) > 4
#
# ) GROUP BY f1
#  ) WHERE f1 IS NOT NULL

# %%
train_and_save(for_99_01, "wv_99_01", "f2")
# Out:
# Saved mean vectors to "/content/drive/My Drive/Research/Data/Mean-title-centroids-3yrs-v02/wv_99_01_f2.csv"

# %% [markdown]
# # 1996-1998

# %%
# %%bigquery --project $pid for_96_98
#
# SELECT * FROM (
# SELECT f1,
#
# AVG(d0) AS d0_mean,
# AVG(d1) AS d1_mean,
# AVG(d2) AS d2_mean,
# AVG(d3) AS d3_mean,
# AVG(d4) AS d4_mean,
# AVG(d5) AS d5_mean,
# AVG(d6) AS d6_mean,
# AVG(d7) AS d7_mean,
# AVG(d8) AS d8_mean,
# AVG(d9) AS d9_mean,
# AVG(d10) AS d10_mean,
# AVG(d11) AS d11_mean,
# AVG(d12) AS d12_mean,
# AVG(d13) AS d13_mean,
# AVG(d14) AS d14_mean,
# AVG(d15) AS d15_mean,
# AVG(d16) AS d16_mean,
# AVG(d17) AS d17_mean,
# AVG(d18) AS d18_mean,
# AVG(d19) AS d19_mean,
# AVG(d20) AS d20_mean,
# AVG(d21) AS d21_mean,
# AVG(d22) AS d22_mean,
# AVG(d23) AS d23_mean,
# AVG(d24) AS d24_mean,
# AVG(d25) AS d25_mean,
# AVG(d26) AS d26_mean,
# AVG(d27) AS d27_mean,
# AVG(d28) AS d28_mean,
# AVG(d29) AS d29_mean,
# AVG(d30) AS d30_mean,
# AVG(d31) AS d31_mean,
# AVG(d32) AS d32_mean,
# AVG(d33) AS d33_mean,
# AVG(d34) AS d34_mean,
# AVG(d35) AS d35_mean,
# AVG(d36) AS d36_mean,
# AVG(d37) AS d37_mean,
# AVG(d38) AS d38_mean,
# AVG(d39) AS d39_mean,
# AVG(d40) AS d40_mean,
# AVG(d41) AS d41_mean,
# AVG(d42) AS d42_mean,
# AVG(d43) AS d43_mean,
# AVG(d44) AS d44_mean,
# AVG(d45) AS d45_mean,
# AVG(d46) AS d46_mean,
# AVG(d47) AS d47_mean,
# AVG(d48) AS d48_mean,
# AVG(d49) AS d49_mean,
# AVG(d50) AS d50_mean,
# AVG(d51) AS d51_mean,
# AVG(d52) AS d52_mean,
# AVG(d53) AS d53_mean,
# AVG(d54) AS d54_mean,
# AVG(d55) AS d55_mean,
# AVG(d56) AS d56_mean,
# AVG(d57) AS d57_mean,
# AVG(d58) AS d58_mean,
# AVG(d59) AS d59_mean,
# AVG(d60) AS d60_mean,
# AVG(d61) AS d61_mean,
# AVG(d62) AS d62_mean,
# AVG(d63) AS d63_mean,
# AVG(d64) AS d64_mean,
# AVG(d65) AS d65_mean,
# AVG(d66) AS d66_mean,
# AVG(d67) AS d67_mean,
# AVG(d68) AS d68_mean,
# AVG(d69) AS d69_mean,
# AVG(d70) AS d70_mean,
# AVG(d71) AS d71_mean,
# AVG(d72) AS d72_mean,
# AVG(d73) AS d73_mean,
# AVG(d74) AS d74_mean,
# AVG(d75) AS d75_mean,
# AVG(d76) AS d76_mean,
# AVG(d77) AS d77_mean,
# AVG(d78) AS d78_mean,
# AVG(d79) AS d79_mean,
# AVG(d80) AS d80_mean,
# AVG(d81) AS d81_mean,
# AVG(d82) AS d82_mean,
# AVG(d83) AS d83_mean,
# AVG(d84) AS d84_mean,
# AVG(d85) AS d85_mean,
# AVG(d86) AS d86_mean,
# AVG(d87) AS d87_mean,
# AVG(d88) AS d88_mean,
# AVG(d89) AS d89_mean,
# AVG(d90) AS d90_mean,
# AVG(d91) AS d91_mean,
# AVG(d92) AS d92_mean,
# AVG(d93) AS d93_mean,
# AVG(d94) AS d94_mean,
# AVG(d95) AS d95_mean,
# AVG(d96) AS d96_mean,
# AVG(d97) AS d97_mean,
# AVG(d98) AS d98_mean,
# AVG(d99) AS d99_mean,
# AVG(d100) AS d100_mean,
# AVG(d101) AS d101_mean,
# AVG(d102) AS d102_mean,
# AVG(d103) AS d103_mean,
# AVG(d104) AS d104_mean,
# AVG(d105) AS d105_mean,
# AVG(d106) AS d106_mean,
# AVG(d107) AS d107_mean,
# AVG(d108) AS d108_mean,
# AVG(d109) AS d109_mean,
# AVG(d110) AS d110_mean,
# AVG(d111) AS d111_mean,
# AVG(d112) AS d112_mean,
# AVG(d113) AS d113_mean,
# AVG(d114) AS d114_mean,
# AVG(d115) AS d115_mean,
# AVG(d116) AS d116_mean,
# AVG(d117) AS d117_mean,
# AVG(d118) AS d118_mean,
# AVG(d119) AS d119_mean,
# AVG(d120) AS d120_mean,
# AVG(d121) AS d121_mean,
# AVG(d122) AS d122_mean,
# AVG(d123) AS d123_mean,
# AVG(d124) AS d124_mean,
# AVG(d125) AS d125_mean,
# AVG(d126) AS d126_mean,
# AVG(d127) AS d127_mean,
# AVG(d128) AS d128_mean,
# AVG(d129) AS d129_mean,
# AVG(d130) AS d130_mean,
# AVG(d131) AS d131_mean,
# AVG(d132) AS d132_mean,
# AVG(d133) AS d133_mean,
# AVG(d134) AS d134_mean,
# AVG(d135) AS d135_mean,
# AVG(d136) AS d136_mean,
# AVG(d137) AS d137_mean,
# AVG(d138) AS d138_mean,
# AVG(d139) AS d139_mean,
# AVG(d140) AS d140_mean,
# AVG(d141) AS d141_mean,
# AVG(d142) AS d142_mean,
# AVG(d143) AS d143_mean,
# AVG(d144) AS d144_mean,
# AVG(d145) AS d145_mean,
# AVG(d146) AS d146_mean,
# AVG(d147) AS d147_mean,
# AVG(d148) AS d148_mean,
# AVG(d149) AS d149_mean,
# AVG(d150) AS d150_mean,
# AVG(d151) AS d151_mean,
# AVG(d152) AS d152_mean,
# AVG(d153) AS d153_mean,
# AVG(d154) AS d154_mean,
# AVG(d155) AS d155_mean,
# AVG(d156) AS d156_mean,
# AVG(d157) AS d157_mean,
# AVG(d158) AS d158_mean,
# AVG(d159) AS d159_mean,
# AVG(d160) AS d160_mean,
# AVG(d161) AS d161_mean,
# AVG(d162) AS d162_mean,
# AVG(d163) AS d163_mean,
# AVG(d164) AS d164_mean,
# AVG(d165) AS d165_mean,
# AVG(d166) AS d166_mean,
# AVG(d167) AS d167_mean,
# AVG(d168) AS d168_mean,
# AVG(d169) AS d169_mean,
# AVG(d170) AS d170_mean,
# AVG(d171) AS d171_mean,
# AVG(d172) AS d172_mean,
# AVG(d173) AS d173_mean,
# AVG(d174) AS d174_mean,
# AVG(d175) AS d175_mean,
# AVG(d176) AS d176_mean,
# AVG(d177) AS d177_mean,
# AVG(d178) AS d178_mean,
# AVG(d179) AS d179_mean,
# AVG(d180) AS d180_mean,
# AVG(d181) AS d181_mean,
# AVG(d182) AS d182_mean,
# AVG(d183) AS d183_mean,
# AVG(d184) AS d184_mean,
# AVG(d185) AS d185_mean,
# AVG(d186) AS d186_mean,
# AVG(d187) AS d187_mean,
# AVG(d188) AS d188_mean,
# AVG(d189) AS d189_mean,
# AVG(d190) AS d190_mean,
# AVG(d191) AS d191_mean,
# AVG(d192) AS d192_mean,
# AVG(d193) AS d193_mean,
# AVG(d194) AS d194_mean,
# AVG(d195) AS d195_mean,
# AVG(d196) AS d196_mean,
# AVG(d197) AS d197_mean,
# AVG(d198) AS d198_mean,
# AVG(d199) AS d199_mean,
# AVG(d200) AS d200_mean,
# AVG(d201) AS d201_mean,
# AVG(d202) AS d202_mean,
# AVG(d203) AS d203_mean,
# AVG(d204) AS d204_mean,
# AVG(d205) AS d205_mean,
# AVG(d206) AS d206_mean,
# AVG(d207) AS d207_mean,
# AVG(d208) AS d208_mean,
# AVG(d209) AS d209_mean,
# AVG(d210) AS d210_mean,
# AVG(d211) AS d211_mean,
# AVG(d212) AS d212_mean,
# AVG(d213) AS d213_mean,
# AVG(d214) AS d214_mean,
# AVG(d215) AS d215_mean,
# AVG(d216) AS d216_mean,
# AVG(d217) AS d217_mean,
# AVG(d218) AS d218_mean,
# AVG(d219) AS d219_mean,
# AVG(d220) AS d220_mean,
# AVG(d221) AS d221_mean,
# AVG(d222) AS d222_mean,
# AVG(d223) AS d223_mean,
# AVG(d224) AS d224_mean,
# AVG(d225) AS d225_mean,
# AVG(d226) AS d226_mean,
# AVG(d227) AS d227_mean,
# AVG(d228) AS d228_mean,
# AVG(d229) AS d229_mean,
# AVG(d230) AS d230_mean,
# AVG(d231) AS d231_mean,
# AVG(d232) AS d232_mean,
# AVG(d233) AS d233_mean,
# AVG(d234) AS d234_mean,
# AVG(d235) AS d235_mean,
# AVG(d236) AS d236_mean,
# AVG(d237) AS d237_mean,
# AVG(d238) AS d238_mean,
# AVG(d239) AS d239_mean,
# AVG(d240) AS d240_mean,
# AVG(d241) AS d241_mean,
# AVG(d242) AS d242_mean,
# AVG(d243) AS d243_mean,
# AVG(d244) AS d244_mean,
# AVG(d245) AS d245_mean,
# AVG(d246) AS d246_mean,
# AVG(d247) AS d247_mean,
# AVG(d248) AS d248_mean,
# AVG(d249) AS d249_mean,
# AVG(d250) AS d250_mean,
# AVG(d251) AS d251_mean,
# AVG(d252) AS d252_mean,
# AVG(d253) AS d253_mean,
# AVG(d254) AS d254_mean,
# AVG(d255) AS d255_mean,
# AVG(d256) AS d256_mean,
# AVG(d257) AS d257_mean,
# AVG(d258) AS d258_mean,
# AVG(d259) AS d259_mean,
# AVG(d260) AS d260_mean,
# AVG(d261) AS d261_mean,
# AVG(d262) AS d262_mean,
# AVG(d263) AS d263_mean,
# AVG(d264) AS d264_mean,
# AVG(d265) AS d265_mean,
# AVG(d266) AS d266_mean,
# AVG(d267) AS d267_mean,
# AVG(d268) AS d268_mean,
# AVG(d269) AS d269_mean,
# AVG(d270) AS d270_mean,
# AVG(d271) AS d271_mean,
# AVG(d272) AS d272_mean,
# AVG(d273) AS d273_mean,
# AVG(d274) AS d274_mean,
# AVG(d275) AS d275_mean,
# AVG(d276) AS d276_mean,
# AVG(d277) AS d277_mean,
# AVG(d278) AS d278_mean,
# AVG(d279) AS d279_mean,
# AVG(d280) AS d280_mean,
# AVG(d281) AS d281_mean,
# AVG(d282) AS d282_mean,
# AVG(d283) AS d283_mean,
# AVG(d284) AS d284_mean,
# AVG(d285) AS d285_mean,
# AVG(d286) AS d286_mean,
# AVG(d287) AS d287_mean,
# AVG(d288) AS d288_mean,
# AVG(d289) AS d289_mean,
# AVG(d290) AS d290_mean,
# AVG(d291) AS d291_mean,
# AVG(d292) AS d292_mean,
# AVG(d293) AS d293_mean,
# AVG(d294) AS d294_mean,
# AVG(d295) AS d295_mean,
# AVG(d296) AS d296_mean,
# AVG(d297) AS d297_mean,
# AVG(d298) AS d298_mean,
# AVG(d299) AS d299_mean,
# AVG(d300) AS d300_mean,
# AVG(d301) AS d301_mean,
# AVG(d302) AS d302_mean,
# AVG(d303) AS d303_mean,
# AVG(d304) AS d304_mean,
# AVG(d305) AS d305_mean,
# AVG(d306) AS d306_mean,
# AVG(d307) AS d307_mean,
# AVG(d308) AS d308_mean,
# AVG(d309) AS d309_mean,
# AVG(d310) AS d310_mean,
# AVG(d311) AS d311_mean,
# AVG(d312) AS d312_mean,
# AVG(d313) AS d313_mean,
# AVG(d314) AS d314_mean,
# AVG(d315) AS d315_mean,
# AVG(d316) AS d316_mean,
# AVG(d317) AS d317_mean,
# AVG(d318) AS d318_mean,
# AVG(d319) AS d319_mean,
# AVG(d320) AS d320_mean,
# AVG(d321) AS d321_mean,
# AVG(d322) AS d322_mean,
# AVG(d323) AS d323_mean,
# AVG(d324) AS d324_mean,
# AVG(d325) AS d325_mean,
# AVG(d326) AS d326_mean,
# AVG(d327) AS d327_mean,
# AVG(d328) AS d328_mean,
# AVG(d329) AS d329_mean,
# AVG(d330) AS d330_mean,
# AVG(d331) AS d331_mean,
# AVG(d332) AS d332_mean,
# AVG(d333) AS d333_mean,
# AVG(d334) AS d334_mean,
# AVG(d335) AS d335_mean,
# AVG(d336) AS d336_mean,
# AVG(d337) AS d337_mean,
# AVG(d338) AS d338_mean,
# AVG(d339) AS d339_mean,
# AVG(d340) AS d340_mean,
# AVG(d341) AS d341_mean,
# AVG(d342) AS d342_mean,
# AVG(d343) AS d343_mean,
# AVG(d344) AS d344_mean,
# AVG(d345) AS d345_mean,
# AVG(d346) AS d346_mean,
# AVG(d347) AS d347_mean,
# AVG(d348) AS d348_mean,
# AVG(d349) AS d349_mean,
# AVG(d350) AS d350_mean,
# AVG(d351) AS d351_mean,
# AVG(d352) AS d352_mean,
# AVG(d353) AS d353_mean,
# AVG(d354) AS d354_mean,
# AVG(d355) AS d355_mean,
# AVG(d356) AS d356_mean,
# AVG(d357) AS d357_mean,
# AVG(d358) AS d358_mean,
# AVG(d359) AS d359_mean,
# AVG(d360) AS d360_mean,
# AVG(d361) AS d361_mean,
# AVG(d362) AS d362_mean,
# AVG(d363) AS d363_mean,
# AVG(d364) AS d364_mean,
# AVG(d365) AS d365_mean,
# AVG(d366) AS d366_mean,
# AVG(d367) AS d367_mean,
# AVG(d368) AS d368_mean,
# AVG(d369) AS d369_mean,
# AVG(d370) AS d370_mean,
# AVG(d371) AS d371_mean,
# AVG(d372) AS d372_mean,
# AVG(d373) AS d373_mean,
# AVG(d374) AS d374_mean,
# AVG(d375) AS d375_mean,
# AVG(d376) AS d376_mean,
# AVG(d377) AS d377_mean,
# AVG(d378) AS d378_mean,
# AVG(d379) AS d379_mean,
# AVG(d380) AS d380_mean,
# AVG(d381) AS d381_mean,
# AVG(d382) AS d382_mean,
# AVG(d383) AS d383_mean,
# AVG(d384) AS d384_mean,
# AVG(d385) AS d385_mean,
# AVG(d386) AS d386_mean,
# AVG(d387) AS d387_mean,
# AVG(d388) AS d388_mean,
# AVG(d389) AS d389_mean,
# AVG(d390) AS d390_mean,
# AVG(d391) AS d391_mean,
# AVG(d392) AS d392_mean,
# AVG(d393) AS d393_mean,
# AVG(d394) AS d394_mean,
# AVG(d395) AS d395_mean,
# AVG(d396) AS d396_mean,
# AVG(d397) AS d397_mean,
# AVG(d398) AS d398_mean,
# AVG(d399) AS d399_mean,
# AVG(d400) AS d400_mean,
# AVG(d401) AS d401_mean,
# AVG(d402) AS d402_mean,
# AVG(d403) AS d403_mean,
# AVG(d404) AS d404_mean,
# AVG(d405) AS d405_mean,
# AVG(d406) AS d406_mean,
# AVG(d407) AS d407_mean,
# AVG(d408) AS d408_mean,
# AVG(d409) AS d409_mean,
# AVG(d410) AS d410_mean,
# AVG(d411) AS d411_mean,
# AVG(d412) AS d412_mean,
# AVG(d413) AS d413_mean,
# AVG(d414) AS d414_mean,
# AVG(d415) AS d415_mean,
# AVG(d416) AS d416_mean,
# AVG(d417) AS d417_mean,
# AVG(d418) AS d418_mean,
# AVG(d419) AS d419_mean,
# AVG(d420) AS d420_mean,
# AVG(d421) AS d421_mean,
# AVG(d422) AS d422_mean,
# AVG(d423) AS d423_mean,
# AVG(d424) AS d424_mean,
# AVG(d425) AS d425_mean,
# AVG(d426) AS d426_mean,
# AVG(d427) AS d427_mean,
# AVG(d428) AS d428_mean,
# AVG(d429) AS d429_mean,
# AVG(d430) AS d430_mean,
# AVG(d431) AS d431_mean,
# AVG(d432) AS d432_mean,
# AVG(d433) AS d433_mean,
# AVG(d434) AS d434_mean,
# AVG(d435) AS d435_mean,
# AVG(d436) AS d436_mean,
# AVG(d437) AS d437_mean,
# AVG(d438) AS d438_mean,
# AVG(d439) AS d439_mean,
# AVG(d440) AS d440_mean,
# AVG(d441) AS d441_mean,
# AVG(d442) AS d442_mean,
# AVG(d443) AS d443_mean,
# AVG(d444) AS d444_mean,
# AVG(d445) AS d445_mean,
# AVG(d446) AS d446_mean,
# AVG(d447) AS d447_mean,
# AVG(d448) AS d448_mean,
# AVG(d449) AS d449_mean,
# AVG(d450) AS d450_mean,
# AVG(d451) AS d451_mean,
# AVG(d452) AS d452_mean,
# AVG(d453) AS d453_mean,
# AVG(d454) AS d454_mean,
# AVG(d455) AS d455_mean,
# AVG(d456) AS d456_mean,
# AVG(d457) AS d457_mean,
# AVG(d458) AS d458_mean,
# AVG(d459) AS d459_mean,
# AVG(d460) AS d460_mean,
# AVG(d461) AS d461_mean,
# AVG(d462) AS d462_mean,
# AVG(d463) AS d463_mean,
# AVG(d464) AS d464_mean,
# AVG(d465) AS d465_mean,
# AVG(d466) AS d466_mean,
# AVG(d467) AS d467_mean,
# AVG(d468) AS d468_mean,
# AVG(d469) AS d469_mean,
# AVG(d470) AS d470_mean,
# AVG(d471) AS d471_mean,
# AVG(d472) AS d472_mean,
# AVG(d473) AS d473_mean,
# AVG(d474) AS d474_mean,
# AVG(d475) AS d475_mean,
# AVG(d476) AS d476_mean,
# AVG(d477) AS d477_mean,
# AVG(d478) AS d478_mean,
# AVG(d479) AS d479_mean,
# AVG(d480) AS d480_mean,
# AVG(d481) AS d481_mean,
# AVG(d482) AS d482_mean,
# AVG(d483) AS d483_mean,
# AVG(d484) AS d484_mean,
# AVG(d485) AS d485_mean,
# AVG(d486) AS d486_mean,
# AVG(d487) AS d487_mean,
# AVG(d488) AS d488_mean,
# AVG(d489) AS d489_mean,
# AVG(d490) AS d490_mean,
# AVG(d491) AS d491_mean,
# AVG(d492) AS d492_mean,
# AVG(d493) AS d493_mean,
# AVG(d494) AS d494_mean,
# AVG(d495) AS d495_mean,
# AVG(d496) AS d496_mean,
# AVG(d497) AS d497_mean,
# AVG(d498) AS d498_mean,
# AVG(d499) AS d499_mean,
# AVG(d500) AS d500_mean,
# AVG(d501) AS d501_mean,
# AVG(d502) AS d502_mean,
# AVG(d503) AS d503_mean,
# AVG(d504) AS d504_mean,
# AVG(d505) AS d505_mean,
# AVG(d506) AS d506_mean,
# AVG(d507) AS d507_mean,
# AVG(d508) AS d508_mean,
# AVG(d509) AS d509_mean,
# AVG(d510) AS d510_mean,
# AVG(d511) AS d511_mean,
#
# FROM (
# SELECT f.first_level.name AS f1,
#
# title_embed[OFFSET(0)] AS d0,
# title_embed[OFFSET(1)] AS d1,
# title_embed[OFFSET(2)] AS d2,
# title_embed[OFFSET(3)] AS d3,
# title_embed[OFFSET(4)] AS d4,
# title_embed[OFFSET(5)] AS d5,
# title_embed[OFFSET(6)] AS d6,
# title_embed[OFFSET(7)] AS d7,
# title_embed[OFFSET(8)] AS d8,
# title_embed[OFFSET(9)] AS d9,
# title_embed[OFFSET(10)] AS d10,
# title_embed[OFFSET(11)] AS d11,
# title_embed[OFFSET(12)] AS d12,
# title_embed[OFFSET(13)] AS d13,
# title_embed[OFFSET(14)] AS d14,
# title_embed[OFFSET(15)] AS d15,
# title_embed[OFFSET(16)] AS d16,
# title_embed[OFFSET(17)] AS d17,
# title_embed[OFFSET(18)] AS d18,
# title_embed[OFFSET(19)] AS d19,
# title_embed[OFFSET(20)] AS d20,
# title_embed[OFFSET(21)] AS d21,
# title_embed[OFFSET(22)] AS d22,
# title_embed[OFFSET(23)] AS d23,
# title_embed[OFFSET(24)] AS d24,
# title_embed[OFFSET(25)] AS d25,
# title_embed[OFFSET(26)] AS d26,
# title_embed[OFFSET(27)] AS d27,
# title_embed[OFFSET(28)] AS d28,
# title_embed[OFFSET(29)] AS d29,
# title_embed[OFFSET(30)] AS d30,
# title_embed[OFFSET(31)] AS d31,
# title_embed[OFFSET(32)] AS d32,
# title_embed[OFFSET(33)] AS d33,
# title_embed[OFFSET(34)] AS d34,
# title_embed[OFFSET(35)] AS d35,
# title_embed[OFFSET(36)] AS d36,
# title_embed[OFFSET(37)] AS d37,
# title_embed[OFFSET(38)] AS d38,
# title_embed[OFFSET(39)] AS d39,
# title_embed[OFFSET(40)] AS d40,
# title_embed[OFFSET(41)] AS d41,
# title_embed[OFFSET(42)] AS d42,
# title_embed[OFFSET(43)] AS d43,
# title_embed[OFFSET(44)] AS d44,
# title_embed[OFFSET(45)] AS d45,
# title_embed[OFFSET(46)] AS d46,
# title_embed[OFFSET(47)] AS d47,
# title_embed[OFFSET(48)] AS d48,
# title_embed[OFFSET(49)] AS d49,
# title_embed[OFFSET(50)] AS d50,
# title_embed[OFFSET(51)] AS d51,
# title_embed[OFFSET(52)] AS d52,
# title_embed[OFFSET(53)] AS d53,
# title_embed[OFFSET(54)] AS d54,
# title_embed[OFFSET(55)] AS d55,
# title_embed[OFFSET(56)] AS d56,
# title_embed[OFFSET(57)] AS d57,
# title_embed[OFFSET(58)] AS d58,
# title_embed[OFFSET(59)] AS d59,
# title_embed[OFFSET(60)] AS d60,
# title_embed[OFFSET(61)] AS d61,
# title_embed[OFFSET(62)] AS d62,
# title_embed[OFFSET(63)] AS d63,
# title_embed[OFFSET(64)] AS d64,
# title_embed[OFFSET(65)] AS d65,
# title_embed[OFFSET(505)] AS d505,
# title_embed[OFFSET(506)] AS d506,
# title_embed[OFFSET(507)] AS d507,
# title_embed[OFFSET(508)] AS d508,
# title_embed[OFFSET(509)] AS d509,
# title_embed[OFFSET(510)] AS d510,
# title_embed[OFFSET(511)] AS d511,
#
# FROM `springer-nature-analytics.DS_dimensions.publications_full_refresh`
# LEFT JOIN UNNEST(`for`) AS f LEFT JOIN UNNEST(journal) AS j
# WHERE ARRAY_LENGTH(title_embed) = 512
# AND
# publication_type LIKE "article"
#         AND j.title IN (SELECT title FROM `springer-nature-analytics.core_journals.core_2018_v01`)
#         AND year >= 1996
#         AND year <= 1998
#         AND language LIKE "en"
#         AND ARRAY_LENGTH(references) > 4
#
# ) GROUP BY f1
#  ) WHERE f1 IS NOT NULL

# %%
train_and_save(for_96_98, "wv_96_98")
# Out:
# Saved mean vectors to "/content/drive/My Drive/Research/Data/Mean-title-centroids-3yrs-v02/wv_96_98_f1.csv"

# %%
# %%bigquery --project $pid for_96_98
#
# SELECT * FROM (
# SELECT f1,
#
# AVG(d0) AS d0_mean,
# AVG(d1) AS d1_mean,
# AVG(d2) AS d2_mean,
# AVG(d3) AS d3_mean,
# AVG(d4) AS d4_mean,
# AVG(d5) AS d5_mean,
# AVG(d6) AS d6_mean,
# AVG(d7) AS d7_mean,
# AVG(d8) AS d8_mean,
# AVG(d9) AS d9_mean,
# AVG(d10) AS d10_mean,
# AVG(d11) AS d11_mean,
# AVG(d12) AS d12_mean,
# AVG(d13) AS d13_mean,
# AVG(d14) AS d14_mean,
# AVG(d15) AS d15_mean,
# AVG(d16) AS d16_mean,
# AVG(d17) AS d17_mean,
# AVG(d18) AS d18_mean,
# AVG(d19) AS d19_mean,
# AVG(d20) AS d20_mean,
# AVG(d21) AS d21_mean,
# AVG(d22) AS d22_mean,
# AVG(d23) AS d23_mean,
# AVG(d24) AS d24_mean,
# AVG(d25) AS d25_mean,
# AVG(d26) AS d26_mean,
# AVG(d27) AS d27_mean,
# AVG(d28) AS d28_mean,
# AVG(d29) AS d29_mean,
# AVG(d30) AS d30_mean,
# AVG(d31) AS d31_mean,
# AVG(d32) AS d32_mean,
# AVG(d33) AS d33_mean,
# AVG(d34) AS d34_mean,
# AVG(d35) AS d35_mean,
# AVG(d36) AS d36_mean,
# AVG(d37) AS d37_mean,
# AVG(d38) AS d38_mean,
# AVG(d39) AS d39_mean,
# AVG(d40) AS d40_mean,
# AVG(d41) AS d41_mean,
# AVG(d42) AS d42_mean,
# AVG(d43) AS d43_mean,
# AVG(d44) AS d44_mean,
# AVG(d45) AS d45_mean,
# AVG(d46) AS d46_mean,
# AVG(d47) AS d47_mean,
# AVG(d48) AS d48_mean,
# AVG(d49) AS d49_mean,
# AVG(d50) AS d50_mean,
# AVG(d51) AS d51_mean,
# AVG(d52) AS d52_mean,
# AVG(d53) AS d53_mean,
# AVG(d54) AS d54_mean,
# AVG(d55) AS d55_mean,
# AVG(d56) AS d56_mean,
# AVG(d57) AS d57_mean,
# AVG(d58) AS d58_mean,
# AVG(d59) AS d59_mean,
# AVG(d60) AS d60_mean,
# AVG(d61) AS d61_mean,
# AVG(d62) AS d62_mean,
# AVG(d63) AS d63_mean,
# AVG(d64) AS d64_mean,
# AVG(d65) AS d65_mean,
# AVG(d66) AS d66_mean,
# AVG(d67) AS d67_mean,
# AVG(d68) AS d68_mean,
# AVG(d69) AS d69_mean,
# AVG(d70) AS d70_mean,
# AVG(d71) AS d71_mean,
# AVG(d72) AS d72_mean,
# AVG(d73) AS d73_mean,
# AVG(d74) AS d74_mean,
# AVG(d75) AS d75_mean,
# AVG(d76) AS d76_mean,
# AVG(d77) AS d77_mean,
# AVG(d78) AS d78_mean,
# AVG(d79) AS d79_mean,
# AVG(d80) AS d80_mean,
# AVG(d81) AS d81_mean,
# AVG(d82) AS d82_mean,
# AVG(d83) AS d83_mean,
# AVG(d84) AS d84_mean,
# AVG(d85) AS d85_mean,
# AVG(d86) AS d86_mean,
# AVG(d87) AS d87_mean,
# AVG(d88) AS d88_mean,
# AVG(d89) AS d89_mean,
# AVG(d90) AS d90_mean,
# AVG(d91) AS d91_mean,
# AVG(d92) AS d92_mean,
# AVG(d93) AS d93_mean,
# AVG(d94) AS d94_mean,
# AVG(d95) AS d95_mean,
# AVG(d96) AS d96_mean,
# AVG(d97) AS d97_mean,
# AVG(d98) AS d98_mean,
# AVG(d99) AS d99_mean,
# AVG(d100) AS d100_mean,
# AVG(d101) AS d101_mean,
# AVG(d102) AS d102_mean,
# AVG(d103) AS d103_mean,
# AVG(d104) AS d104_mean,
# AVG(d105) AS d105_mean,
# AVG(d106) AS d106_mean,
# AVG(d107) AS d107_mean,
# AVG(d108) AS d108_mean,
# AVG(d109) AS d109_mean,
# AVG(d110) AS d110_mean,
# AVG(d111) AS d111_mean,
# AVG(d112) AS d112_mean,
# AVG(d113) AS d113_mean,
# AVG(d114) AS d114_mean,
# AVG(d115) AS d115_mean,
# AVG(d116) AS d116_mean,
# AVG(d117) AS d117_mean,
# AVG(d118) AS d118_mean,
# AVG(d119) AS d119_mean,
# AVG(d120) AS d120_mean,
# AVG(d121) AS d121_mean,
# AVG(d122) AS d122_mean,
# AVG(d123) AS d123_mean,
# AVG(d124) AS d124_mean,
# AVG(d125) AS d125_mean,
# AVG(d126) AS d126_mean,
# AVG(d127) AS d127_mean,
# AVG(d128) AS d128_mean,
# AVG(d129) AS d129_mean,
# AVG(d130) AS d130_mean,
# AVG(d131) AS d131_mean,
# AVG(d132) AS d132_mean,
# AVG(d133) AS d133_mean,
# AVG(d134) AS d134_mean,
# AVG(d135) AS d135_mean,
# AVG(d136) AS d136_mean,
# AVG(d137) AS d137_mean,
# AVG(d138) AS d138_mean,
# AVG(d139) AS d139_mean,
# AVG(d140) AS d140_mean,
# AVG(d141) AS d141_mean,
# AVG(d142) AS d142_mean,
# AVG(d143) AS d143_mean,
# AVG(d144) AS d144_mean,
# AVG(d145) AS d145_mean,
# AVG(d146) AS d146_mean,
# AVG(d147) AS d147_mean,
# AVG(d148) AS d148_mean,
# AVG(d149) AS d149_mean,
# AVG(d150) AS d150_mean,
# AVG(d151) AS d151_mean,
# AVG(d152) AS d152_mean,
# AVG(d153) AS d153_mean,
# AVG(d154) AS d154_mean,
# AVG(d155) AS d155_mean,
# AVG(d156) AS d156_mean,
# AVG(d157) AS d157_mean,
# AVG(d158) AS d158_mean,
# AVG(d159) AS d159_mean,
# AVG(d160) AS d160_mean,
# AVG(d161) AS d161_mean,
# AVG(d162) AS d162_mean,
# AVG(d163) AS d163_mean,
# AVG(d164) AS d164_mean,
# AVG(d165) AS d165_mean,
# AVG(d166) AS d166_mean,
# AVG(d167) AS d167_mean,
# AVG(d168) AS d168_mean,
# AVG(d169) AS d169_mean,
# AVG(d170) AS d170_mean,
# AVG(d171) AS d171_mean,
# AVG(d172) AS d172_mean,
# AVG(d173) AS d173_mean,
# AVG(d174) AS d174_mean,
# AVG(d175) AS d175_mean,
# AVG(d176) AS d176_mean,
# AVG(d177) AS d177_mean,
# AVG(d178) AS d178_mean,
# AVG(d179) AS d179_mean,
# AVG(d180) AS d180_mean,
# AVG(d181) AS d181_mean,
# AVG(d182) AS d182_mean,
# AVG(d183) AS d183_mean,
# AVG(d184) AS d184_mean,
# AVG(d185) AS d185_mean,
# AVG(d186) AS d186_mean,
# AVG(d187) AS d187_mean,
# AVG(d188) AS d188_mean,
# AVG(d189) AS d189_mean,
# AVG(d190) AS d190_mean,
# AVG(d191) AS d191_mean,
# AVG(d192) AS d192_mean,
# AVG(d193) AS d193_mean,
# AVG(d194) AS d194_mean,
# AVG(d195) AS d195_mean,
# AVG(d196) AS d196_mean,
# AVG(d197) AS d197_mean,
# AVG(d198) AS d198_mean,
# AVG(d199) AS d199_mean,
# AVG(d200) AS d200_mean,
# AVG(d201) AS d201_mean,
# AVG(d202) AS d202_mean,
# AVG(d203) AS d203_mean,
# AVG(d204) AS d204_mean,
# AVG(d205) AS d205_mean,
# AVG(d206) AS d206_mean,
# AVG(d207) AS d207_mean,
# AVG(d208) AS d208_mean,
# AVG(d209) AS d209_mean,
# AVG(d210) AS d210_mean,
# AVG(d211) AS d211_mean,
# AVG(d212) AS d212_mean,
# AVG(d213) AS d213_mean,
# AVG(d214) AS d214_mean,
# AVG(d215) AS d215_mean,
# AVG(d216) AS d216_mean,
# AVG(d217) AS d217_mean,
# AVG(d218) AS d218_mean,
# AVG(d219) AS d219_mean,
# AVG(d220) AS d220_mean,
# AVG(d221) AS d221_mean,
# AVG(d222) AS d222_mean,
# AVG(d223) AS d223_mean,
# AVG(d224) AS d224_mean,
# AVG(d225) AS d225_mean,
# AVG(d226) AS d226_mean,
# AVG(d227) AS d227_mean,
# AVG(d228) AS d228_mean,
# AVG(d229) AS d229_mean,
# AVG(d230) AS d230_mean,
# AVG(d231) AS d231_mean,
# AVG(d232) AS d232_mean,
# AVG(d233) AS d233_mean,
# AVG(d234) AS d234_mean,
# AVG(d235) AS d235_mean,
# AVG(d236) AS d236_mean,
# AVG(d237) AS d237_mean,
# AVG(d238) AS d238_mean,
# AVG(d239) AS d239_mean,
# AVG(d240) AS d240_mean,
# AVG(d241) AS d241_mean,
# AVG(d242) AS d242_mean,
# AVG(d243) AS d243_mean,
# AVG(d244) AS d244_mean,
# AVG(d245) AS d245_mean,
# AVG(d246) AS d246_mean,
# AVG(d247) AS d247_mean,
# AVG(d248) AS d248_mean,
# AVG(d249) AS d249_mean,
# AVG(d250) AS d250_mean,
# AVG(d251) AS d251_mean,
# AVG(d252) AS d252_mean,
# AVG(d253) AS d253_mean,
# AVG(d254) AS d254_mean,
# AVG(d255) AS d255_mean,
# AVG(d256) AS d256_mean,
# AVG(d257) AS d257_mean,
# AVG(d258) AS d258_mean,
# AVG(d259) AS d259_mean,
# AVG(d260) AS d260_mean,
# AVG(d261) AS d261_mean,
# AVG(d262) AS d262_mean,
# AVG(d263) AS d263_mean,
# AVG(d264) AS d264_mean,
# AVG(d265) AS d265_mean,
# AVG(d266) AS d266_mean,
# AVG(d267) AS d267_mean,
# AVG(d268) AS d268_mean,
# AVG(d269) AS d269_mean,
# AVG(d270) AS d270_mean,
# AVG(d271) AS d271_mean,
# AVG(d272) AS d272_mean,
# AVG(d273) AS d273_mean,
# AVG(d274) AS d274_mean,
# AVG(d275) AS d275_mean,
# AVG(d276) AS d276_mean,
# AVG(d277) AS d277_mean,
# AVG(d278) AS d278_mean,
# AVG(d279) AS d279_mean,
# AVG(d280) AS d280_mean,
# AVG(d281) AS d281_mean,
# AVG(d282) AS d282_mean,
# AVG(d283) AS d283_mean,
# AVG(d284) AS d284_mean,
# AVG(d285) AS d285_mean,
# AVG(d286) AS d286_mean,
# AVG(d287) AS d287_mean,
# AVG(d288) AS d288_mean,
# AVG(d289) AS d289_mean,
# AVG(d290) AS d290_mean,
# AVG(d291) AS d291_mean,
# AVG(d292) AS d292_mean,
# AVG(d293) AS d293_mean,
# AVG(d294) AS d294_mean,
# AVG(d295) AS d295_mean,
# AVG(d296) AS d296_mean,
# AVG(d297) AS d297_mean,
# AVG(d298) AS d298_mean,
# AVG(d299) AS d299_mean,
# AVG(d300) AS d300_mean,
# AVG(d301) AS d301_mean,
# AVG(d302) AS d302_mean,
# AVG(d303) AS d303_mean,
# AVG(d304) AS d304_mean,
# AVG(d305) AS d305_mean,
# AVG(d306) AS d306_mean,
# AVG(d307) AS d307_mean,
# AVG(d308) AS d308_mean,
# AVG(d309) AS d309_mean,
# AVG(d310) AS d310_mean,
# AVG(d311) AS d311_mean,
# AVG(d312) AS d312_mean,
# AVG(d313) AS d313_mean,
# AVG(d314) AS d314_mean,
# AVG(d315) AS d315_mean,
# AVG(d316) AS d316_mean,
# AVG(d317) AS d317_mean,
# AVG(d318) AS d318_mean,
# AVG(d319) AS d319_mean,
# AVG(d320) AS d320_mean,
# AVG(d321) AS d321_mean,
# AVG(d322) AS d322_mean,
# AVG(d323) AS d323_mean,
# AVG(d324) AS d324_mean,
# AVG(d325) AS d325_mean,
# AVG(d326) AS d326_mean,
# AVG(d327) AS d327_mean,
# AVG(d328) AS d328_mean,
# AVG(d329) AS d329_mean,
# AVG(d330) AS d330_mean,
# AVG(d331) AS d331_mean,
# AVG(d332) AS d332_mean,
# AVG(d333) AS d333_mean,
# AVG(d334) AS d334_mean,
# AVG(d335) AS d335_mean,
# AVG(d336) AS d336_mean,
# AVG(d337) AS d337_mean,
# AVG(d338) AS d338_mean,
# AVG(d339) AS d339_mean,
# AVG(d340) AS d340_mean,
# AVG(d341) AS d341_mean,
# AVG(d342) AS d342_mean,
# AVG(d343) AS d343_mean,
# AVG(d344) AS d344_mean,
# AVG(d345) AS d345_mean,
# AVG(d346) AS d346_mean,
# AVG(d347) AS d347_mean,
# AVG(d348) AS d348_mean,
# AVG(d349) AS d349_mean,
# AVG(d350) AS d350_mean,
# AVG(d351) AS d351_mean,
# AVG(d352) AS d352_mean,
# AVG(d353) AS d353_mean,
# AVG(d354) AS d354_mean,
# AVG(d355) AS d355_mean,
# AVG(d356) AS d356_mean,
# AVG(d357) AS d357_mean,
# AVG(d358) AS d358_mean,
# AVG(d359) AS d359_mean,
# AVG(d360) AS d360_mean,
# AVG(d361) AS d361_mean,
# AVG(d362) AS d362_mean,
# AVG(d363) AS d363_mean,
# AVG(d364) AS d364_mean,
# AVG(d365) AS d365_mean,
# AVG(d366) AS d366_mean,
# AVG(d367) AS d367_mean,
# AVG(d368) AS d368_mean,
# AVG(d369) AS d369_mean,
# AVG(d370) AS d370_mean,
# AVG(d371) AS d371_mean,
# AVG(d372) AS d372_mean,
# AVG(d373) AS d373_mean,
# AVG(d374) AS d374_mean,
# AVG(d375) AS d375_mean,
# AVG(d376) AS d376_mean,
# AVG(d377) AS d377_mean,
# AVG(d378) AS d378_mean,
# AVG(d379) AS d379_mean,
# AVG(d380) AS d380_mean,
# AVG(d381) AS d381_mean,
# AVG(d382) AS d382_mean,
# AVG(d383) AS d383_mean,
# AVG(d384) AS d384_mean,
# AVG(d385) AS d385_mean,
# AVG(d386) AS d386_mean,
# AVG(d387) AS d387_mean,
# AVG(d388) AS d388_mean,
# AVG(d389) AS d389_mean,
# AVG(d390) AS d390_mean,
# AVG(d391) AS d391_mean,
# AVG(d392) AS d392_mean,
# AVG(d393) AS d393_mean,
# AVG(d394) AS d394_mean,
# AVG(d395) AS d395_mean,
# AVG(d396) AS d396_mean,
# AVG(d397) AS d397_mean,
# AVG(d398) AS d398_mean,
# AVG(d399) AS d399_mean,
# AVG(d400) AS d400_mean,
# AVG(d401) AS d401_mean,
# AVG(d402) AS d402_mean,
# AVG(d403) AS d403_mean,
# AVG(d404) AS d404_mean,
# AVG(d405) AS d405_mean,
# AVG(d406) AS d406_mean,
# AVG(d407) AS d407_mean,
# AVG(d408) AS d408_mean,
# AVG(d409) AS d409_mean,
# AVG(d410) AS d410_mean,
# AVG(d411) AS d411_mean,
# AVG(d412) AS d412_mean,
# AVG(d413) AS d413_mean,
# AVG(d414) AS d414_mean,
# AVG(d415) AS d415_mean,
# AVG(d416) AS d416_mean,
# AVG(d417) AS d417_mean,
# AVG(d418) AS d418_mean,
# AVG(d419) AS d419_mean,
# AVG(d420) AS d420_mean,
# AVG(d421) AS d421_mean,
# AVG(d422) AS d422_mean,
# AVG(d423) AS d423_mean,
# AVG(d424) AS d424_mean,
# AVG(d425) AS d425_mean,
# AVG(d426) AS d426_mean,
# AVG(d427) AS d427_mean,
# AVG(d428) AS d428_mean,
# AVG(d429) AS d429_mean,
# AVG(d430) AS d430_mean,
# AVG(d431) AS d431_mean,
# AVG(d432) AS d432_mean,
# AVG(d433) AS d433_mean,
# AVG(d434) AS d434_mean,
# AVG(d435) AS d435_mean,
# AVG(d436) AS d436_mean,
# AVG(d437) AS d437_mean,
# AVG(d438) AS d438_mean,
# AVG(d439) AS d439_mean,
# AVG(d440) AS d440_mean,
# AVG(d441) AS d441_mean,
# AVG(d442) AS d442_mean,
# AVG(d443) AS d443_mean,
# AVG(d444) AS d444_mean,
# AVG(d445) AS d445_mean,
# AVG(d446) AS d446_mean,
# AVG(d447) AS d447_mean,
# AVG(d448) AS d448_mean,
# AVG(d449) AS d449_mean,
# AVG(d450) AS d450_mean,
# AVG(d451) AS d451_mean,
# AVG(d452) AS d452_mean,
# AVG(d453) AS d453_mean,
# AVG(d454) AS d454_mean,
# AVG(d455) AS d455_mean,
# AVG(d456) AS d456_mean,
# AVG(d457) AS d457_mean,
# AVG(d458) AS d458_mean,
# AVG(d459) AS d459_mean,
# AVG(d460) AS d460_mean,
# AVG(d461) AS d461_mean,
# AVG(d462) AS d462_mean,
# AVG(d463) AS d463_mean,
# AVG(d464) AS d464_mean,
# AVG(d465) AS d465_mean,
# AVG(d466) AS d466_mean,
# AVG(d467) AS d467_mean,
# AVG(d468) AS d468_mean,
# AVG(d469) AS d469_mean,
# AVG(d470) AS d470_mean,
# AVG(d471) AS d471_mean,
# AVG(d472) AS d472_mean,
# AVG(d473) AS d473_mean,
# AVG(d474) AS d474_mean,
# AVG(d475) AS d475_mean,
# AVG(d476) AS d476_mean,
# AVG(d477) AS d477_mean,
# AVG(d478) AS d478_mean,
# AVG(d479) AS d479_mean,
# AVG(d480) AS d480_mean,
# AVG(d481) AS d481_mean,
# AVG(d482) AS d482_mean,
# AVG(d483) AS d483_mean,
# AVG(d484) AS d484_mean,
# AVG(d485) AS d485_mean,
# AVG(d486) AS d486_mean,
# AVG(d487) AS d487_mean,
# AVG(d488) AS d488_mean,
# AVG(d489) AS d489_mean,
# AVG(d490) AS d490_mean,
# AVG(d491) AS d491_mean,
# AVG(d492) AS d492_mean,
# AVG(d493) AS d493_mean,
# AVG(d494) AS d494_mean,
# AVG(d495) AS d495_mean,
# AVG(d496) AS d496_mean,
# AVG(d497) AS d497_mean,
# AVG(d498) AS d498_mean,
# AVG(d499) AS d499_mean,
# AVG(d500) AS d500_mean,
# AVG(d501) AS d501_mean,
# AVG(d502) AS d502_mean,
# AVG(d503) AS d503_mean,
# AVG(d504) AS d504_mean,
# AVG(d505) AS d505_mean,
# AVG(d506) AS d506_mean,
# AVG(d507) AS d507_mean,
# AVG(d508) AS d508_mean,
# AVG(d509) AS d509_mean,
# AVG(d510) AS d510_mean,
# AVG(d511) AS d511_mean,
#
# FROM (
# SELECT f.second_level.name AS f1,
#
# title_embed[OFFSET(0)] AS d0,
# title_embed[OFFSET(1)] AS d1,
# title_embed[OFFSET(2)] AS d2,
# title_embed[OFFSET(3)] AS d3,
# title_embed[OFFSET(4)] AS d4,
# title_embed[OFFSET(5)] AS d5,
# title_embed[OFFSET(6)] AS d6,
# title_embed[OFFSET(7)] AS d7,
# title_embed[OFFSET(8)] AS d8,
# title_embed[OFFSET(9)] AS d9,
# title_embed[OFFSET(10)] AS d10,
# title_embed[OFFSET(11)] AS d11,
# title_embed[OFFSET(12)] AS d12,
# title_embed[OFFSET(13)] AS d13,
# title_embed[OFFSET(14)] AS d14,
# title_embed[OFFSET(15)] AS d15,
# title_embed[OFFSET(16)] AS d16,
# title_embed[OFFSET(17)] AS d17,
# title_embed[OFFSET(18)] AS d18,
# title_embed[OFFSET(19)] AS d19,
# title_embed[OFFSET(20)] AS d20,
# title_embed[OFFSET(21)] AS d21,
# title_embed[OFFSET(22)] AS d22,
# title_embed[OFFSET(23)] AS d23,
# title_embed[OFFSET(24)] AS d24,
# title_embed[OFFSET(25)] AS d25,
# title_embed[OFFSET(26)] AS d26,
# title_embed[OFFSET(27)] AS d27,
# title_embed[OFFSET(28)] AS d28,
# title_embed[OFFSET(29)] AS d29,
# title_embed[OFFSET(30)] AS d30,
# title_embed[OFFSET(31)] AS d31,
# title_embed[OFFSET(32)] AS d32,
# title_embed[OFFSET(33)] AS d33,
# title_embed[OFFSET(34)] AS d34,
# title_embed[OFFSET(35)] AS d35,
# title_embed[OFFSET(36)] AS d36,
# title_embed[OFFSET(37)] AS d37,
# title_embed[OFFSET(38)] AS d38,
# title_embed[OFFSET(39)] AS d39,
# title_embed[OFFSET(40)] AS d40,
# title_embed[OFFSET(41)] AS d41,
# title_embed[OFFSET(42)] AS d42,
# title_embed[OFFSET(43)] AS d43,
# title_embed[OFFSET(44)] AS d44,
# title_embed[OFFSET(45)] AS d45,
# title_embed[OFFSET(46)] AS d46,
# title_embed[OFFSET(47)] AS d47,
# title_embed[OFFSET(48)] AS d48,
# title_embed[OFFSET(49)] AS d49,
# title_embed[OFFSET(50)] AS d50,
# title_embed[OFFSET(51)] AS d51,
# title_embed[OFFSET(52)] AS d52,
# title_embed[OFFSET(53)] AS d53,
# title_embed[OFFSET(54)] AS d54,
# title_embed[OFFSET(55)] AS d55,
# title_embed[OFFSET(56)] AS d56,
# title_embed[OFFSET(57)] AS d57,
# title_embed[OFFSET(58)] AS d58,
# title_embed[OFFSET(59)] AS d59,
# title_embed[OFFSET(60)] AS d60,
# title_embed[OFFSET(61)] AS d61,
# title_embed[OFFSET(62)] AS d62,
# title_embed[OFFSET(63)] AS d63,
# title_embed[OFFSET(64)] AS d64,
# title_embed[OFFSET(65)] AS d65,
# title_embed[OFFSET(66)] AS d66,
# title_embed[OFFSET(67)] AS d67,
# title_embed[OFFSET(68)] AS d68,
# title_embed[OFFSET(69)] AS d69,
# title_embed[OFFSET(70)] AS d70,
# title_embed[OFFSET(511)] AS d511,
#
# FROM `springer-nature-analytics.DS_dimensions.publications_full_refresh`
# LEFT JOIN UNNEST(`for`) AS f LEFT JOIN UNNEST(journal) AS j
# WHERE ARRAY_LENGTH(title_embed) = 512
# AND
# publication_type LIKE "article"
#         AND j.title IN (SELECT title FROM `springer-nature-analytics.core_journals.core_2018_v01`)
#         AND year >= 1996
#         AND year <= 1998
#         AND language LIKE "en"
#         AND ARRAY_LENGTH(references) > 4
#
# ) GROUP BY f1
#  ) WHERE f1 IS NOT NULL

# %%
train_and_save(for_96_98, "wv_96_98", "f2")
# Out:
# Saved mean vectors to "/content/drive/My Drive/Research/Data/Mean-title-centroids-3yrs-v02/wv_96_98_f2.csv"

# %% [markdown]
# # 1993-1995

# %%
# %%bigquery --project $pid for_93_95
#
# SELECT * FROM (
# SELECT f1,
#
# AVG(d0) AS d0_mean,
# AVG(d1) AS d1_mean,
# AVG(d2) AS d2_mean,
# AVG(d3) AS d3_mean,
# AVG(d4) AS d4_mean,
# AVG(d5) AS d5_mean,
# AVG(d6) AS d6_mean,
# AVG(d7) AS d7_mean,
# AVG(d8) AS d8_mean,
# AVG(d9) AS d9_mean,
# AVG(d10) AS d10_mean,
# AVG(d11) AS d11_mean,
# AVG(d12) AS d12_mean,
# AVG(d13) AS d13_mean,
# AVG(d14) AS d14_mean,
# AVG(d15) AS d15_mean,
# AVG(d16) AS d16_mean,
# AVG(d17) AS d17_mean,
# AVG(d18) AS d18_mean,
# AVG(d19) AS d19_mean,
# AVG(d20) AS d20_mean,
# AVG(d21) AS d21_mean,
# AVG(d22) AS d22_mean,
# AVG(d23) AS d23_mean,
# AVG(d24) AS d24_mean,
# AVG(d25) AS d25_mean,
# AVG(d26) AS d26_mean,
# AVG(d27) AS d27_mean,
# AVG(d28) AS d28_mean,
# AVG(d29) AS d29_mean,
# AVG(d30) AS d30_mean,
# AVG(d31) AS d31_mean,
# AVG(d32) AS d32_mean,
# AVG(d33) AS d33_mean,
# AVG(d34) AS d34_mean,
# AVG(d35) AS d35_mean,
# AVG(d36) AS d36_mean,
# AVG(d37) AS d37_mean,
# AVG(d38) AS d38_mean,
# AVG(d39) AS d39_mean,
# AVG(d40) AS d40_mean,
# AVG(d41) AS d41_mean,
# AVG(d42) AS d42_mean,
# AVG(d43) AS d43_mean,
# AVG(d44) AS d44_mean,
# AVG(d45) AS d45_mean,
# AVG(d46) AS d46_mean,
# AVG(d47) AS d47_mean,
# AVG(d48) AS d48_mean,
# AVG(d49) AS d49_mean,
# AVG(d50) AS d50_mean,
# AVG(d51) AS d51_mean,
# AVG(d52) AS d52_mean,
# AVG(d53) AS d53_mean,
# AVG(d54) AS d54_mean,
# AVG(d55) AS d55_mean,
# AVG(d56) AS d56_mean,
# AVG(d57) AS d57_mean,
# AVG(d58) AS d58_mean,
# AVG(d59) AS d59_mean,
# AVG(d60) AS d60_mean,
# AVG(d61) AS d61_mean,
# AVG(d62) AS d62_mean,
# AVG(d63) AS d63_mean,
# AVG(d64) AS d64_mean,
# AVG(d65) AS d65_mean,
# AVG(d66) AS d66_mean,
# AVG(d67) AS d67_mean,
# AVG(d68) AS d68_mean,
# AVG(d69) AS d69_mean,
# AVG(d70) AS d70_mean,
# AVG(d71) AS d71_mean,
# AVG(d72) AS d72_mean,
# AVG(d73) AS d73_mean,
# AVG(d74) AS d74_mean,
# AVG(d75) AS d75_mean,
# AVG(d76) AS d76_mean,
# AVG(d77) AS d77_mean,
# AVG(d78) AS d78_mean,
# AVG(d79) AS d79_mean,
# AVG(d80) AS d80_mean,
# AVG(d81) AS d81_mean,
# AVG(d82) AS d82_mean,
# AVG(d83) AS d83_mean,
# AVG(d84) AS d84_mean,
# AVG(d85) AS d85_mean,
# AVG(d86) AS d86_mean,
# AVG(d87) AS d87_mean,
# AVG(d88) AS d88_mean,
# AVG(d89) AS d89_mean,
# AVG(d90) AS d90_mean,
# AVG(d91) AS d91_mean,
# AVG(d92) AS d92_mean,
# AVG(d93) AS d93_mean,
# AVG(d94) AS d94_mean,
# AVG(d95) AS d95_mean,
# AVG(d96) AS d96_mean,
# AVG(d97) AS d97_mean,
# AVG(d98) AS d98_mean,
# AVG(d99) AS d99_mean,
# AVG(d100) AS d100_mean,
# AVG(d101) AS d101_mean,
# AVG(d102) AS d102_mean,
# AVG(d103) AS d103_mean,
# AVG(d104) AS d104_mean,
# AVG(d105) AS d105_mean,
# AVG(d106) AS d106_mean,
# AVG(d107) AS d107_mean,
# AVG(d108) AS d108_mean,
# AVG(d109) AS d109_mean,
# AVG(d110) AS d110_mean,
# AVG(d111) AS d111_mean,
# AVG(d112) AS d112_mean,
# AVG(d113) AS d113_mean,
# AVG(d114) AS d114_mean,
# AVG(d115) AS d115_mean,
# AVG(d116) AS d116_mean,
# AVG(d117) AS d117_mean,
# AVG(d118) AS d118_mean,
# AVG(d119) AS d119_mean,
# AVG(d120) AS d120_mean,
# AVG(d121) AS d121_mean,
# AVG(d122) AS d122_mean,
# AVG(d123) AS d123_mean,
# AVG(d124) AS d124_mean,
# AVG(d125) AS d125_mean,
# AVG(d126) AS d126_mean,
# AVG(d127) AS d127_mean,
# AVG(d128) AS d128_mean,
# AVG(d129) AS d129_mean,
# AVG(d130) AS d130_mean,
# AVG(d131) AS d131_mean,
# AVG(d132) AS d132_mean,
# AVG(d133) AS d133_mean,
# AVG(d134) AS d134_mean,
# AVG(d135) AS d135_mean,
# AVG(d136) AS d136_mean,
# AVG(d137) AS d137_mean,
# AVG(d138) AS d138_mean,
# AVG(d139) AS d139_mean,
# AVG(d140) AS d140_mean,
# AVG(d141) AS d141_mean,
# AVG(d142) AS d142_mean,
# AVG(d143) AS d143_mean,
# AVG(d144) AS d144_mean,
# AVG(d145) AS d145_mean,
# AVG(d146) AS d146_mean,
# AVG(d147) AS d147_mean,
# AVG(d148) AS d148_mean,
# AVG(d149) AS d149_mean,
# AVG(d150) AS d150_mean,
# AVG(d151) AS d151_mean,
# AVG(d152) AS d152_mean,
# AVG(d153) AS d153_mean,
# AVG(d154) AS d154_mean,
# AVG(d155) AS d155_mean,
# AVG(d156) AS d156_mean,
# AVG(d157) AS d157_mean,
# AVG(d158) AS d158_mean,
# AVG(d159) AS d159_mean,
# AVG(d160) AS d160_mean,
# AVG(d161) AS d161_mean,
# AVG(d162) AS d162_mean,
# AVG(d163) AS d163_mean,
# AVG(d164) AS d164_mean,
# AVG(d165) AS d165_mean,
# AVG(d166) AS d166_mean,
# AVG(d167) AS d167_mean,
# AVG(d168) AS d168_mean,
# AVG(d169) AS d169_mean,
# AVG(d170) AS d170_mean,
# AVG(d171) AS d171_mean,
# AVG(d172) AS d172_mean,
# AVG(d173) AS d173_mean,
# AVG(d174) AS d174_mean,
# AVG(d175) AS d175_mean,
# AVG(d176) AS d176_mean,
# AVG(d177) AS d177_mean,
# AVG(d178) AS d178_mean,
# AVG(d179) AS d179_mean,
# AVG(d180) AS d180_mean,
# AVG(d181) AS d181_mean,
# AVG(d182) AS d182_mean,
# AVG(d183) AS d183_mean,
# AVG(d184) AS d184_mean,
# AVG(d185) AS d185_mean,
# AVG(d186) AS d186_mean,
# AVG(d187) AS d187_mean,
# AVG(d188) AS d188_mean,
# AVG(d189) AS d189_mean,
# AVG(d190) AS d190_mean,
# AVG(d191) AS d191_mean,
# AVG(d192) AS d192_mean,
# AVG(d193) AS d193_mean,
# AVG(d194) AS d194_mean,
# AVG(d195) AS d195_mean,
# AVG(d196) AS d196_mean,
# AVG(d197) AS d197_mean,
# AVG(d198) AS d198_mean,
# AVG(d199) AS d199_mean,
# AVG(d200) AS d200_mean,
# AVG(d201) AS d201_mean,
# AVG(d202) AS d202_mean,
# AVG(d203) AS d203_mean,
# AVG(d204) AS d204_mean,
# AVG(d205) AS d205_mean,
# AVG(d206) AS d206_mean,
# AVG(d207) AS d207_mean,
# AVG(d208) AS d208_mean,
# AVG(d209) AS d209_mean,
# AVG(d210) AS d210_mean,
# AVG(d211) AS d211_mean,
# AVG(d212) AS d212_mean,
# AVG(d213) AS d213_mean,
# AVG(d214) AS d214_mean,
# AVG(d215) AS d215_mean,
# AVG(d216) AS d216_mean,
# AVG(d217) AS d217_mean,
# AVG(d218) AS d218_mean,
# AVG(d219) AS d219_mean,
# AVG(d220) AS d220_mean,
# AVG(d221) AS d221_mean,
# AVG(d222) AS d222_mean,
# AVG(d223) AS d223_mean,
# AVG(d224) AS d224_mean,
# AVG(d225) AS d225_mean,
# AVG(d226) AS d226_mean,
# AVG(d227) AS d227_mean,
# AVG(d228) AS d228_mean,
# AVG(d229) AS d229_mean,
# AVG(d230) AS d230_mean,
# AVG(d231) AS d231_mean,
# AVG(d232) AS d232_mean,
# AVG(d233) AS d233_mean,
# AVG(d234) AS d234_mean,
# AVG(d235) AS d235_mean,
# AVG(d236) AS d236_mean,
# AVG(d237) AS d237_mean,
# AVG(d238) AS d238_mean,
# AVG(d239) AS d239_mean,
# AVG(d240) AS d240_mean,
# AVG(d241) AS d241_mean,
# AVG(d242) AS d242_mean,
# AVG(d243) AS d243_mean,
# AVG(d244) AS d244_mean,
# AVG(d245) AS d245_mean,
# AVG(d246) AS d246_mean,
# AVG(d247) AS d247_mean,
# AVG(d248) AS d248_mean,
# AVG(d249) AS d249_mean,
# AVG(d250) AS d250_mean,
# AVG(d251) AS d251_mean,
# AVG(d252) AS d252_mean,
# AVG(d253) AS d253_mean,
# AVG(d254) AS d254_mean,
# AVG(d255) AS d255_mean,
# AVG(d256) AS d256_mean,
# AVG(d257) AS d257_mean,
# AVG(d258) AS d258_mean,
# AVG(d259) AS d259_mean,
# AVG(d260) AS d260_mean,
# AVG(d261) AS d261_mean,
# AVG(d262) AS d262_mean,
# AVG(d263) AS d263_mean,
# AVG(d264) AS d264_mean,
# AVG(d265) AS d265_mean,
# AVG(d266) AS d266_mean,
# AVG(d267) AS d267_mean,
# AVG(d268) AS d268_mean,
# AVG(d269) AS d269_mean,
# AVG(d270) AS d270_mean,
# AVG(d271) AS d271_mean,
# AVG(d272) AS d272_mean,
# AVG(d273) AS d273_mean,
# AVG(d274) AS d274_mean,
# AVG(d275) AS d275_mean,
# AVG(d276) AS d276_mean,
# AVG(d277) AS d277_mean,
# AVG(d278) AS d278_mean,
# AVG(d279) AS d279_mean,
# AVG(d280) AS d280_mean,
# AVG(d281) AS d281_mean,
# AVG(d282) AS d282_mean,
# AVG(d283) AS d283_mean,
# AVG(d284) AS d284_mean,
# AVG(d285) AS d285_mean,
# AVG(d286) AS d286_mean,
# AVG(d287) AS d287_mean,
# AVG(d288) AS d288_mean,
# AVG(d289) AS d289_mean,
# AVG(d290) AS d290_mean,
# AVG(d291) AS d291_mean,
# AVG(d292) AS d292_mean,
# AVG(d293) AS d293_mean,
# AVG(d294) AS d294_mean,
# AVG(d295) AS d295_mean,
# AVG(d296) AS d296_mean,
# AVG(d297) AS d297_mean,
# AVG(d298) AS d298_mean,
# AVG(d299) AS d299_mean,
# AVG(d300) AS d300_mean,
# AVG(d301) AS d301_mean,
# AVG(d302) AS d302_mean,
# AVG(d303) AS d303_mean,
# AVG(d304) AS d304_mean,
# AVG(d305) AS d305_mean,
# AVG(d306) AS d306_mean,
# AVG(d307) AS d307_mean,
# AVG(d308) AS d308_mean,
# AVG(d309) AS d309_mean,
# AVG(d310) AS d310_mean,
# AVG(d311) AS d311_mean,
# AVG(d312) AS d312_mean,
# AVG(d313) AS d313_mean,
# AVG(d314) AS d314_mean,
# AVG(d315) AS d315_mean,
# AVG(d316) AS d316_mean,
# AVG(d317) AS d317_mean,
# AVG(d318) AS d318_mean,
# AVG(d319) AS d319_mean,
# AVG(d320) AS d320_mean,
# AVG(d321) AS d321_mean,
# AVG(d322) AS d322_mean,
# AVG(d323) AS d323_mean,
# AVG(d324) AS d324_mean,
# AVG(d325) AS d325_mean,
# AVG(d326) AS d326_mean,
# AVG(d327) AS d327_mean,
# AVG(d328) AS d328_mean,
# AVG(d329) AS d329_mean,
# AVG(d330) AS d330_mean,
# AVG(d331) AS d331_mean,
# AVG(d332) AS d332_mean,
# AVG(d333) AS d333_mean,
# AVG(d334) AS d334_mean,
# AVG(d335) AS d335_mean,
# AVG(d336) AS d336_mean,
# AVG(d337) AS d337_mean,
# AVG(d338) AS d338_mean,
# AVG(d339) AS d339_mean,
# AVG(d340) AS d340_mean,
# AVG(d341) AS d341_mean,
# AVG(d342) AS d342_mean,
# AVG(d343) AS d343_mean,
# AVG(d344) AS d344_mean,
# AVG(d345) AS d345_mean,
# AVG(d346) AS d346_mean,
# AVG(d347) AS d347_mean,
# AVG(d348) AS d348_mean,
# AVG(d349) AS d349_mean,
# AVG(d350) AS d350_mean,
# AVG(d351) AS d351_mean,
# AVG(d352) AS d352_mean,
# AVG(d353) AS d353_mean,
# AVG(d354) AS d354_mean,
# AVG(d355) AS d355_mean,
# AVG(d356) AS d356_mean,
# AVG(d357) AS d357_mean,
# AVG(d358) AS d358_mean,
# AVG(d359) AS d359_mean,
# AVG(d360) AS d360_mean,
# AVG(d361) AS d361_mean,
# AVG(d362) AS d362_mean,
# AVG(d363) AS d363_mean,
# AVG(d364) AS d364_mean,
# AVG(d365) AS d365_mean,
# AVG(d366) AS d366_mean,
# AVG(d367) AS d367_mean,
# AVG(d368) AS d368_mean,
# AVG(d369) AS d369_mean,
# AVG(d370) AS d370_mean,
# AVG(d371) AS d371_mean,
# AVG(d372) AS d372_mean,
# AVG(d373) AS d373_mean,
# AVG(d374) AS d374_mean,
# AVG(d375) AS d375_mean,
# AVG(d376) AS d376_mean,
# AVG(d377) AS d377_mean,
# AVG(d378) AS d378_mean,
# AVG(d379) AS d379_mean,
# AVG(d380) AS d380_mean,
# AVG(d381) AS d381_mean,
# AVG(d382) AS d382_mean,
# AVG(d383) AS d383_mean,
# AVG(d384) AS d384_mean,
# AVG(d385) AS d385_mean,
# AVG(d386) AS d386_mean,
# AVG(d387) AS d387_mean,
# AVG(d388) AS d388_mean,
# AVG(d389) AS d389_mean,
# AVG(d390) AS d390_mean,
# AVG(d391) AS d391_mean,
# AVG(d392) AS d392_mean,
# AVG(d393) AS d393_mean,
# AVG(d394) AS d394_mean,
# AVG(d395) AS d395_mean,
# AVG(d396) AS d396_mean,
# AVG(d397) AS d397_mean,
# AVG(d398) AS d398_mean,
# AVG(d399) AS d399_mean,
# AVG(d400) AS d400_mean,
# AVG(d401) AS d401_mean,
# AVG(d402) AS d402_mean,
# AVG(d403) AS d403_mean,
# AVG(d404) AS d404_mean,
# AVG(d405) AS d405_mean,
# AVG(d406) AS d406_mean,
# AVG(d407) AS d407_mean,
# AVG(d408) AS d408_mean,
# AVG(d409) AS d409_mean,
# AVG(d410) AS d410_mean,
# AVG(d411) AS d411_mean,
# AVG(d412) AS d412_mean,
# AVG(d413) AS d413_mean,
# AVG(d414) AS d414_mean,
# AVG(d415) AS d415_mean,
# AVG(d416) AS d416_mean,
# AVG(d417) AS d417_mean,
# AVG(d418) AS d418_mean,
# AVG(d419) AS d419_mean,
# AVG(d420) AS d420_mean,
# AVG(d421) AS d421_mean,
# AVG(d422) AS d422_mean,
# AVG(d423) AS d423_mean,
# AVG(d424) AS d424_mean,
# AVG(d425) AS d425_mean,
# AVG(d426) AS d426_mean,
# AVG(d427) AS d427_mean,
# AVG(d428) AS d428_mean,
# AVG(d429) AS d429_mean,
# AVG(d430) AS d430_mean,
# AVG(d431) AS d431_mean,
# AVG(d432) AS d432_mean,
# AVG(d433) AS d433_mean,
# AVG(d434) AS d434_mean,
# AVG(d435) AS d435_mean,
# AVG(d436) AS d436_mean,
# AVG(d437) AS d437_mean,
# AVG(d438) AS d438_mean,
# AVG(d439) AS d439_mean,
# AVG(d440) AS d440_mean,
# AVG(d441) AS d441_mean,
# AVG(d442) AS d442_mean,
# AVG(d443) AS d443_mean,
# AVG(d444) AS d444_mean,
# AVG(d445) AS d445_mean,
# AVG(d446) AS d446_mean,
# AVG(d447) AS d447_mean,
# AVG(d448) AS d448_mean,
# AVG(d449) AS d449_mean,
# AVG(d450) AS d450_mean,
# AVG(d451) AS d451_mean,
# AVG(d452) AS d452_mean,
# AVG(d453) AS d453_mean,
# AVG(d454) AS d454_mean,
# AVG(d455) AS d455_mean,
# AVG(d456) AS d456_mean,
# AVG(d457) AS d457_mean,
# AVG(d458) AS d458_mean,
# AVG(d459) AS d459_mean,
# AVG(d460) AS d460_mean,
# AVG(d461) AS d461_mean,
# AVG(d462) AS d462_mean,
# AVG(d463) AS d463_mean,
# AVG(d464) AS d464_mean,
# AVG(d465) AS d465_mean,
# AVG(d466) AS d466_mean,
# AVG(d467) AS d467_mean,
# AVG(d468) AS d468_mean,
# AVG(d469) AS d469_mean,
# AVG(d470) AS d470_mean,
# AVG(d471) AS d471_mean,
# AVG(d472) AS d472_mean,
# AVG(d473) AS d473_mean,
# AVG(d474) AS d474_mean,
# AVG(d475) AS d475_mean,
# AVG(d476) AS d476_mean,
# AVG(d477) AS d477_mean,
# AVG(d478) AS d478_mean,
# AVG(d479) AS d479_mean,
# AVG(d480) AS d480_mean,
# AVG(d481) AS d481_mean,
# AVG(d482) AS d482_mean,
# AVG(d483) AS d483_mean,
# AVG(d484) AS d484_mean,
# AVG(d485) AS d485_mean,
# AVG(d486) AS d486_mean,
# AVG(d487) AS d487_mean,
# AVG(d488) AS d488_mean,
# AVG(d489) AS d489_mean,
# AVG(d490) AS d490_mean,
# AVG(d491) AS d491_mean,
# AVG(d492) AS d492_mean,
# AVG(d493) AS d493_mean,
# AVG(d494) AS d494_mean,
# AVG(d495) AS d495_mean,
# AVG(d496) AS d496_mean,
# AVG(d497) AS d497_mean,
# AVG(d498) AS d498_mean,
# AVG(d499) AS d499_mean,
# AVG(d500) AS d500_mean,
# AVG(d501) AS d501_mean,
# AVG(d502) AS d502_mean,
# AVG(d503) AS d503_mean,
# AVG(d504) AS d504_mean,
# AVG(d505) AS d505_mean,
# AVG(d506) AS d506_mean,
# AVG(d507) AS d507_mean,
# AVG(d508) AS d508_mean,
# AVG(d509) AS d509_mean,
# AVG(d510) AS d510_mean,
# AVG(d511) AS d511_mean,
#
# FROM (
# SELECT f.first_level.name AS f1,
#
# title_embed[OFFSET(0)] AS d0,
# title_embed[OFFSET(1)] AS d1,
# title_embed[OFFSET(441)] AS d441,
# title_embed[OFFSET(442)] AS d442,
# title_embed[OFFSET(443)] AS d443,
# title_embed[OFFSET(444)] AS d444,
# title_embed[OFFSET(445)] AS d445,
# title_embed[OFFSET(446)] AS d446,
# title_embed[OFFSET(447)] AS d447,
# title_embed[OFFSET(448)] AS d448,
# title_embed[OFFSET(449)] AS d449,
# title_embed[OFFSET(450)] AS d450,
# title_embed[OFFSET(451)] AS d451,
# title_embed[OFFSET(452)] AS d452,
# title_embed[OFFSET(453)] AS d453,
# title_embed[OFFSET(454)] AS d454,
# title_embed[OFFSET(455)] AS d455,
# title_embed[OFFSET(456)] AS d456,
# title_embed[OFFSET(457)] AS d457,
# title_embed[OFFSET(458)] AS d458,
# title_embed[OFFSET(459)] AS d459,
# title_embed[OFFSET(460)] AS d460,
# title_embed[OFFSET(461)] AS d461,
# title_embed[OFFSET(462)] AS d462,
# title_embed[OFFSET(463)] AS d463,
# title_embed[OFFSET(464)] AS d464,
# title_embed[OFFSET(465)] AS d465,
# title_embed[OFFSET(466)] AS d466,
# title_embed[OFFSET(467)] AS d467,
# title_embed[OFFSET(468)] AS d468,
# title_embed[OFFSET(469)] AS d469,
# title_embed[OFFSET(470)] AS d470,
# title_embed[OFFSET(471)] AS d471,
# title_embed[OFFSET(472)] AS d472,
# title_embed[OFFSET(473)] AS d473,
# title_embed[OFFSET(474)] AS d474,
# title_embed[OFFSET(475)] AS d475,
# title_embed[OFFSET(476)] AS d476,
# title_embed[OFFSET(477)] AS d477,
# title_embed[OFFSET(478)] AS d478,
# title_embed[OFFSET(479)] AS d479,
# title_embed[OFFSET(480)] AS d480,
# title_embed[OFFSET(481)] AS d481,
# title_embed[OFFSET(482)] AS d482,
# title_embed[OFFSET(483)] AS d483,
# title_embed[OFFSET(484)] AS d484,
# title_embed[OFFSET(485)] AS d485,
# title_embed[OFFSET(486)] AS d486,
# title_embed[OFFSET(487)] AS d487,
# title_embed[OFFSET(488)] AS d488,
# title_embed[OFFSET(489)] AS d489,
# title_embed[OFFSET(490)] AS d490,
# title_embed[OFFSET(491)] AS d491,
# title_embed[OFFSET(492)] AS d492,
# title_embed[OFFSET(493)] AS d493,
# title_embed[OFFSET(494)] AS d494,
# title_embed[OFFSET(495)] AS d495,
# title_embed[OFFSET(496)] AS d496,
# title_embed[OFFSET(497)] AS d497,
# title_embed[OFFSET(498)] AS d498,
# title_embed[OFFSET(499)] AS d499,
# title_embed[OFFSET(500)] AS d500,
# title_embed[OFFSET(501)] AS d501,
# title_embed[OFFSET(502)] AS d502,
# title_embed[OFFSET(503)] AS d503,
# title_embed[OFFSET(504)] AS d504,
# title_embed[OFFSET(505)] AS d505,
# title_embed[OFFSET(506)] AS d506,
# title_embed[OFFSET(507)] AS d507,
# title_embed[OFFSET(508)] AS d508,
# title_embed[OFFSET(509)] AS d509,
# title_embed[OFFSET(510)] AS d510,
# title_embed[OFFSET(511)] AS d511,
#
# FROM `springer-nature-analytics.DS_dimensions.publications_full_refresh`
# LEFT JOIN UNNEST(`for`) AS f LEFT JOIN UNNEST(journal) AS j
# WHERE ARRAY_LENGTH(title_embed) = 512
# AND
# publication_type LIKE "article"
#         AND j.title IN (SELECT title FROM `springer-nature-analytics.core_journals.core_2018_v01`)
#         AND year >= 1993
#         AND year <= 1995
#         AND language LIKE "en"
#         AND ARRAY_LENGTH(references) > 4
#
# ) GROUP BY f1
#  ) WHERE f1 IS NOT NULL

# %%
train_and_save(for_93_95, "wv_93_95")
# Out:
# Saved mean vectors to "/content/drive/My Drive/Research/Data/Mean-title-centroids-3yrs-v02/wv_93_95_f1.csv"

# %%
# %%bigquery --project $pid for_93_95
#
# SELECT * FROM (
# SELECT f1,
#
# AVG(d0) AS d0_mean,
# AVG(d1) AS d1_mean,
# AVG(d2) AS d2_mean,
# AVG(d3) AS d3_mean,
# AVG(d4) AS d4_mean,
# AVG(d5) AS d5_mean,
# AVG(d6) AS d6_mean,
# AVG(d7) AS d7_mean,
# AVG(d8) AS d8_mean,
# AVG(d9) AS d9_mean,
# AVG(d10) AS d10_mean,
# AVG(d11) AS d11_mean,
# AVG(d12) AS d12_mean,
# AVG(d13) AS d13_mean,
# AVG(d14) AS d14_mean,
# AVG(d15) AS d15_mean,
# AVG(d16) AS d16_mean,
# AVG(d17) AS d17_mean,
# AVG(d18) AS d18_mean,
# AVG(d19) AS d19_mean,
# AVG(d20) AS d20_mean,
# AVG(d21) AS d21_mean,
# AVG(d22) AS d22_mean,
# AVG(d23) AS d23_mean,
# AVG(d24) AS d24_mean,
# AVG(d25) AS d25_mean,
# AVG(d26) AS d26_mean,
# AVG(d27) AS d27_mean,
# AVG(d28) AS d28_mean,
# AVG(d29) AS d29_mean,
# AVG(d30) AS d30_mean,
# AVG(d31) AS d31_mean,
# AVG(d32) AS d32_mean,
# AVG(d33) AS d33_mean,
# AVG(d34) AS d34_mean,
# AVG(d35) AS d35_mean,
# AVG(d36) AS d36_mean,
# AVG(d37) AS d37_mean,
# AVG(d38) AS d38_mean,
# AVG(d39) AS d39_mean,
# AVG(d40) AS d40_mean,
# AVG(d41) AS d41_mean,
# AVG(d42) AS d42_mean,
# AVG(d43) AS d43_mean,
# AVG(d44) AS d44_mean,
# AVG(d45) AS d45_mean,
# AVG(d46) AS d46_mean,
# AVG(d47) AS d47_mean,
# AVG(d48) AS d48_mean,
# AVG(d49) AS d49_mean,
# AVG(d50) AS d50_mean,
# AVG(d51) AS d51_mean,
# AVG(d52) AS d52_mean,
# AVG(d53) AS d53_mean,
# AVG(d54) AS d54_mean,
# AVG(d55) AS d55_mean,
# AVG(d56) AS d56_mean,
# AVG(d57) AS d57_mean,
# AVG(d58) AS d58_mean,
# AVG(d59) AS d59_mean,
# AVG(d60) AS d60_mean,
# AVG(d61) AS d61_mean,
# AVG(d62) AS d62_mean,
# AVG(d63) AS d63_mean,
# AVG(d64) AS d64_mean,
# AVG(d65) AS d65_mean,
# AVG(d66) AS d66_mean,
# AVG(d67) AS d67_mean,
# AVG(d68) AS d68_mean,
# AVG(d69) AS d69_mean,
# AVG(d70) AS d70_mean,
# AVG(d71) AS d71_mean,
# AVG(d72) AS d72_mean,
# AVG(d73) AS d73_mean,
# AVG(d74) AS d74_mean,
# AVG(d75) AS d75_mean,
# AVG(d76) AS d76_mean,
# AVG(d77) AS d77_mean,
# AVG(d78) AS d78_mean,
# AVG(d79) AS d79_mean,
# AVG(d80) AS d80_mean,
# AVG(d81) AS d81_mean,
# AVG(d82) AS d82_mean,
# AVG(d83) AS d83_mean,
# AVG(d84) AS d84_mean,
# AVG(d85) AS d85_mean,
# AVG(d86) AS d86_mean,
# AVG(d87) AS d87_mean,
# AVG(d88) AS d88_mean,
# AVG(d89) AS d89_mean,
# AVG(d90) AS d90_mean,
# AVG(d91) AS d91_mean,
# AVG(d92) AS d92_mean,
# AVG(d93) AS d93_mean,
# AVG(d94) AS d94_mean,
# AVG(d95) AS d95_mean,
# AVG(d96) AS d96_mean,
# AVG(d97) AS d97_mean,
# AVG(d98) AS d98_mean,
# AVG(d99) AS d99_mean,
# AVG(d100) AS d100_mean,
# AVG(d101) AS d101_mean,
# AVG(d102) AS d102_mean,
# AVG(d103) AS d103_mean,
# AVG(d104) AS d104_mean,
# AVG(d105) AS d105_mean,
# AVG(d106) AS d106_mean,
# AVG(d107) AS d107_mean,
# AVG(d108) AS d108_mean,
# AVG(d109) AS d109_mean,
# AVG(d110) AS d110_mean,
# AVG(d111) AS d111_mean,
# AVG(d112) AS d112_mean,
# AVG(d113) AS d113_mean,
# AVG(d114) AS d114_mean,
# AVG(d115) AS d115_mean,
# AVG(d116) AS d116_mean,
# AVG(d117) AS d117_mean,
# AVG(d118) AS d118_mean,
# AVG(d119) AS d119_mean,
# AVG(d120) AS d120_mean,
# AVG(d121) AS d121_mean,
# AVG(d122) AS d122_mean,
# AVG(d123) AS d123_mean,
# AVG(d124) AS d124_mean,
# AVG(d125) AS d125_mean,
# AVG(d126) AS d126_mean,
# AVG(d127) AS d127_mean,
# AVG(d128) AS d128_mean,
# AVG(d129) AS d129_mean,
# AVG(d130) AS d130_mean,
# AVG(d131) AS d131_mean,
# AVG(d132) AS d132_mean,
# AVG(d133) AS d133_mean,
# AVG(d134) AS d134_mean,
# AVG(d135) AS d135_mean,
# AVG(d136) AS d136_mean,
# AVG(d137) AS d137_mean,
# AVG(d138) AS d138_mean,
# AVG(d139) AS d139_mean,
# AVG(d140) AS d140_mean,
# AVG(d141) AS d141_mean,
# AVG(d142) AS d142_mean,
# AVG(d143) AS d143_mean,
# AVG(d144) AS d144_mean,
# AVG(d145) AS d145_mean,
# AVG(d146) AS d146_mean,
# AVG(d147) AS d147_mean,
# AVG(d148) AS d148_mean,
# AVG(d149) AS d149_mean,
# AVG(d150) AS d150_mean,
# AVG(d151) AS d151_mean,
# AVG(d152) AS d152_mean,
# AVG(d153) AS d153_mean,
# AVG(d154) AS d154_mean,
# AVG(d155) AS d155_mean,
# AVG(d156) AS d156_mean,
# AVG(d157) AS d157_mean,
# AVG(d158) AS d158_mean,
# AVG(d159) AS d159_mean,
# AVG(d160) AS d160_mean,
# AVG(d161) AS d161_mean,
# AVG(d162) AS d162_mean,
# AVG(d163) AS d163_mean,
# AVG(d164) AS d164_mean,
# AVG(d165) AS d165_mean,
# AVG(d166) AS d166_mean,
# AVG(d167) AS d167_mean,
# AVG(d168) AS d168_mean,
# AVG(d169) AS d169_mean,
# AVG(d170) AS d170_mean,
# AVG(d171) AS d171_mean,
# AVG(d172) AS d172_mean,
# AVG(d173) AS d173_mean,
# AVG(d174) AS d174_mean,
# AVG(d175) AS d175_mean,
# AVG(d176) AS d176_mean,
# AVG(d177) AS d177_mean,
# AVG(d178) AS d178_mean,
# AVG(d179) AS d179_mean,
# AVG(d180) AS d180_mean,
# AVG(d181) AS d181_mean,
# AVG(d182) AS d182_mean,
# AVG(d183) AS d183_mean,
# AVG(d184) AS d184_mean,
# AVG(d185) AS d185_mean,
# AVG(d186) AS d186_mean,
# AVG(d187) AS d187_mean,
# AVG(d188) AS d188_mean,
# AVG(d189) AS d189_mean,
# AVG(d190) AS d190_mean,
# AVG(d191) AS d191_mean,
# AVG(d192) AS d192_mean,
# AVG(d193) AS d193_mean,
# AVG(d194) AS d194_mean,
# AVG(d195) AS d195_mean,
# AVG(d196) AS d196_mean,
# AVG(d197) AS d197_mean,
# AVG(d198) AS d198_mean,
# AVG(d199) AS d199_mean,
# AVG(d200) AS d200_mean,
# AVG(d201) AS d201_mean,
# AVG(d202) AS d202_mean,
# AVG(d203) AS d203_mean,
# AVG(d204) AS d204_mean,
# AVG(d205) AS d205_mean,
# AVG(d206) AS d206_mean,
# AVG(d207) AS d207_mean,
# AVG(d208) AS d208_mean,
# AVG(d209) AS d209_mean,
# AVG(d210) AS d210_mean,
# AVG(d211) AS d211_mean,
# AVG(d212) AS d212_mean,
# AVG(d213) AS d213_mean,
# AVG(d214) AS d214_mean,
# AVG(d215) AS d215_mean,
# AVG(d216) AS d216_mean,
# AVG(d217) AS d217_mean,
# AVG(d218) AS d218_mean,
# AVG(d219) AS d219_mean,
# AVG(d220) AS d220_mean,
# AVG(d221) AS d221_mean,
# AVG(d222) AS d222_mean,
# AVG(d223) AS d223_mean,
# AVG(d224) AS d224_mean,
# AVG(d225) AS d225_mean,
# AVG(d226) AS d226_mean,
# AVG(d227) AS d227_mean,
# AVG(d228) AS d228_mean,
# AVG(d229) AS d229_mean,
# AVG(d230) AS d230_mean,
# AVG(d231) AS d231_mean,
# AVG(d232) AS d232_mean,
# AVG(d233) AS d233_mean,
# AVG(d234) AS d234_mean,
# AVG(d235) AS d235_mean,
# AVG(d236) AS d236_mean,
# AVG(d237) AS d237_mean,
# AVG(d238) AS d238_mean,
# AVG(d239) AS d239_mean,
# AVG(d240) AS d240_mean,
# AVG(d241) AS d241_mean,
# AVG(d242) AS d242_mean,
# AVG(d243) AS d243_mean,
# AVG(d244) AS d244_mean,
# AVG(d245) AS d245_mean,
# AVG(d246) AS d246_mean,
# AVG(d247) AS d247_mean,
# AVG(d248) AS d248_mean,
# AVG(d249) AS d249_mean,
# AVG(d250) AS d250_mean,
# AVG(d251) AS d251_mean,
# AVG(d252) AS d252_mean,
# AVG(d253) AS d253_mean,
# AVG(d254) AS d254_mean,
# AVG(d255) AS d255_mean,
# AVG(d256) AS d256_mean,
# AVG(d257) AS d257_mean,
# AVG(d258) AS d258_mean,
# AVG(d259) AS d259_mean,
# AVG(d260) AS d260_mean,
# AVG(d261) AS d261_mean,
# AVG(d262) AS d262_mean,
# AVG(d263) AS d263_mean,
# AVG(d264) AS d264_mean,
# AVG(d265) AS d265_mean,
# AVG(d266) AS d266_mean,
# AVG(d267) AS d267_mean,
# AVG(d268) AS d268_mean,
# AVG(d269) AS d269_mean,
# AVG(d270) AS d270_mean,
# AVG(d271) AS d271_mean,
# AVG(d272) AS d272_mean,
# AVG(d273) AS d273_mean,
# AVG(d274) AS d274_mean,
# AVG(d275) AS d275_mean,
# AVG(d276) AS d276_mean,
# AVG(d277) AS d277_mean,
# AVG(d278) AS d278_mean,
# AVG(d279) AS d279_mean,
# AVG(d280) AS d280_mean,
# AVG(d281) AS d281_mean,
# AVG(d282) AS d282_mean,
# AVG(d283) AS d283_mean,
# AVG(d284) AS d284_mean,
# AVG(d285) AS d285_mean,
# AVG(d286) AS d286_mean,
# AVG(d287) AS d287_mean,
# AVG(d288) AS d288_mean,
# AVG(d289) AS d289_mean,
# AVG(d290) AS d290_mean,
# AVG(d291) AS d291_mean,
# AVG(d292) AS d292_mean,
# AVG(d293) AS d293_mean,
# AVG(d294) AS d294_mean,
# AVG(d295) AS d295_mean,
# AVG(d296) AS d296_mean,
# AVG(d297) AS d297_mean,
# AVG(d298) AS d298_mean,
# AVG(d299) AS d299_mean,
# AVG(d300) AS d300_mean,
# AVG(d301) AS d301_mean,
# AVG(d302) AS d302_mean,
# AVG(d303) AS d303_mean,
# AVG(d304) AS d304_mean,
# AVG(d305) AS d305_mean,
# AVG(d306) AS d306_mean,
# AVG(d307) AS d307_mean,
# AVG(d308) AS d308_mean,
# AVG(d309) AS d309_mean,
# AVG(d310) AS d310_mean,
# AVG(d311) AS d311_mean,
# AVG(d312) AS d312_mean,
# AVG(d313) AS d313_mean,
# AVG(d314) AS d314_mean,
# AVG(d315) AS d315_mean,
# AVG(d316) AS d316_mean,
# AVG(d317) AS d317_mean,
# AVG(d318) AS d318_mean,
# AVG(d319) AS d319_mean,
# AVG(d320) AS d320_mean,
# AVG(d321) AS d321_mean,
# AVG(d322) AS d322_mean,
# AVG(d323) AS d323_mean,
# AVG(d324) AS d324_mean,
# AVG(d325) AS d325_mean,
# AVG(d326) AS d326_mean,
# AVG(d327) AS d327_mean,
# AVG(d328) AS d328_mean,
# AVG(d329) AS d329_mean,
# AVG(d330) AS d330_mean,
# AVG(d331) AS d331_mean,
# AVG(d332) AS d332_mean,
# AVG(d333) AS d333_mean,
# AVG(d334) AS d334_mean,
# AVG(d335) AS d335_mean,
# AVG(d336) AS d336_mean,
# AVG(d337) AS d337_mean,
# AVG(d338) AS d338_mean,
# AVG(d339) AS d339_mean,
# AVG(d340) AS d340_mean,
# AVG(d341) AS d341_mean,
# AVG(d342) AS d342_mean,
# AVG(d343) AS d343_mean,
# AVG(d344) AS d344_mean,
# AVG(d345) AS d345_mean,
# AVG(d346) AS d346_mean,
# AVG(d347) AS d347_mean,
# AVG(d348) AS d348_mean,
# AVG(d349) AS d349_mean,
# AVG(d350) AS d350_mean,
# AVG(d351) AS d351_mean,
# AVG(d352) AS d352_mean,
# AVG(d353) AS d353_mean,
# AVG(d354) AS d354_mean,
# AVG(d355) AS d355_mean,
# AVG(d356) AS d356_mean,
# AVG(d357) AS d357_mean,
# AVG(d358) AS d358_mean,
# AVG(d359) AS d359_mean,
# AVG(d360) AS d360_mean,
# AVG(d361) AS d361_mean,
# AVG(d362) AS d362_mean,
# AVG(d363) AS d363_mean,
# AVG(d364) AS d364_mean,
# AVG(d365) AS d365_mean,
# AVG(d366) AS d366_mean,
# AVG(d367) AS d367_mean,
# AVG(d368) AS d368_mean,
# AVG(d369) AS d369_mean,
# AVG(d370) AS d370_mean,
# AVG(d371) AS d371_mean,
# AVG(d372) AS d372_mean,
# AVG(d373) AS d373_mean,
# AVG(d374) AS d374_mean,
# AVG(d375) AS d375_mean,
# AVG(d376) AS d376_mean,
# AVG(d377) AS d377_mean,
# AVG(d378) AS d378_mean,
# AVG(d379) AS d379_mean,
# AVG(d380) AS d380_mean,
# AVG(d381) AS d381_mean,
# AVG(d382) AS d382_mean,
# AVG(d383) AS d383_mean,
# AVG(d384) AS d384_mean,
# AVG(d385) AS d385_mean,
# AVG(d386) AS d386_mean,
# AVG(d387) AS d387_mean,
# AVG(d388) AS d388_mean,
# AVG(d389) AS d389_mean,
# AVG(d390) AS d390_mean,
# AVG(d391) AS d391_mean,
# AVG(d392) AS d392_mean,
# AVG(d393) AS d393_mean,
# AVG(d394) AS d394_mean,
# AVG(d395) AS d395_mean,
# AVG(d396) AS d396_mean,
# AVG(d397) AS d397_mean,
# AVG(d398) AS d398_mean,
# AVG(d399) AS d399_mean,
# AVG(d400) AS d400_mean,
# AVG(d401) AS d401_mean,
# AVG(d402) AS d402_mean,
# AVG(d403) AS d403_mean,
# AVG(d404) AS d404_mean,
# AVG(d405) AS d405_mean,
# AVG(d406) AS d406_mean,
# AVG(d407) AS d407_mean,
# AVG(d408) AS d408_mean,
# AVG(d409) AS d409_mean,
# AVG(d410) AS d410_mean,
# AVG(d411) AS d411_mean,
# AVG(d412) AS d412_mean,
# AVG(d413) AS d413_mean,
# AVG(d414) AS d414_mean,
# AVG(d415) AS d415_mean,
# AVG(d416) AS d416_mean,
# AVG(d417) AS d417_mean,
# AVG(d418) AS d418_mean,
# AVG(d419) AS d419_mean,
# AVG(d420) AS d420_mean,
# AVG(d421) AS d421_mean,
# AVG(d422) AS d422_mean,
# AVG(d423) AS d423_mean,
# AVG(d424) AS d424_mean,
# AVG(d425) AS d425_mean,
# AVG(d426) AS d426_mean,
# AVG(d427) AS d427_mean,
# AVG(d428) AS d428_mean,
# AVG(d429) AS d429_mean,
# AVG(d430) AS d430_mean,
# AVG(d431) AS d431_mean,
# AVG(d432) AS d432_mean,
# AVG(d433) AS d433_mean,
# AVG(d434) AS d434_mean,
# AVG(d435) AS d435_mean,
# AVG(d436) AS d436_mean,
# AVG(d437) AS d437_mean,
# AVG(d438) AS d438_mean,
# AVG(d439) AS d439_mean,
# AVG(d440) AS d440_mean,
# AVG(d441) AS d441_mean,
# AVG(d442) AS d442_mean,
# AVG(d443) AS d443_mean,
# AVG(d444) AS d444_mean,
# AVG(d445) AS d445_mean,
# AVG(d446) AS d446_mean,
# AVG(d447) AS d447_mean,
# AVG(d448) AS d448_mean,
# AVG(d449) AS d449_mean,
# AVG(d450) AS d450_mean,
# AVG(d451) AS d451_mean,
# AVG(d452) AS d452_mean,
# AVG(d453) AS d453_mean,
# AVG(d454) AS d454_mean,
# AVG(d455) AS d455_mean,
# AVG(d456) AS d456_mean,
# AVG(d457) AS d457_mean,
# AVG(d458) AS d458_mean,
# AVG(d459) AS d459_mean,
# AVG(d460) AS d460_mean,
# AVG(d461) AS d461_mean,
# AVG(d462) AS d462_mean,
# AVG(d463) AS d463_mean,
# AVG(d464) AS d464_mean,
# AVG(d465) AS d465_mean,
# AVG(d466) AS d466_mean,
# AVG(d467) AS d467_mean,
# AVG(d468) AS d468_mean,
# AVG(d469) AS d469_mean,
# AVG(d470) AS d470_mean,
# AVG(d471) AS d471_mean,
# AVG(d472) AS d472_mean,
# AVG(d473) AS d473_mean,
# AVG(d474) AS d474_mean,
# AVG(d475) AS d475_mean,
# AVG(d476) AS d476_mean,
# AVG(d477) AS d477_mean,
# AVG(d478) AS d478_mean,
# AVG(d479) AS d479_mean,
# AVG(d480) AS d480_mean,
# AVG(d481) AS d481_mean,
# AVG(d482) AS d482_mean,
# AVG(d483) AS d483_mean,
# AVG(d484) AS d484_mean,
# AVG(d485) AS d485_mean,
# AVG(d486) AS d486_mean,
# AVG(d487) AS d487_mean,
# AVG(d488) AS d488_mean,
# AVG(d489) AS d489_mean,
# AVG(d490) AS d490_mean,
# AVG(d491) AS d491_mean,
# AVG(d492) AS d492_mean,
# AVG(d493) AS d493_mean,
# AVG(d494) AS d494_mean,
# AVG(d495) AS d495_mean,
# AVG(d496) AS d496_mean,
# AVG(d497) AS d497_mean,
# AVG(d498) AS d498_mean,
# AVG(d499) AS d499_mean,
# AVG(d500) AS d500_mean,
# AVG(d501) AS d501_mean,
# AVG(d502) AS d502_mean,
# AVG(d503) AS d503_mean,
# AVG(d504) AS d504_mean,
# AVG(d505) AS d505_mean,
# AVG(d506) AS d506_mean,
# AVG(d507) AS d507_mean,
# AVG(d508) AS d508_mean,
# AVG(d509) AS d509_mean,
# AVG(d510) AS d510_mean,
# AVG(d511) AS d511_mean,
#
# FROM (
# SELECT f.second_level.name AS f1,
#
# title_embed[OFFSET(0)] AS d0,
# title_embed[OFFSET(1)] AS d1,
# title_embed[OFFSET(2)] AS d2,
# title_embed[OFFSET(3)] AS d3,
# title_embed[OFFSET(4)] AS d4,
# title_embed[OFFSET(5)] AS d5,
# title_embed[OFFSET(6)] AS d6,
# title_embed[OFFSET(446)] AS d446,
# title_embed[OFFSET(447)] AS d447,
# title_embed[OFFSET(448)] AS d448,
# title_embed[OFFSET(449)] AS d449,
# title_embed[OFFSET(450)] AS d450,
# title_embed[OFFSET(451)] AS d451,
# title_embed[OFFSET(452)] AS d452,
# title_embed[OFFSET(453)] AS d453,
# title_embed[OFFSET(454)] AS d454,
# title_embed[OFFSET(455)] AS d455,
# title_embed[OFFSET(456)] AS d456,
# title_embed[OFFSET(457)] AS d457,
# title_embed[OFFSET(458)] AS d458,
# title_embed[OFFSET(459)] AS d459,
# title_embed[OFFSET(460)] AS d460,
# title_embed[OFFSET(461)] AS d461,
# title_embed[OFFSET(462)] AS d462,
# title_embed[OFFSET(463)] AS d463,
# title_embed[OFFSET(464)] AS d464,
# title_embed[OFFSET(465)] AS d465,
# title_embed[OFFSET(466)] AS d466,
# title_embed[OFFSET(467)] AS d467,
# title_embed[OFFSET(468)] AS d468,
# title_embed[OFFSET(469)] AS d469,
# title_embed[OFFSET(470)] AS d470,
# title_embed[OFFSET(471)] AS d471,
# title_embed[OFFSET(472)] AS d472,
# title_embed[OFFSET(473)] AS d473,
# title_embed[OFFSET(474)] AS d474,
# title_embed[OFFSET(475)] AS d475,
# title_embed[OFFSET(476)] AS d476,
# title_embed[OFFSET(477)] AS d477,
# title_embed[OFFSET(478)] AS d478,
# title_embed[OFFSET(479)] AS d479,
# title_embed[OFFSET(480)] AS d480,
# title_embed[OFFSET(481)] AS d481,
# title_embed[OFFSET(482)] AS d482,
# title_embed[OFFSET(483)] AS d483,
# title_embed[OFFSET(484)] AS d484,
# title_embed[OFFSET(485)] AS d485,
# title_embed[OFFSET(486)] AS d486,
# title_embed[OFFSET(487)] AS d487,
# title_embed[OFFSET(488)] AS d488,
# title_embed[OFFSET(489)] AS d489,
# title_embed[OFFSET(490)] AS d490,
# title_embed[OFFSET(491)] AS d491,
# title_embed[OFFSET(492)] AS d492,
# title_embed[OFFSET(493)] AS d493,
# title_embed[OFFSET(494)] AS d494,
# title_embed[OFFSET(495)] AS d495,
# title_embed[OFFSET(496)] AS d496,
# title_embed[OFFSET(497)] AS d497,
# title_embed[OFFSET(498)] AS d498,
# title_embed[OFFSET(499)] AS d499,
# title_embed[OFFSET(500)] AS d500,
# title_embed[OFFSET(501)] AS d501,
# title_embed[OFFSET(502)] AS d502,
# title_embed[OFFSET(503)] AS d503,
# title_embed[OFFSET(504)] AS d504,
# title_embed[OFFSET(505)] AS d505,
# title_embed[OFFSET(506)] AS d506,
# title_embed[OFFSET(507)] AS d507,
# title_embed[OFFSET(508)] AS d508,
# title_embed[OFFSET(509)] AS d509,
# title_embed[OFFSET(510)] AS d510,
# title_embed[OFFSET(511)] AS d511,
#
# FROM `springer-nature-analytics.DS_dimensions.publications_full_refresh`
# LEFT JOIN UNNEST(`for`) AS f LEFT JOIN UNNEST(journal) AS j
# WHERE ARRAY_LENGTH(title_embed) = 512
# AND
# publication_type LIKE "article"
#         AND j.title IN (SELECT title FROM `springer-nature-analytics.core_journals.core_2018_v01`)
#         AND year >= 1993
#         AND year <= 1995
#         AND language LIKE "en"
#         AND ARRAY_LENGTH(references) > 4
#
# ) GROUP BY f1
#  ) WHERE f1 IS NOT NULL

# %%
train_and_save(for_93_95, "wv_93_95", "f2")
# Out:
# Saved mean vectors to "/content/drive/My Drive/Research/Data/Mean-title-centroids-3yrs-v02/wv_93_95_f2.csv"

# %% [markdown]
# # 1990-1992

# %%
# %%bigquery --project $pid for_90_92
#
# SELECT * FROM (
# SELECT f1,
#
# AVG(d0) AS d0_mean,
# AVG(d1) AS d1_mean,
# AVG(d2) AS d2_mean,
# AVG(d3) AS d3_mean,
# AVG(d4) AS d4_mean,
# AVG(d5) AS d5_mean,
# AVG(d6) AS d6_mean,
# AVG(d7) AS d7_mean,
# AVG(d8) AS d8_mean,
# AVG(d9) AS d9_mean,
# AVG(d10) AS d10_mean,
# AVG(d11) AS d11_mean,
# AVG(d12) AS d12_mean,
# AVG(d13) AS d13_mean,
# AVG(d14) AS d14_mean,
# AVG(d15) AS d15_mean,
# AVG(d16) AS d16_mean,
# AVG(d17) AS d17_mean,
# AVG(d18) AS d18_mean,
# AVG(d19) AS d19_mean,
# AVG(d20) AS d20_mean,
# AVG(d21) AS d21_mean,
# AVG(d22) AS d22_mean,
# AVG(d23) AS d23_mean,
# AVG(d24) AS d24_mean,
# AVG(d25) AS d25_mean,
# AVG(d26) AS d26_mean,
# AVG(d27) AS d27_mean,
# AVG(d28) AS d28_mean,
# AVG(d29) AS d29_mean,
# AVG(d30) AS d30_mean,
# AVG(d31) AS d31_mean,
# AVG(d32) AS d32_mean,
# AVG(d33) AS d33_mean,
# AVG(d34) AS d34_mean,
# AVG(d35) AS d35_mean,
# AVG(d36) AS d36_mean,
# AVG(d37) AS d37_mean,
# AVG(d38) AS d38_mean,
# AVG(d39) AS d39_mean,
# AVG(d40) AS d40_mean,
# AVG(d41) AS d41_mean,
# AVG(d42) AS d42_mean,
# AVG(d43) AS d43_mean,
# AVG(d44) AS d44_mean,
# AVG(d45) AS d45_mean,
# AVG(d46) AS d46_mean,
# AVG(d47) AS d47_mean,
# AVG(d48) AS d48_mean,
# AVG(d49) AS d49_mean,
# AVG(d50) AS d50_mean,
# AVG(d51) AS d51_mean,
# AVG(d52) AS d52_mean,
# AVG(d53) AS d53_mean,
# AVG(d54) AS d54_mean,
# AVG(d55) AS d55_mean,
# AVG(d56) AS d56_mean,
# AVG(d57) AS d57_mean,
# AVG(d58) AS d58_mean,
# AVG(d59) AS d59_mean,
# AVG(d60) AS d60_mean,
# AVG(d61) AS d61_mean,
# AVG(d62) AS d62_mean,
# AVG(d63) AS d63_mean,
# AVG(d64) AS d64_mean,
# AVG(d65) AS d65_mean,
# AVG(d66) AS d66_mean,
# AVG(d67) AS d67_mean,
# AVG(d68) AS d68_mean,
# AVG(d69) AS d69_mean,
# AVG(d70) AS d70_mean,
# AVG(d71) AS d71_mean,
# AVG(d72) AS d72_mean,
# AVG(d73) AS d73_mean,
# AVG(d74) AS d74_mean,
# AVG(d75) AS d75_mean,
# AVG(d76) AS d76_mean,
# AVG(d77) AS d77_mean,
# AVG(d78) AS d78_mean,
# AVG(d79) AS d79_mean,
# AVG(d80) AS d80_mean,
# AVG(d81) AS d81_mean,
# AVG(d82) AS d82_mean,
# AVG(d83) AS d83_mean,
# AVG(d84) AS d84_mean,
# AVG(d85) AS d85_mean,
# AVG(d86) AS d86_mean,
# AVG(d87) AS d87_mean,
# AVG(d88) AS d88_mean,
# AVG(d89) AS d89_mean,
# AVG(d90) AS d90_mean,
# AVG(d91) AS d91_mean,
# AVG(d92) AS d92_mean,
# AVG(d93) AS d93_mean,
# AVG(d94) AS d94_mean,
# AVG(d95) AS d95_mean,
# AVG(d96) AS d96_mean,
# AVG(d97) AS d97_mean,
# AVG(d98) AS d98_mean,
# AVG(d99) AS d99_mean,
# AVG(d100) AS d100_mean,
# AVG(d101) AS d101_mean,
# AVG(d102) AS d102_mean,
# AVG(d103) AS d103_mean,
# AVG(d104) AS d104_mean,
# AVG(d105) AS d105_mean,
# AVG(d106) AS d106_mean,
# AVG(d107) AS d107_mean,
# AVG(d108) AS d108_mean,
# AVG(d109) AS d109_mean,
# AVG(d110) AS d110_mean,
# AVG(d111) AS d111_mean,
# AVG(d112) AS d112_mean,
# AVG(d113) AS d113_mean,
# AVG(d114) AS d114_mean,
# AVG(d115) AS d115_mean,
# AVG(d116) AS d116_mean,
# AVG(d117) AS d117_mean,
# AVG(d118) AS d118_mean,
# AVG(d119) AS d119_mean,
# AVG(d120) AS d120_mean,
# AVG(d121) AS d121_mean,
# AVG(d122) AS d122_mean,
# AVG(d123) AS d123_mean,
# AVG(d124) AS d124_mean,
# AVG(d125) AS d125_mean,
# AVG(d126) AS d126_mean,
# AVG(d127) AS d127_mean,
# AVG(d128) AS d128_mean,
# AVG(d129) AS d129_mean,
# AVG(d130) AS d130_mean,
# AVG(d131) AS d131_mean,
# AVG(d132) AS d132_mean,
# AVG(d133) AS d133_mean,
# AVG(d134) AS d134_mean,
# AVG(d135) AS d135_mean,
# AVG(d136) AS d136_mean,
# AVG(d137) AS d137_mean,
# AVG(d138) AS d138_mean,
# AVG(d139) AS d139_mean,
# AVG(d140) AS d140_mean,
# AVG(d141) AS d141_mean,
# AVG(d142) AS d142_mean,
# AVG(d143) AS d143_mean,
# AVG(d144) AS d144_mean,
# AVG(d145) AS d145_mean,
# AVG(d146) AS d146_mean,
# AVG(d147) AS d147_mean,
# AVG(d148) AS d148_mean,
# AVG(d149) AS d149_mean,
# AVG(d150) AS d150_mean,
# AVG(d151) AS d151_mean,
# AVG(d152) AS d152_mean,
# AVG(d153) AS d153_mean,
# AVG(d154) AS d154_mean,
# AVG(d155) AS d155_mean,
# AVG(d156) AS d156_mean,
# AVG(d157) AS d157_mean,
# AVG(d158) AS d158_mean,
# AVG(d159) AS d159_mean,
# AVG(d160) AS d160_mean,
# AVG(d161) AS d161_mean,
# AVG(d162) AS d162_mean,
# AVG(d163) AS d163_mean,
# AVG(d164) AS d164_mean,
# AVG(d165) AS d165_mean,
# AVG(d166) AS d166_mean,
# AVG(d167) AS d167_mean,
# AVG(d168) AS d168_mean,
# AVG(d169) AS d169_mean,
# AVG(d170) AS d170_mean,
# AVG(d171) AS d171_mean,
# AVG(d172) AS d172_mean,
# AVG(d173) AS d173_mean,
# AVG(d174) AS d174_mean,
# AVG(d175) AS d175_mean,
# AVG(d176) AS d176_mean,
# AVG(d177) AS d177_mean,
# AVG(d178) AS d178_mean,
# AVG(d179) AS d179_mean,
# AVG(d180) AS d180_mean,
# AVG(d181) AS d181_mean,
# AVG(d182) AS d182_mean,
# AVG(d183) AS d183_mean,
# AVG(d184) AS d184_mean,
# AVG(d185) AS d185_mean,
# AVG(d186) AS d186_mean,
# AVG(d187) AS d187_mean,
# AVG(d188) AS d188_mean,
# AVG(d189) AS d189_mean,
# AVG(d190) AS d190_mean,
# AVG(d191) AS d191_mean,
# AVG(d192) AS d192_mean,
# AVG(d193) AS d193_mean,
# AVG(d194) AS d194_mean,
# AVG(d195) AS d195_mean,
# AVG(d196) AS d196_mean,
# AVG(d197) AS d197_mean,
# AVG(d198) AS d198_mean,
# AVG(d199) AS d199_mean,
# AVG(d200) AS d200_mean,
# AVG(d201) AS d201_mean,
# AVG(d202) AS d202_mean,
# AVG(d203) AS d203_mean,
# AVG(d204) AS d204_mean,
# AVG(d205) AS d205_mean,
# AVG(d206) AS d206_mean,
# AVG(d207) AS d207_mean,
# AVG(d208) AS d208_mean,
# AVG(d209) AS d209_mean,
# AVG(d210) AS d210_mean,
# AVG(d211) AS d211_mean,
# AVG(d212) AS d212_mean,
# AVG(d213) AS d213_mean,
# AVG(d214) AS d214_mean,
# AVG(d215) AS d215_mean,
# AVG(d216) AS d216_mean,
# AVG(d217) AS d217_mean,
# AVG(d218) AS d218_mean,
# AVG(d219) AS d219_mean,
# AVG(d220) AS d220_mean,
# AVG(d221) AS d221_mean,
# AVG(d222) AS d222_mean,
# AVG(d223) AS d223_mean,
# AVG(d224) AS d224_mean,
# AVG(d225) AS d225_mean,
# AVG(d226) AS d226_mean,
# AVG(d227) AS d227_mean,
# AVG(d228) AS d228_mean,
# AVG(d229) AS d229_mean,
# AVG(d230) AS d230_mean,
# AVG(d231) AS d231_mean,
# AVG(d232) AS d232_mean,
# AVG(d233) AS d233_mean,
# AVG(d234) AS d234_mean,
# AVG(d235) AS d235_mean,
# AVG(d236) AS d236_mean,
# AVG(d237) AS d237_mean,
# AVG(d238) AS d238_mean,
# AVG(d239) AS d239_mean,
# AVG(d240) AS d240_mean,
# AVG(d241) AS d241_mean,
# AVG(d242) AS d242_mean,
# AVG(d243) AS d243_mean,
# AVG(d244) AS d244_mean,
# AVG(d245) AS d245_mean,
# AVG(d246) AS d246_mean,
# AVG(d247) AS d247_mean,
# AVG(d248) AS d248_mean,
# AVG(d249) AS d249_mean,
# AVG(d250) AS d250_mean,
# AVG(d251) AS d251_mean,
# AVG(d252) AS d252_mean,
# AVG(d253) AS d253_mean,
# AVG(d254) AS d254_mean,
# AVG(d255) AS d255_mean,
# AVG(d256) AS d256_mean,
# AVG(d257) AS d257_mean,
# AVG(d258) AS d258_mean,
# AVG(d259) AS d259_mean,
# AVG(d260) AS d260_mean,
# AVG(d261) AS d261_mean,
# AVG(d262) AS d262_mean,
# AVG(d263) AS d263_mean,
# AVG(d264) AS d264_mean,
# AVG(d265) AS d265_mean,
# AVG(d266) AS d266_mean,
# AVG(d267) AS d267_mean,
# AVG(d268) AS d268_mean,
# AVG(d269) AS d269_mean,
# AVG(d270) AS d270_mean,
# AVG(d271) AS d271_mean,
# AVG(d272) AS d272_mean,
# AVG(d273) AS d273_mean,
# AVG(d274) AS d274_mean,
# AVG(d275) AS d275_mean,
# AVG(d276) AS d276_mean,
# AVG(d277) AS d277_mean,
# AVG(d278) AS d278_mean,
# AVG(d279) AS d279_mean,
# AVG(d280) AS d280_mean,
# AVG(d281) AS d281_mean,
# AVG(d282) AS d282_mean,
# AVG(d283) AS d283_mean,
# AVG(d284) AS d284_mean,
# AVG(d285) AS d285_mean,
# AVG(d286) AS d286_mean,
# AVG(d287) AS d287_mean,
# AVG(d288) AS d288_mean,
# AVG(d289) AS d289_mean,
# AVG(d290) AS d290_mean,
# AVG(d291) AS d291_mean,
# AVG(d292) AS d292_mean,
# AVG(d293) AS d293_mean,
# AVG(d294) AS d294_mean,
# AVG(d295) AS d295_mean,
# AVG(d296) AS d296_mean,
# AVG(d297) AS d297_mean,
# AVG(d298) AS d298_mean,
# AVG(d299) AS d299_mean,
# AVG(d300) AS d300_mean,
# AVG(d301) AS d301_mean,
# AVG(d302) AS d302_mean,
# AVG(d303) AS d303_mean,
# AVG(d304) AS d304_mean,
# AVG(d305) AS d305_mean,
# AVG(d306) AS d306_mean,
# AVG(d307) AS d307_mean,
# AVG(d308) AS d308_mean,
# AVG(d309) AS d309_mean,
# AVG(d310) AS d310_mean,
# AVG(d311) AS d311_mean,
# AVG(d312) AS d312_mean,
# AVG(d313) AS d313_mean,
# AVG(d314) AS d314_mean,
# AVG(d315) AS d315_mean,
# AVG(d316) AS d316_mean,
# AVG(d317) AS d317_mean,
# AVG(d318) AS d318_mean,
# AVG(d319) AS d319_mean,
# AVG(d320) AS d320_mean,
# AVG(d321) AS d321_mean,
# AVG(d322) AS d322_mean,
# AVG(d323) AS d323_mean,
# AVG(d324) AS d324_mean,
# AVG(d325) AS d325_mean,
# AVG(d326) AS d326_mean,
# AVG(d327) AS d327_mean,
# AVG(d328) AS d328_mean,
# AVG(d329) AS d329_mean,
# AVG(d330) AS d330_mean,
# AVG(d331) AS d331_mean,
# AVG(d332) AS d332_mean,
# AVG(d333) AS d333_mean,
# AVG(d334) AS d334_mean,
# AVG(d335) AS d335_mean,
# AVG(d336) AS d336_mean,
# AVG(d337) AS d337_mean,
# AVG(d338) AS d338_mean,
# AVG(d339) AS d339_mean,
# AVG(d340) AS d340_mean,
# AVG(d341) AS d341_mean,
# AVG(d342) AS d342_mean,
# AVG(d343) AS d343_mean,
# AVG(d344) AS d344_mean,
# AVG(d345) AS d345_mean,
# AVG(d346) AS d346_mean,
# AVG(d347) AS d347_mean,
# AVG(d348) AS d348_mean,
# AVG(d349) AS d349_mean,
# AVG(d350) AS d350_mean,
# AVG(d351) AS d351_mean,
# AVG(d352) AS d352_mean,
# AVG(d353) AS d353_mean,
# AVG(d354) AS d354_mean,
# AVG(d355) AS d355_mean,
# AVG(d356) AS d356_mean,
# AVG(d357) AS d357_mean,
# AVG(d358) AS d358_mean,
# AVG(d359) AS d359_mean,
# AVG(d360) AS d360_mean,
# AVG(d361) AS d361_mean,
# AVG(d362) AS d362_mean,
# AVG(d363) AS d363_mean,
# AVG(d364) AS d364_mean,
# AVG(d365) AS d365_mean,
# AVG(d366) AS d366_mean,
# AVG(d367) AS d367_mean,
# AVG(d368) AS d368_mean,
# AVG(d369) AS d369_mean,
# AVG(d370) AS d370_mean,
# AVG(d371) AS d371_mean,
# AVG(d372) AS d372_mean,
# AVG(d373) AS d373_mean,
# AVG(d374) AS d374_mean,
# AVG(d375) AS d375_mean,
# AVG(d376) AS d376_mean,
# AVG(d377) AS d377_mean,
# AVG(d378) AS d378_mean,
# AVG(d379) AS d379_mean,
# AVG(d380) AS d380_mean,
# AVG(d381) AS d381_mean,
# AVG(d382) AS d382_mean,
# AVG(d383) AS d383_mean,
# AVG(d384) AS d384_mean,
# AVG(d385) AS d385_mean,
# AVG(d386) AS d386_mean,
# AVG(d387) AS d387_mean,
# AVG(d388) AS d388_mean,
# AVG(d389) AS d389_mean,
# AVG(d390) AS d390_mean,
# AVG(d391) AS d391_mean,
# AVG(d392) AS d392_mean,
# AVG(d393) AS d393_mean,
# AVG(d394) AS d394_mean,
# AVG(d395) AS d395_mean,
# AVG(d396) AS d396_mean,
# AVG(d397) AS d397_mean,
# AVG(d398) AS d398_mean,
# AVG(d399) AS d399_mean,
# AVG(d400) AS d400_mean,
# AVG(d401) AS d401_mean,
# AVG(d402) AS d402_mean,
# AVG(d403) AS d403_mean,
# AVG(d404) AS d404_mean,
# AVG(d405) AS d405_mean,
# AVG(d406) AS d406_mean,
# AVG(d407) AS d407_mean,
# AVG(d408) AS d408_mean,
# AVG(d409) AS d409_mean,
# AVG(d410) AS d410_mean,
# AVG(d411) AS d411_mean,
# AVG(d412) AS d412_mean,
# AVG(d413) AS d413_mean,
# AVG(d414) AS d414_mean,
# AVG(d415) AS d415_mean,
# AVG(d416) AS d416_mean,
# AVG(d417) AS d417_mean,
# AVG(d418) AS d418_mean,
# AVG(d419) AS d419_mean,
# AVG(d420) AS d420_mean,
# AVG(d421) AS d421_mean,
# AVG(d422) AS d422_mean,
# AVG(d423) AS d423_mean,
# AVG(d424) AS d424_mean,
# AVG(d425) AS d425_mean,
# AVG(d426) AS d426_mean,
# AVG(d427) AS d427_mean,
# AVG(d428) AS d428_mean,
# AVG(d429) AS d429_mean,
# AVG(d430) AS d430_mean,
# AVG(d431) AS d431_mean,
# AVG(d432) AS d432_mean,
# AVG(d433) AS d433_mean,
# AVG(d434) AS d434_mean,
# AVG(d435) AS d435_mean,
# AVG(d436) AS d436_mean,
# AVG(d437) AS d437_mean,
# AVG(d438) AS d438_mean,
# AVG(d439) AS d439_mean,
# AVG(d440) AS d440_mean,
# AVG(d441) AS d441_mean,
# AVG(d442) AS d442_mean,
# AVG(d443) AS d443_mean,
# AVG(d444) AS d444_mean,
# AVG(d445) AS d445_mean,
# AVG(d446) AS d446_mean,
# AVG(d447) AS d447_mean,
# AVG(d448) AS d448_mean,
# AVG(d449) AS d449_mean,
# AVG(d450) AS d450_mean,
# AVG(d451) AS d451_mean,
# AVG(d452) AS d452_mean,
# AVG(d453) AS d453_mean,
# AVG(d454) AS d454_mean,
# AVG(d455) AS d455_mean,
# AVG(d456) AS d456_mean,
# AVG(d457) AS d457_mean,
# AVG(d458) AS d458_mean,
# AVG(d459) AS d459_mean,
# AVG(d460) AS d460_mean,
# AVG(d461) AS d461_mean,
# AVG(d462) AS d462_mean,
# AVG(d463) AS d463_mean,
# AVG(d464) AS d464_mean,
# AVG(d465) AS d465_mean,
# AVG(d466) AS d466_mean,
# AVG(d467) AS d467_mean,
# AVG(d468) AS d468_mean,
# AVG(d469) AS d469_mean,
# AVG(d470) AS d470_mean,
# AVG(d471) AS d471_mean,
# AVG(d472) AS d472_mean,
# AVG(d473) AS d473_mean,
# AVG(d474) AS d474_mean,
# AVG(d475) AS d475_mean,
# AVG(d476) AS d476_mean,
# AVG(d477) AS d477_mean,
# AVG(d478) AS d478_mean,
# AVG(d479) AS d479_mean,
# AVG(d480) AS d480_mean,
# AVG(d481) AS d481_mean,
# AVG(d482) AS d482_mean,
# AVG(d483) AS d483_mean,
# AVG(d484) AS d484_mean,
# AVG(d485) AS d485_mean,
# AVG(d486) AS d486_mean,
# AVG(d487) AS d487_mean,
# AVG(d488) AS d488_mean,
# AVG(d489) AS d489_mean,
# AVG(d490) AS d490_mean,
# AVG(d491) AS d491_mean,
# AVG(d492) AS d492_mean,
# AVG(d493) AS d493_mean,
# AVG(d494) AS d494_mean,
# AVG(d495) AS d495_mean,
# AVG(d496) AS d496_mean,
# AVG(d497) AS d497_mean,
# AVG(d498) AS d498_mean,
# AVG(d499) AS d499_mean,
# AVG(d500) AS d500_mean,
# AVG(d501) AS d501_mean,
# AVG(d502) AS d502_mean,
# AVG(d503) AS d503_mean,
# AVG(d504) AS d504_mean,
# AVG(d505) AS d505_mean,
# AVG(d506) AS d506_mean,
# AVG(d507) AS d507_mean,
# AVG(d508) AS d508_mean,
# AVG(d509) AS d509_mean,
# AVG(d510) AS d510_mean,
# AVG(d511) AS d511_mean,
#
# FROM (
# SELECT f.first_level.name AS f1,
#
# title_embed[OFFSET(0)] AS d0,
# title_embed[OFFSET(1)] AS d1,
# title_embed[OFFSET(2)] AS d2,
# title_embed[OFFSET(3)] AS d3,
# title_embed[OFFSET(4)] AS d4,
# title_embed[OFFSET(5)] AS d5,
# title_embed[OFFSET(6)] AS d6,
# title_embed[OFFSET(7)] AS d7,
# title_embed[OFFSET(8)] AS d8,
# title_embed[OFFSET(9)] AS d9,
# title_embed[OFFSET(10)] AS d10,
# title_embed[OFFSET(450)] AS d450,
# title_embed[OFFSET(451)] AS d451,
# title_embed[OFFSET(452)] AS d452,
# title_embed[OFFSET(453)] AS d453,
# title_embed[OFFSET(454)] AS d454,
# title_embed[OFFSET(455)] AS d455,
# title_embed[OFFSET(456)] AS d456,
# title_embed[OFFSET(457)] AS d457,
# title_embed[OFFSET(458)] AS d458,
# title_embed[OFFSET(459)] AS d459,
# title_embed[OFFSET(460)] AS d460,
# title_embed[OFFSET(461)] AS d461,
# title_embed[OFFSET(462)] AS d462,
# title_embed[OFFSET(463)] AS d463,
# title_embed[OFFSET(464)] AS d464,
# title_embed[OFFSET(465)] AS d465,
# title_embed[OFFSET(466)] AS d466,
# title_embed[OFFSET(467)] AS d467,
# title_embed[OFFSET(468)] AS d468,
# title_embed[OFFSET(469)] AS d469,
# title_embed[OFFSET(470)] AS d470,
# title_embed[OFFSET(471)] AS d471,
# title_embed[OFFSET(472)] AS d472,
# title_embed[OFFSET(473)] AS d473,
# title_embed[OFFSET(474)] AS d474,
# title_embed[OFFSET(475)] AS d475,
# title_embed[OFFSET(476)] AS d476,
# title_embed[OFFSET(477)] AS d477,
# title_embed[OFFSET(478)] AS d478,
# title_embed[OFFSET(479)] AS d479,
# title_embed[OFFSET(480)] AS d480,
# title_embed[OFFSET(481)] AS d481,
# title_embed[OFFSET(482)] AS d482,
# title_embed[OFFSET(483)] AS d483,
# title_embed[OFFSET(484)] AS d484,
# title_embed[OFFSET(485)] AS d485,
# title_embed[OFFSET(486)] AS d486,
# title_embed[OFFSET(487)] AS d487,
# title_embed[OFFSET(488)] AS d488,
# title_embed[OFFSET(489)] AS d489,
# title_embed[OFFSET(490)] AS d490,
# title_embed[OFFSET(491)] AS d491,
# title_embed[OFFSET(492)] AS d492,
# title_embed[OFFSET(493)] AS d493,
# title_embed[OFFSET(494)] AS d494,
# title_embed[OFFSET(495)] AS d495,
# title_embed[OFFSET(496)] AS d496,
# title_embed[OFFSET(497)] AS d497,
# title_embed[OFFSET(498)] AS d498,
# title_embed[OFFSET(499)] AS d499,
# title_embed[OFFSET(500)] AS d500,
# title_embed[OFFSET(501)] AS d501,
# title_embed[OFFSET(502)] AS d502,
# title_embed[OFFSET(503)] AS d503,
# title_embed[OFFSET(504)] AS d504,
# title_embed[OFFSET(505)] AS d505,
# title_embed[OFFSET(506)] AS d506,
# title_embed[OFFSET(507)] AS d507,
# title_embed[OFFSET(508)] AS d508,
# title_embed[OFFSET(509)] AS d509,
# title_embed[OFFSET(510)] AS d510,
# title_embed[OFFSET(511)] AS d511,
#
# FROM `springer-nature-analytics.DS_dimensions.publications_full_refresh`
# LEFT JOIN UNNEST(`for`) AS f LEFT JOIN UNNEST(journal) AS j
# WHERE ARRAY_LENGTH(title_embed) = 512
# AND
# publication_type LIKE "article"
#         AND j.title IN (SELECT title FROM `springer-nature-analytics.core_journals.core_2018_v01`)
#         AND year >= 1990
#         AND year <= 1992
#         AND language LIKE "en"
#         AND ARRAY_LENGTH(references) > 4
#
# ) GROUP BY f1
#  ) WHERE f1 IS NOT NULL

# %%
train_and_save(for_90_92, "wv_90_92")
# Out:
# Saved mean vectors to "/content/drive/My Drive/Research/Data/Mean-title-centroids-3yrs-v02/wv_90_92_f1.csv"

# %%
# %%bigquery --project $pid for_90_92
#
# SELECT * FROM (
# SELECT f1,
#
# AVG(d0) AS d0_mean,
# AVG(d1) AS d1_mean,
# AVG(d2) AS d2_mean,
# AVG(d3) AS d3_mean,
# AVG(d4) AS d4_mean,
# AVG(d5) AS d5_mean,
# AVG(d6) AS d6_mean,
# AVG(d7) AS d7_mean,
# AVG(d8) AS d8_mean,
# AVG(d9) AS d9_mean,
# AVG(d10) AS d10_mean,
# AVG(d11) AS d11_mean,
# AVG(d12) AS d12_mean,
# AVG(d13) AS d13_mean,
# AVG(d14) AS d14_mean,
# AVG(d15) AS d15_mean,
# AVG(d16) AS d16_mean,
# AVG(d17) AS d17_mean,
# AVG(d18) AS d18_mean,
# AVG(d19) AS d19_mean,
# AVG(d20) AS d20_mean,
# AVG(d21) AS d21_mean,
# AVG(d22) AS d22_mean,
# AVG(d23) AS d23_mean,
# AVG(d24) AS d24_mean,
# AVG(d25) AS d25_mean,
# AVG(d26) AS d26_mean,
# AVG(d27) AS d27_mean,
# AVG(d28) AS d28_mean,
# AVG(d29) AS d29_mean,
# AVG(d30) AS d30_mean,
# AVG(d31) AS d31_mean,
# AVG(d32) AS d32_mean,
# AVG(d33) AS d33_mean,
# AVG(d34) AS d34_mean,
# AVG(d35) AS d35_mean,
# AVG(d36) AS d36_mean,
# AVG(d37) AS d37_mean,
# AVG(d38) AS d38_mean,
# AVG(d39) AS d39_mean,
# AVG(d40) AS d40_mean,
# AVG(d41) AS d41_mean,
# AVG(d42) AS d42_mean,
# AVG(d43) AS d43_mean,
# AVG(d44) AS d44_mean,
# AVG(d45) AS d45_mean,
# AVG(d46) AS d46_mean,
# AVG(d47) AS d47_mean,
# AVG(d48) AS d48_mean,
# AVG(d49) AS d49_mean,
# AVG(d50) AS d50_mean,
# AVG(d51) AS d51_mean,
# AVG(d52) AS d52_mean,
# AVG(d53) AS d53_mean,
# AVG(d54) AS d54_mean,
# AVG(d55) AS d55_mean,
# AVG(d56) AS d56_mean,
# AVG(d57) AS d57_mean,
# AVG(d58) AS d58_mean,
# AVG(d59) AS d59_mean,
# AVG(d60) AS d60_mean,
# AVG(d61) AS d61_mean,
# AVG(d62) AS d62_mean,
# AVG(d63) AS d63_mean,
# AVG(d64) AS d64_mean,
# AVG(d65) AS d65_mean,
# AVG(d66) AS d66_mean,
# AVG(d67) AS d67_mean,
# AVG(d68) AS d68_mean,
# AVG(d69) AS d69_mean,
# AVG(d70) AS d70_mean,
# AVG(d71) AS d71_mean,
# AVG(d72) AS d72_mean,
# AVG(d73) AS d73_mean,
# AVG(d74) AS d74_mean,
# AVG(d75) AS d75_mean,
# AVG(d76) AS d76_mean,
# AVG(d77) AS d77_mean,
# AVG(d78) AS d78_mean,
# AVG(d79) AS d79_mean,
# AVG(d80) AS d80_mean,
# AVG(d81) AS d81_mean,
# AVG(d82) AS d82_mean,
# AVG(d83) AS d83_mean,
# AVG(d84) AS d84_mean,
# AVG(d85) AS d85_mean,
# AVG(d86) AS d86_mean,
# AVG(d87) AS d87_mean,
# AVG(d88) AS d88_mean,
# AVG(d89) AS d89_mean,
# AVG(d90) AS d90_mean,
# AVG(d91) AS d91_mean,
# AVG(d92) AS d92_mean,
# AVG(d93) AS d93_mean,
# AVG(d94) AS d94_mean,
# AVG(d95) AS d95_mean,
# AVG(d96) AS d96_mean,
# AVG(d97) AS d97_mean,
# AVG(d98) AS d98_mean,
# AVG(d99) AS d99_mean,
# AVG(d100) AS d100_mean,
# AVG(d101) AS d101_mean,
# AVG(d102) AS d102_mean,
# AVG(d103) AS d103_mean,
# AVG(d104) AS d104_mean,
# AVG(d105) AS d105_mean,
# AVG(d106) AS d106_mean,
# AVG(d107) AS d107_mean,
# AVG(d108) AS d108_mean,
# AVG(d109) AS d109_mean,
# AVG(d110) AS d110_mean,
# AVG(d111) AS d111_mean,
# AVG(d112) AS d112_mean,
# AVG(d113) AS d113_mean,
# AVG(d114) AS d114_mean,
# AVG(d115) AS d115_mean,
# AVG(d116) AS d116_mean,
# AVG(d117) AS d117_mean,
# AVG(d118) AS d118_mean,
# AVG(d119) AS d119_mean,
# AVG(d120) AS d120_mean,
# AVG(d121) AS d121_mean,
# AVG(d122) AS d122_mean,
# AVG(d123) AS d123_mean,
# AVG(d124) AS d124_mean,
# AVG(d125) AS d125_mean,
# AVG(d126) AS d126_mean,
# AVG(d127) AS d127_mean,
# AVG(d128) AS d128_mean,
# AVG(d129) AS d129_mean,
# AVG(d130) AS d130_mean,
# AVG(d131) AS d131_mean,
# AVG(d132) AS d132_mean,
# AVG(d133) AS d133_mean,
# AVG(d134) AS d134_mean,
# AVG(d135) AS d135_mean,
# AVG(d136) AS d136_mean,
# AVG(d137) AS d137_mean,
# AVG(d138) AS d138_mean,
# AVG(d139) AS d139_mean,
# AVG(d140) AS d140_mean,
# AVG(d141) AS d141_mean,
# AVG(d142) AS d142_mean,
# AVG(d143) AS d143_mean,
# AVG(d144) AS d144_mean,
# AVG(d145) AS d145_mean,
# AVG(d146) AS d146_mean,
# AVG(d147) AS d147_mean,
# AVG(d148) AS d148_mean,
# AVG(d149) AS d149_mean,
# AVG(d150) AS d150_mean,
# AVG(d151) AS d151_mean,
# AVG(d152) AS d152_mean,
# AVG(d153) AS d153_mean,
# AVG(d154) AS d154_mean,
# AVG(d155) AS d155_mean,
# AVG(d156) AS d156_mean,
# AVG(d157) AS d157_mean,
# AVG(d158) AS d158_mean,
# AVG(d159) AS d159_mean,
# AVG(d160) AS d160_mean,
# AVG(d161) AS d161_mean,
# AVG(d162) AS d162_mean,
# AVG(d163) AS d163_mean,
# AVG(d164) AS d164_mean,
# AVG(d165) AS d165_mean,
# AVG(d166) AS d166_mean,
# AVG(d167) AS d167_mean,
# AVG(d168) AS d168_mean,
# AVG(d169) AS d169_mean,
# AVG(d170) AS d170_mean,
# AVG(d171) AS d171_mean,
# AVG(d172) AS d172_mean,
# AVG(d173) AS d173_mean,
# AVG(d174) AS d174_mean,
# AVG(d175) AS d175_mean,
# AVG(d176) AS d176_mean,
# AVG(d177) AS d177_mean,
# AVG(d178) AS d178_mean,
# AVG(d179) AS d179_mean,
# AVG(d180) AS d180_mean,
# AVG(d181) AS d181_mean,
# AVG(d182) AS d182_mean,
# AVG(d183) AS d183_mean,
# AVG(d184) AS d184_mean,
# AVG(d185) AS d185_mean,
# AVG(d186) AS d186_mean,
# AVG(d187) AS d187_mean,
# AVG(d188) AS d188_mean,
# AVG(d189) AS d189_mean,
# AVG(d190) AS d190_mean,
# AVG(d191) AS d191_mean,
# AVG(d192) AS d192_mean,
# AVG(d193) AS d193_mean,
# AVG(d194) AS d194_mean,
# AVG(d195) AS d195_mean,
# AVG(d196) AS d196_mean,
# AVG(d197) AS d197_mean,
# AVG(d198) AS d198_mean,
# AVG(d199) AS d199_mean,
# AVG(d200) AS d200_mean,
# AVG(d201) AS d201_mean,
# AVG(d202) AS d202_mean,
# AVG(d203) AS d203_mean,
# AVG(d204) AS d204_mean,
# AVG(d205) AS d205_mean,
# AVG(d206) AS d206_mean,
# AVG(d207) AS d207_mean,
# AVG(d208) AS d208_mean,
# AVG(d209) AS d209_mean,
# AVG(d210) AS d210_mean,
# AVG(d211) AS d211_mean,
# AVG(d212) AS d212_mean,
# AVG(d213) AS d213_mean,
# AVG(d214) AS d214_mean,
# AVG(d215) AS d215_mean,
# AVG(d216) AS d216_mean,
# AVG(d217) AS d217_mean,
# AVG(d218) AS d218_mean,
# AVG(d219) AS d219_mean,
# AVG(d220) AS d220_mean,
# AVG(d221) AS d221_mean,
# AVG(d222) AS d222_mean,
# AVG(d223) AS d223_mean,
# AVG(d224) AS d224_mean,
# AVG(d225) AS d225_mean,
# AVG(d226) AS d226_mean,
# AVG(d227) AS d227_mean,
# AVG(d228) AS d228_mean,
# AVG(d229) AS d229_mean,
# AVG(d230) AS d230_mean,
# AVG(d231) AS d231_mean,
# AVG(d232) AS d232_mean,
# AVG(d233) AS d233_mean,
# AVG(d234) AS d234_mean,
# AVG(d235) AS d235_mean,
# AVG(d236) AS d236_mean,
# AVG(d237) AS d237_mean,
# AVG(d238) AS d238_mean,
# AVG(d239) AS d239_mean,
# AVG(d240) AS d240_mean,
# AVG(d241) AS d241_mean,
# AVG(d242) AS d242_mean,
# AVG(d243) AS d243_mean,
# AVG(d244) AS d244_mean,
# AVG(d245) AS d245_mean,
# AVG(d246) AS d246_mean,
# AVG(d247) AS d247_mean,
# AVG(d248) AS d248_mean,
# AVG(d249) AS d249_mean,
# AVG(d250) AS d250_mean,
# AVG(d251) AS d251_mean,
# AVG(d252) AS d252_mean,
# AVG(d253) AS d253_mean,
# AVG(d254) AS d254_mean,
# AVG(d255) AS d255_mean,
# AVG(d256) AS d256_mean,
# AVG(d257) AS d257_mean,
# AVG(d258) AS d258_mean,
# AVG(d259) AS d259_mean,
# AVG(d260) AS d260_mean,
# AVG(d261) AS d261_mean,
# AVG(d262) AS d262_mean,
# AVG(d263) AS d263_mean,
# AVG(d264) AS d264_mean,
# AVG(d265) AS d265_mean,
# AVG(d266) AS d266_mean,
# AVG(d267) AS d267_mean,
# AVG(d268) AS d268_mean,
# AVG(d269) AS d269_mean,
# AVG(d270) AS d270_mean,
# AVG(d271) AS d271_mean,
# AVG(d272) AS d272_mean,
# AVG(d273) AS d273_mean,
# AVG(d274) AS d274_mean,
# AVG(d275) AS d275_mean,
# AVG(d276) AS d276_mean,
# AVG(d277) AS d277_mean,
# AVG(d278) AS d278_mean,
# AVG(d279) AS d279_mean,
# AVG(d280) AS d280_mean,
# AVG(d281) AS d281_mean,
# AVG(d282) AS d282_mean,
# AVG(d283) AS d283_mean,
# AVG(d284) AS d284_mean,
# AVG(d285) AS d285_mean,
# AVG(d286) AS d286_mean,
# AVG(d287) AS d287_mean,
# AVG(d288) AS d288_mean,
# AVG(d289) AS d289_mean,
# AVG(d290) AS d290_mean,
# AVG(d291) AS d291_mean,
# AVG(d292) AS d292_mean,
# AVG(d293) AS d293_mean,
# AVG(d294) AS d294_mean,
# AVG(d295) AS d295_mean,
# AVG(d296) AS d296_mean,
# AVG(d297) AS d297_mean,
# AVG(d298) AS d298_mean,
# AVG(d299) AS d299_mean,
# AVG(d300) AS d300_mean,
# AVG(d301) AS d301_mean,
# AVG(d302) AS d302_mean,
# AVG(d303) AS d303_mean,
# AVG(d304) AS d304_mean,
# AVG(d305) AS d305_mean,
# AVG(d306) AS d306_mean,
# AVG(d307) AS d307_mean,
# AVG(d308) AS d308_mean,
# AVG(d309) AS d309_mean,
# AVG(d310) AS d310_mean,
# AVG(d311) AS d311_mean,
# AVG(d312) AS d312_mean,
# AVG(d313) AS d313_mean,
# AVG(d314) AS d314_mean,
# AVG(d315) AS d315_mean,
# AVG(d316) AS d316_mean,
# AVG(d317) AS d317_mean,
# AVG(d318) AS d318_mean,
# AVG(d319) AS d319_mean,
# AVG(d320) AS d320_mean,
# AVG(d321) AS d321_mean,
# AVG(d322) AS d322_mean,
# AVG(d323) AS d323_mean,
# AVG(d324) AS d324_mean,
# AVG(d325) AS d325_mean,
# AVG(d326) AS d326_mean,
# AVG(d327) AS d327_mean,
# AVG(d328) AS d328_mean,
# AVG(d329) AS d329_mean,
# AVG(d330) AS d330_mean,
# AVG(d331) AS d331_mean,
# AVG(d332) AS d332_mean,
# AVG(d333) AS d333_mean,
# AVG(d334) AS d334_mean,
# AVG(d335) AS d335_mean,
# AVG(d336) AS d336_mean,
# AVG(d337) AS d337_mean,
# AVG(d338) AS d338_mean,
# AVG(d339) AS d339_mean,
# AVG(d340) AS d340_mean,
# AVG(d341) AS d341_mean,
# AVG(d342) AS d342_mean,
# AVG(d343) AS d343_mean,
# AVG(d344) AS d344_mean,
# AVG(d345) AS d345_mean,
# AVG(d346) AS d346_mean,
# AVG(d347) AS d347_mean,
# AVG(d348) AS d348_mean,
# AVG(d349) AS d349_mean,
# AVG(d350) AS d350_mean,
# AVG(d351) AS d351_mean,
# AVG(d352) AS d352_mean,
# AVG(d353) AS d353_mean,
# AVG(d354) AS d354_mean,
# AVG(d355) AS d355_mean,
# AVG(d356) AS d356_mean,
# AVG(d357) AS d357_mean,
# AVG(d358) AS d358_mean,
# AVG(d359) AS d359_mean,
# AVG(d360) AS d360_mean,
# AVG(d361) AS d361_mean,
# AVG(d362) AS d362_mean,
# AVG(d363) AS d363_mean,
# AVG(d364) AS d364_mean,
# AVG(d365) AS d365_mean,
# AVG(d366) AS d366_mean,
# AVG(d367) AS d367_mean,
# AVG(d368) AS d368_mean,
# AVG(d369) AS d369_mean,
# AVG(d370) AS d370_mean,
# AVG(d371) AS d371_mean,
# AVG(d372) AS d372_mean,
# AVG(d373) AS d373_mean,
# AVG(d374) AS d374_mean,
# AVG(d375) AS d375_mean,
# AVG(d376) AS d376_mean,
# AVG(d377) AS d377_mean,
# AVG(d378) AS d378_mean,
# AVG(d379) AS d379_mean,
# AVG(d380) AS d380_mean,
# AVG(d381) AS d381_mean,
# AVG(d382) AS d382_mean,
# AVG(d383) AS d383_mean,
# AVG(d384) AS d384_mean,
# AVG(d385) AS d385_mean,
# AVG(d386) AS d386_mean,
# AVG(d387) AS d387_mean,
# AVG(d388) AS d388_mean,
# AVG(d389) AS d389_mean,
# AVG(d390) AS d390_mean,
# AVG(d391) AS d391_mean,
# AVG(d392) AS d392_mean,
# AVG(d393) AS d393_mean,
# AVG(d394) AS d394_mean,
# AVG(d395) AS d395_mean,
# AVG(d396) AS d396_mean,
# AVG(d397) AS d397_mean,
# AVG(d398) AS d398_mean,
# AVG(d399) AS d399_mean,
# AVG(d400) AS d400_mean,
# AVG(d401) AS d401_mean,
# AVG(d402) AS d402_mean,
# AVG(d403) AS d403_mean,
# AVG(d404) AS d404_mean,
# AVG(d405) AS d405_mean,
# AVG(d406) AS d406_mean,
# AVG(d407) AS d407_mean,
# AVG(d408) AS d408_mean,
# AVG(d409) AS d409_mean,
# AVG(d410) AS d410_mean,
# AVG(d411) AS d411_mean,
# AVG(d412) AS d412_mean,
# AVG(d413) AS d413_mean,
# AVG(d414) AS d414_mean,
# AVG(d415) AS d415_mean,
# AVG(d416) AS d416_mean,
# AVG(d417) AS d417_mean,
# AVG(d418) AS d418_mean,
# AVG(d419) AS d419_mean,
# AVG(d420) AS d420_mean,
# AVG(d421) AS d421_mean,
# AVG(d422) AS d422_mean,
# AVG(d423) AS d423_mean,
# AVG(d424) AS d424_mean,
# AVG(d425) AS d425_mean,
# AVG(d426) AS d426_mean,
# AVG(d427) AS d427_mean,
# AVG(d428) AS d428_mean,
# AVG(d429) AS d429_mean,
# AVG(d430) AS d430_mean,
# AVG(d431) AS d431_mean,
# AVG(d432) AS d432_mean,
# AVG(d433) AS d433_mean,
# AVG(d434) AS d434_mean,
# AVG(d435) AS d435_mean,
# AVG(d436) AS d436_mean,
# AVG(d437) AS d437_mean,
# AVG(d438) AS d438_mean,
# AVG(d439) AS d439_mean,
# AVG(d440) AS d440_mean,
# AVG(d441) AS d441_mean,
# AVG(d442) AS d442_mean,
# AVG(d443) AS d443_mean,
# AVG(d444) AS d444_mean,
# AVG(d445) AS d445_mean,
# AVG(d446) AS d446_mean,
# AVG(d447) AS d447_mean,
# AVG(d448) AS d448_mean,
# AVG(d449) AS d449_mean,
# AVG(d450) AS d450_mean,
# AVG(d451) AS d451_mean,
# AVG(d452) AS d452_mean,
# AVG(d453) AS d453_mean,
# AVG(d454) AS d454_mean,
# AVG(d455) AS d455_mean,
# AVG(d456) AS d456_mean,
# AVG(d457) AS d457_mean,
# AVG(d458) AS d458_mean,
# AVG(d459) AS d459_mean,
# AVG(d460) AS d460_mean,
# AVG(d461) AS d461_mean,
# AVG(d462) AS d462_mean,
# AVG(d463) AS d463_mean,
# AVG(d464) AS d464_mean,
# AVG(d465) AS d465_mean,
# AVG(d466) AS d466_mean,
# AVG(d467) AS d467_mean,
# AVG(d468) AS d468_mean,
# AVG(d469) AS d469_mean,
# AVG(d470) AS d470_mean,
# AVG(d471) AS d471_mean,
# AVG(d472) AS d472_mean,
# AVG(d473) AS d473_mean,
# AVG(d474) AS d474_mean,
# AVG(d475) AS d475_mean,
# AVG(d476) AS d476_mean,
# AVG(d477) AS d477_mean,
# AVG(d478) AS d478_mean,
# AVG(d479) AS d479_mean,
# AVG(d480) AS d480_mean,
# AVG(d481) AS d481_mean,
# AVG(d482) AS d482_mean,
# AVG(d483) AS d483_mean,
# AVG(d484) AS d484_mean,
# AVG(d485) AS d485_mean,
# AVG(d486) AS d486_mean,
# AVG(d487) AS d487_mean,
# AVG(d488) AS d488_mean,
# AVG(d489) AS d489_mean,
# AVG(d490) AS d490_mean,
# AVG(d491) AS d491_mean,
# AVG(d492) AS d492_mean,
# AVG(d493) AS d493_mean,
# AVG(d494) AS d494_mean,
# AVG(d495) AS d495_mean,
# AVG(d496) AS d496_mean,
# AVG(d497) AS d497_mean,
# AVG(d498) AS d498_mean,
# AVG(d499) AS d499_mean,
# AVG(d500) AS d500_mean,
# AVG(d501) AS d501_mean,
# AVG(d502) AS d502_mean,
# AVG(d503) AS d503_mean,
# AVG(d504) AS d504_mean,
# AVG(d505) AS d505_mean,
# AVG(d506) AS d506_mean,
# AVG(d507) AS d507_mean,
# AVG(d508) AS d508_mean,
# AVG(d509) AS d509_mean,
# AVG(d510) AS d510_mean,
# AVG(d511) AS d511_mean,
#
# FROM (
# SELECT f.second_level.name AS f1,
#
# title_embed[OFFSET(0)] AS d0,
# title_embed[OFFSET(1)] AS d1,
# title_embed[OFFSET(2)] AS d2,
# title_embed[OFFSET(3)] AS d3,
# title_embed[OFFSET(4)] AS d4,
# title_embed[OFFSET(5)] AS d5,
# title_embed[OFFSET(6)] AS d6,
# title_embed[OFFSET(7)] AS d7,
# title_embed[OFFSET(8)] AS d8,
# title_embed[OFFSET(9)] AS d9,
# title_embed[OFFSET(10)] AS d10,
# title_embed[OFFSET(11)] AS d11,
# title_embed[OFFSET(12)] AS d12,
# title_embed[OFFSET(13)] AS d13,
# title_embed[OFFSET(14)] AS d14,
# title_embed[OFFSET(15)] AS d15,
# title_embed[OFFSET(382)] AS d382,
# title_embed[OFFSET(383)] AS d383,
# title_embed[OFFSET(384)] AS d384,
# title_embed[OFFSET(385)] AS d385,
# title_embed[OFFSET(386)] AS d386,
# title_embed[OFFSET(387)] AS d387,
# title_embed[OFFSET(388)] AS d388,
# title_embed[OFFSET(389)] AS d389,
# title_embed[OFFSET(390)] AS d390,
# title_embed[OFFSET(391)] AS d391,
# title_embed[OFFSET(392)] AS d392,
# title_embed[OFFSET(393)] AS d393,
# title_embed[OFFSET(394)] AS d394,
# title_embed[OFFSET(395)] AS d395,
# title_embed[OFFSET(396)] AS d396,
# title_embed[OFFSET(397)] AS d397,
# title_embed[OFFSET(398)] AS d398,
# title_embed[OFFSET(399)] AS d399,
# title_embed[OFFSET(400)] AS d400,
# title_embed[OFFSET(401)] AS d401,
# title_embed[OFFSET(402)] AS d402,
# title_embed[OFFSET(403)] AS d403,
# title_embed[OFFSET(404)] AS d404,
# title_embed[OFFSET(405)] AS d405,
# title_embed[OFFSET(406)] AS d406,
# title_embed[OFFSET(407)] AS d407,
# title_embed[OFFSET(408)] AS d408,
# title_embed[OFFSET(409)] AS d409,
# title_embed[OFFSET(410)] AS d410,
# title_embed[OFFSET(411)] AS d411,
# title_embed[OFFSET(412)] AS d412,
# title_embed[OFFSET(413)] AS d413,
# title_embed[OFFSET(414)] AS d414,
# title_embed[OFFSET(415)] AS d415,
# title_embed[OFFSET(416)] AS d416,
# title_embed[OFFSET(417)] AS d417,
# title_embed[OFFSET(418)] AS d418,
# title_embed[OFFSET(419)] AS d419,
# title_embed[OFFSET(420)] AS d420,
# title_embed[OFFSET(421)] AS d421,
# title_embed[OFFSET(422)] AS d422,
# title_embed[OFFSET(423)] AS d423,
# title_embed[OFFSET(424)] AS d424,
# title_embed[OFFSET(425)] AS d425,
# title_embed[OFFSET(426)] AS d426,
# title_embed[OFFSET(427)] AS d427,
# title_embed[OFFSET(428)] AS d428,
# title_embed[OFFSET(429)] AS d429,
# title_embed[OFFSET(430)] AS d430,
# title_embed[OFFSET(431)] AS d431,
# title_embed[OFFSET(432)] AS d432,
# title_embed[OFFSET(433)] AS d433,
# title_embed[OFFSET(434)] AS d434,
# title_embed[OFFSET(435)] AS d435,
# title_embed[OFFSET(436)] AS d436,
# title_embed[OFFSET(437)] AS d437,
# title_embed[OFFSET(438)] AS d438,
# title_embed[OFFSET(439)] AS d439,
# title_embed[OFFSET(440)] AS d440,
# title_embed[OFFSET(441)] AS d441,
# title_embed[OFFSET(442)] AS d442,
# title_embed[OFFSET(443)] AS d443,
# title_embed[OFFSET(444)] AS d444,
# title_embed[OFFSET(445)] AS d445,
# title_embed[OFFSET(446)] AS d446,
# title_embed[OFFSET(447)] AS d447,
# title_embed[OFFSET(448)] AS d448,
# title_embed[OFFSET(449)] AS d449,
# title_embed[OFFSET(450)] AS d450,
# title_embed[OFFSET(451)] AS d451,
# title_embed[OFFSET(452)] AS d452,
# title_embed[OFFSET(453)] AS d453,
# title_embed[OFFSET(454)] AS d454,
# title_embed[OFFSET(455)] AS d455,
# title_embed[OFFSET(456)] AS d456,
# title_embed[OFFSET(457)] AS d457,
# title_embed[OFFSET(458)] AS d458,
# title_embed[OFFSET(459)] AS d459,
# title_embed[OFFSET(460)] AS d460,
# title_embed[OFFSET(461)] AS d461,
# title_embed[OFFSET(462)] AS d462,
# title_embed[OFFSET(463)] AS d463,
# title_embed[OFFSET(464)] AS d464,
# title_embed[OFFSET(465)] AS d465,
# title_embed[OFFSET(466)] AS d466,
# title_embed[OFFSET(467)] AS d467,
# title_embed[OFFSET(468)] AS d468,
# title_embed[OFFSET(469)] AS d469,
# title_embed[OFFSET(470)] AS d470,
# title_embed[OFFSET(471)] AS d471,
# title_embed[OFFSET(472)] AS d472,
# title_embed[OFFSET(473)] AS d473,
# title_embed[OFFSET(474)] AS d474,
# title_embed[OFFSET(475)] AS d475,
# title_embed[OFFSET(476)] AS d476,
# title_embed[OFFSET(477)] AS d477,
# title_embed[OFFSET(478)] AS d478,
# title_embed[OFFSET(479)] AS d479,
# title_embed[OFFSET(480)] AS d480,
# title_embed[OFFSET(481)] AS d481,
# title_embed[OFFSET(482)] AS d482,
# title_embed[OFFSET(483)] AS d483,
# title_embed[OFFSET(484)] AS d484,
# title_embed[OFFSET(485)] AS d485,
# title_embed[OFFSET(486)] AS d486,
# title_embed[OFFSET(487)] AS d487,
# title_embed[OFFSET(488)] AS d488,
# title_embed[OFFSET(489)] AS d489,
# title_embed[OFFSET(490)] AS d490,
# title_embed[OFFSET(491)] AS d491,
# title_embed[OFFSET(492)] AS d492,
# title_embed[OFFSET(493)] AS d493,
# title_embed[OFFSET(494)] AS d494,
# title_embed[OFFSET(495)] AS d495,
# title_embed[OFFSET(496)] AS d496,
# title_embed[OFFSET(497)] AS d497,
# title_embed[OFFSET(498)] AS d498,
# title_embed[OFFSET(499)] AS d499,
# title_embed[OFFSET(500)] AS d500,
# title_embed[OFFSET(501)] AS d501,
# title_embed[OFFSET(502)] AS d502,
# title_embed[OFFSET(503)] AS d503,
# title_embed[OFFSET(504)] AS d504,
# title_embed[OFFSET(505)] AS d505,
# title_embed[OFFSET(506)] AS d506,
# title_embed[OFFSET(507)] AS d507,
# title_embed[OFFSET(508)] AS d508,
# title_embed[OFFSET(509)] AS d509,
# title_embed[OFFSET(510)] AS d510,
# title_embed[OFFSET(511)] AS d511,
#
# FROM `springer-nature-analytics.DS_dimensions.publications_full_refresh`
# LEFT JOIN UNNEST(`for`) AS f LEFT JOIN UNNEST(journal) AS j
# WHERE ARRAY_LENGTH(title_embed) = 512
# AND
# publication_type LIKE "article"
#         AND j.title IN (SELECT title FROM `springer-nature-analytics.core_journals.core_2018_v01`)
#         AND year >= 1990
#         AND year <= 1992
#         AND language LIKE "en"
#         AND ARRAY_LENGTH(references) > 4
#
# ) GROUP BY f1
#  ) WHERE f1 IS NOT NULL

# %%
train_and_save(for_90_92, "wv_90_92", "f2")
# Out:
# Saved mean vectors to "/content/drive/My Drive/Research/Data/Mean-title-centroids-3yrs-v02/wv_90_92_f2.csv"
